# %%
# %load_ext autoreload
# %autoreload 2

from ff_energy.simulations import charmm, plots
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
cl = charmm.read_charmm_log("/home/boittier/pcbach/test_water_sim_ewald/dynamics.log")
# Out:
# water.2000.heat.dcd
# water.2000.equi.dcd
# water.2000.dyna.dcd

# %%
cl
# Out:
#              vdw         elec  user                dyna                  dcd  \
# 0     2424.46560 -25554.36732   0.0   0: DYNA STRT VERL  water.2000.heat.dcd
# 1     2231.13351 -24673.94032   0.0   0: DYNA STRT VERL  water.2000.heat.dcd
# 2     2231.13351 -24673.94032   0.0   0: DYNA STRT VERL  water.2000.heat.dcd
# 3     2421.35008 -25025.24980   0.0   0: DYNA STRT VERL  water.2000.heat.dcd
# 4     2421.35008 -25025.24980   0.0   0: DYNA STRT VERL  water.2000.heat.dcd
# ...          ...          ...   ...                 ...                  ...
# 2012  1814.31134 -21482.82241   0.0  2: DYNA RESTRT CPT  water.2000.dyna.dcd
# 2013  1680.79465 -21169.63717   0.0  2: DYNA RESTRT CPT  water.2000.dyna.dcd
# 2014  1792.86660 -21445.10521   0.0  2: DYNA RESTRT CPT  water.2000.dyna.dcd
# 2015  1836.02466 -21432.90442   0.0  2: DYNA RESTRT CPT  water.2000.dyna.dcd
# 2016  1759.59130 -21381.72993   0.0  2: DYNA RESTRT CPT  water.2000.dyna.dcd
#
#       time       temp          tot       energy   volume      pressi  \
# 0      0.0  124.96157 -23408.46981  25642.99990  68921.0 -3191.58832
# 1      0.1   69.21519 -23405.59658  24643.28443  68921.0 -3127.62847
# 2      0.1   69.20207 -23405.83107  24643.28443  68921.0 -3127.78399
# 3      0.2   72.26811 -23405.11873  24697.39817  68921.0 -2220.99098
# 4      0.2   72.26811 -23405.11874  24697.39817  68921.0 -2220.99098
# ...    ...        ...          ...          ...      ...         ...
# 2012   NaN        NaN          NaN          NaN      NaN         NaN
# 2013   NaN        NaN          NaN          NaN      NaN         NaN
# 2014   NaN        NaN          NaN          NaN      NaN         NaN
# 2015   NaN        NaN          NaN          NaN      NaN         NaN
# 2016   NaN        NaN          NaN          NaN      NaN         NaN
#
#           presse                                               path  \
# 0    -4003.56703  /home/boittier/pcbach/test_water_sim_ewald/dyn...
# 1    -4181.64271  /home/boittier/pcbach/test_water_sim_ewald/dyn...
# 2    -4181.64271  /home/boittier/pcbach/test_water_sim_ewald/dyn...
# 3    -3680.66021  /home/boittier/pcbach/test_water_sim_ewald/dyn...
# 4    -3680.66021  /home/boittier/pcbach/test_water_sim_ewald/dyn...
# ...          ...                                                ...
# 2012         NaN  /home/boittier/pcbach/test_water_sim_ewald/dyn...
# 2013         NaN  /home/boittier/pcbach/test_water_sim_ewald/dyn...
# 2014         NaN  /home/boittier/pcbach/test_water_sim_ewald/dyn...
# 2015         NaN  /home/boittier/pcbach/test_water_sim_ewald/dyn...
# 2016         NaN  /home/boittier/pcbach/test_water_sim_ewald/dyn...
#
#                                                   title
# 0     _home_boittier_pcbach_test_water_sim_ewald_dyn...
# 1     _home_boittier_pcbach_test_water_sim_ewald_dyn...
# 2     _home_boittier_pcbach_test_water_sim_ewald_dyn...
# 3     _home_boittier_pcbach_test_water_sim_ewald_dyn...
# 4     _home_boittier_pcbach_test_water_sim_ewald_dyn...
# ...                                                 ...
# 2012  _home_boittier_pcbach_test_water_sim_ewald_dyn...
# 2013  _home_boittier_pcbach_test_water_sim_ewald_dyn...
# 2014  _home_boittier_pcbach_test_water_sim_ewald_dyn...
# 2015  _home_boittier_pcbach_test_water_sim_ewald_dyn...
# 2016  _home_boittier_pcbach_test_water_sim_ewald_dyn...
#
# [2017 rows x 14 columns]

# %%
plots.make_plots(cl)
# Out:
# plotting
# ['1: DYNA RESTRT CPT', '0: DYNA STRT VERL', '2: DYNA RESTRT CPT']
