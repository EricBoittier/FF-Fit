# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from ff_energy.ffe.utils import read_from_pickle
import jax.numpy as jnp
from ff_energy.ffe.plot import plot_energy_MSE, plot_ff_fit
from ff_energy.ffe.structure import atom_key_pairs
from ff_energy.ffe.potential import LJ, akp_indx
from ff_energy.ffe.ff import FF
from ff_energy.ffe.ff_fit import LJ_bound, load_ff, fit_func, fit_repeat
from ff_energy.ffe.data import pairs_data
from ff_energy.ffe.utils import pickle_output, read_from_pickle, str2int

# %%
sig_bound = (0.05, 2.5)
ep_bound = (0.001, 0.5)
LJ_bound = ((sig_bound), (sig_bound), (ep_bound), (ep_bound))
DE_bound = ((sig_bound), (sig_bound), (ep_bound), (ep_bound), 
            (1, 8), (6, 20))

# %%
#  example
# ffpkl = "ECOL_pbe0dz_FOE.ff.pkl"

# %%
# Parameters
ffpkl = "ECOL_pbe0dz_pairs.ff.pkl"

# %% [markdown]
# #  LJ fit

# %%
_c = next(read_from_pickle(f"ff/{ffpkl}"))
_c
# Out:
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# FF: LJ water_cluster ECOL Exact P_intE (jax_coloumb: False)

# %%
# _c.targets

# %%
fit_repeat(_c, 
           30, 
           f"{ffpkl}_LJ",
           bounds = LJ_bound,
           loss="jax",
           # quiet='true'
          )
# Out:
# /home/boittier/Documents/phd/ff_energy/ff_energy/ffe/ff_fit.py:174: OptimizeWarning: Unknown solver options: pgtol
#   res = minimize(
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.4242796061654047, 1.050376661487219, 0.18740002645894877, 0.22959822344800523]
# final_loss_fn:  6081.623046875
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 6081.623046875
#              x: [ 5.000e-02  5.000e-02  4.966e-01  4.686e-01]
#            nit: 49
#           nfev: 144
#  final_simplex: (array([[ 5.000e-02,  5.000e-02,  4.966e-01,  4.686e-01],
#                        [ 5.000e-02,  5.000e-02,  4.966e-01,  4.686e-01],
#                        ...,
#                        [ 5.000e-02,  5.000e-02,  4.966e-01,  4.686e-01],
#                        [ 5.000e-02,  5.000e-02,  4.966e-01,  4.686e-01]]), array([ 6.082e+03,  6.082e+03,  6.082e+03,  6.082e+03,
#                         6.082e+03]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.6235186242639266, 1.7304336775837101, 0.031075510007443383, 0.2554944250248993]
# final_loss_fn:  13.789721488952637
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 13.789721488952637
#              x: [ 4.514e-01  2.499e+00  2.496e-03  3.551e-03]
#            nit: 328
#           nfev: 593
#  final_simplex: (array([[ 4.514e-01,  2.499e+00,  2.496e-03,  3.551e-03],
#                        [ 4.514e-01,  2.499e+00,  2.496e-03,  3.551e-03],
#                        ...,
#                        [ 4.514e-01,  2.499e+00,  2.496e-03,  3.551e-03],
#                        [ 4.514e-01,  2.499e+00,  2.496e-03,  3.551e-03]]), array([ 1.379e+01,  1.379e+01,  1.379e+01,  1.379e+01,
#                         1.379e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.5151140062580206, 2.082785097843728, 0.28983194861807643, 0.28157125433594077]
# final_loss_fn:  13.196199417114258
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 13.196199417114258
#              x: [ 4.965e-01  2.149e+00  2.773e-03  2.637e-02]
#            nit: 373
#           nfev: 660
#  final_simplex: (array([[ 4.965e-01,  2.149e+00,  2.773e-03,  2.637e-02],
#                        [ 4.965e-01,  2.149e+00,  2.773e-03,  2.637e-02],
#                        ...,
#                        [ 4.965e-01,  2.149e+00,  2.773e-03,  2.637e-02],
#                        [ 4.965e-01,  2.149e+00,  2.773e-03,  2.637e-02]]), array([ 1.320e+01,  1.320e+01,  1.320e+01,  1.320e+01,
#                         1.320e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [2.2222809481743577, 2.4855173731579, 0.24172551968665798, 0.021969837978896137]
# final_loss_fn:  13.914070129394531
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 13.914070129394531
#              x: [ 5.000e-02  2.500e+00  7.794e-02  3.698e-03]
#            nit: 149
#           nfev: 286
#  final_simplex: (array([[ 5.000e-02,  2.500e+00,  7.794e-02,  3.698e-03],
#                        [ 5.000e-02,  2.500e+00,  7.794e-02,  3.698e-03],
#                        ...,
#                        [ 5.000e-02,  2.500e+00,  7.794e-02,  3.698e-03],
#                        [ 5.000e-02,  2.500e+00,  7.794e-02,  3.698e-03]]), array([ 1.391e+01,  1.391e+01,  1.391e+01,  1.391e+01,
#                         1.391e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.4618794889648268, 1.550722192510714, 0.39655153285354644, 0.003176964817419652]
# final_loss_fn:  13.777749061584473
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 13.777749061584473
#              x: [ 5.000e-02  2.301e+00  1.341e-01  1.117e-02]
#            nit: 192
#           nfev: 357
#  final_simplex: (array([[ 5.000e-02,  2.301e+00,  1.341e-01,  1.117e-02],
#                        [ 5.000e-02,  2.301e+00,  1.341e-01,  1.117e-02],
#                        ...,
#                        [ 5.000e-02,  2.301e+00,  1.341e-01,  1.117e-02],
#                        [ 5.000e-02,  2.301e+00,  1.341e-01,  1.117e-02]]), array([ 1.378e+01,  1.378e+01,  1.378e+01,  1.378e+01,
#                         1.378e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.0060572778162307, 1.6665543942132286, 0.36773402311893155, 0.41021031821608234]
# final_loss_fn:  14.533711433410645
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 14.533711433410645
#              x: [ 5.000e-02  2.017e+00  1.952e-03  7.156e-02]
#            nit: 344
#           nfev: 596
#  final_simplex: (array([[ 5.000e-02,  2.017e+00,  1.952e-03,  7.156e-02],
#                        [ 5.000e-02,  2.017e+00,  1.952e-03,  7.156e-02],
#                        ...,
#                        [ 5.000e-02,  2.017e+00,  1.952e-03,  7.156e-02],
#                        [ 5.000e-02,  2.017e+00,  1.952e-03,  7.156e-02]]), array([ 1.453e+01,  1.453e+01,  1.453e+01,  1.453e+01,
#                         1.453e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.48289877979347506, 0.4084294507330171, 0.34538456967349623, 0.3831674877391764]
# final_loss_fn:  6081.623046875
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 6081.623046875
#              x: [ 5.438e-02  5.198e-02  4.964e-01  4.933e-01]
#            nit: 54
#           nfev: 140
#  final_simplex: (array([[ 5.438e-02,  5.198e-02,  4.964e-01,  4.933e-01],
#                        [ 5.438e-02,  5.198e-02,  4.964e-01,  4.933e-01],
#                        ...,
#                        [ 5.438e-02,  5.198e-02,  4.964e-01,  4.933e-01],
#                        [ 5.438e-02,  5.198e-02,  4.964e-01,  4.933e-01]]), array([ 6.082e+03,  6.082e+03,  6.082e+03,  6.082e+03,
#                         6.082e+03]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.7522886565162343, 1.5161386418598253, 0.02360185275739656, 0.30042253660162516]
# final_loss_fn:  61.90041732788086
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 61.90041732788086
#              x: [ 1.125e+00  2.500e+00  1.000e-03  1.000e-03]
#            nit: 631
#           nfev: 1079
#  final_simplex: (array([[ 1.125e+00,  2.500e+00,  1.000e-03,  1.000e-03],
#                        [ 1.125e+00,  2.500e+00,  1.000e-03,  1.000e-03],
#                        ...,
#                        [ 1.125e+00,  2.500e+00,  1.000e-03,  1.000e-03],
#                        [ 1.125e+00,  2.500e+00,  1.000e-03,  1.000e-03]]), array([ 6.190e+01,  6.190e+01,  6.190e+01,  6.190e+01,
#                         6.190e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.1367385109348682, 2.4868180825399007, 0.31430704709589946, 0.15152033745695478]
# final_loss_fn:  15.511401176452637
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 15.511401176452637
#              x: [ 5.000e-02  2.168e+00  5.000e-01  2.474e-02]
#            nit: 385
#           nfev: 673
#  final_simplex: (array([[ 5.000e-02,  2.168e+00,  5.000e-01,  2.474e-02],
#                        [ 5.000e-02,  2.168e+00,  5.000e-01,  2.474e-02],
#                        ...,
#                        [ 5.000e-02,  2.168e+00,  5.000e-01,  2.474e-02],
#                        [ 5.000e-02,  2.168e+00,  5.000e-01,  2.474e-02]]), array([ 1.551e+01,  1.551e+01,  1.551e+01,  1.551e+01,
#                         1.551e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.8944174886564804, 1.8005411579476915, 0.2721333190043929, 0.3983317231639697]
# final_loss_fn:  13.111592292785645
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 13.111592292785645
#              x: [ 6.075e-01  2.124e+00  1.000e-03  3.087e-02]
#            nit: 436
#           nfev: 775
#  final_simplex: (array([[ 6.075e-01,  2.124e+00,  1.000e-03,  3.087e-02],
#                        [ 6.075e-01,  2.124e+00,  1.000e-03,  3.087e-02],
#                        ...,
#                        [ 6.075e-01,  2.124e+00,  1.000e-03,  3.087e-02],
#                        [ 6.075e-01,  2.124e+00,  1.000e-03,  3.087e-02]]), array([ 1.311e+01,  1.311e+01,  1.311e+01,  1.311e+01,
#                         1.311e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.21678881083875923, 1.1126765973915667, 0.4741794280481102, 0.2913799048248937]
# final_loss_fn:  6081.623046875
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 6081.623046875
#              x: [ 5.000e-02  5.000e-02  2.379e-01  3.343e-01]
#            nit: 53
#           nfev: 164
#  final_simplex: (array([[ 5.000e-02,  5.000e-02,  2.379e-01,  3.343e-01],
#                        [ 5.000e-02,  5.000e-02,  2.379e-01,  3.343e-01],
#                        ...,
#                        [ 5.000e-02,  5.000e-02,  2.379e-01,  3.343e-01],
#                        [ 5.000e-02,  5.000e-02,  2.379e-01,  3.343e-01]]), array([ 6.082e+03,  6.082e+03,  6.082e+03,  6.082e+03,
#                         6.082e+03]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.5445872621141925, 2.245160844416635, 0.032296560299963396, 0.42470247980920095]
# final_loss_fn:  50.105369567871094
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 50.105369567871094
#              x: [ 5.000e-02  1.790e+00  1.000e-03  5.000e-01]
#            nit: 167
#           nfev: 305
#  final_simplex: (array([[ 5.000e-02,  1.790e+00,  1.000e-03,  5.000e-01],
#                        [ 5.000e-02,  1.790e+00,  1.000e-03,  5.000e-01],
#                        ...,
#                        [ 5.000e-02,  1.790e+00,  1.000e-03,  5.000e-01],
#                        [ 5.000e-02,  1.790e+00,  1.000e-03,  5.000e-01]]), array([ 5.011e+01,  5.011e+01,  5.011e+01,  5.011e+01,
#                         5.011e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [2.2779337055417996, 0.26068408640486346, 0.008260028895729736, 0.3789037804372507]
# final_loss_fn:  151.0857696533203
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 151.0857696533203
#              x: [ 1.798e+00  1.073e+00  1.000e-03  5.000e-01]
#            nit: 360
#           nfev: 651
#  final_simplex: (array([[ 1.798e+00,  1.073e+00,  1.000e-03,  5.000e-01],
#                        [ 1.798e+00,  1.073e+00,  1.000e-03,  5.000e-01],
#                        ...,
#                        [ 1.798e+00,  1.073e+00,  1.000e-03,  5.000e-01],
#                        [ 1.798e+00,  1.073e+00,  1.000e-03,  5.000e-01]]), array([ 1.511e+02,  1.511e+02,  1.511e+02,  1.511e+02,
#                         1.511e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [2.207168531199238, 1.8505637616558264, 0.2830588376841849, 0.3876321288905408]
# final_loss_fn:  15.511397361755371
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 15.511397361755371
#              x: [ 5.000e-02  2.168e+00  5.000e-01  2.474e-02]
#            nit: 370
#           nfev: 667
#  final_simplex: (array([[ 5.000e-02,  2.168e+00,  5.000e-01,  2.474e-02],
#                        [ 5.000e-02,  2.168e+00,  5.000e-01,  2.474e-02],
#                        ...,
#                        [ 5.000e-02,  2.168e+00,  5.000e-01,  2.474e-02],
#                        [ 5.000e-02,  2.168e+00,  5.000e-01,  2.474e-02]]), array([ 1.551e+01,  1.551e+01,  1.551e+01,  1.551e+01,
#                         1.551e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.8865657333724642, 2.475274281052879, 0.1606681830892899, 0.34815968072280207]
# final_loss_fn:  6081.623046875
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 6081.623046875
#              x: [ 5.000e-02  5.000e-02  3.814e-01  5.000e-01]
#            nit: 40
#           nfev: 141
#  final_simplex: (array([[ 5.000e-02,  5.000e-02,  3.814e-01,  5.000e-01],
#                        [ 5.000e-02,  5.000e-02,  3.814e-01,  5.000e-01],
#                        ...,
#                        [ 5.000e-02,  5.000e-02,  3.814e-01,  5.000e-01],
#                        [ 5.000e-02,  5.000e-02,  3.814e-01,  5.000e-01]]), array([ 6.082e+03,  6.082e+03,  6.082e+03,  6.082e+03,
#                         6.082e+03]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.2241835343316483, 0.9919094655917563, 0.4282283714715341, 0.16439583086126944]
# final_loss_fn:  14.160215377807617
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 14.160215377807617
#              x: [ 5.000e-02  2.276e+00  2.549e-01  1.261e-02]
#            nit: 628
#           nfev: 1102
#  final_simplex: (array([[ 5.000e-02,  2.276e+00,  2.549e-01,  1.261e-02],
#                        [ 5.000e-02,  2.276e+00,  2.549e-01,  1.261e-02],
#                        ...,
#                        [ 5.000e-02,  2.276e+00,  2.549e-01,  1.261e-02],
#                        [ 5.000e-02,  2.276e+00,  2.549e-01,  1.261e-02]]), array([ 1.416e+01,  1.416e+01,  1.416e+01,  1.416e+01,
#                         1.416e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.5665928368641588, 0.4386864757401555, 0.07788295443791016, 0.2436661744484508]
# final_loss_fn:  13.333855628967285
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 13.333855628967285
#              x: [ 3.472e-01  2.158e+00  1.055e-02  2.532e-02]
#            nit: 871
#           nfev: 1503
#  final_simplex: (array([[ 3.472e-01,  2.158e+00,  1.055e-02,  2.532e-02],
#                        [ 3.472e-01,  2.158e+00,  1.055e-02,  2.532e-02],
#                        ...,
#                        [ 3.472e-01,  2.158e+00,  1.055e-02,  2.532e-02],
#                        [ 3.472e-01,  2.158e+00,  1.055e-02,  2.532e-02]]), array([ 1.333e+01,  1.333e+01,  1.333e+01,  1.333e+01,
#                         1.333e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.4773756047405315, 2.3018661959725204, 0.3591488115764621, 0.205110034758457]
# final_loss_fn:  15.855048179626465
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 15.855048179626465
#              x: [ 6.782e-02  2.089e+00  4.250e-01  4.230e-02]
#            nit: 351
#           nfev: 632
#  final_simplex: (array([[ 6.782e-02,  2.089e+00,  4.250e-01,  4.230e-02],
#                        [ 6.782e-02,  2.089e+00,  4.250e-01,  4.230e-02],
#                        ...,
#                        [ 6.782e-02,  2.089e+00,  4.250e-01,  4.230e-02],
#                        [ 6.782e-02,  2.089e+00,  4.250e-01,  4.230e-02]]), array([ 1.586e+01,  1.586e+01,  1.586e+01,  1.586e+01,
#                         1.586e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.1254137189592756, 1.2392263806999195, 0.4370733744041428, 0.2899624515151364]
# final_loss_fn:  6081.623046875
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 6081.623046875
#              x: [ 5.000e-02  5.000e-02  4.735e-01  2.990e-01]
#            nit: 40
#           nfev: 137
#  final_simplex: (array([[ 5.000e-02,  5.000e-02,  4.735e-01,  2.990e-01],
#                        [ 5.000e-02,  5.000e-02,  4.735e-01,  2.990e-01],
#                        ...,
#                        [ 5.000e-02,  5.000e-02,  4.735e-01,  2.990e-01],
#                        [ 5.000e-02,  5.000e-02,  4.735e-01,  2.990e-01]]), array([ 6.082e+03,  6.082e+03,  6.082e+03,  6.082e+03,
#                         6.082e+03]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.4961668144980964, 1.7981189611885933, 0.20815032924182159, 0.2980312177600746]
# final_loss_fn:  13.775050163269043
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 13.775050163269043
#              x: [ 5.000e-02  2.277e+00  1.397e-01  1.289e-02]
#            nit: 696
#           nfev: 1196
#  final_simplex: (array([[ 5.000e-02,  2.277e+00,  1.397e-01,  1.289e-02],
#                        [ 5.000e-02,  2.277e+00,  1.397e-01,  1.289e-02],
#                        ...,
#                        [ 5.000e-02,  2.277e+00,  1.397e-01,  1.289e-02],
#                        [ 5.000e-02,  2.277e+00,  1.397e-01,  1.289e-02]]), array([ 1.378e+01,  1.378e+01,  1.378e+01,  1.378e+01,
#                         1.378e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.6098531702679154, 1.4407293755166992, 0.024649761452278155, 0.3246274875295176]
# final_loss_fn:  13.771585464477539
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 13.771585464477539
#              x: [ 8.366e-02  2.187e+00  1.290e-01  2.227e-02]
#            nit: 616
#           nfev: 1061
#  final_simplex: (array([[ 8.366e-02,  2.187e+00,  1.290e-01,  2.227e-02],
#                        [ 8.366e-02,  2.187e+00,  1.290e-01,  2.227e-02],
#                        ...,
#                        [ 8.366e-02,  2.187e+00,  1.290e-01,  2.227e-02],
#                        [ 8.366e-02,  2.187e+00,  1.290e-01,  2.227e-02]]), array([ 1.377e+01,  1.377e+01,  1.377e+01,  1.377e+01,
#                         1.377e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.5833696414235976, 0.9780239958416438, 0.05776449235153645, 0.37211476129541987]
# final_loss_fn:  13.112337112426758
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 13.112337112426758
#              x: [ 6.065e-01  2.125e+00  1.010e-03  3.067e-02]
#            nit: 1298
#           nfev: 2178
#  final_simplex: (array([[ 6.065e-01,  2.125e+00,  1.010e-03,  3.067e-02],
#                        [ 6.065e-01,  2.125e+00,  1.010e-03,  3.067e-02],
#                        ...,
#                        [ 6.065e-01,  2.125e+00,  1.010e-03,  3.067e-02],
#                        [ 6.065e-01,  2.125e+00,  1.010e-03,  3.067e-02]]), array([ 1.311e+01,  1.311e+01,  1.311e+01,  1.311e+01,
#                         1.311e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [2.3231320339501504, 1.2784430305553414, 0.006155720977949481, 0.22571235162501768]
# final_loss_fn:  13.387118339538574
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 13.387118339538574
#              x: [ 3.023e-01  2.167e+00  1.595e-02  2.407e-02]
#            nit: 958
#           nfev: 1614
#  final_simplex: (array([[ 3.023e-01,  2.167e+00,  1.595e-02,  2.407e-02],
#                        [ 3.023e-01,  2.167e+00,  1.595e-02,  2.407e-02],
#                        ...,
#                        [ 3.023e-01,  2.167e+00,  1.595e-02,  2.407e-02],
#                        [ 3.023e-01,  2.167e+00,  1.595e-02,  2.407e-02]]), array([ 1.339e+01,  1.339e+01,  1.339e+01,  1.339e+01,
#                         1.339e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.7807075217051772, 1.3747819421512628, 0.41343606891775164, 0.11287863293947548]
# final_loss_fn:  13.77512264251709
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 13.77512264251709
#              x: [ 5.000e-02  2.281e+00  1.387e-01  1.257e-02]
#            nit: 274
#           nfev: 504
#  final_simplex: (array([[ 5.000e-02,  2.281e+00,  1.387e-01,  1.257e-02],
#                        [ 5.000e-02,  2.281e+00,  1.387e-01,  1.257e-02],
#                        ...,
#                        [ 5.000e-02,  2.281e+00,  1.387e-01,  1.257e-02],
#                        [ 5.000e-02,  2.281e+00,  1.387e-01,  1.257e-02]]), array([ 1.378e+01,  1.378e+01,  1.378e+01,  1.378e+01,
#                         1.378e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.2526490966379902, 1.2463178568427238, 0.4607347963080138, 0.3117717633679378]
# final_loss_fn:  13.122859001159668
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 13.122859001159668
#              x: [ 6.089e-01  2.149e+00  1.000e-03  2.620e-02]
#            nit: 562
#           nfev: 972
#  final_simplex: (array([[ 6.089e-01,  2.149e+00,  1.000e-03,  2.620e-02],
#                        [ 6.089e-01,  2.149e+00,  1.000e-03,  2.620e-02],
#                        ...,
#                        [ 6.089e-01,  2.149e+00,  1.000e-03,  2.620e-02],
#                        [ 6.089e-01,  2.149e+00,  1.000e-03,  2.620e-02]]), array([ 1.312e+01,  1.312e+01,  1.312e+01,  1.312e+01,
#                         1.312e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.1267478458014486, 0.41682268598560546, 0.06300159696227965, 0.061561135822003045]
# final_loss_fn:  13.775318145751953
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 13.775318145751953
#              x: [ 4.750e-01  2.491e+00  2.107e-03  3.681e-03]
#            nit: 700
#           nfev: 1232
#  final_simplex: (array([[ 4.750e-01,  2.491e+00,  2.107e-03,  3.681e-03],
#                        [ 4.750e-01,  2.491e+00,  2.107e-03,  3.681e-03],
#                        ...,
#                        [ 4.750e-01,  2.491e+00,  2.107e-03,  3.681e-03],
#                        [ 4.750e-01,  2.491e+00,  2.107e-03,  3.681e-03]]), array([ 1.378e+01,  1.378e+01,  1.378e+01,  1.378e+01,
#                         1.378e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [2.298771067523478, 1.1096282658040004, 0.4849282353937052, 0.18256673967879386]
# final_loss_fn:  15.511395454406738
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 15.511395454406738
#              x: [ 5.000e-02  2.168e+00  5.000e-01  2.474e-02]
#            nit: 469
#           nfev: 819
#  final_simplex: (array([[ 5.000e-02,  2.168e+00,  5.000e-01,  2.474e-02],
#                        [ 5.000e-02,  2.168e+00,  5.000e-01,  2.474e-02],
#                        ...,
#                        [ 5.000e-02,  2.168e+00,  5.000e-01,  2.474e-02],
#                        [ 5.000e-02,  2.168e+00,  5.000e-01,  2.474e-02]]), array([ 1.551e+01,  1.551e+01,  1.551e+01,  1.551e+01,
#                         1.551e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.12527316978527653, 2.4241816809852073, 0.11438174274766527, 0.3974759649257013]
# final_loss_fn:  13.677968978881836
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 13.677968978881836
#              x: [ 1.976e-01  2.361e+00  3.328e-02  7.618e-03]
#            nit: 714
#           nfev: 1241
#  final_simplex: (array([[ 1.976e-01,  2.361e+00,  3.328e-02,  7.618e-03],
#                        [ 1.976e-01,  2.361e+00,  3.328e-02,  7.618e-03],
#                        ...,
#                        [ 1.976e-01,  2.361e+00,  3.328e-02,  7.618e-03],
#                        [ 1.976e-01,  2.361e+00,  3.328e-02,  7.618e-03]]), array([ 1.368e+01,  1.368e+01,  1.368e+01,  1.368e+01,
#                         1.368e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.941679390877588, 2.069037341689946, 0.20931282839768933, 0.4659072384722263]
# final_loss_fn:  13.93986988067627
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 13.93986988067627
#              x: [ 5.000e-02  2.133e+00  1.178e-01  3.217e-02]
#            nit: 353
#           nfev: 651
#  final_simplex: (array([[ 5.000e-02,  2.133e+00,  1.178e-01,  3.217e-02],
#                        [ 5.000e-02,  2.133e+00,  1.178e-01,  3.217e-02],
#                        ...,
#                        [ 5.000e-02,  2.133e+00,  1.178e-01,  3.217e-02],
#                        [ 5.000e-02,  2.133e+00,  1.178e-01,  3.217e-02]]), array([ 1.394e+01,  1.394e+01,  1.394e+01,  1.394e+01,
#                         1.394e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.2085728795540511, 2.254056934550177, 0.49697350247414557, 0.37301115181002725]
# final_loss_fn:  14.809834480285645
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 14.809834480285645
#              x: [ 5.000e-02  2.193e+00  3.924e-01  2.109e-02]
#            nit: 233
#           nfev: 440
#  final_simplex: (array([[ 5.000e-02,  2.193e+00,  3.924e-01,  2.109e-02],
#                        [ 5.000e-02,  2.193e+00,  3.924e-01,  2.109e-02],
#                        ...,
#                        [ 5.000e-02,  2.193e+00,  3.924e-01,  2.109e-02],
#                        [ 5.000e-02,  2.193e+00,  3.924e-01,  2.109e-02]]), array([ 1.481e+01,  1.481e+01,  1.481e+01,  1.481e+01,
#                         1.481e+01]))

# %%
pd.DataFrame(_c.opt_results).sort_values("fun")
# Out:
#             fun   nit  nfev  status  success  \
# 9     13.111592   436   775       0     True
# 21    13.112337  1298  2178       0     True
# 24    13.122859   562   972       0     True
# 2     13.196199   373   660       0     True
# 16    13.333856   871  1503       0     True
# 22    13.387118   958  1614       0     True
# 27    13.677969   714  1241       0     True
# 20    13.771585   616  1061       0     True
# 19    13.775050   696  1196       0     True
# 23    13.775123   274   504       0     True
# 25    13.775318   700  1232       0     True
# 4     13.777749   192   357       0     True
# 1     13.789721   328   593       0     True
# 3     13.914070   149   286       0     True
# 28    13.939870   353   651       0     True
# 15    14.160215   628  1102       0     True
# 5     14.533711   344   596       0     True
# 29    14.809834   233   440       0     True
# 26    15.511395   469   819       0     True
# 13    15.511397   370   667       0     True
# 8     15.511401   385   673       0     True
# 17    15.855048   351   632       0     True
# 11    50.105370   167   305       0     True
# 7     61.900417   631  1079       0     True
# 12   151.085770   360   651       0     True
# 0   6081.623047    49   144       0     True
# 10  6081.623047    53   164       0     True
# 6   6081.623047    54   140       0     True
# 18  6081.623047    40   137       0     True
# 14  6081.623047    40   141       0     True
#
#                                   message  \
# 9   Optimization terminated successfully.
# 21  Optimization terminated successfully.
# 24  Optimization terminated successfully.
# 2   Optimization terminated successfully.
# 16  Optimization terminated successfully.
# 22  Optimization terminated successfully.
# 27  Optimization terminated successfully.
# 20  Optimization terminated successfully.
# 19  Optimization terminated successfully.
# 23  Optimization terminated successfully.
# 25  Optimization terminated successfully.
# 4   Optimization terminated successfully.
# 1   Optimization terminated successfully.
# 3   Optimization terminated successfully.
# 28  Optimization terminated successfully.
# 15  Optimization terminated successfully.
# 5   Optimization terminated successfully.
# 29  Optimization terminated successfully.
# 26  Optimization terminated successfully.
# 13  Optimization terminated successfully.
# 8   Optimization terminated successfully.
# 17  Optimization terminated successfully.
# 11  Optimization terminated successfully.
# 7   Optimization terminated successfully.
# 12  Optimization terminated successfully.
# 0   Optimization terminated successfully.
# 10  Optimization terminated successfully.
# 6   Optimization terminated successfully.
# 18  Optimization terminated successfully.
# 14  Optimization terminated successfully.
#
#                                                     x  \
# 9   [0.6075273163583736, 2.1238903341144395, 0.001...
# 21  [0.606517643992778, 2.124902854490619, 0.00101...
# 24  [0.6088640246225708, 2.1489345432184597, 0.001...
# 2   [0.4965363856614282, 2.149079770783592, 0.0027...
# 16  [0.34719771078975326, 2.1583846752268006, 0.01...
# 22  [0.3022779302602089, 2.167322700629401, 0.0159...
# 27  [0.1976058676244282, 2.3606089148822704, 0.033...
# 20  [0.08366198856209661, 2.1868678527055003, 0.12...
# 19  [0.05000000000000118, 2.2770296441594393, 0.13...
# 23  [0.05000000000000014, 2.2811721592841336, 0.13...
# 25  [0.4749731928766744, 2.4914221027689076, 0.002...
# 4   [0.05000000000000021, 2.30103356939623, 0.1341...
# 1   [0.45135192403175706, 2.4987992032971538, 0.00...
# 3   [0.05000000000000002, 2.499522162179398, 0.077...
# 28  [0.050000000000000044, 2.1331893267059776, 0.1...
# 15  [0.050000000000016226, 2.2762178053918647, 0.2...
# 5   [0.05000000000000032, 2.0169358527719465, 0.00...
# 29  [0.05000006521738573, 2.193133376659253, 0.392...
# 26  [0.05000000000000006, 2.1679823866285997, 0.5,...
# 13  [0.050000000000000405, 2.167982822828778, 0.5,...
# 8   [0.050000000000000544, 2.1679559894042457, 0.5...
# 17  [0.06781893232493783, 2.0894123956453967, 0.42...
# 11             [0.05, 1.7902246939801816, 0.001, 0.5]
# 7   [1.1249947305175576, 2.4999999642903603, 0.001...
# 12  [1.798441530484272, 1.0733982986018809, 0.0010...
# 0   [0.05, 0.05, 0.4966204183464187, 0.46864873754...
# 10  [0.05, 0.05, 0.2379442488671959, 0.33429219495...
# 6   [0.05438286337625384, 0.0519847259525249, 0.49...
# 18  [0.05, 0.050000000000000044, 0.473500365015193...
# 14             [0.05, 0.05, 0.38137730270269754, 0.5]
#
#                                         final_simplex
# 9   ([[0.6075273163583736, 2.1238903341144395, 0.0...
# 21  ([[0.606517643992778, 2.124902854490619, 0.001...
# 24  ([[0.6088640246225708, 2.1489345432184597, 0.0...
# 2   ([[0.4965363856614282, 2.149079770783592, 0.00...
# 16  ([[0.34719771078975326, 2.1583846752268006, 0....
# 22  ([[0.3022779302602089, 2.167322700629401, 0.01...
# 27  ([[0.1976058676244282, 2.3606089148822704, 0.0...
# 20  ([[0.08366198856209661, 2.1868678527055003, 0....
# 19  ([[0.05000000000000118, 2.2770296441594393, 0....
# 23  ([[0.05000000000000014, 2.2811721592841336, 0....
# 25  ([[0.4749731928766744, 2.4914221027689076, 0.0...
# 4   ([[0.05000000000000021, 2.30103356939623, 0.13...
# 1   ([[0.45135192403175706, 2.4987992032971538, 0....
# 3   ([[0.05000000000000002, 2.499522162179398, 0.0...
# 28  ([[0.050000000000000044, 2.1331893267059776, 0...
# 15  ([[0.050000000000016226, 2.2762178053918647, 0...
# 5   ([[0.05000000000000032, 2.0169358527719465, 0....
# 29  ([[0.05000006521738573, 2.193133376659253, 0.3...
# 26  ([[0.05000000000000006, 2.1679823866285997, 0....
# 13  ([[0.050000000000000405, 2.167982822828778, 0....
# 8   ([[0.050000000000000544, 2.1679559894042457, 0...
# 17  ([[0.06781893232493783, 2.0894123956453967, 0....
# 11  ([[0.05, 1.7902246939801816, 0.001, 0.5], [0.0...
# 7   ([[1.1249947305175576, 2.4999999642903603, 0.0...
# 12  ([[1.798441530484272, 1.0733982986018809, 0.00...
# 0   ([[0.05, 0.05, 0.4966204183464187, 0.468648737...
# 10  ([[0.05, 0.05, 0.2379442488671959, 0.334292194...
# 6   ([[0.05438286337625384, 0.0519847259525249, 0....
# 18  ([[0.05, 0.050000000000000044, 0.4735003650151...
# 14  ([[0.05, 0.05, 0.38137730270269754, 0.5], [0.0...

# %% [markdown]
# #  DE fit

# %%
_c = next(read_from_pickle(f"ff/{ffpkl}"))

# %%
fit_repeat(_c, 
           30, 
           "test",
           bounds = DE_bound,
           loss="jax_de",
           quiet='true'
          )
# Out:
# /home/boittier/Documents/phd/ff_energy/ff_energy/ffe/ff_fit.py:174: OptimizeWarning: Unknown solver options: pgtol
#   res = minimize(

# %%
pd.DataFrame(_c.opt_results).sort_values("fun")
# Out:
#             fun   nit  nfev  status  success  \
# 22     8.558699  1662  2645       0     True
# 16     8.608765  1330  2127       0     True
# 20     8.959163   778  1293       0     True
# 23     9.263350   561   952       0     True
# 26     9.274531   760  1285       0     True
# 29     9.593822   536   905       0     True
# 18     9.777595   540   931       0     True
# 13     9.989751   320   581       0     True
# 28    10.049688   740  1216       0     True
# 10    10.401322   643  1076       0     True
# 6     10.563690   526   909       0     True
# 24    10.619364   974  1578       0     True
# 0     10.628485   902  1469       0     True
# 8     10.881477   559   964       0     True
# 19    11.209083   590  1004       0     True
# 2     11.719383   473   840       0     True
# 7     12.067774  1351  2207       0     True
# 12    12.301665  1176  1907       0     True
# 3     15.006655   432   764       0     True
# 9     15.179872  1000  1626       0     True
# 4     20.126072  1155  1856       0     True
# 15   108.809395   633  1068       0     True
# 11  6081.623047    37   188       0     True
# 27  6081.623047    37   188       0     True
# 1   6081.623047    49   192       0     True
# 21  6081.623047    42   202       0     True
# 5   6081.623047    42   202       0     True
# 17  6081.623047    60   220       0     True
# 25  6081.623047    42   202       0     True
# 14  6081.623047    52   217       0     True
#
#                                   message  \
# 22  Optimization terminated successfully.
# 16  Optimization terminated successfully.
# 20  Optimization terminated successfully.
# 23  Optimization terminated successfully.
# 26  Optimization terminated successfully.
# 29  Optimization terminated successfully.
# 18  Optimization terminated successfully.
# 13  Optimization terminated successfully.
# 28  Optimization terminated successfully.
# 10  Optimization terminated successfully.
# 6   Optimization terminated successfully.
# 24  Optimization terminated successfully.
# 0   Optimization terminated successfully.
# 8   Optimization terminated successfully.
# 19  Optimization terminated successfully.
# 2   Optimization terminated successfully.
# 7   Optimization terminated successfully.
# 12  Optimization terminated successfully.
# 3   Optimization terminated successfully.
# 9   Optimization terminated successfully.
# 4   Optimization terminated successfully.
# 15  Optimization terminated successfully.
# 11  Optimization terminated successfully.
# 27  Optimization terminated successfully.
# 1   Optimization terminated successfully.
# 21  Optimization terminated successfully.
# 5   Optimization terminated successfully.
# 17  Optimization terminated successfully.
# 25  Optimization terminated successfully.
# 14  Optimization terminated successfully.
#
#                                                     x  \
# 22  [1.28096892135492, 1.8742760826350922, 0.00100...
# 16  [1.3794230348990628, 1.869992711573052, 0.0010...
# 20  [1.218900284584365, 2.0268489452535503, 0.0012...
# 23  [0.6061729398738087, 1.967862071700327, 0.0455...
# 26  [0.6106216838175349, 1.9777285711073878, 0.048...
# 29  [0.5168726311375258, 2.0260885531593993, 0.088...
# 18  [0.4450419632012804, 2.0158404251428546, 0.152...
# 13  [0.37686930848457656, 2.0236788861909845, 0.21...
# 28  [1.0301181137419082, 2.2781495516465027, 0.001...
# 10  [0.3434727647915302, 2.196005385990775, 0.2472...
# 6   [0.52494889834683, 2.3337518031081568, 0.03019...
# 24  [0.27510627065833937, 2.060352546565605, 0.466...
# 0   [0.27097483533508304, 2.058153872078765, 0.477...
# 8   [0.19691375259402538, 2.249923871925847, 0.5, ...
# 19  [0.24110015913667576, 2.082238943520724, 0.461...
# 2   [0.11403130311251854, 2.049786548103324, 0.359...
# 7   [2.218002451648272, 1.8495891332884473, 0.0010...
# 12  [0.5693059562698524, 2.2741785066806015, 0.001...
# 3   [0.8922015090409638, 1.9503238559385379, 0.010...
# 9   [2.5, 1.9001474450492035, 0.001000011790590158...
# 4   [2.4502502528930767, 2.2780807698816554, 0.001...
# 15  [2.483313458910353, 0.16451599000817674, 0.008...
# 11  [0.2898895226268644, 0.3095972096066766, 0.275...
# 27  [0.10929268499708775, 0.1533979160085357, 0.21...
# 1   [0.05, 0.1358784813931868, 0.5, 0.111702872920...
# 21  [0.14921473936443108, 0.31314047793685607, 0.0...
# 5   [0.3097621493229803, 0.2219698173738449, 0.424...
# 17  [0.2893835193600106, 0.29552333128658825, 0.21...
# 25  [0.2932545143462084, 0.27005136078382963, 0.00...
# 14  [0.05, 0.2787167110978497, 0.3214059225472401,...
#
#                                         final_simplex
# 22  ([[1.28096892135492, 1.8742760826350922, 0.001...
# 16  ([[1.3794230348990628, 1.869992711573052, 0.00...
# 20  ([[1.218900284584365, 2.0268489452535503, 0.00...
# 23  ([[0.6061729398738087, 1.967862071700327, 0.04...
# 26  ([[0.6106216838175349, 1.9777285711073878, 0.0...
# 29  ([[0.5168726311375258, 2.0260885531593993, 0.0...
# 18  ([[0.4450419632012804, 2.0158404251428546, 0.1...
# 13  ([[0.37686930848457656, 2.0236788861909845, 0....
# 28  ([[1.0301181137419082, 2.2781495516465027, 0.0...
# 10  ([[0.3434727647915302, 2.196005385990775, 0.24...
# 6   ([[0.52494889834683, 2.3337518031081568, 0.030...
# 24  ([[0.27510627065833937, 2.060352546565605, 0.4...
# 0   ([[0.27097483533508304, 2.058153872078765, 0.4...
# 8   ([[0.19691375259402538, 2.249923871925847, 0.5...
# 19  ([[0.24110015913667576, 2.082238943520724, 0.4...
# 2   ([[0.11403130311251854, 2.049786548103324, 0.3...
# 7   ([[2.218002451648272, 1.8495891332884473, 0.00...
# 12  ([[0.5693059562698524, 2.2741785066806015, 0.0...
# 3   ([[0.8922015090409638, 1.9503238559385379, 0.0...
# 9   ([[2.5, 1.9001474450492035, 0.0010000117905901...
# 4   ([[2.4502502528930767, 2.2780807698816554, 0.0...
# 15  ([[2.483313458910353, 0.16451599000817674, 0.0...
# 11  ([[0.2898895226268644, 0.3095972096066766, 0.2...
# 27  ([[0.10929268499708775, 0.1533979160085357, 0....
# 1   ([[0.05, 0.1358784813931868, 0.5, 0.1117028729...
# 21  ([[0.14921473936443108, 0.31314047793685607, 0...
# 5   ([[0.3097621493229803, 0.2219698173738449, 0.4...
# 17  ([[0.2893835193600106, 0.29552333128658825, 0....
# 25  ([[0.2932545143462084, 0.27005136078382963, 0....
# 14  ([[0.05, 0.2787167110978497, 0.321405922547240...
