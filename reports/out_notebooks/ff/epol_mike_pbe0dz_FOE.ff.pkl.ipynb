# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from ff_energy.ffe.utils import read_from_pickle
import jax.numpy as jnp
from ff_energy.ffe.plot import plot_energy_MSE, plot_ff_fit
from ff_energy.ffe.structure import atom_key_pairs
from ff_energy.ffe.potential import LJ, akp_indx
from ff_energy.ffe.ff import FF
from ff_energy.ffe.ff_fit import LJ_bound, load_ff, fit_func, fit_repeat
from ff_energy.ffe.data import pairs_data
from ff_energy.ffe.utils import pickle_output, read_from_pickle, str2int

# %%
sig_bound = (0.05, 2.5)
ep_bound = (0.001, 0.5)
LJ_bound = ((sig_bound), (sig_bound), (ep_bound), (ep_bound))
DE_bound = ((sig_bound), (sig_bound), (ep_bound), (ep_bound), 
            (1, 8), (6, 20))

# %%
#  example
# ffpkl = "ECOL_pbe0dz_FOE.ff.pkl"

# %%
# Parameters
ffpkl = "epol_mike_pbe0dz_FOE.ff.pkl"

# %% [markdown]
# #  LJ fit

# %%
_c = next(read_from_pickle(f"ff/{ffpkl}"))
_c
# Out:
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# FF: LJ water_cluster epol_mike Exact first_order_energy (jax_coloumb: False)

# %%
# _c.targets

# %%
fit_repeat(_c, 
           30, 
           f"{ffpkl}_LJ",
           bounds = LJ_bound,
           loss="jax",
           # quiet='true'
          )
# Out:
# /home/boittier/Documents/phd/ff_energy/ff_energy/ffe/ff_fit.py:174: OptimizeWarning: Unknown solver options: pgtol
#   res = minimize(
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [2.379378849151063, 0.5945560375715365, 0.355909118873635, 0.20769130687740603]
# final_loss_fn:  26090.95703125
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 26090.95703125
#              x: [ 6.511e-02  1.636e-01  3.613e-01  1.000e-03]
#            nit: 60
#           nfev: 167
#  final_simplex: (array([[ 6.511e-02,  1.636e-01,  3.613e-01,  1.000e-03],
#                        [ 6.511e-02,  1.636e-01,  3.613e-01,  1.000e-03],
#                        ...,
#                        [ 6.511e-02,  1.636e-01,  3.613e-01,  1.000e-03],
#                        [ 6.511e-02,  1.636e-01,  3.613e-01,  1.000e-03]]), array([ 2.609e+04,  2.609e+04,  2.609e+04,  2.609e+04,
#                         2.609e+04]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [2.3941067248554817, 1.1996060337665524, 0.3629778835893735, 0.36816207850776766]
# final_loss_fn:  69.05086517333984
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 69.05086517333984
#              x: [ 7.572e-01  2.169e+00  1.000e-03  4.540e-02]
#            nit: 550
#           nfev: 966
#  final_simplex: (array([[ 7.572e-01,  2.169e+00,  1.000e-03,  4.540e-02],
#                        [ 7.572e-01,  2.169e+00,  1.000e-03,  4.540e-02],
#                        ...,
#                        [ 7.572e-01,  2.169e+00,  1.000e-03,  4.540e-02],
#                        [ 7.572e-01,  2.169e+00,  1.000e-03,  4.540e-02]]), array([ 6.905e+01,  6.905e+01,  6.905e+01,  6.905e+01,
#                         6.905e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [2.2507204755892265, 2.4429613272103072, 0.4745587094929712, 0.014125808473948932]
# final_loss_fn:  72.8146743774414
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 72.8146743774414
#              x: [ 5.000e-02  2.368e+00  5.000e-01  1.494e-02]
#            nit: 155
#           nfev: 308
#  final_simplex: (array([[ 5.000e-02,  2.368e+00,  5.000e-01,  1.494e-02],
#                        [ 5.000e-02,  2.368e+00,  5.000e-01,  1.494e-02],
#                        ...,
#                        [ 5.000e-02,  2.368e+00,  5.000e-01,  1.494e-02],
#                        [ 5.000e-02,  2.368e+00,  5.000e-01,  1.494e-02]]), array([ 7.281e+01,  7.281e+01,  7.281e+01,  7.281e+01,
#                         7.281e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.3088122281250456, 1.0581617068851004, 0.35418441690594504, 0.008581795380201832]
# final_loss_fn:  59.10626983642578
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 59.10626983642578
#              x: [ 6.514e-01  2.499e+00  1.000e-03  7.336e-03]
#            nit: 840
#           nfev: 1430
#  final_simplex: (array([[ 6.514e-01,  2.499e+00,  1.000e-03,  7.336e-03],
#                        [ 6.514e-01,  2.499e+00,  1.000e-03,  7.336e-03],
#                        ...,
#                        [ 6.514e-01,  2.499e+00,  1.000e-03,  7.336e-03],
#                        [ 6.514e-01,  2.499e+00,  1.000e-03,  7.336e-03]]), array([ 5.911e+01,  5.911e+01,  5.911e+01,  5.911e+01,
#                         5.911e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.35722949375102636, 1.3346078866343212, 0.1123020459625966, 0.3313143571204527]
# final_loss_fn:  26090.95703125
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 26090.95703125
#              x: [ 6.166e-02  5.859e-02  3.385e-01  4.894e-01]
#            nit: 63
#           nfev: 174
#  final_simplex: (array([[ 6.166e-02,  5.859e-02,  3.385e-01,  4.894e-01],
#                        [ 6.166e-02,  5.859e-02,  3.385e-01,  4.894e-01],
#                        ...,
#                        [ 6.166e-02,  5.859e-02,  3.385e-01,  4.894e-01],
#                        [ 6.166e-02,  5.859e-02,  3.385e-01,  4.894e-01]]), array([ 2.609e+04,  2.609e+04,  2.609e+04,  2.609e+04,
#                         2.609e+04]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [2.240221908035589, 0.7145392415389877, 0.2670868866833263, 0.3526050526503892]
# final_loss_fn:  59.116920471191406
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 59.116920471191406
#              x: [ 6.424e-01  2.500e+00  1.070e-03  7.292e-03]
#            nit: 770
#           nfev: 1332
#  final_simplex: (array([[ 6.424e-01,  2.500e+00,  1.070e-03,  7.292e-03],
#                        [ 6.424e-01,  2.500e+00,  1.070e-03,  7.292e-03],
#                        ...,
#                        [ 6.424e-01,  2.500e+00,  1.070e-03,  7.292e-03],
#                        [ 6.424e-01,  2.500e+00,  1.070e-03,  7.292e-03]]), array([ 5.912e+01,  5.912e+01,  5.912e+01,  5.912e+01,
#                         5.912e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.2844859149517105, 2.2206123359051784, 0.01845395424591858, 0.28223686903603157]
# final_loss_fn:  61.449806213378906
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 61.449806213378906
#              x: [ 1.866e-01  2.500e+00  4.300e-02  7.551e-03]
#            nit: 407
#           nfev: 721
#  final_simplex: (array([[ 1.866e-01,  2.500e+00,  4.300e-02,  7.551e-03],
#                        [ 1.866e-01,  2.500e+00,  4.300e-02,  7.551e-03],
#                        ...,
#                        [ 1.866e-01,  2.500e+00,  4.300e-02,  7.551e-03],
#                        [ 1.866e-01,  2.500e+00,  4.300e-02,  7.551e-03]]), array([ 6.145e+01,  6.145e+01,  6.145e+01,  6.145e+01,
#                         6.145e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [2.034998831942789, 0.41397003933133103, 0.49978060434645283, 0.24238265721567367]
# final_loss_fn:  15773.32421875
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 15773.32421875
#              x: [ 1.378e+00  5.000e-02  5.000e-01  1.000e-03]
#            nit: 133
#           nfev: 260
#  final_simplex: (array([[ 1.378e+00,  5.000e-02,  5.000e-01,  1.000e-03],
#                        [ 1.378e+00,  5.000e-02,  5.000e-01,  1.000e-03],
#                        ...,
#                        [ 1.378e+00,  5.000e-02,  5.000e-01,  1.000e-03],
#                        [ 1.378e+00,  5.000e-02,  5.000e-01,  1.000e-03]]), array([ 1.577e+04,  1.577e+04,  1.577e+04,  1.577e+04,
#                         1.577e+04]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.6671179081584806, 2.375647822636718, 0.09287753870820696, 0.1291632466585537]
# final_loss_fn:  59.38251495361328
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 59.38251495361328
#              x: [ 5.572e-01  2.500e+00  2.058e-03  7.321e-03]
#            nit: 826
#           nfev: 1413
#  final_simplex: (array([[ 5.572e-01,  2.500e+00,  2.058e-03,  7.321e-03],
#                        [ 5.572e-01,  2.500e+00,  2.058e-03,  7.321e-03],
#                        ...,
#                        [ 5.572e-01,  2.500e+00,  2.058e-03,  7.321e-03],
#                        [ 5.572e-01,  2.500e+00,  2.058e-03,  7.321e-03]]), array([ 5.938e+01,  5.938e+01,  5.938e+01,  5.938e+01,
#                         5.938e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.539419366390884, 1.3791989784161245, 0.3607143974740619, 0.2047162460463928]
# final_loss_fn:  59.09186935424805
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 59.09186935424805
#              x: [ 6.515e-01  2.500e+00  1.000e-03  7.289e-03]
#            nit: 782
#           nfev: 1353
#  final_simplex: (array([[ 6.515e-01,  2.500e+00,  1.000e-03,  7.289e-03],
#                        [ 6.515e-01,  2.500e+00,  1.000e-03,  7.289e-03],
#                        ...,
#                        [ 6.515e-01,  2.500e+00,  1.000e-03,  7.289e-03],
#                        [ 6.515e-01,  2.500e+00,  1.000e-03,  7.289e-03]]), array([ 5.909e+01,  5.909e+01,  5.909e+01,  5.909e+01,
#                         5.909e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [2.191148782427914, 0.3316941046942366, 0.16647035323396941, 0.06574439894110264]
# final_loss_fn:  5291.1201171875
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 5291.1201171875
#              x: [ 2.118e+00  5.591e-01  1.598e-03  1.093e-02]
#            nit: 216
#           nfev: 405
#  final_simplex: (array([[ 2.118e+00,  5.591e-01,  1.598e-03,  1.093e-02],
#                        [ 2.118e+00,  5.591e-01,  1.598e-03,  1.093e-02],
#                        ...,
#                        [ 2.118e+00,  5.591e-01,  1.598e-03,  1.093e-02],
#                        [ 2.118e+00,  5.591e-01,  1.598e-03,  1.093e-02]]), array([ 5.291e+03,  5.291e+03,  5.291e+03,  5.291e+03,
#                         5.291e+03]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.6948058434302882, 1.2601098924564513, 0.01948552687477523, 0.2111936882242421]
# final_loss_fn:  26090.95703125
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 26090.95703125
#              x: [ 1.036e-01  5.000e-02  3.033e-02  3.759e-01]
#            nit: 48
#           nfev: 150
#  final_simplex: (array([[ 1.036e-01,  5.000e-02,  3.033e-02,  3.759e-01],
#                        [ 1.036e-01,  5.000e-02,  3.033e-02,  3.759e-01],
#                        ...,
#                        [ 1.036e-01,  5.000e-02,  3.033e-02,  3.759e-01],
#                        [ 1.036e-01,  5.000e-02,  3.033e-02,  3.759e-01]]), array([ 2.609e+04,  2.609e+04,  2.609e+04,  2.609e+04,
#                         2.609e+04]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [2.468713646165635, 1.663565605388487, 0.3120876252275897, 0.24378462760614883]
# final_loss_fn:  162.8755340576172
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 162.8755340576172
#              x: [ 5.000e-02  1.863e+00  1.000e-03  5.000e-01]
#            nit: 247
#           nfev: 433
#  final_simplex: (array([[ 5.000e-02,  1.863e+00,  1.000e-03,  5.000e-01],
#                        [ 5.000e-02,  1.863e+00,  1.000e-03,  5.000e-01],
#                        ...,
#                        [ 5.000e-02,  1.863e+00,  1.000e-03,  5.000e-01],
#                        [ 5.000e-02,  1.863e+00,  1.000e-03,  5.000e-01]]), array([ 1.629e+02,  1.629e+02,  1.629e+02,  1.629e+02,
#                         1.629e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.5580135763744024, 1.0321522707521877, 0.4483818392891117, 0.4321201373524313]
# final_loss_fn:  26090.95703125
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 26090.95703125
#              x: [ 5.000e-02  5.893e-02  4.365e-01  5.000e-01]
#            nit: 59
#           nfev: 161
#  final_simplex: (array([[ 5.000e-02,  5.893e-02,  4.365e-01,  5.000e-01],
#                        [ 5.000e-02,  5.893e-02,  4.365e-01,  5.000e-01],
#                        ...,
#                        [ 5.000e-02,  5.893e-02,  4.365e-01,  5.000e-01],
#                        [ 5.000e-02,  5.893e-02,  4.365e-01,  5.000e-01]]), array([ 2.609e+04,  2.609e+04,  2.609e+04,  2.609e+04,
#                         2.609e+04]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.3986521562313474, 2.287343671454774, 0.018255497251496992, 0.1344715052242299]
# final_loss_fn:  539.3799438476562
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 539.3799438476562
#              x: [ 1.860e+00  1.279e+00  1.000e-03  2.236e-01]
#            nit: 345
#           nfev: 608
#  final_simplex: (array([[ 1.860e+00,  1.279e+00,  1.000e-03,  2.236e-01],
#                        [ 1.860e+00,  1.279e+00,  1.000e-03,  2.236e-01],
#                        ...,
#                        [ 1.860e+00,  1.279e+00,  1.000e-03,  2.236e-01],
#                        [ 1.860e+00,  1.279e+00,  1.000e-03,  2.236e-01]]), array([ 5.394e+02,  5.394e+02,  5.394e+02,  5.394e+02,
#                         5.394e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.7587286627978982, 1.9259474319126828, 0.15234294537537701, 0.4132864338752525]
# final_loss_fn:  62.76797103881836
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 62.76797103881836
#              x: [ 5.070e-02  2.499e+00  1.228e-01  7.834e-03]
#            nit: 392
#           nfev: 713
#  final_simplex: (array([[ 5.070e-02,  2.499e+00,  1.228e-01,  7.834e-03],
#                        [ 5.070e-02,  2.499e+00,  1.228e-01,  7.834e-03],
#                        ...,
#                        [ 5.070e-02,  2.499e+00,  1.228e-01,  7.834e-03],
#                        [ 5.070e-02,  2.499e+00,  1.228e-01,  7.834e-03]]), array([ 6.277e+01,  6.277e+01,  6.277e+01,  6.277e+01,
#                         6.277e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.6526488492073732, 1.551744118407453, 0.49056350048455516, 0.08731812895608788]
# final_loss_fn:  73.37741088867188
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 73.37741088867188
#              x: [ 7.480e-02  2.328e+00  4.256e-01  1.883e-02]
#            nit: 398
#           nfev: 709
#  final_simplex: (array([[ 7.480e-02,  2.328e+00,  4.256e-01,  1.883e-02],
#                        [ 7.480e-02,  2.328e+00,  4.256e-01,  1.883e-02],
#                        ...,
#                        [ 7.480e-02,  2.328e+00,  4.256e-01,  1.883e-02],
#                        [ 7.480e-02,  2.328e+00,  4.256e-01,  1.883e-02]]), array([ 7.338e+01,  7.338e+01,  7.338e+01,  7.338e+01,
#                         7.338e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.713548179201244, 0.50189918791944, 0.11598782016216778, 0.4895049917829794]
# final_loss_fn:  59.09186935424805
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 59.09186935424805
#              x: [ 6.513e-01  2.500e+00  1.000e-03  7.290e-03]
#            nit: 489
#           nfev: 850
#  final_simplex: (array([[ 6.513e-01,  2.500e+00,  1.000e-03,  7.290e-03],
#                        [ 6.513e-01,  2.500e+00,  1.000e-03,  7.290e-03],
#                        ...,
#                        [ 6.513e-01,  2.500e+00,  1.000e-03,  7.290e-03],
#                        [ 6.513e-01,  2.500e+00,  1.000e-03,  7.290e-03]]), array([ 5.909e+01,  5.909e+01,  5.909e+01,  5.909e+01,
#                         5.909e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.5610240643647406, 1.1895735026925125, 0.08512568215768762, 0.0787472505612825]
# final_loss_fn:  60.535736083984375
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 60.535736083984375
#              x: [ 3.098e-01  2.500e+00  1.499e-02  7.453e-03]
#            nit: 767
#           nfev: 1314
#  final_simplex: (array([[ 3.098e-01,  2.500e+00,  1.499e-02,  7.453e-03],
#                        [ 3.098e-01,  2.500e+00,  1.499e-02,  7.453e-03],
#                        ...,
#                        [ 3.098e-01,  2.500e+00,  1.499e-02,  7.453e-03],
#                        [ 3.098e-01,  2.500e+00,  1.499e-02,  7.453e-03]]), array([ 6.054e+01,  6.054e+01,  6.054e+01,  6.054e+01,
#                         6.054e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.5615623005976155, 2.3307652165168222, 0.37861954343327936, 0.4570565583750034]
# final_loss_fn:  209.38104248046875
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 209.38104248046875
#              x: [ 5.000e-02  1.870e+00  5.000e-01  5.000e-01]
#            nit: 149
#           nfev: 289
#  final_simplex: (array([[ 5.000e-02,  1.870e+00,  5.000e-01,  5.000e-01],
#                        [ 5.000e-02,  1.870e+00,  5.000e-01,  5.000e-01],
#                        ...,
#                        [ 5.000e-02,  1.870e+00,  5.000e-01,  5.000e-01],
#                        [ 5.000e-02,  1.870e+00,  5.000e-01,  5.000e-01]]), array([ 2.094e+02,  2.094e+02,  2.094e+02,  2.094e+02,
#                         2.094e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.16809106933921097, 0.27676716726225487, 0.0023956291787463595, 0.4704652029857552]
# final_loss_fn:  26090.96484375
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 26090.96484375
#              x: [ 1.951e-01  8.149e-02  2.834e-03  4.777e-01]
#            nit: 29
#           nfev: 115
#  final_simplex: (array([[ 1.951e-01,  8.149e-02,  2.834e-03,  4.777e-01],
#                        [ 1.951e-01,  8.149e-02,  2.834e-03,  4.777e-01],
#                        ...,
#                        [ 1.951e-01,  8.149e-02,  2.834e-03,  4.777e-01],
#                        [ 1.951e-01,  8.149e-02,  2.834e-03,  4.777e-01]]), array([ 2.609e+04,  2.609e+04,  2.609e+04,  2.609e+04,
#                         2.609e+04]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.832468107883987, 1.174568443152729, 0.4186036777224086, 0.3785244676435399]
# final_loss_fn:  471.2690124511719
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 471.2690124511719
#              x: [ 1.864e+00  1.535e+00  1.000e-03  2.911e-02]
#            nit: 427
#           nfev: 759
#  final_simplex: (array([[ 1.864e+00,  1.535e+00,  1.000e-03,  2.911e-02],
#                        [ 1.864e+00,  1.535e+00,  1.000e-03,  2.911e-02],
#                        ...,
#                        [ 1.864e+00,  1.535e+00,  1.000e-03,  2.911e-02],
#                        [ 1.864e+00,  1.535e+00,  1.000e-03,  2.911e-02]]), array([ 4.713e+02,  4.713e+02,  4.713e+02,  4.713e+02,
#                         4.713e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.2938036434711064, 1.8337647095167695, 0.03649628281087455, 0.4671788238521878]
# final_loss_fn:  60.18392562866211
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 60.18392562866211
#              x: [ 3.692e-01  2.500e+00  9.057e-03  7.422e-03]
#            nit: 498
#           nfev: 882
#  final_simplex: (array([[ 3.692e-01,  2.500e+00,  9.057e-03,  7.422e-03],
#                        [ 3.692e-01,  2.500e+00,  9.057e-03,  7.422e-03],
#                        ...,
#                        [ 3.692e-01,  2.500e+00,  9.057e-03,  7.422e-03],
#                        [ 3.692e-01,  2.500e+00,  9.057e-03,  7.422e-03]]), array([ 6.018e+01,  6.018e+01,  6.018e+01,  6.018e+01,
#                         6.018e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.922758095860854, 1.6090066062960913, 0.3891404461181176, 0.4228457407786316]
# final_loss_fn:  62.74721908569336
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 62.74721908569336
#              x: [ 5.000e-02  2.500e+00  1.194e-01  7.802e-03]
#            nit: 575
#           nfev: 1014
#  final_simplex: (array([[ 5.000e-02,  2.500e+00,  1.194e-01,  7.802e-03],
#                        [ 5.000e-02,  2.500e+00,  1.194e-01,  7.802e-03],
#                        ...,
#                        [ 5.000e-02,  2.500e+00,  1.194e-01,  7.802e-03],
#                        [ 5.000e-02,  2.500e+00,  1.194e-01,  7.802e-03]]), array([ 6.275e+01,  6.275e+01,  6.275e+01,  6.275e+01,
#                         6.275e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.48075739883589097, 1.572394824498472, 0.008648069120843841, 0.33078542170651376]
# final_loss_fn:  60.79366683959961
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 60.79366683959961
#              x: [ 2.733e-01  2.500e+00  2.079e-02  7.466e-03]
#            nit: 579
#           nfev: 1021
#  final_simplex: (array([[ 2.733e-01,  2.500e+00,  2.079e-02,  7.466e-03],
#                        [ 2.733e-01,  2.500e+00,  2.079e-02,  7.466e-03],
#                        ...,
#                        [ 2.733e-01,  2.500e+00,  2.079e-02,  7.466e-03],
#                        [ 2.733e-01,  2.500e+00,  2.079e-02,  7.466e-03]]), array([ 6.079e+01,  6.079e+01,  6.079e+01,  6.079e+01,
#                         6.079e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [2.2236516080301256, 0.9458543079477693, 0.4044903368830319, 0.3201999039131907]
# final_loss_fn:  62.7431640625
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 62.7431640625
#              x: [ 5.000e-02  2.500e+00  1.202e-01  7.791e-03]
#            nit: 757
#           nfev: 1296
#  final_simplex: (array([[ 5.000e-02,  2.500e+00,  1.202e-01,  7.791e-03],
#                        [ 5.000e-02,  2.500e+00,  1.202e-01,  7.791e-03],
#                        ...,
#                        [ 5.000e-02,  2.500e+00,  1.202e-01,  7.791e-03],
#                        [ 5.000e-02,  2.500e+00,  1.202e-01,  7.791e-03]]), array([ 6.274e+01,  6.274e+01,  6.274e+01,  6.274e+01,
#                         6.274e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.039220906098432, 0.6369630149608145, 0.2690645039295854, 0.23104590815431905]
# final_loss_fn:  26090.9609375
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 26090.9609375
#              x: [ 9.614e-02  1.336e-01  1.000e-03  4.511e-01]
#            nit: 60
#           nfev: 170
#  final_simplex: (array([[ 9.614e-02,  1.336e-01,  1.000e-03,  4.511e-01],
#                        [ 9.614e-02,  1.336e-01,  1.000e-03,  4.511e-01],
#                        ...,
#                        [ 9.614e-02,  1.336e-01,  1.000e-03,  4.511e-01],
#                        [ 9.614e-02,  1.336e-01,  1.000e-03,  4.511e-01]]), array([ 2.609e+04,  2.609e+04,  2.609e+04,  2.609e+04,
#                         2.609e+04]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.7456507442913364, 0.7933089447251821, 0.06746764748728398, 0.33079608521098663]
# final_loss_fn:  26090.95703125
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 26090.95703125
#              x: [ 8.619e-02  5.000e-02  1.069e-01  5.000e-01]
#            nit: 33
#           nfev: 127
#  final_simplex: (array([[ 8.619e-02,  5.000e-02,  1.069e-01,  5.000e-01],
#                        [ 8.619e-02,  5.000e-02,  1.069e-01,  5.000e-01],
#                        ...,
#                        [ 8.619e-02,  5.000e-02,  1.069e-01,  5.000e-01],
#                        [ 8.619e-02,  5.000e-02,  1.069e-01,  5.000e-01]]), array([ 2.609e+04,  2.609e+04,  2.609e+04,  2.609e+04,
#                         2.609e+04]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.4794143405934262, 0.7704266662420579, 0.10758415280530405, 0.205054673904447]
# final_loss_fn:  26090.95703125
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 26090.95703125
#              x: [ 5.000e-02  5.000e-02  2.926e-01  4.684e-01]
#            nit: 50
#           nfev: 153
#  final_simplex: (array([[ 5.000e-02,  5.000e-02,  2.926e-01,  4.684e-01],
#                        [ 5.000e-02,  5.000e-02,  2.926e-01,  4.684e-01],
#                        ...,
#                        [ 5.000e-02,  5.000e-02,  2.926e-01,  4.684e-01],
#                        [ 5.000e-02,  5.000e-02,  2.926e-01,  4.684e-01]]), array([ 2.609e+04,  2.609e+04,  2.609e+04,  2.609e+04,
#                         2.609e+04]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.24591467836284436, 1.8219911299835105, 0.2210155739200064, 0.4067040240173363]
# final_loss_fn:  62.083595275878906
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 62.083595275878906
#              x: [ 7.094e-01  2.332e+00  1.000e-03  1.753e-02]
#            nit: 554
#           nfev: 967
#  final_simplex: (array([[ 7.094e-01,  2.332e+00,  1.000e-03,  1.753e-02],
#                        [ 7.094e-01,  2.332e+00,  1.000e-03,  1.753e-02],
#                        ...,
#                        [ 7.094e-01,  2.332e+00,  1.000e-03,  1.753e-02],
#                        [ 7.094e-01,  2.332e+00,  1.000e-03,  1.753e-02]]), array([ 6.208e+01,  6.208e+01,  6.208e+01,  6.208e+01,
#                         6.208e+01]))

# %%
pd.DataFrame(_c.opt_results).sort_values("fun")
# Out:
#              fun  nit  nfev  status  success  \
# 9      59.091869  782  1353       0     True
# 17     59.091869  489   850       0     True
# 3      59.106270  840  1430       0     True
# 5      59.116920  770  1332       0     True
# 8      59.382515  826  1413       0     True
# 22     60.183926  498   882       0     True
# 18     60.535736  767  1314       0     True
# 24     60.793667  579  1021       0     True
# 6      61.449806  407   721       0     True
# 29     62.083595  554   967       0     True
# 25     62.743164  757  1296       0     True
# 23     62.747219  575  1014       0     True
# 15     62.767971  392   713       0     True
# 1      69.050865  550   966       0     True
# 2      72.814674  155   308       0     True
# 16     73.377411  398   709       0     True
# 12    162.875534  247   433       0     True
# 19    209.381042  149   289       0     True
# 21    471.269012  427   759       0     True
# 14    539.379944  345   608       0     True
# 10   5291.120117  216   405       0     True
# 7   15773.324219  133   260       0     True
# 13  26090.957031   59   161       0     True
# 11  26090.957031   48   150       0     True
# 4   26090.957031   63   174       0     True
# 27  26090.957031   33   127       0     True
# 28  26090.957031   50   153       0     True
# 0   26090.957031   60   167       0     True
# 26  26090.960938   60   170       0     True
# 20  26090.964844   29   115       0     True
#
#                                   message  \
# 9   Optimization terminated successfully.
# 17  Optimization terminated successfully.
# 3   Optimization terminated successfully.
# 5   Optimization terminated successfully.
# 8   Optimization terminated successfully.
# 22  Optimization terminated successfully.
# 18  Optimization terminated successfully.
# 24  Optimization terminated successfully.
# 6   Optimization terminated successfully.
# 29  Optimization terminated successfully.
# 25  Optimization terminated successfully.
# 23  Optimization terminated successfully.
# 15  Optimization terminated successfully.
# 1   Optimization terminated successfully.
# 2   Optimization terminated successfully.
# 16  Optimization terminated successfully.
# 12  Optimization terminated successfully.
# 19  Optimization terminated successfully.
# 21  Optimization terminated successfully.
# 14  Optimization terminated successfully.
# 10  Optimization terminated successfully.
# 7   Optimization terminated successfully.
# 13  Optimization terminated successfully.
# 11  Optimization terminated successfully.
# 4   Optimization terminated successfully.
# 27  Optimization terminated successfully.
# 28  Optimization terminated successfully.
# 0   Optimization terminated successfully.
# 26  Optimization terminated successfully.
# 20  Optimization terminated successfully.
#
#                                                     x  \
# 9   [0.6514503982822832, 2.4999998952348292, 0.001...
# 17  [0.6513444788751404, 2.499999007042918, 0.001,...
# 3   [0.6513511871496138, 2.4987960375207816, 0.001...
# 5   [0.6424385542756643, 2.4999975464713504, 0.001...
# 8   [0.5572109143041418, 2.4999999999771614, 0.002...
# 22  [0.36920579811600096, 2.4999979709565316, 0.00...
# 18  [0.3097776367171917, 2.499998250939866, 0.0149...
# 24  [0.2733158749145275, 2.4999994203345786, 0.020...
# 6   [0.1866072594345895, 2.499925277779141, 0.0429...
# 29  [0.7094496077797656, 2.332439547880055, 0.0010...
# 25  [0.05000000000003403, 2.4999999430794912, 0.12...
# 23  [0.05000000000005697, 2.499819693383709, 0.119...
# 15  [0.05069829631991196, 2.4986350517445155, 0.12...
# 1   [0.7572216082640091, 2.1688467554230284, 0.001...
# 2   [0.050000000000001446, 2.3680812020541095, 0.5...
# 16  [0.07480411126543844, 2.327638511024567, 0.425...
# 12  [0.05000000000000002, 1.8633734263319477, 0.00...
# 19               [0.05, 1.8702011942558499, 0.5, 0.5]
# 21  [1.8640490703278725, 1.5352531825179685, 0.001...
# 14  [1.8604088574928928, 1.2787414194837985, 0.001...
# 10  [2.1178808491674337, 0.5591439861132381, 0.001...
# 7   [1.3782277387987358, 0.05000000000000113, 0.5,...
# 13  [0.05, 0.05892993156046633, 0.4364634779224899...
# 11  [0.10358214482797234, 0.05, 0.0303297667794695...
# 4   [0.06166017831846336, 0.05859417296042979, 0.3...
# 27  [0.08619222296889362, 0.05, 0.1069421143660177...
# 28  [0.05, 0.05, 0.2925742382476268, 0.46841797114...
# 0   [0.06511235370008585, 0.1635998624718747, 0.36...
# 26  [0.09614014414257444, 0.13360629065063084, 0.0...
# 20  [0.19506157489949877, 0.0814861731835733, 0.00...
#
#                                         final_simplex
# 9   ([[0.6514503982822832, 2.4999998952348292, 0.0...
# 17  ([[0.6513444788751404, 2.499999007042918, 0.00...
# 3   ([[0.6513511871496138, 2.4987960375207816, 0.0...
# 5   ([[0.6424385542756643, 2.4999975464713504, 0.0...
# 8   ([[0.5572109143041418, 2.4999999999771614, 0.0...
# 22  ([[0.36920579811600096, 2.4999979709565316, 0....
# 18  ([[0.3097776367171917, 2.499998250939866, 0.01...
# 24  ([[0.2733158749145275, 2.4999994203345786, 0.0...
# 6   ([[0.1866072594345895, 2.499925277779141, 0.04...
# 29  ([[0.7094496077797656, 2.332439547880055, 0.00...
# 25  ([[0.05000000000003403, 2.4999999430794912, 0....
# 23  ([[0.05000000000005697, 2.499819693383709, 0.1...
# 15  ([[0.05069829631991196, 2.4986350517445155, 0....
# 1   ([[0.7572216082640091, 2.1688467554230284, 0.0...
# 2   ([[0.050000000000001446, 2.3680812020541095, 0...
# 16  ([[0.07480411126543844, 2.327638511024567, 0.4...
# 12  ([[0.05000000000000002, 1.8633734263319477, 0....
# 19  ([[0.05, 1.8702011942558499, 0.5, 0.5], [0.05,...
# 21  ([[1.8640490703278725, 1.5352531825179685, 0.0...
# 14  ([[1.8604088574928928, 1.2787414194837985, 0.0...
# 10  ([[2.1178808491674337, 0.5591439861132381, 0.0...
# 7   ([[1.3782277387987358, 0.05000000000000113, 0....
# 13  ([[0.05, 0.05892993156046633, 0.43646347792248...
# 11  ([[0.10358214482797234, 0.05, 0.03032976677946...
# 4   ([[0.06166017831846336, 0.05859417296042979, 0...
# 27  ([[0.08619222296889362, 0.05, 0.10694211436601...
# 28  ([[0.05, 0.05, 0.2925742382476268, 0.468417971...
# 0   ([[0.06511235370008585, 0.1635998624718747, 0....
# 26  ([[0.09614014414257444, 0.13360629065063084, 0...
# 20  ([[0.19506157489949877, 0.0814861731835733, 0....

# %% [markdown]
# #  DE fit

# %%
_c = next(read_from_pickle(f"ff/{ffpkl}"))

# %%
fit_repeat(_c, 
           30, 
           "test",
           bounds = DE_bound,
           loss="jax_de",
           quiet='true'
          )
# Out:
# /home/boittier/Documents/phd/ff_energy/ff_energy/ffe/ff_fit.py:174: OptimizeWarning: Unknown solver options: pgtol
#   res = minimize(

# %%
pd.DataFrame(_c.opt_results).sort_values("fun")
# Out:
#              fun   nit  nfev  status  success  \
# 18     26.774380   604  1013       0     True
# 23     26.981478  1364  2220       0     True
# 8      27.959930   608  1063       0     True
# 22     28.070398  1672  2627       0     True
# 28     28.122772  1108  1793       0     True
# 16     28.655512  1023  1659       0     True
# 24     28.766556   320   589       0     True
# 19     30.306431   329   610       0     True
# 25     30.436350   412   728       0     True
# 14     30.792059  1904  2997       0     True
# 7      31.821785   475   814       0     True
# 27     32.177132  1147  1830       0     True
# 5      34.179016  1710  2731       0     True
# 2      34.223080  1149  1868       0     True
# 11     34.916946   966  1567       0     True
# 6      35.086292  1536  2457       0     True
# 29     35.182312  1242  2012       0     True
# 26     36.457165  1334  2119       0     True
# 4      37.484035  1528  2442       0     True
# 12     39.316299   840  1382       0     True
# 17     49.250645   452   776       0     True
# 1      51.735748   515   865       0     True
# 13  26090.957031    49   219       0     True
# 20  26090.957031    50   207       0     True
# 21  26090.957031    52   210       0     True
# 10  26090.957031    43   196       0     True
# 9   26090.957031    56   201       0     True
# 3   26090.957031    44   204       0     True
# 15  26090.957031    53   218       0     True
# 0   26090.957031    42   202       0     True
#
#                                   message  \
# 18  Optimization terminated successfully.
# 23  Optimization terminated successfully.
# 8   Optimization terminated successfully.
# 22  Optimization terminated successfully.
# 28  Optimization terminated successfully.
# 16  Optimization terminated successfully.
# 24  Optimization terminated successfully.
# 19  Optimization terminated successfully.
# 25  Optimization terminated successfully.
# 14  Optimization terminated successfully.
# 7   Optimization terminated successfully.
# 27  Optimization terminated successfully.
# 5   Optimization terminated successfully.
# 2   Optimization terminated successfully.
# 11  Optimization terminated successfully.
# 6   Optimization terminated successfully.
# 29  Optimization terminated successfully.
# 26  Optimization terminated successfully.
# 4   Optimization terminated successfully.
# 12  Optimization terminated successfully.
# 17  Optimization terminated successfully.
# 1   Optimization terminated successfully.
# 13  Optimization terminated successfully.
# 20  Optimization terminated successfully.
# 21  Optimization terminated successfully.
# 10  Optimization terminated successfully.
# 9   Optimization terminated successfully.
# 3   Optimization terminated successfully.
# 15  Optimization terminated successfully.
# 0   Optimization terminated successfully.
#
#                                                     x  \
# 18  [1.2950121574621243, 2.2635972169351533, 0.012...
# 23  [0.7945666621365591, 2.4999974130736184, 0.077...
# 8   [0.6421622900600751, 2.4999994694947913, 0.287...
# 22  [0.44510483242032334, 2.499992534707741, 0.499...
# 28  [0.6177499243684804, 2.490606988511678, 0.2594...
# 16  [0.45714953869792263, 2.418452711593313, 0.497...
# 24  [0.4895222027768178, 2.3421927891883025, 0.376...
# 19  [1.2076575665101954, 2.194531556102418, 0.0175...
# 25  [0.5048950959952636, 2.2771010166178325, 0.330...
# 14  [1.875073500514982, 1.859049970953592, 0.00100...
# 7   [0.6874049899890352, 2.094416944279583, 0.1227...
# 27  [0.9623372177750836, 2.383642582600566, 0.0193...
# 5   [2.0475979991279765, 1.7679827309004077, 0.001...
# 2   [2.4514563120860537, 1.8040845979170916, 0.001...
# 11  [0.6333577655908031, 2.3618510685844263, 0.5, ...
# 6   [2.5, 1.7591244755303421, 0.001, 0.49864948869...
# 29  [2.095247588929212, 1.7449775617703167, 0.0013...
# 26  [2.020547519931533, 1.7775385706824243, 0.0018...
# 4   [0.15479004343221447, 2.4560306274610526, 0.26...
# 12  [1.7387439289536586, 1.8649738199746617, 0.002...
# 17  [0.7433090567297362, 2.089414747324951, 0.1071...
# 1   [0.6327839783163907, 2.148718778085642, 0.2030...
# 13  [0.05, 0.35504038426681106, 0.3393054252448488...
# 20  [0.3255089072067118, 0.05, 0.3546924902990869,...
# 21  [0.05, 0.44408874498210027, 0.4635759026104409...
# 10  [0.3984946540603057, 0.20201360157086623, 0.01...
# 9   [0.35977108612458364, 0.2784086352402354, 0.14...
# 3   [0.16033435776050187, 0.24483703229281473, 0.1...
# 15  [0.06985097400991253, 0.45266357086471576, 0.3...
# 0   [0.2115233966273573, 0.3335887599007319, 0.012...
#
#                                         final_simplex
# 18  ([[1.2950121574621243, 2.2635972169351533, 0.0...
# 23  ([[0.7945666621365591, 2.4999974130736184, 0.0...
# 8   ([[0.6421622900600751, 2.4999994694947913, 0.2...
# 22  ([[0.44510483242032334, 2.499992534707741, 0.4...
# 28  ([[0.6177499243684804, 2.490606988511678, 0.25...
# 16  ([[0.45714953869792263, 2.418452711593313, 0.4...
# 24  ([[0.4895222027768178, 2.3421927891883025, 0.3...
# 19  ([[1.2076575665101954, 2.194531556102418, 0.01...
# 25  ([[0.5048950959952636, 2.2771010166178325, 0.3...
# 14  ([[1.875073500514982, 1.859049970953592, 0.001...
# 7   ([[0.6874049899890352, 2.094416944279583, 0.12...
# 27  ([[0.9623372177750836, 2.383642582600566, 0.01...
# 5   ([[2.0475979991279765, 1.7679827309004077, 0.0...
# 2   ([[2.4514563120860537, 1.8040845979170916, 0.0...
# 11  ([[0.6333577655908031, 2.3618510685844263, 0.5...
# 6   ([[2.5, 1.7591244755303421, 0.001, 0.498649488...
# 29  ([[2.095247588929212, 1.7449775617703167, 0.00...
# 26  ([[2.020547519931533, 1.7775385706824243, 0.00...
# 4   ([[0.15479004343221447, 2.4560306274610526, 0....
# 12  ([[1.7387439289536586, 1.8649738199746617, 0.0...
# 17  ([[0.7433090567297362, 2.089414747324951, 0.10...
# 1   ([[0.6327839783163907, 2.148718778085642, 0.20...
# 13  ([[0.05, 0.35504038426681106, 0.33930542524484...
# 20  ([[0.3255089072067118, 0.05, 0.354692490299086...
# 21  ([[0.05, 0.44408874498210027, 0.46357590261044...
# 10  ([[0.3984946540603057, 0.20201360157086623, 0....
# 9   ([[0.35977108612458364, 0.2784086352402354, 0....
# 3   ([[0.16033435776050187, 0.24483703229281473, 0...
# 15  ([[0.06985097400991253, 0.45266357086471576, 0...
# 0   ([[0.2115233966273573, 0.3335887599007319, 0.0...
