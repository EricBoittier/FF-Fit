# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from ff_energy.ffe.utils import read_from_pickle
import jax.numpy as jnp
from ff_energy.ffe.plot import plot_energy_MSE, plot_ff_fit
from ff_energy.ffe.structure import atom_key_pairs
from ff_energy.ffe.potential import LJ, akp_indx
from ff_energy.ffe.ff import FF
from ff_energy.ffe.ff_fit import LJ_bound, load_ff, fit_func, fit_repeat
from ff_energy.ffe.data import pairs_data
from ff_energy.ffe.utils import pickle_output, read_from_pickle, str2int

# %%
sig_bound = (0.05, 2.5)
ep_bound = (0.001, 0.5)
LJ_bound = ((sig_bound), (sig_bound), (ep_bound), (ep_bound))
DE_bound = ((sig_bound), (sig_bound), (ep_bound), (ep_bound), 
            (1, 8), (6, 20))

# %%
#  example
# ffpkl = "ECOL_pbe0dz_FOE.ff.pkl"

# %%
# Parameters
ffpkl = "DUMMY_pbe0dz_pairs.ff.pkl"

# %% [markdown]
# #  LJ fit

# %%
_c = next(read_from_pickle(f"ff/{ffpkl}"))
_c
# Out:
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# FF: LJ water_cluster DUMMY Exact P_intE (jax_coloumb: False)

# %%
# _c.targets

# %%
fit_repeat(_c, 
           30, 
           f"{ffpkl}_LJ",
           bounds = LJ_bound,
           loss="jax",
           # quiet='true'
          )
# Out:
# /home/boittier/Documents/phd/ff_energy/ff_energy/ffe/ff_fit.py:174: OptimizeWarning: Unknown solver options: pgtol
#   res = minimize(
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.6317033193464009, 1.1040559746103438, 0.014851898767064088, 0.06619854849945192]
# final_loss_fn:  1119.5928955078125
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 1119.5928955078125
#              x: [ 4.367e-01  1.449e+00  5.000e-01  5.000e-01]
#            nit: 183
#           nfev: 327
#  final_simplex: (array([[ 4.367e-01,  1.449e+00,  5.000e-01,  5.000e-01],
#                        [ 4.367e-01,  1.449e+00,  5.000e-01,  5.000e-01],
#                        ...,
#                        [ 4.367e-01,  1.449e+00,  5.000e-01,  5.000e-01],
#                        [ 4.367e-01,  1.449e+00,  5.000e-01,  5.000e-01]]), array([ 1.120e+03,  1.120e+03,  1.120e+03,  1.120e+03,
#                         1.120e+03]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [2.241367210070064, 0.7080337215355351, 0.16924370210841516, 0.008453528102218479]
# final_loss_fn:  699.72216796875
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 699.72216796875
#              x: [ 1.116e+00  7.825e-01  5.000e-01  5.000e-01]
#            nit: 427
#           nfev: 724
#  final_simplex: (array([[ 1.116e+00,  7.825e-01,  5.000e-01,  5.000e-01],
#                        [ 1.116e+00,  7.825e-01,  5.000e-01,  5.000e-01],
#                        ...,
#                        [ 1.116e+00,  7.825e-01,  5.000e-01,  5.000e-01],
#                        [ 1.116e+00,  7.825e-01,  5.000e-01,  5.000e-01]]), array([ 6.997e+02,  6.997e+02,  6.997e+02,  6.997e+02,
#                         6.997e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.38233850464312485, 0.2606489538116578, 0.21678318039447808, 0.2557665821980211]
# final_loss_fn:  699.7218017578125
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 699.7218017578125
#              x: [ 1.116e+00  7.825e-01  5.000e-01  5.000e-01]
#            nit: 397
#           nfev: 669
#  final_simplex: (array([[ 1.116e+00,  7.825e-01,  5.000e-01,  5.000e-01],
#                        [ 1.116e+00,  7.825e-01,  5.000e-01,  5.000e-01],
#                        ...,
#                        [ 1.116e+00,  7.825e-01,  5.000e-01,  5.000e-01],
#                        [ 1.116e+00,  7.825e-01,  5.000e-01,  5.000e-01]]), array([ 6.997e+02,  6.997e+02,  6.997e+02,  6.997e+02,
#                         6.997e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.6255142312283912, 1.958551550632192, 0.11023691750567254, 0.19697329221038318]
# final_loss_fn:  699.7218017578125
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 699.7218017578125
#              x: [ 1.116e+00  7.825e-01  5.000e-01  5.000e-01]
#            nit: 151
#           nfev: 294
#  final_simplex: (array([[ 1.116e+00,  7.825e-01,  5.000e-01,  5.000e-01],
#                        [ 1.116e+00,  7.825e-01,  5.000e-01,  5.000e-01],
#                        ...,
#                        [ 1.116e+00,  7.825e-01,  5.000e-01,  5.000e-01],
#                        [ 1.116e+00,  7.825e-01,  5.000e-01,  5.000e-01]]), array([ 6.997e+02,  6.997e+02,  6.997e+02,  6.997e+02,
#                         6.997e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.521772844604751, 1.6721243180645413, 0.08842203783647354, 0.06077012604572576]
# final_loss_fn:  699.72265625
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 699.72265625
#              x: [ 1.116e+00  7.826e-01  5.000e-01  5.000e-01]
#            nit: 366
#           nfev: 624
#  final_simplex: (array([[ 1.116e+00,  7.826e-01,  5.000e-01,  5.000e-01],
#                        [ 1.116e+00,  7.826e-01,  5.000e-01,  5.000e-01],
#                        ...,
#                        [ 1.116e+00,  7.826e-01,  5.000e-01,  5.000e-01],
#                        [ 1.116e+00,  7.826e-01,  5.000e-01,  5.000e-01]]), array([ 6.997e+02,  6.997e+02,  6.997e+02,  6.997e+02,
#                         6.997e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [2.438760249421565, 2.010993209708938, 0.14992423369302943, 0.06301094008795785]
# final_loss_fn:  1540.0445556640625
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 1540.0445556640625
#              x: [ 5.000e-02  1.484e+00  5.000e-01  5.000e-01]
#            nit: 126
#           nfev: 243
#  final_simplex: (array([[ 5.000e-02,  1.484e+00,  5.000e-01,  5.000e-01],
#                        [ 5.000e-02,  1.484e+00,  5.000e-01,  5.000e-01],
#                        ...,
#                        [ 5.000e-02,  1.484e+00,  5.000e-01,  5.000e-01],
#                        [ 5.000e-02,  1.484e+00,  5.000e-01,  5.000e-01]]), array([ 1.540e+03,  1.540e+03,  1.540e+03,  1.540e+03,
#                         1.540e+03]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.4606384949067805, 2.1629189996149782, 0.1878898180565341, 0.4090870076223596]
# final_loss_fn:  1119.591552734375
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 1119.591552734375
#              x: [ 4.367e-01  1.449e+00  5.000e-01  5.000e-01]
#            nit: 502
#           nfev: 846
#  final_simplex: (array([[ 4.367e-01,  1.449e+00,  5.000e-01,  5.000e-01],
#                        [ 4.367e-01,  1.449e+00,  5.000e-01,  5.000e-01],
#                        ...,
#                        [ 4.367e-01,  1.449e+00,  5.000e-01,  5.000e-01],
#                        [ 4.367e-01,  1.449e+00,  5.000e-01,  5.000e-01]]), array([ 1.120e+03,  1.120e+03,  1.120e+03,  1.120e+03,
#                         1.120e+03]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [2.379340990117624, 2.4240971096587214, 0.1866325246180689, 0.337656117168794]
# final_loss_fn:  1540.0498046875
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 1540.0498046875
#              x: [ 5.000e-02  1.484e+00  5.000e-01  5.000e-01]
#            nit: 89
#           nfev: 182
#  final_simplex: (array([[ 5.000e-02,  1.484e+00,  5.000e-01,  5.000e-01],
#                        [ 5.000e-02,  1.484e+00,  5.000e-01,  5.000e-01],
#                        ...,
#                        [ 5.000e-02,  1.484e+00,  5.000e-01,  5.000e-01],
#                        [ 5.000e-02,  1.484e+00,  5.000e-01,  5.000e-01]]), array([ 1.540e+03,  1.540e+03,  1.540e+03,  1.540e+03,
#                         1.540e+03]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.4330858528876544, 1.587830305898218, 0.07473269513861593, 0.2977350650444612]
# final_loss_fn:  699.7218017578125
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 699.7218017578125
#              x: [ 1.116e+00  7.826e-01  5.000e-01  5.000e-01]
#            nit: 181
#           nfev: 331
#  final_simplex: (array([[ 1.116e+00,  7.826e-01,  5.000e-01,  5.000e-01],
#                        [ 1.116e+00,  7.826e-01,  5.000e-01,  5.000e-01],
#                        ...,
#                        [ 1.116e+00,  7.826e-01,  5.000e-01,  5.000e-01],
#                        [ 1.116e+00,  7.826e-01,  5.000e-01,  5.000e-01]]), array([ 6.997e+02,  6.997e+02,  6.997e+02,  6.997e+02,
#                         6.997e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.118870476215171, 1.6545940982687883, 0.3695940979477207, 0.0584346264537264]
# final_loss_fn:  699.7218017578125
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 699.7218017578125
#              x: [ 1.116e+00  7.824e-01  5.000e-01  5.000e-01]
#            nit: 363
#           nfev: 619
#  final_simplex: (array([[ 1.116e+00,  7.824e-01,  5.000e-01,  5.000e-01],
#                        [ 1.116e+00,  7.824e-01,  5.000e-01,  5.000e-01],
#                        ...,
#                        [ 1.116e+00,  7.824e-01,  5.000e-01,  5.000e-01],
#                        [ 1.116e+00,  7.824e-01,  5.000e-01,  5.000e-01]]), array([ 6.997e+02,  6.997e+02,  6.997e+02,  6.997e+02,
#                         6.997e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.69437513003299, 2.466396968358488, 0.008281328819455334, 0.34667499000774255]
# final_loss_fn:  1119.5919189453125
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 1119.5919189453125
#              x: [ 4.368e-01  1.449e+00  5.000e-01  5.000e-01]
#            nit: 223
#           nfev: 398
#  final_simplex: (array([[ 4.368e-01,  1.449e+00,  5.000e-01,  5.000e-01],
#                        [ 4.368e-01,  1.449e+00,  5.000e-01,  5.000e-01],
#                        ...,
#                        [ 4.368e-01,  1.449e+00,  5.000e-01,  5.000e-01],
#                        [ 4.368e-01,  1.449e+00,  5.000e-01,  5.000e-01]]), array([ 1.120e+03,  1.120e+03,  1.120e+03,  1.120e+03,
#                         1.120e+03]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.2421741396773483, 2.062633853443847, 0.42995931711791086, 0.2261047979309293]
# final_loss_fn:  1119.591552734375
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 1119.591552734375
#              x: [ 4.369e-01  1.449e+00  5.000e-01  5.000e-01]
#            nit: 116
#           nfev: 234
#  final_simplex: (array([[ 4.369e-01,  1.449e+00,  5.000e-01,  5.000e-01],
#                        [ 4.369e-01,  1.449e+00,  5.000e-01,  5.000e-01],
#                        ...,
#                        [ 4.369e-01,  1.449e+00,  5.000e-01,  5.000e-01],
#                        [ 4.369e-01,  1.449e+00,  5.000e-01,  5.000e-01]]), array([ 1.120e+03,  1.120e+03,  1.120e+03,  1.120e+03,
#                         1.120e+03]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.49441039991950786, 0.36187531298488296, 0.1929372894631188, 0.3348517508612958]
# final_loss_fn:  699.7218627929688
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 699.7218627929688
#              x: [ 1.116e+00  7.826e-01  5.000e-01  5.000e-01]
#            nit: 177
#           nfev: 320
#  final_simplex: (array([[ 1.116e+00,  7.826e-01,  5.000e-01,  5.000e-01],
#                        [ 1.116e+00,  7.826e-01,  5.000e-01,  5.000e-01],
#                        ...,
#                        [ 1.116e+00,  7.826e-01,  5.000e-01,  5.000e-01],
#                        [ 1.116e+00,  7.826e-01,  5.000e-01,  5.000e-01]]), array([ 6.997e+02,  6.997e+02,  6.997e+02,  6.997e+02,
#                         6.997e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.7570488997683499, 1.6646418094760476, 0.13157726624854182, 0.38283487877277356]
# final_loss_fn:  1120.00634765625
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 1120.00634765625
#              x: [ 4.367e-01  1.450e+00  4.995e-01  5.000e-01]
#            nit: 238
#           nfev: 425
#  final_simplex: (array([[ 4.367e-01,  1.450e+00,  4.995e-01,  5.000e-01],
#                        [ 4.367e-01,  1.450e+00,  4.995e-01,  5.000e-01],
#                        ...,
#                        [ 4.367e-01,  1.450e+00,  4.995e-01,  5.000e-01],
#                        [ 4.367e-01,  1.450e+00,  4.995e-01,  5.000e-01]]), array([ 1.120e+03,  1.120e+03,  1.120e+03,  1.120e+03,
#                         1.120e+03]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [2.265090361114543, 1.8419631125493072, 0.4271377318794044, 0.2644768167446892]
# final_loss_fn:  699.7220458984375
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 699.7220458984375
#              x: [ 1.116e+00  7.825e-01  5.000e-01  5.000e-01]
#            nit: 158
#           nfev: 285
#  final_simplex: (array([[ 1.116e+00,  7.825e-01,  5.000e-01,  5.000e-01],
#                        [ 1.116e+00,  7.825e-01,  5.000e-01,  5.000e-01],
#                        ...,
#                        [ 1.116e+00,  7.825e-01,  5.000e-01,  5.000e-01],
#                        [ 1.116e+00,  7.825e-01,  5.000e-01,  5.000e-01]]), array([ 6.997e+02,  6.997e+02,  6.997e+02,  6.997e+02,
#                         6.997e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.569811920724778, 2.1580800823567694, 0.004404007237174318, 0.1003991740392238]
# final_loss_fn:  1119.591552734375
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 1119.591552734375
#              x: [ 4.369e-01  1.449e+00  5.000e-01  5.000e-01]
#            nit: 214
#           nfev: 388
#  final_simplex: (array([[ 4.369e-01,  1.449e+00,  5.000e-01,  5.000e-01],
#                        [ 4.369e-01,  1.449e+00,  5.000e-01,  5.000e-01],
#                        ...,
#                        [ 4.369e-01,  1.449e+00,  5.000e-01,  5.000e-01],
#                        [ 4.369e-01,  1.449e+00,  5.000e-01,  5.000e-01]]), array([ 1.120e+03,  1.120e+03,  1.120e+03,  1.120e+03,
#                         1.120e+03]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.812760332439453, 0.9009473147550496, 0.4230401604435642, 0.19233625763141965]
# final_loss_fn:  699.7260131835938
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 699.7260131835938
#              x: [ 1.116e+00  7.818e-01  5.000e-01  5.000e-01]
#            nit: 343
#           nfev: 604
#  final_simplex: (array([[ 1.116e+00,  7.818e-01,  5.000e-01,  5.000e-01],
#                        [ 1.116e+00,  7.818e-01,  5.000e-01,  5.000e-01],
#                        ...,
#                        [ 1.116e+00,  7.818e-01,  5.000e-01,  5.000e-01],
#                        [ 1.116e+00,  7.818e-01,  5.000e-01,  5.000e-01]]), array([ 6.997e+02,  6.997e+02,  6.997e+02,  6.997e+02,
#                         6.997e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.7565289646859901, 0.5772766981857341, 0.23487071816205896, 0.2070268605066044]
# final_loss_fn:  699.7218017578125
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 699.7218017578125
#              x: [ 1.116e+00  7.826e-01  5.000e-01  5.000e-01]
#            nit: 169
#           nfev: 329
#  final_simplex: (array([[ 1.116e+00,  7.826e-01,  5.000e-01,  5.000e-01],
#                        [ 1.116e+00,  7.826e-01,  5.000e-01,  5.000e-01],
#                        ...,
#                        [ 1.116e+00,  7.826e-01,  5.000e-01,  5.000e-01],
#                        [ 1.116e+00,  7.826e-01,  5.000e-01,  5.000e-01]]), array([ 6.997e+02,  6.997e+02,  6.997e+02,  6.997e+02,
#                         6.997e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.10896277921959951, 0.9357001589666188, 0.2607261889722722, 0.13602638748773696]
# final_loss_fn:  1119.5916748046875
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 1119.5916748046875
#              x: [ 4.368e-01  1.449e+00  5.000e-01  5.000e-01]
#            nit: 299
#           nfev: 522
#  final_simplex: (array([[ 4.368e-01,  1.449e+00,  5.000e-01,  5.000e-01],
#                        [ 4.368e-01,  1.449e+00,  5.000e-01,  5.000e-01],
#                        ...,
#                        [ 4.368e-01,  1.449e+00,  5.000e-01,  5.000e-01],
#                        [ 4.368e-01,  1.449e+00,  5.000e-01,  5.000e-01]]), array([ 1.120e+03,  1.120e+03,  1.120e+03,  1.120e+03,
#                         1.120e+03]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.3308688993827535, 2.1269251844200983, 0.038812110139546586, 0.23292049489638533]
# final_loss_fn:  1119.591552734375
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 1119.591552734375
#              x: [ 4.369e-01  1.449e+00  5.000e-01  5.000e-01]
#            nit: 283
#           nfev: 491
#  final_simplex: (array([[ 4.369e-01,  1.449e+00,  5.000e-01,  5.000e-01],
#                        [ 4.369e-01,  1.449e+00,  5.000e-01,  5.000e-01],
#                        ...,
#                        [ 4.369e-01,  1.449e+00,  5.000e-01,  5.000e-01],
#                        [ 4.369e-01,  1.449e+00,  5.000e-01,  5.000e-01]]), array([ 1.120e+03,  1.120e+03,  1.120e+03,  1.120e+03,
#                         1.120e+03]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.2393047818599497, 1.7684750516615453, 0.4368573265587894, 0.47847942328795723]
# final_loss_fn:  1119.591796875
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 1119.591796875
#              x: [ 4.367e-01  1.449e+00  5.000e-01  5.000e-01]
#            nit: 618
#           nfev: 1013
#  final_simplex: (array([[ 4.367e-01,  1.449e+00,  5.000e-01,  5.000e-01],
#                        [ 4.367e-01,  1.449e+00,  5.000e-01,  5.000e-01],
#                        ...,
#                        [ 4.367e-01,  1.449e+00,  5.000e-01,  5.000e-01],
#                        [ 4.367e-01,  1.449e+00,  5.000e-01,  5.000e-01]]), array([ 1.120e+03,  1.120e+03,  1.120e+03,  1.120e+03,
#                         1.120e+03]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [2.2184799420738024, 0.34574964880685743, 0.46016987902834344, 0.4653871887815538]
# final_loss_fn:  699.7218017578125
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 699.7218017578125
#              x: [ 1.116e+00  7.826e-01  5.000e-01  5.000e-01]
#            nit: 195
#           nfev: 354
#  final_simplex: (array([[ 1.116e+00,  7.826e-01,  5.000e-01,  5.000e-01],
#                        [ 1.116e+00,  7.826e-01,  5.000e-01,  5.000e-01],
#                        ...,
#                        [ 1.116e+00,  7.826e-01,  5.000e-01,  5.000e-01],
#                        [ 1.116e+00,  7.826e-01,  5.000e-01,  5.000e-01]]), array([ 6.997e+02,  6.997e+02,  6.997e+02,  6.997e+02,
#                         6.997e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [2.2511793329803997, 1.3389527826086436, 0.06015400446019741, 0.06174215939803497]
# final_loss_fn:  1119.593017578125
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 1119.593017578125
#              x: [ 4.367e-01  1.449e+00  5.000e-01  5.000e-01]
#            nit: 187
#           nfev: 339
#  final_simplex: (array([[ 4.367e-01,  1.449e+00,  5.000e-01,  5.000e-01],
#                        [ 4.367e-01,  1.449e+00,  5.000e-01,  5.000e-01],
#                        ...,
#                        [ 4.367e-01,  1.449e+00,  5.000e-01,  5.000e-01],
#                        [ 4.367e-01,  1.449e+00,  5.000e-01,  5.000e-01]]), array([ 1.120e+03,  1.120e+03,  1.120e+03,  1.120e+03,
#                         1.120e+03]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.7778173705259914, 0.3759601622088934, 0.1305570981000365, 0.3055931893170721]
# final_loss_fn:  699.7218017578125
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 699.7218017578125
#              x: [ 1.116e+00  7.825e-01  5.000e-01  5.000e-01]
#            nit: 337
#           nfev: 590
#  final_simplex: (array([[ 1.116e+00,  7.825e-01,  5.000e-01,  5.000e-01],
#                        [ 1.116e+00,  7.825e-01,  5.000e-01,  5.000e-01],
#                        ...,
#                        [ 1.116e+00,  7.825e-01,  5.000e-01,  5.000e-01],
#                        [ 1.116e+00,  7.825e-01,  5.000e-01,  5.000e-01]]), array([ 6.997e+02,  6.997e+02,  6.997e+02,  6.997e+02,
#                         6.997e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.8374559927771323, 1.6439626711074335, 0.11555189871243428, 0.3059315441477715]
# final_loss_fn:  1540.0445556640625
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 1540.0445556640625
#              x: [ 5.000e-02  1.484e+00  5.000e-01  5.000e-01]
#            nit: 115
#           nfev: 220
#  final_simplex: (array([[ 5.000e-02,  1.484e+00,  5.000e-01,  5.000e-01],
#                        [ 5.000e-02,  1.484e+00,  5.000e-01,  5.000e-01],
#                        ...,
#                        [ 5.000e-02,  1.484e+00,  5.000e-01,  5.000e-01],
#                        [ 5.000e-02,  1.484e+00,  5.000e-01,  5.000e-01]]), array([ 1.540e+03,  1.540e+03,  1.540e+03,  1.540e+03,
#                         1.540e+03]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.075194685554701, 0.4222258969673293, 0.19788467682219602, 0.30194728046786873]
# final_loss_fn:  1345.792724609375
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 1345.792724609375
#              x: [ 1.123e+00  7.589e-01  4.782e-01  1.665e-02]
#            nit: 104
#           nfev: 225
#  final_simplex: (array([[ 1.123e+00,  7.589e-01,  4.782e-01,  1.665e-02],
#                        [ 1.123e+00,  7.589e-01,  4.782e-01,  1.665e-02],
#                        ...,
#                        [ 1.123e+00,  7.589e-01,  4.782e-01,  1.665e-02],
#                        [ 1.123e+00,  7.589e-01,  4.782e-01,  1.665e-02]]), array([ 1.346e+03,  1.346e+03,  1.346e+03,  1.346e+03,
#                         1.346e+03]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.7370567532789055, 2.29850567335747, 0.43466850317423394, 0.06281454870105613]
# final_loss_fn:  699.7218627929688
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 699.7218627929688
#              x: [ 1.116e+00  7.824e-01  5.000e-01  5.000e-01]
#            nit: 166
#           nfev: 321
#  final_simplex: (array([[ 1.116e+00,  7.824e-01,  5.000e-01,  5.000e-01],
#                        [ 1.116e+00,  7.824e-01,  5.000e-01,  5.000e-01],
#                        ...,
#                        [ 1.116e+00,  7.824e-01,  5.000e-01,  5.000e-01],
#                        [ 1.116e+00,  7.824e-01,  5.000e-01,  5.000e-01]]), array([ 6.997e+02,  6.997e+02,  6.997e+02,  6.997e+02,
#                         6.997e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.197882301606007, 1.2564067424057423, 0.2681750740889119, 0.4115609456807633]
# final_loss_fn:  1119.591552734375
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 1119.591552734375
#              x: [ 4.368e-01  1.449e+00  5.000e-01  5.000e-01]
#            nit: 243
#           nfev: 434
#  final_simplex: (array([[ 4.368e-01,  1.449e+00,  5.000e-01,  5.000e-01],
#                        [ 4.368e-01,  1.449e+00,  5.000e-01,  5.000e-01],
#                        ...,
#                        [ 4.368e-01,  1.449e+00,  5.000e-01,  5.000e-01],
#                        [ 4.368e-01,  1.449e+00,  5.000e-01,  5.000e-01]]), array([ 1.120e+03,  1.120e+03,  1.120e+03,  1.120e+03,
#                         1.120e+03]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.3123955181669262, 1.9130326274710723, 0.22332188708811535, 0.10599277843192108]
# final_loss_fn:  1119.591552734375
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 1119.591552734375
#              x: [ 4.367e-01  1.449e+00  5.000e-01  5.000e-01]
#            nit: 191
#           nfev: 357
#  final_simplex: (array([[ 4.367e-01,  1.449e+00,  5.000e-01,  5.000e-01],
#                        [ 4.367e-01,  1.449e+00,  5.000e-01,  5.000e-01],
#                        ...,
#                        [ 4.367e-01,  1.449e+00,  5.000e-01,  5.000e-01],
#                        [ 4.367e-01,  1.449e+00,  5.000e-01,  5.000e-01]]), array([ 1.120e+03,  1.120e+03,  1.120e+03,  1.120e+03,
#                         1.120e+03]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [2.37600583892865, 0.4872364052073127, 0.10385702110339351, 0.47809138813759555]
# final_loss_fn:  699.7218627929688
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 699.7218627929688
#              x: [ 1.116e+00  7.824e-01  5.000e-01  5.000e-01]
#            nit: 394
#           nfev: 685
#  final_simplex: (array([[ 1.116e+00,  7.824e-01,  5.000e-01,  5.000e-01],
#                        [ 1.116e+00,  7.824e-01,  5.000e-01,  5.000e-01],
#                        ...,
#                        [ 1.116e+00,  7.824e-01,  5.000e-01,  5.000e-01],
#                        [ 1.116e+00,  7.824e-01,  5.000e-01,  5.000e-01]]), array([ 6.997e+02,  6.997e+02,  6.997e+02,  6.997e+02,
#                         6.997e+02]))

# %%
pd.DataFrame(_c.opt_results).sort_values("fun")
# Out:
#             fun  nit  nfev  status  success  \
# 2    699.721802  397   669       0     True
# 3    699.721802  151   294       0     True
# 23   699.721802  337   590       0     True
# 21   699.721802  195   354       0     True
# 17   699.721802  169   329       0     True
# 8    699.721802  181   331       0     True
# 9    699.721802  363   619       0     True
# 29   699.721863  394   685       0     True
# 26   699.721863  166   321       0     True
# 12   699.721863  177   320       0     True
# 14   699.722046  158   285       0     True
# 1    699.722168  427   724       0     True
# 4    699.722656  366   624       0     True
# 16   699.726013  343   604       0     True
# 11  1119.591553  116   234       0     True
# 27  1119.591553  243   434       0     True
# 28  1119.591553  191   357       0     True
# 15  1119.591553  214   388       0     True
# 6   1119.591553  502   846       0     True
# 19  1119.591553  283   491       0     True
# 18  1119.591675  299   522       0     True
# 20  1119.591797  618  1013       0     True
# 10  1119.591919  223   398       0     True
# 0   1119.592896  183   327       0     True
# 22  1119.593018  187   339       0     True
# 13  1120.006348  238   425       0     True
# 25  1345.792725  104   225       0     True
# 24  1540.044556  115   220       0     True
# 5   1540.044556  126   243       0     True
# 7   1540.049805   89   182       0     True
#
#                                   message  \
# 2   Optimization terminated successfully.
# 3   Optimization terminated successfully.
# 23  Optimization terminated successfully.
# 21  Optimization terminated successfully.
# 17  Optimization terminated successfully.
# 8   Optimization terminated successfully.
# 9   Optimization terminated successfully.
# 29  Optimization terminated successfully.
# 26  Optimization terminated successfully.
# 12  Optimization terminated successfully.
# 14  Optimization terminated successfully.
# 1   Optimization terminated successfully.
# 4   Optimization terminated successfully.
# 16  Optimization terminated successfully.
# 11  Optimization terminated successfully.
# 27  Optimization terminated successfully.
# 28  Optimization terminated successfully.
# 15  Optimization terminated successfully.
# 6   Optimization terminated successfully.
# 19  Optimization terminated successfully.
# 18  Optimization terminated successfully.
# 20  Optimization terminated successfully.
# 10  Optimization terminated successfully.
# 0   Optimization terminated successfully.
# 22  Optimization terminated successfully.
# 13  Optimization terminated successfully.
# 25  Optimization terminated successfully.
# 24  Optimization terminated successfully.
# 5   Optimization terminated successfully.
# 7   Optimization terminated successfully.
#
#                                                     x  \
# 2   [1.1157747334900527, 0.7825302253042986, 0.5, ...
# 3   [1.1157801239951561, 0.7825230722079007, 0.5, ...
# 23   [1.11578121926315, 0.7825133449851435, 0.5, 0.5]
# 21  [1.1157454784667986, 0.7825820909575728, 0.499...
# 17  [1.1157329157595581, 0.782572847529099, 0.5, 0.5]
# 8   [1.1157898837755906, 0.7825535778421688, 0.5, ...
# 9   [1.1158000678228974, 0.782449143434748, 0.5, 0.5]
# 29  [1.115811204942443, 0.7824269933379742, 0.5, 0.5]
# 26  [1.115795052253736, 0.7824427408927865, 0.5, 0.5]
# 12  [1.115762634796738, 0.7825817048341235, 0.5, 0...
# 14  [1.1157635245683553, 0.7825462135732798, 0.5, ...
# 1   [1.1158069519526501, 0.7824831478077756, 0.499...
# 4   [1.1157434581111012, 0.7826194435690277, 0.499...
# 16  [1.115705903700335, 0.7817868092529949, 0.5, 0...
# 11  [0.43692271545699374, 1.4486841302256357, 0.5,...
# 27  [0.43676039270698486, 1.4488283746640727, 0.5,...
# 28  [0.4367094086160457, 1.4488139400920184, 0.5, ...
# 15   [0.436889655195765, 1.448747641142337, 0.5, 0.5]
# 6   [0.43671368165699936, 1.4487660761590213, 0.5,...
# 19  [0.43688629871779033, 1.448689994839735, 0.5, ...
# 18  [0.4368135478515086, 1.448748076854482, 0.4999...
# 20  [0.4366517011783316, 1.4487680880075735, 0.5, ...
# 10  [0.4367737500389921, 1.448814497260641, 0.4999...
# 0   [0.4366635799422993, 1.4488815143873484, 0.499...
# 22  [0.4366673090808465, 1.4487176048084855, 0.499...
# 13  [0.43668965757579586, 1.4495042943551728, 0.49...
# 25  [1.1231623948361857, 0.7588907842515304, 0.478...
# 24  [0.050000000000000544, 1.4844360565207064, 0.5...
# 5   [0.05, 1.4844185490380037, 0.49999999890595903...
# 7   [0.050000000000000044, 1.484393560223859, 0.49...
#
#                                         final_simplex
# 2   ([[1.1157747334900527, 0.7825302253042986, 0.5...
# 3   ([[1.1157801239951561, 0.7825230722079007, 0.5...
# 23  ([[1.11578121926315, 0.7825133449851435, 0.5, ...
# 21  ([[1.1157454784667986, 0.7825820909575728, 0.4...
# 17  ([[1.1157329157595581, 0.782572847529099, 0.5,...
# 8   ([[1.1157898837755906, 0.7825535778421688, 0.5...
# 9   ([[1.1158000678228974, 0.782449143434748, 0.5,...
# 29  ([[1.115811204942443, 0.7824269933379742, 0.5,...
# 26  ([[1.115795052253736, 0.7824427408927865, 0.5,...
# 12  ([[1.115762634796738, 0.7825817048341235, 0.5,...
# 14  ([[1.1157635245683553, 0.7825462135732798, 0.5...
# 1   ([[1.1158069519526501, 0.7824831478077756, 0.4...
# 4   ([[1.1157434581111012, 0.7826194435690277, 0.4...
# 16  ([[1.115705903700335, 0.7817868092529949, 0.5,...
# 11  ([[0.43692271545699374, 1.4486841302256357, 0....
# 27  ([[0.43676039270698486, 1.4488283746640727, 0....
# 28  ([[0.4367094086160457, 1.4488139400920184, 0.5...
# 15  ([[0.436889655195765, 1.448747641142337, 0.5, ...
# 6   ([[0.43671368165699936, 1.4487660761590213, 0....
# 19  ([[0.43688629871779033, 1.448689994839735, 0.5...
# 18  ([[0.4368135478515086, 1.448748076854482, 0.49...
# 20  ([[0.4366517011783316, 1.4487680880075735, 0.5...
# 10  ([[0.4367737500389921, 1.448814497260641, 0.49...
# 0   ([[0.4366635799422993, 1.4488815143873484, 0.4...
# 22  ([[0.4366673090808465, 1.4487176048084855, 0.4...
# 13  ([[0.43668965757579586, 1.4495042943551728, 0....
# 25  ([[1.1231623948361857, 0.7588907842515304, 0.4...
# 24  ([[0.050000000000000544, 1.4844360565207064, 0...
# 5   ([[0.05, 1.4844185490380037, 0.499999998905959...
# 7   ([[0.050000000000000044, 1.484393560223859, 0....

# %% [markdown]
# #  DE fit

# %%
_c = next(read_from_pickle(f"ff/{ffpkl}"))

# %%
fit_repeat(_c, 
           30, 
           "test",
           bounds = DE_bound,
           loss="jax_de",
           quiet='true'
          )
# Out:
# /home/boittier/Documents/phd/ff_energy/ff_energy/ffe/ff_fit.py:174: OptimizeWarning: Unknown solver options: pgtol
#   res = minimize(

# %%
pd.DataFrame(_c.opt_results).sort_values("fun")
# Out:
#           fun   nit  nfev  status  success  \
# 17  73.633438   438   762       0     True
# 12  73.692329   845  1399       0     True
# 28  73.830345   535   896       0     True
# 3   73.886383  1001  1583       0     True
# 21  73.984985   567   956       0     True
# 19  74.498116   702  1174       0     True
# 2   74.501579   314   587       0     True
# 4   74.521393   325   590       0     True
# 24  74.527283  1037  1651       0     True
# 22  74.759956   309   561       0     True
# 0   74.760025   305   545       0     True
# 27  74.806755   523   913       0     True
# 8   74.817780   368   660       0     True
# 14  74.952003   260   482       0     True
# 25  74.978706   242   466       0     True
# 7   75.394669   408   752       0     True
# 29  75.457527   398   708       0     True
# 13  75.534866   736  1214       0     True
# 26  75.714737   208   412       0     True
# 11  75.720848   728  1231       0     True
# 1   75.797569   457   828       0     True
# 16  75.808098   393   685       0     True
# 5   75.866425   324   560       0     True
# 10  76.437103   429   761       0     True
# 18  76.669342   477   827       0     True
# 20  77.031456   437   777       0     True
# 15  77.464546   598  1027       0     True
# 6   80.223679   415   722       0     True
# 9   80.257538   384   657       0     True
# 23  88.374077   616  1063       0     True
#
#                                   message  \
# 17  Optimization terminated successfully.
# 12  Optimization terminated successfully.
# 28  Optimization terminated successfully.
# 3   Optimization terminated successfully.
# 21  Optimization terminated successfully.
# 19  Optimization terminated successfully.
# 2   Optimization terminated successfully.
# 4   Optimization terminated successfully.
# 24  Optimization terminated successfully.
# 22  Optimization terminated successfully.
# 0   Optimization terminated successfully.
# 27  Optimization terminated successfully.
# 8   Optimization terminated successfully.
# 14  Optimization terminated successfully.
# 25  Optimization terminated successfully.
# 7   Optimization terminated successfully.
# 29  Optimization terminated successfully.
# 13  Optimization terminated successfully.
# 26  Optimization terminated successfully.
# 11  Optimization terminated successfully.
# 1   Optimization terminated successfully.
# 16  Optimization terminated successfully.
# 5   Optimization terminated successfully.
# 10  Optimization terminated successfully.
# 18  Optimization terminated successfully.
# 20  Optimization terminated successfully.
# 15  Optimization terminated successfully.
# 6   Optimization terminated successfully.
# 9   Optimization terminated successfully.
# 23  Optimization terminated successfully.
#
#                                                     x  \
# 17  [0.405863376916751, 1.431458326674505, 0.49999...
# 12  [0.3948319327729677, 1.4353252252145532, 0.499...
# 28  [1.1524616819736528, 0.696113473518833, 0.3375...
# 3   [1.1535178862728048, 0.694543968842786, 0.3402...
# 21  [1.1674930989948284, 0.563565515803442, 0.3491...
# 19  [0.26820801271588657, 1.408546977377879, 0.499...
# 2   [0.2655189382306413, 1.4115454719824378, 0.5, ...
# 4   [1.1858112374157819, 0.7325809103422686, 0.191...
# 24  [0.26881356033553094, 1.3632520842679696, 0.49...
# 22  [0.5907334096253238, 1.3009301241191664, 0.319...
# 0   [0.39347662983907794, 1.3715845771833846, 0.35...
# 27  [0.3473961324463603, 1.1688094122661061, 0.499...
# 8   [0.1992009812711384, 1.4691118337618918, 0.387...
# 14  [1.1186074712464587, 0.75304707209844, 0.20044...
# 25  [0.05, 1.474249564949877, 0.5, 0.5, 1.39229794...
# 7   [0.3802668193965727, 0.9434569548817593, 0.498...
# 29  [0.36293912861151034, 0.9911844622362125, 0.5,...
# 13  [0.37498703243347065, 0.9827539415252085, 0.42...
# 26  [1.175112724411761, 0.6041825921442586, 0.5, 0...
# 11  [1.2518360703714175, 0.4053554404734825, 0.397...
# 1   [1.224516241114308, 0.4266477726744775, 0.4251...
# 16  [1.2409281884807095, 0.33397666564820505, 0.43...
# 5   [0.05, 1.1710989005951196, 0.5, 0.499958209735...
# 10  [0.523985359568017, 1.006656579071342, 0.17462...
# 18  [1.2261289358491063, 0.4210208663576349, 0.430...
# 20  [1.3205904965758202, 0.7162207440641232, 0.129...
# 15  [0.6363029448791265, 1.3184520417573475, 0.499...
# 6   [1.0201993752774574, 2.4998398251856147, 0.5, ...
# 9   [1.0875639705733016, 0.33323817551437673, 0.28...
# 23  [2.5, 1.304486766054291, 0.003655396964065259,...
#
#                                         final_simplex
# 17  ([[0.405863376916751, 1.431458326674505, 0.499...
# 12  ([[0.3948319327729677, 1.4353252252145532, 0.4...
# 28  ([[1.1524616819736528, 0.696113473518833, 0.33...
# 3   ([[1.1535178862728048, 0.694543968842786, 0.34...
# 21  ([[1.1674930989948284, 0.563565515803442, 0.34...
# 19  ([[0.26820801271588657, 1.408546977377879, 0.4...
# 2   ([[0.2655189382306413, 1.4115454719824378, 0.5...
# 4   ([[1.1858112374157819, 0.7325809103422686, 0.1...
# 24  ([[0.26881356033553094, 1.3632520842679696, 0....
# 22  ([[0.5907334096253238, 1.3009301241191664, 0.3...
# 0   ([[0.39347662983907794, 1.3715845771833846, 0....
# 27  ([[0.3473961324463603, 1.1688094122661061, 0.4...
# 8   ([[0.1992009812711384, 1.4691118337618918, 0.3...
# 14  ([[1.1186074712464587, 0.75304707209844, 0.200...
# 25  ([[0.05, 1.474249564949877, 0.5, 0.5, 1.392297...
# 7   ([[0.3802668193965727, 0.9434569548817593, 0.4...
# 29  ([[0.36293912861151034, 0.9911844622362125, 0....
# 13  ([[0.37498703243347065, 0.9827539415252085, 0....
# 26  ([[1.175112724411761, 0.6041825921442586, 0.5,...
# 11  ([[1.2518360703714175, 0.4053554404734825, 0.3...
# 1   ([[1.224516241114308, 0.4266477726744775, 0.42...
# 16  ([[1.2409281884807095, 0.33397666564820505, 0....
# 5   ([[0.05, 1.1710989005951196, 0.5, 0.4999582097...
# 10  ([[0.523985359568017, 1.006656579071342, 0.174...
# 18  ([[1.2261289358491063, 0.4210208663576349, 0.4...
# 20  ([[1.3205904965758202, 0.7162207440641232, 0.1...
# 15  ([[0.6363029448791265, 1.3184520417573475, 0.4...
# 6   ([[1.0201993752774574, 2.4998398251856147, 0.5...
# 9   ([[1.0875639705733016, 0.33323817551437673, 0....
# 23  ([[2.5, 1.304486766054291, 0.00365539696406525...
