# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from ff_energy.ffe.utils import read_from_pickle
import jax.numpy as jnp
from ff_energy.ffe.plot import plot_energy_MSE, plot_ff_fit
from ff_energy.ffe.structure import atom_key_pairs
from ff_energy.ffe.potential import LJ, akp_indx
from ff_energy.ffe.ff import FF
from ff_energy.ffe.ff_fit import LJ_bound, load_ff, fit_func, fit_repeat
from ff_energy.ffe.data import pairs_data
from ff_energy.ffe.utils import pickle_output, read_from_pickle, str2int

# %%
sig_bound = (0.05, 2.5)
ep_bound = (0.001, 0.5)
LJ_bound = ((sig_bound), (sig_bound), (ep_bound), (ep_bound))
DE_bound = ((sig_bound), (sig_bound), (ep_bound), (ep_bound), 
            (1, 8), (6, 20))

# %%
#  example
# ffpkl = "ECOL_pbe0dz_FOE.ff.pkl"

# %%
# Parameters
ffpkl = "DUMMY_pbe0dz_clusters.ff.pkl"

# %% [markdown]
# #  LJ fit

# %%
_c = next(read_from_pickle(f"ff/{ffpkl}"))
_c
# Out:
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# FF: LJ water_cluster DUMMY Exact intE (jax_coloumb: False)

# %%
# _c.targets

# %%
fit_repeat(_c, 
           30, 
           f"{ffpkl}_LJ",
           bounds = LJ_bound,
           loss="jax",
           # quiet='true'
          )
# Out:
# /home/boittier/Documents/phd/ff_energy/ff_energy/ffe/ff_fit.py:174: OptimizeWarning: Unknown solver options: pgtol
#   res = minimize(
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [2.147023858208276, 0.49500116955008217, 0.13782012379233424, 0.4453802905065376]
# final_loss_fn:  320.2102966308594
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 320.2102966308594
#              x: [ 5.000e-02  5.000e-02  5.000e-01  2.697e-01]
#            nit: 61
#           nfev: 174
#  final_simplex: (array([[ 5.000e-02,  5.000e-02,  5.000e-01,  2.697e-01],
#                        [ 5.000e-02,  5.000e-02,  5.000e-01,  2.697e-01],
#                        ...,
#                        [ 5.000e-02,  5.000e-02,  5.000e-01,  2.697e-01],
#                        [ 5.000e-02,  5.000e-02,  5.000e-01,  2.697e-01]]), array([ 3.202e+02,  3.202e+02,  3.202e+02,  3.202e+02,
#                         3.202e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [2.4709026940329197, 1.243286129115748, 0.13224989255814823, 0.21958768498255082]
# final_loss_fn:  320.2102966308594
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 320.2102966308594
#              x: [ 5.000e-02  5.000e-02  5.000e-01  5.000e-01]
#            nit: 71
#           nfev: 180
#  final_simplex: (array([[ 5.000e-02,  5.000e-02,  5.000e-01,  5.000e-01],
#                        [ 5.000e-02,  5.000e-02,  5.000e-01,  5.000e-01],
#                        ...,
#                        [ 5.000e-02,  5.000e-02,  5.000e-01,  5.000e-01],
#                        [ 5.000e-02,  5.000e-02,  5.000e-01,  5.000e-01]]), array([ 3.202e+02,  3.202e+02,  3.202e+02,  3.202e+02,
#                         3.202e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [2.2523386998776207, 1.8719900460162926, 0.06829345940972564, 0.25574859291345053]
# final_loss_fn:  307.9480285644531
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 307.9480285644531
#              x: [ 1.093e-01  2.127e+00  5.000e-01  1.000e-03]
#            nit: 215
#           nfev: 396
#  final_simplex: (array([[ 1.093e-01,  2.127e+00,  5.000e-01,  1.000e-03],
#                        [ 1.093e-01,  2.127e+00,  5.000e-01,  1.000e-03],
#                        ...,
#                        [ 1.093e-01,  2.127e+00,  5.000e-01,  1.000e-03],
#                        [ 1.093e-01,  2.127e+00,  5.000e-01,  1.000e-03]]), array([ 3.079e+02,  3.079e+02,  3.079e+02,  3.079e+02,
#                         3.079e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.6680108819790123, 0.2850465805136235, 0.36907806949728544, 0.46300944076637196]
# final_loss_fn:  320.2102966308594
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 320.2102966308594
#              x: [ 5.000e-02  5.000e-02  4.133e-01  4.977e-01]
#            nit: 42
#           nfev: 140
#  final_simplex: (array([[ 5.000e-02,  5.000e-02,  4.133e-01,  4.977e-01],
#                        [ 5.000e-02,  5.000e-02,  4.133e-01,  4.977e-01],
#                        ...,
#                        [ 5.000e-02,  5.000e-02,  4.133e-01,  4.977e-01],
#                        [ 5.000e-02,  5.000e-02,  4.133e-01,  4.977e-01]]), array([ 3.202e+02,  3.202e+02,  3.202e+02,  3.202e+02,
#                         3.202e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.07504104229152392, 2.358884215587445, 0.3477122277174328, 0.18029454086329194]
# final_loss_fn:  307.3108215332031
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 307.3108215332031
#              x: [ 5.000e-02  2.200e+00  1.000e-03  1.000e-03]
#            nit: 254
#           nfev: 465
#  final_simplex: (array([[ 5.000e-02,  2.200e+00,  1.000e-03,  1.000e-03],
#                        [ 5.000e-02,  2.200e+00,  1.000e-03,  1.000e-03],
#                        ...,
#                        [ 5.000e-02,  2.200e+00,  1.000e-03,  1.000e-03],
#                        [ 5.000e-02,  2.200e+00,  1.000e-03,  1.000e-03]]), array([ 3.073e+02,  3.073e+02,  3.073e+02,  3.073e+02,
#                         3.073e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.5691550629073062, 0.670503520840464, 0.35321438893156626, 0.04556320389484951]
# final_loss_fn:  320.21026611328125
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 320.21026611328125
#              x: [ 5.000e-02  5.000e-02  5.000e-01  1.180e-01]
#            nit: 57
#           nfev: 153
#  final_simplex: (array([[ 5.000e-02,  5.000e-02,  5.000e-01,  1.180e-01],
#                        [ 5.000e-02,  5.000e-02,  5.000e-01,  1.180e-01],
#                        ...,
#                        [ 5.000e-02,  5.000e-02,  5.000e-01,  1.180e-01],
#                        [ 5.000e-02,  5.000e-02,  5.000e-01,  1.180e-01]]), array([ 3.202e+02,  3.202e+02,  3.202e+02,  3.202e+02,
#                         3.202e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.22791362673778565, 0.4335961668980742, 0.45231527740705113, 0.32784356569267753]
# final_loss_fn:  320.2102966308594
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 320.2102966308594
#              x: [ 5.000e-02  5.000e-02  5.000e-01  5.000e-01]
#            nit: 50
#           nfev: 148
#  final_simplex: (array([[ 5.000e-02,  5.000e-02,  5.000e-01,  5.000e-01],
#                        [ 5.000e-02,  5.000e-02,  5.000e-01,  5.000e-01],
#                        ...,
#                        [ 5.000e-02,  5.000e-02,  5.000e-01,  5.000e-01],
#                        [ 5.000e-02,  5.000e-02,  5.000e-01,  5.000e-01]]), array([ 3.202e+02,  3.202e+02,  3.202e+02,  3.202e+02,
#                         3.202e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.6786819616445146, 1.518849803983034, 0.33396459778361787, 0.283714676804502]
# final_loss_fn:  307.3107604980469
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 307.3107604980469
#              x: [ 5.111e-02  2.199e+00  1.000e-03  1.000e-03]
#            nit: 206
#           nfev: 391
#  final_simplex: (array([[ 5.111e-02,  2.199e+00,  1.000e-03,  1.000e-03],
#                        [ 5.111e-02,  2.199e+00,  1.000e-03,  1.000e-03],
#                        ...,
#                        [ 5.111e-02,  2.199e+00,  1.000e-03,  1.000e-03],
#                        [ 5.111e-02,  2.199e+00,  1.000e-03,  1.000e-03]]), array([ 3.073e+02,  3.073e+02,  3.073e+02,  3.073e+02,
#                         3.073e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [2.2742314806503354, 2.454236732151959, 0.44193703556739355, 0.06339089480639175]
# final_loss_fn:  320.2102966308594
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 320.2102966308594
#              x: [ 5.000e-02  5.000e-02  5.000e-01  2.201e-01]
#            nit: 48
#           nfev: 153
#  final_simplex: (array([[ 5.000e-02,  5.000e-02,  5.000e-01,  2.201e-01],
#                        [ 5.000e-02,  5.000e-02,  5.000e-01,  2.201e-01],
#                        ...,
#                        [ 5.000e-02,  5.000e-02,  5.000e-01,  2.201e-01],
#                        [ 5.000e-02,  5.000e-02,  5.000e-01,  2.201e-01]]), array([ 3.202e+02,  3.202e+02,  3.202e+02,  3.202e+02,
#                         3.202e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.6463453314955983, 0.7934500349530865, 0.15035990938818677, 0.49969674153685595]
# final_loss_fn:  320.2102966308594
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 320.2102966308594
#              x: [ 5.000e-02  5.000e-02  3.634e-01  4.996e-01]
#            nit: 36
#           nfev: 135
#  final_simplex: (array([[ 5.000e-02,  5.000e-02,  3.634e-01,  4.996e-01],
#                        [ 5.000e-02,  5.000e-02,  3.634e-01,  4.996e-01],
#                        ...,
#                        [ 5.000e-02,  5.000e-02,  3.634e-01,  4.996e-01],
#                        [ 5.000e-02,  5.000e-02,  3.634e-01,  4.996e-01]]), array([ 3.202e+02,  3.202e+02,  3.202e+02,  3.202e+02,
#                         3.202e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.8340961282683746, 0.835756939800649, 0.27218455244630585, 0.3589941781895643]
# final_loss_fn:  320.2102966308594
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 320.2102966308594
#              x: [ 5.000e-02  5.000e-02  3.197e-01  5.000e-01]
#            nit: 40
#           nfev: 132
#  final_simplex: (array([[ 5.000e-02,  5.000e-02,  3.197e-01,  5.000e-01],
#                        [ 5.000e-02,  5.000e-02,  3.197e-01,  5.000e-01],
#                        ...,
#                        [ 5.000e-02,  5.000e-02,  3.197e-01,  5.000e-01],
#                        [ 5.000e-02,  5.000e-02,  3.197e-01,  5.000e-01]]), array([ 3.202e+02,  3.202e+02,  3.202e+02,  3.202e+02,
#                         3.202e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.515929951364893, 1.533236783472835, 0.17742696521599025, 0.08462143459980223]
# final_loss_fn:  307.3108215332031
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 307.3108215332031
#              x: [ 5.000e-02  2.200e+00  1.000e-03  1.000e-03]
#            nit: 369
#           nfev: 648
#  final_simplex: (array([[ 5.000e-02,  2.200e+00,  1.000e-03,  1.000e-03],
#                        [ 5.000e-02,  2.200e+00,  1.000e-03,  1.000e-03],
#                        ...,
#                        [ 5.000e-02,  2.200e+00,  1.000e-03,  1.000e-03],
#                        [ 5.000e-02,  2.200e+00,  1.000e-03,  1.000e-03]]), array([ 3.073e+02,  3.073e+02,  3.073e+02,  3.073e+02,
#                         3.073e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.7939443296379227, 1.5701189463614575, 0.4733912658921477, 0.03964954022627763]
# final_loss_fn:  307.8473815917969
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 307.8473815917969
#              x: [ 5.000e-02  2.155e+00  4.941e-01  1.000e-03]
#            nit: 164
#           nfev: 317
#  final_simplex: (array([[ 5.000e-02,  2.155e+00,  4.941e-01,  1.000e-03],
#                        [ 5.000e-02,  2.155e+00,  4.941e-01,  1.000e-03],
#                        ...,
#                        [ 5.000e-02,  2.155e+00,  4.941e-01,  1.000e-03],
#                        [ 5.000e-02,  2.155e+00,  4.941e-01,  1.000e-03]]), array([ 3.078e+02,  3.078e+02,  3.078e+02,  3.078e+02,
#                         3.078e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.8511158094076918, 0.4561775436136772, 0.3152230237542323, 0.3886926554361333]
# final_loss_fn:  320.21026611328125
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 320.21026611328125
#              x: [ 5.000e-02  5.207e-02  3.530e-01  2.256e-01]
#            nit: 44
#           nfev: 143
#  final_simplex: (array([[ 5.000e-02,  5.207e-02,  3.530e-01,  2.256e-01],
#                        [ 5.000e-02,  5.207e-02,  3.530e-01,  2.256e-01],
#                        ...,
#                        [ 5.000e-02,  5.207e-02,  3.530e-01,  2.256e-01],
#                        [ 5.000e-02,  5.207e-02,  3.530e-01,  2.256e-01]]), array([ 3.202e+02,  3.202e+02,  3.202e+02,  3.202e+02,
#                         3.202e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.9815547135190923, 1.0239086824048882, 0.0830800059597412, 0.10129831046387007]
# final_loss_fn:  307.31170654296875
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 307.31170654296875
#              x: [ 5.000e-02  2.199e+00  1.143e-03  1.000e-03]
#            nit: 216
#           nfev: 423
#  final_simplex: (array([[ 5.000e-02,  2.199e+00,  1.143e-03,  1.000e-03],
#                        [ 5.000e-02,  2.199e+00,  1.143e-03,  1.000e-03],
#                        ...,
#                        [ 5.000e-02,  2.199e+00,  1.143e-03,  1.000e-03],
#                        [ 5.000e-02,  2.199e+00,  1.143e-03,  1.000e-03]]), array([ 3.073e+02,  3.073e+02,  3.073e+02,  3.073e+02,
#                         3.073e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.3207550432888708, 0.9031496310806334, 0.12739053699929334, 0.47936985593084097]
# final_loss_fn:  299.7438049316406
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 299.7438049316406
#              x: [ 1.672e+00  5.892e-01  1.000e-03  1.000e-03]
#            nit: 165
#           nfev: 329
#  final_simplex: (array([[ 1.672e+00,  5.892e-01,  1.000e-03,  1.000e-03],
#                        [ 1.672e+00,  5.892e-01,  1.000e-03,  1.000e-03],
#                        ...,
#                        [ 1.672e+00,  5.892e-01,  1.000e-03,  1.000e-03],
#                        [ 1.672e+00,  5.892e-01,  1.000e-03,  1.000e-03]]), array([ 2.997e+02,  2.997e+02,  2.997e+02,  2.997e+02,
#                         2.997e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.4299234354980863, 1.4592732763042313, 0.4573468482842301, 0.24907656015872157]
# final_loss_fn:  307.851806640625
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 307.851806640625
#              x: [ 5.000e-02  2.155e+00  5.000e-01  1.000e-03]
#            nit: 124
#           nfev: 255
#  final_simplex: (array([[ 5.000e-02,  2.155e+00,  5.000e-01,  1.000e-03],
#                        [ 5.000e-02,  2.155e+00,  5.000e-01,  1.000e-03],
#                        ...,
#                        [ 5.000e-02,  2.155e+00,  5.000e-01,  1.000e-03],
#                        [ 5.000e-02,  2.155e+00,  5.000e-01,  1.000e-03]]), array([ 3.079e+02,  3.079e+02,  3.079e+02,  3.079e+02,
#                         3.079e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.9901424088323578, 0.5881900590030961, 0.2238366206865109, 0.22109431892380454]
# final_loss_fn:  320.2102966308594
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 320.2102966308594
#              x: [ 5.000e-02  5.000e-02  3.881e-01  3.480e-01]
#            nit: 54
#           nfev: 161
#  final_simplex: (array([[ 5.000e-02,  5.000e-02,  3.881e-01,  3.480e-01],
#                        [ 5.000e-02,  5.000e-02,  3.881e-01,  3.480e-01],
#                        ...,
#                        [ 5.000e-02,  5.000e-02,  3.881e-01,  3.480e-01],
#                        [ 5.000e-02,  5.000e-02,  3.881e-01,  3.480e-01]]), array([ 3.202e+02,  3.202e+02,  3.202e+02,  3.202e+02,
#                         3.202e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.3044466727704707, 2.0911533703212997, 0.002906426207552446, 0.33868657621689335]
# final_loss_fn:  299.6289367675781
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 299.6289367675781
#              x: [ 1.683e+00  5.000e-02  1.000e-03  4.150e-01]
#            nit: 142
#           nfev: 285
#  final_simplex: (array([[ 1.683e+00,  5.000e-02,  1.000e-03,  4.150e-01],
#                        [ 1.683e+00,  5.000e-02,  1.000e-03,  4.150e-01],
#                        ...,
#                        [ 1.683e+00,  5.000e-02,  1.000e-03,  4.150e-01],
#                        [ 1.683e+00,  5.000e-02,  1.000e-03,  4.150e-01]]), array([ 2.996e+02,  2.996e+02,  2.996e+02,  2.996e+02,
#                         2.996e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.8166447282615051, 1.3389862953806189, 0.29967990525535143, 0.39535277572434196]
# final_loss_fn:  307.8527526855469
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 307.8527526855469
#              x: [ 5.001e-02  2.155e+00  5.000e-01  1.002e-03]
#            nit: 143
#           nfev: 264
#  final_simplex: (array([[ 5.001e-02,  2.155e+00,  5.000e-01,  1.002e-03],
#                        [ 5.001e-02,  2.155e+00,  5.000e-01,  1.002e-03],
#                        ...,
#                        [ 5.001e-02,  2.155e+00,  5.000e-01,  1.002e-03],
#                        [ 5.001e-02,  2.155e+00,  5.000e-01,  1.002e-03]]), array([ 3.079e+02,  3.079e+02,  3.079e+02,  3.079e+02,
#                         3.079e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.8672606895056969, 0.8672761031675887, 0.32578030748285886, 0.08997687453045945]
# final_loss_fn:  320.21026611328125
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 320.21026611328125
#              x: [ 5.000e-02  7.631e-02  3.378e-01  1.795e-02]
#            nit: 47
#           nfev: 153
#  final_simplex: (array([[ 5.000e-02,  7.631e-02,  3.378e-01,  1.795e-02],
#                        [ 5.000e-02,  7.631e-02,  3.378e-01,  1.795e-02],
#                        ...,
#                        [ 5.000e-02,  7.631e-02,  3.378e-01,  1.795e-02],
#                        [ 5.000e-02,  7.631e-02,  3.378e-01,  1.795e-02]]), array([ 3.202e+02,  3.202e+02,  3.202e+02,  3.202e+02,
#                         3.202e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [2.398231862930261, 0.44084610700272014, 0.08036253093898589, 0.23423170548267513]
# final_loss_fn:  320.21026611328125
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 320.21026611328125
#              x: [ 5.708e-02  6.789e-02  1.170e-01  5.610e-02]
#            nit: 54
#           nfev: 159
#  final_simplex: (array([[ 5.708e-02,  6.789e-02,  1.170e-01,  5.610e-02],
#                        [ 5.708e-02,  6.789e-02,  1.170e-01,  5.610e-02],
#                        ...,
#                        [ 5.708e-02,  6.789e-02,  1.170e-01,  5.610e-02],
#                        [ 5.708e-02,  6.789e-02,  1.170e-01,  5.610e-02]]), array([ 3.202e+02,  3.202e+02,  3.202e+02,  3.202e+02,
#                         3.202e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.7412973893378356, 1.1351844410452492, 0.23367227465767706, 0.1160604966906852]
# final_loss_fn:  320.2102966308594
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 320.2102966308594
#              x: [ 5.000e-02  5.000e-02  4.683e-01  2.288e-01]
#            nit: 33
#           nfev: 127
#  final_simplex: (array([[ 5.000e-02,  5.000e-02,  4.683e-01,  2.288e-01],
#                        [ 5.000e-02,  5.000e-02,  4.683e-01,  2.288e-01],
#                        ...,
#                        [ 5.000e-02,  5.000e-02,  4.683e-01,  2.288e-01],
#                        [ 5.000e-02,  5.000e-02,  4.683e-01,  2.288e-01]]), array([ 3.202e+02,  3.202e+02,  3.202e+02,  3.202e+02,
#                         3.202e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.9622522804123131, 1.0078581869899217, 0.2661516411264671, 0.43823775749589555]
# final_loss_fn:  307.2744445800781
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 307.2744445800781
#              x: [ 5.170e-01  2.143e+00  1.000e-03  1.000e-03]
#            nit: 213
#           nfev: 403
#  final_simplex: (array([[ 5.170e-01,  2.143e+00,  1.000e-03,  1.000e-03],
#                        [ 5.170e-01,  2.143e+00,  1.000e-03,  1.000e-03],
#                        ...,
#                        [ 5.170e-01,  2.143e+00,  1.000e-03,  1.000e-03],
#                        [ 5.170e-01,  2.143e+00,  1.000e-03,  1.000e-03]]), array([ 3.073e+02,  3.073e+02,  3.073e+02,  3.073e+02,
#                         3.073e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.0595726353718429, 1.5555936653069864, 0.14934467911650495, 0.24583772031052248]
# final_loss_fn:  299.6288757324219
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 299.6288757324219
#              x: [ 1.683e+00  5.072e-02  1.013e-03  4.936e-01]
#            nit: 230
#           nfev: 432
#  final_simplex: (array([[ 1.683e+00,  5.072e-02,  1.013e-03,  4.936e-01],
#                        [ 1.683e+00,  5.072e-02,  1.013e-03,  4.936e-01],
#                        ...,
#                        [ 1.683e+00,  5.071e-02,  1.013e-03,  4.936e-01],
#                        [ 1.683e+00,  5.072e-02,  1.013e-03,  4.936e-01]]), array([ 2.996e+02,  2.996e+02,  2.996e+02,  2.996e+02,
#                         2.996e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.7332212561610728, 0.8222383038420585, 0.08975160209112894, 0.38525217036186615]
# final_loss_fn:  320.21026611328125
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 320.21026611328125
#              x: [ 5.000e-02  5.000e-02  1.720e-01  5.000e-01]
#            nit: 35
#           nfev: 130
#  final_simplex: (array([[ 5.000e-02,  5.000e-02,  1.720e-01,  5.000e-01],
#                        [ 5.000e-02,  5.000e-02,  1.720e-01,  5.000e-01],
#                        ...,
#                        [ 5.000e-02,  5.000e-02,  1.720e-01,  5.000e-01],
#                        [ 5.000e-02,  5.000e-02,  1.720e-01,  5.000e-01]]), array([ 3.202e+02,  3.202e+02,  3.202e+02,  3.202e+02,
#                         3.202e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.3759451872106521, 1.773189865705286, 0.37287438261404204, 0.19191534530001852]
# final_loss_fn:  307.8426513671875
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 307.8426513671875
#              x: [ 5.000e-02  2.155e+00  4.878e-01  1.000e-03]
#            nit: 178
#           nfev: 350
#  final_simplex: (array([[ 5.000e-02,  2.155e+00,  4.878e-01,  1.000e-03],
#                        [ 5.000e-02,  2.155e+00,  4.878e-01,  1.000e-03],
#                        ...,
#                        [ 5.000e-02,  2.155e+00,  4.878e-01,  1.000e-03],
#                        [ 5.000e-02,  2.155e+00,  4.878e-01,  1.000e-03]]), array([ 3.078e+02,  3.078e+02,  3.078e+02,  3.078e+02,
#                         3.078e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [2.0268484612311486, 2.3088410744618444, 0.024768015643998387, 0.3527785200136966]
# final_loss_fn:  299.6265869140625
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 299.6265869140625
#              x: [ 1.684e+00  5.000e-02  1.000e-03  4.999e-01]
#            nit: 188
#           nfev: 368
#  final_simplex: (array([[ 1.684e+00,  5.000e-02,  1.000e-03,  4.999e-01],
#                        [ 1.684e+00,  5.000e-02,  1.000e-03,  4.999e-01],
#                        ...,
#                        [ 1.684e+00,  5.000e-02,  1.000e-03,  4.999e-01],
#                        [ 1.684e+00,  5.000e-02,  1.000e-03,  4.999e-01]]), array([ 2.996e+02,  2.996e+02,  2.996e+02,  2.996e+02,
#                         2.996e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.8606693015865308, 2.378531586116874, 0.3878780910765464, 0.02319203086118522]
# final_loss_fn:  307.8518981933594
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 307.8518981933594
#              x: [ 5.008e-02  2.155e+00  5.000e-01  1.000e-03]
#            nit: 253
#           nfev: 467
#  final_simplex: (array([[ 5.008e-02,  2.155e+00,  5.000e-01,  1.000e-03],
#                        [ 5.008e-02,  2.155e+00,  5.000e-01,  1.000e-03],
#                        ...,
#                        [ 5.008e-02,  2.155e+00,  5.000e-01,  1.000e-03],
#                        [ 5.008e-02,  2.155e+00,  5.000e-01,  1.000e-03]]), array([ 3.079e+02,  3.079e+02,  3.079e+02,  3.079e+02,
#                         3.079e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.5440376254140861, 1.614791093511215, 0.07870148067255416, 0.27142828735597596]
# final_loss_fn:  307.7116394042969
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 307.7116394042969
#              x: [ 8.642e-02  2.150e+00  2.804e-01  1.000e-03]
#            nit: 181
#           nfev: 359
#  final_simplex: (array([[ 8.642e-02,  2.150e+00,  2.804e-01,  1.000e-03],
#                        [ 8.642e-02,  2.150e+00,  2.804e-01,  1.000e-03],
#                        ...,
#                        [ 8.642e-02,  2.150e+00,  2.804e-01,  1.000e-03],
#                        [ 8.642e-02,  2.150e+00,  2.804e-01,  1.000e-03]]), array([ 3.077e+02,  3.077e+02,  3.077e+02,  3.077e+02,
#                         3.077e+02]))

# %%
pd.DataFrame(_c.opt_results).sort_values("fun")
# Out:
#            fun  nit  nfev  status  success  \
# 27  299.626587  188   368       0     True
# 24  299.628876  230   432       0     True
# 18  299.628937  142   285       0     True
# 15  299.743805  165   329       0     True
# 23  307.274445  213   403       0     True
# 7   307.310760  206   391       0     True
# 4   307.310822  254   465       0     True
# 11  307.310822  369   648       0     True
# 14  307.311707  216   423       0     True
# 29  307.711639  181   359       0     True
# 26  307.842651  178   350       0     True
# 12  307.847382  164   317       0     True
# 16  307.851807  124   255       0     True
# 28  307.851898  253   467       0     True
# 19  307.852753  143   264       0     True
# 2   307.948029  215   396       0     True
# 13  320.210266   44   143       0     True
# 25  320.210266   35   130       0     True
# 5   320.210266   57   153       0     True
# 20  320.210266   47   153       0     True
# 21  320.210266   54   159       0     True
# 1   320.210297   71   180       0     True
# 3   320.210297   42   140       0     True
# 10  320.210297   40   132       0     True
# 9   320.210297   36   135       0     True
# 17  320.210297   54   161       0     True
# 6   320.210297   50   148       0     True
# 8   320.210297   48   153       0     True
# 22  320.210297   33   127       0     True
# 0   320.210297   61   174       0     True
#
#                                   message  \
# 27  Optimization terminated successfully.
# 24  Optimization terminated successfully.
# 18  Optimization terminated successfully.
# 15  Optimization terminated successfully.
# 23  Optimization terminated successfully.
# 7   Optimization terminated successfully.
# 4   Optimization terminated successfully.
# 11  Optimization terminated successfully.
# 14  Optimization terminated successfully.
# 29  Optimization terminated successfully.
# 26  Optimization terminated successfully.
# 12  Optimization terminated successfully.
# 16  Optimization terminated successfully.
# 28  Optimization terminated successfully.
# 19  Optimization terminated successfully.
# 2   Optimization terminated successfully.
# 13  Optimization terminated successfully.
# 25  Optimization terminated successfully.
# 5   Optimization terminated successfully.
# 20  Optimization terminated successfully.
# 21  Optimization terminated successfully.
# 1   Optimization terminated successfully.
# 3   Optimization terminated successfully.
# 10  Optimization terminated successfully.
# 9   Optimization terminated successfully.
# 17  Optimization terminated successfully.
# 6   Optimization terminated successfully.
# 8   Optimization terminated successfully.
# 22  Optimization terminated successfully.
# 0   Optimization terminated successfully.
#
#                                                     x  \
# 27  [1.6842606833142482, 0.05, 0.00100000317455543...
# 24  [1.6826487170492173, 0.050715087802965304, 0.0...
# 18  [1.6833831715599699, 0.05000000000000125, 0.00...
# 15  [1.672336437499292, 0.5891696694600612, 0.0010...
# 23  [0.5170357888088828, 2.142511570439397, 0.001,...
# 7   [0.05111457411419329, 2.199325057278557, 0.001...
# 4   [0.05000000000000021, 2.1995428386471563, 0.00...
# 11  [0.050000000000004485, 2.1995534537447754, 0.0...
# 14  [0.05, 2.1991485855546022, 0.00114301119332222...
# 29  [0.08642314506811134, 2.149584131062883, 0.280...
# 26  [0.05000000000000018, 2.1552851803724766, 0.48...
# 12  [0.05000000000000038, 2.155239315806808, 0.494...
# 16  [0.05000034693808864, 2.1548069754327024, 0.5,...
# 28  [0.05007775970240279, 2.1547973273956855, 0.5,...
# 19  [0.05000734754689232, 2.155241744022941, 0.5, ...
# 2   [0.10926720876320187, 2.1269783311105885, 0.5,...
# 13  [0.050000000000000044, 0.05207444671440187, 0....
# 25             [0.05, 0.05, 0.17199005130433684, 0.5]
# 5              [0.05, 0.05, 0.5, 0.11802561157114322]
# 20  [0.050000000000000065, 0.07631100124784065, 0....
# 21  [0.057081877626007374, 0.06788802799869989, 0....
# 1                              [0.05, 0.05, 0.5, 0.5]
# 3   [0.050000000000000044, 0.05, 0.413293879569035...
# 10  [0.050000000000000044, 0.05, 0.319653120070143...
# 9   [0.05, 0.05, 0.3633815378672335, 0.49963127831...
# 17  [0.05, 0.05, 0.3881129312026006, 0.34797435938...
# 6                              [0.05, 0.05, 0.5, 0.5]
# 8   [0.05000000000000021, 0.05, 0.5, 0.22006384552...
# 22  [0.05, 0.05, 0.46832953971737656, 0.2288480727...
# 0              [0.05, 0.05, 0.5, 0.26967611748893217]
#
#                                         final_simplex
# 27  ([[1.6842606833142482, 0.05, 0.001000003174555...
# 24  ([[1.6826487170492173, 0.050715087802965304, 0...
# 18  ([[1.6833831715599699, 0.05000000000000125, 0....
# 15  ([[1.672336437499292, 0.5891696694600612, 0.00...
# 23  ([[0.5170357888088828, 2.142511570439397, 0.00...
# 7   ([[0.05111457411419329, 2.199325057278557, 0.0...
# 4   ([[0.05000000000000021, 2.1995428386471563, 0....
# 11  ([[0.050000000000004485, 2.1995534537447754, 0...
# 14  ([[0.05, 2.1991485855546022, 0.001143011193322...
# 29  ([[0.08642314506811134, 2.149584131062883, 0.2...
# 26  ([[0.05000000000000018, 2.1552851803724766, 0....
# 12  ([[0.05000000000000038, 2.155239315806808, 0.4...
# 16  ([[0.05000034693808864, 2.1548069754327024, 0....
# 28  ([[0.05007775970240279, 2.1547973273956855, 0....
# 19  ([[0.05000734754689232, 2.155241744022941, 0.5...
# 2   ([[0.10926720876320187, 2.1269783311105885, 0....
# 13  ([[0.050000000000000044, 0.05207444671440187, ...
# 25  ([[0.05, 0.05, 0.17199005130433684, 0.5], [0.0...
# 5   ([[0.05, 0.05, 0.5, 0.11802561157114322], [0.0...
# 20  ([[0.050000000000000065, 0.07631100124784065, ...
# 21  ([[0.057081877626007374, 0.06788802799869989, ...
# 1   ([[0.05, 0.05, 0.5, 0.5], [0.05000012584267203...
# 3   ([[0.050000000000000044, 0.05, 0.4132938795690...
# 10  ([[0.050000000000000044, 0.05, 0.3196531200701...
# 9   ([[0.05, 0.05, 0.3633815378672335, 0.499631278...
# 17  ([[0.05, 0.05, 0.3881129312026006, 0.347974359...
# 6   ([[0.05, 0.05, 0.5, 0.5], [0.05000001552283945...
# 8   ([[0.05000000000000021, 0.05, 0.5, 0.220063845...
# 22  ([[0.05, 0.05, 0.46832953971737656, 0.22884807...
# 0   ([[0.05, 0.05, 0.5, 0.26967611748893217], [0.0...

# %% [markdown]
# #  DE fit

# %%
_c = next(read_from_pickle(f"ff/{ffpkl}"))

# %%
fit_repeat(_c, 
           30, 
           "test",
           bounds = DE_bound,
           loss="jax_de",
           quiet='true'
          )
# Out:
# /home/boittier/Documents/phd/ff_energy/ff_energy/ffe/ff_fit.py:174: OptimizeWarning: Unknown solver options: pgtol
#   res = minimize(

# %%
pd.DataFrame(_c.opt_results).sort_values("fun")
# Out:
#            fun  nit  nfev  status  success  \
# 15  298.996216  543   947       0     True
# 29  299.054321  486   820       0     True
# 27  299.128876  381   683       0     True
# 6   299.240692  463   827       0     True
# 12  299.250824  460   806       0     True
# 1   299.318817  381   684       0     True
# 2   299.325195  416   758       0     True
# 5   299.337067  542   953       0     True
# 13  299.340149  277   546       0     True
# 16  299.341461  457   840       0     True
# 11  299.359772  557   974       0     True
# 10  306.269135  360   646       0     True
# 14  306.501190  226   377       0     True
# 26  306.820526  507   914       0     True
# 28  306.821838  814  1324       0     True
# 25  306.827423  664  1119       0     True
# 17  306.828583  492   856       0     True
# 18  306.902405  637  1074       0     True
# 9   306.909210  391   704       0     True
# 8   306.933655  290   540       0     True
# 20  312.267700   75   112       0     True
# 24  320.210266   49   211       0     True
# 23  320.210266   51   202       0     True
# 21  320.210266   59   226       0     True
# 19  320.210266   66   233       0     True
# 4   320.210297   89   276       0     True
# 7   320.210297   49   200       0     True
# 3   320.210297   46   199       0     True
# 22  320.210297  120   323       0     True
# 0   320.210297  107   307       0     True
#
#                                   message  \
# 15  Optimization terminated successfully.
# 29  Optimization terminated successfully.
# 27  Optimization terminated successfully.
# 6   Optimization terminated successfully.
# 12  Optimization terminated successfully.
# 1   Optimization terminated successfully.
# 2   Optimization terminated successfully.
# 5   Optimization terminated successfully.
# 13  Optimization terminated successfully.
# 16  Optimization terminated successfully.
# 11  Optimization terminated successfully.
# 10  Optimization terminated successfully.
# 14  Optimization terminated successfully.
# 26  Optimization terminated successfully.
# 28  Optimization terminated successfully.
# 25  Optimization terminated successfully.
# 17  Optimization terminated successfully.
# 18  Optimization terminated successfully.
# 9   Optimization terminated successfully.
# 8   Optimization terminated successfully.
# 20  Optimization terminated successfully.
# 24  Optimization terminated successfully.
# 23  Optimization terminated successfully.
# 21  Optimization terminated successfully.
# 19  Optimization terminated successfully.
# 4   Optimization terminated successfully.
# 7   Optimization terminated successfully.
# 3   Optimization terminated successfully.
# 22  Optimization terminated successfully.
# 0   Optimization terminated successfully.
#
#                                                     x  \
# 15  [1.4138622664335485, 0.5097309074081215, 0.004...
# 29  [1.522291365193846, 0.3915310260047219, 0.001,...
# 27  [1.50546284421383, 0.23797628080503744, 0.0013...
# 6   [1.5067959741732668, 0.42812173886044047, 0.00...
# 12  [1.5425899489114026, 0.05022078330887091, 0.00...
# 1   [1.4666741425175982, 0.24750622394646382, 0.00...
# 2   [1.5095100895446496, 0.07919747731612564, 0.00...
# 5   [1.5053299482685583, 0.05, 0.001, 0.001, 7.592...
# 13  [1.5184134561247542, 0.05, 0.00100058718023704...
# 16  [1.4904139380245671, 0.5302053884617751, 0.001...
# 11  [1.478690037033782, 0.4158894218007038, 0.0019...
# 10  [0.05, 2.4999856887391614, 0.00100006511135809...
# 14  [0.050313252541567405, 2.5, 0.001, 0.004369708...
# 26  [0.05, 2.05940199833665, 0.4988641966844382, 0...
# 28  [0.05108888908079809, 2.060461355873942, 0.495...
# 25  [0.05, 2.054025035522878, 0.5, 0.0010836792250...
# 17  [0.0500604260317067, 2.070525021333842, 0.4343...
# 18  [0.6318919042244766, 1.6680220749332655, 0.028...
# 9   [0.0651540558465406, 2.058808030044932, 0.3612...
# 8   [0.5678342016727562, 1.6424920669795362, 0.188...
# 20                  [0.05, 2.5, 0.5, 0.001, 8.0, 6.0]
# 24  [0.20739614300588358, 0.3344796743699852, 0.49...
# 23  [0.051344984152081725, 0.14147622684433156, 0....
# 21  [0.05, 0.4511207286303518, 0.45673475713536404...
# 19  [0.05, 0.42522226590009493, 0.2307155834381990...
# 4   [0.1148473475598677, 0.34464307979877756, 0.03...
# 7   [0.05, 0.36696613710037074, 0.5, 0.09665533562...
# 3   [0.05, 0.23201590679618372, 0.1854953498961455...
# 22  [0.10308359734526595, 0.05, 0.001, 0.5, 4.0547...
# 0   [0.3299321343904682, 0.05, 0.001, 0.3072996536...
#
#                                         final_simplex
# 15  ([[1.4138622664335485, 0.5097309074081215, 0.0...
# 29  ([[1.522291365193846, 0.3915310260047219, 0.00...
# 27  ([[1.50546284421383, 0.23797628080503744, 0.00...
# 6   ([[1.5067959741732668, 0.42812173886044047, 0....
# 12  ([[1.5425899489114026, 0.05022078330887091, 0....
# 1   ([[1.4666741425175982, 0.24750622394646382, 0....
# 2   ([[1.5095100895446496, 0.07919747731612564, 0....
# 5   ([[1.5053299482685583, 0.05, 0.001, 0.001, 7.5...
# 13  ([[1.5184134561247542, 0.05, 0.001000587180237...
# 16  ([[1.4904139380245671, 0.5302053884617751, 0.0...
# 11  ([[1.478690037033782, 0.4158894218007038, 0.00...
# 10  ([[0.05, 2.4999856887391614, 0.001000065111358...
# 14  ([[0.050313252541567405, 2.5, 0.001, 0.0043697...
# 26  ([[0.05, 2.05940199833665, 0.4988641966844382,...
# 28  ([[0.05108888908079809, 2.060461355873942, 0.4...
# 25  ([[0.05, 2.054025035522878, 0.5, 0.00108367922...
# 17  ([[0.0500604260317067, 2.070525021333842, 0.43...
# 18  ([[0.6318919042244766, 1.6680220749332655, 0.0...
# 9   ([[0.0651540558465406, 2.058808030044932, 0.36...
# 8   ([[0.5678342016727562, 1.6424920669795362, 0.1...
# 20  ([[0.05, 2.5, 0.5, 0.001, 8.0, 6.0], [0.05, 2....
# 24  ([[0.20739614300588358, 0.3344796743699852, 0....
# 23  ([[0.051344984152081725, 0.14147622684433156, ...
# 21  ([[0.05, 0.4511207286303518, 0.456734757135364...
# 19  ([[0.05, 0.42522226590009493, 0.23071558343819...
# 4   ([[0.1148473475598677, 0.34464307979877756, 0....
# 7   ([[0.05, 0.36696613710037074, 0.5, 0.096655335...
# 3   ([[0.05, 0.23201590679618372, 0.18549534989614...
# 22  ([[0.10308359734526595, 0.05, 0.001, 0.5, 4.05...
# 0   ([[0.3299321343904682, 0.05, 0.001, 0.30729965...
