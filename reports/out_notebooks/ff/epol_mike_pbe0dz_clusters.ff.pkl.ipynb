# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from ff_energy.ffe.utils import read_from_pickle
import jax.numpy as jnp
from ff_energy.ffe.plot import plot_energy_MSE, plot_ff_fit
from ff_energy.ffe.structure import atom_key_pairs
from ff_energy.ffe.potential import LJ, akp_indx
from ff_energy.ffe.ff import FF
from ff_energy.ffe.ff_fit import LJ_bound, load_ff, fit_func, fit_repeat
from ff_energy.ffe.data import pairs_data
from ff_energy.ffe.utils import pickle_output, read_from_pickle, str2int

# %%
sig_bound = (0.001, 2.5)
ep_bound = (0.001, 2.5)
chg_bound = (100,2000)

CHGPEN_bound = [(chg_bound),(chg_bound),(chg_bound),(chg_bound),(0,2000)]
LJ_bound = ((sig_bound), (sig_bound), (ep_bound), (ep_bound))
DE_bound = ((sig_bound), (sig_bound), (ep_bound), (ep_bound), 
            (1, 8), (6, 20))

# %%
#  example
# ffpkl = "ECOL_pbe0dz_FOE.ff.pkl"

# %%
# Parameters
ffpkl = "epol_mike_pbe0dz_clusters.ff.pkl"

# %% [markdown]
# #  LJ fit

# %%
_c = next(read_from_pickle(f"ff/{ffpkl}"))
_c
# Out:
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# FF: LJ water_cluster epol_mike Exact intE (jax_coloumb: False)

# %%
# _c.targets

# %%
fit_repeat(_c, 
           30, 
           f"{ffpkl}_LJ",
           bounds = LJ_bound,
           loss="jax",
           quiet='true'
          )
# Out:
# /home/boittier/Documents/phd/ff_energy/ff_energy/ffe/ff_fit.py:175: OptimizeWarning: Unknown solver options: pgtol
#   res = minimize(

# %%
pd.DataFrame(_c.opt_results).sort_values("fun")
# Out:
#              fun  nit  nfev  status  success  \
# 5     324.426819  831  1438       0     True
# 7     324.426819  519   885       0     True
# 20    324.426880  782  1317       0     True
# 27    324.426941  460   783       0     True
# 12    324.427429  384   679       0     True
# 3     324.430206  924  1555       0     True
# 4     324.430237  671  1137       0     True
# 24    382.047913  346   642       0     True
# 19    391.597839  351   643       0     True
# 16    469.659027  308   559       0     True
# 6     470.446411  178   357       0     True
# 21    470.446472  406   733       0     True
# 15    470.446503  282   521       0     True
# 10    822.917419  479   826       0     True
# 11    828.238525  829  1407       0     True
# 0     836.322266  502   892       0     True
# 2     864.607300  773  1328       0     True
# 28    884.380798  500   892       0     True
# 25    970.351562  455   799       0     True
# 1    1114.145508  346   612       0     True
# 26   1158.072266  339   622       0     True
# 23  24113.593750   43   155       0     True
# 14  24113.593750   38   137       0     True
# 18  24113.593750   53   171       0     True
# 17  24113.593750   43   150       0     True
# 13  24113.593750   44   150       0     True
# 9   24113.593750   44   153       0     True
# 8   24113.593750   58   179       0     True
# 29  24113.593750   44   141       0     True
# 22  24113.607422   39   144       0     True
#
#                                   message  \
# 5   Optimization terminated successfully.
# 7   Optimization terminated successfully.
# 20  Optimization terminated successfully.
# 27  Optimization terminated successfully.
# 12  Optimization terminated successfully.
# 3   Optimization terminated successfully.
# 4   Optimization terminated successfully.
# 24  Optimization terminated successfully.
# 19  Optimization terminated successfully.
# 16  Optimization terminated successfully.
# 6   Optimization terminated successfully.
# 21  Optimization terminated successfully.
# 15  Optimization terminated successfully.
# 10  Optimization terminated successfully.
# 11  Optimization terminated successfully.
# 0   Optimization terminated successfully.
# 2   Optimization terminated successfully.
# 28  Optimization terminated successfully.
# 25  Optimization terminated successfully.
# 1   Optimization terminated successfully.
# 26  Optimization terminated successfully.
# 23  Optimization terminated successfully.
# 14  Optimization terminated successfully.
# 18  Optimization terminated successfully.
# 17  Optimization terminated successfully.
# 13  Optimization terminated successfully.
# 9   Optimization terminated successfully.
# 8   Optimization terminated successfully.
# 29  Optimization terminated successfully.
# 22  Optimization terminated successfully.
#
#                                                     x  \
# 5   [0.001, 2.499999977486486, 0.001, 0.0083587891...
# 7   [0.001, 2.499999632421222, 0.001, 0.0083583093...
# 20          [0.001, 2.5, 0.001, 0.008358201582395483]
# 27  [0.0010339825764228618, 2.5, 0.001, 0.00835840...
# 12  [0.0010947948428169302, 2.499995512406253, 0.0...
# 3   [0.001, 2.49997580104458, 0.001003053084652514...
# 4   [0.00102053260686, 2.4999408299667394, 0.001, ...
# 24  [0.0027093543545160526, 2.3952383559415713, 0....
# 19  [0.001, 2.4039093139247507, 0.659840069229841,...
# 16  [0.001, 2.2442644068767708, 2.477585748495625,...
# 6   [0.001, 2.2433656860663382, 2.5, 0.02967302918...
# 21  [0.0010000002764349223, 2.243301182111513, 2.5...
# 15  [0.001, 2.243337141019631, 2.5, 0.029677137072...
# 10  [1.5242643885758458, 2.371205922374566, 0.001,...
# 11  [1.8160777386142588, 2.0477368557621, 0.001149...
# 0   [1.8632548761299814, 1.8803905266645327, 0.001...
# 2   [1.5654690867916434, 2.044130761121619, 0.0050...
# 28  [1.9221650677461088, 1.5506751797315768, 0.001...
# 25  [0.47466261324481895, 2.433142544818423, 1.394...
# 1   [1.9402932133084865, 0.9133089022659423, 0.001...
# 26  [1.9060648020188906, 0.9004222055092832, 0.001...
# 23  [0.05090560389606069, 0.001, 0.831299052696488...
# 14            [0.001, 0.001, 2.3907941208692662, 2.5]
# 18            [0.001, 0.001, 2.5, 0.8442495126527354]
# 17  [0.001, 0.10762091489956815, 1.270220354336398...
# 13  [0.001, 0.0782166500796817, 0.4386496395504045...
# 9   [0.0015195008967303636, 0.001, 2.5, 1.80460071...
# 8   [0.05942579061290015, 0.001, 1.654255585661023...
# 29           [0.001, 0.001, 2.5, 0.35525926017627685]
# 22  [0.001, 0.12253059000347893, 0.654759691693262...
#
#                                         final_simplex
# 5   ([[0.001, 2.499999977486486, 0.001, 0.00835878...
# 7   ([[0.001, 2.499999632421222, 0.001, 0.00835830...
# 20  ([[0.001, 2.5, 0.001, 0.008358201582395483], [...
# 27  ([[0.0010339825764228618, 2.5, 0.001, 0.008358...
# 12  ([[0.0010947948428169302, 2.499995512406253, 0...
# 3   ([[0.001, 2.49997580104458, 0.0010030530846525...
# 4   ([[0.00102053260686, 2.4999408299667394, 0.001...
# 24  ([[0.0027093543545160526, 2.3952383559415713, ...
# 19  ([[0.001, 2.4039093139247507, 0.65984006922984...
# 16  ([[0.001, 2.2442644068767708, 2.47758574849562...
# 6   ([[0.001, 2.2433656860663382, 2.5, 0.029673029...
# 21  ([[0.0010000002764349223, 2.243301182111513, 2...
# 15  ([[0.001, 2.243337141019631, 2.5, 0.0296771370...
# 10  ([[1.5242643885758458, 2.371205922374566, 0.00...
# 11  ([[1.8160777386142588, 2.0477368557621, 0.0011...
# 0   ([[1.8632548761299814, 1.8803905266645327, 0.0...
# 2   ([[1.5654690867916434, 2.044130761121619, 0.00...
# 28  ([[1.9221650677461088, 1.5506751797315768, 0.0...
# 25  ([[0.47466261324481895, 2.433142544818423, 1.3...
# 1   ([[1.9402932133084865, 0.9133089022659423, 0.0...
# 26  ([[1.9060648020188906, 0.9004222055092832, 0.0...
# 23  ([[0.05090560389606069, 0.001, 0.8312990526964...
# 14  ([[0.001, 0.001, 2.3907941208692662, 2.5], [0....
# 18  ([[0.001, 0.001, 2.5, 0.8442495126527354], [0....
# 17  ([[0.001, 0.10762091489956815, 1.2702203543363...
# 13  ([[0.001, 0.0782166500796817, 0.43864963955040...
# 9   ([[0.0015195008967303636, 0.001, 2.5, 1.804600...
# 8   ([[0.05942579061290015, 0.001, 1.6542555856610...
# 29  ([[0.001, 0.001, 2.5, 0.35525926017627685], [0...
# 22  ([[0.001, 0.12253059000347893, 0.6547596916932...

# %% [markdown]
# #  DE fit

# %%
DEFF = next(read_from_pickle(f"ff/{ffpkl}"))

# %%
fit_repeat(DEFF, 
           30, 
           "test",
           bounds = DE_bound,
           loss="jax_de",
           quiet='true'
          )
# Out:
# /home/boittier/Documents/phd/ff_energy/ff_energy/ffe/ff_fit.py:175: OptimizeWarning: Unknown solver options: pgtol
#   res = minimize(

# %%
pd.DataFrame(DEFF.opt_results).sort_values("fun")
# Out:
#              fun   nit  nfev  status  success  \
# 12    220.996964  1875  2961       0     True
# 26    221.478455  1860  2957       0     True
# 20    225.158127  1624  2594       0     True
# 17    225.915390  2058  3258       0     True
# 6     229.313080   864  1456       0     True
# 19    230.454849   495   848       0     True
# 13    232.988876  1872  2973       0     True
# 24    237.615799  1164  1870       0     True
# 3     238.155258   689  1142       0     True
# 10    244.933075   568   961       0     True
# 1     245.799622   800  1323       0     True
# 16    245.825455  1270  2075       0     True
# 9     246.866394  1330  2118       0     True
# 0     247.850266   748  1242       0     True
# 8     250.824966  1067  1739       0     True
# 14    258.560669   474   796       0     True
# 29    259.029877   294   547       0     True
# 2     264.580627   541   928       0     True
# 28    298.960541   575   946       0     True
# 11  24113.593750    63   239       0     True
# 18  24113.593750    36   180       0     True
# 7   24113.593750    42   195       0     True
# 5   24113.593750    21   167       0     True
# 21  24113.593750    87   264       0     True
# 22  24113.593750    51   221       0     True
# 23  24113.593750    66   233       0     True
# 4   24113.593750    63   232       0     True
# 25  24113.593750    44   199       0     True
# 27  24113.593750    62   209       0     True
# 15  24113.593750    56   222       0     True
#
#                                   message  \
# 12  Optimization terminated successfully.
# 26  Optimization terminated successfully.
# 20  Optimization terminated successfully.
# 17  Optimization terminated successfully.
# 6   Optimization terminated successfully.
# 19  Optimization terminated successfully.
# 13  Optimization terminated successfully.
# 24  Optimization terminated successfully.
# 3   Optimization terminated successfully.
# 10  Optimization terminated successfully.
# 1   Optimization terminated successfully.
# 16  Optimization terminated successfully.
# 9   Optimization terminated successfully.
# 0   Optimization terminated successfully.
# 8   Optimization terminated successfully.
# 14  Optimization terminated successfully.
# 29  Optimization terminated successfully.
# 2   Optimization terminated successfully.
# 28  Optimization terminated successfully.
# 11  Optimization terminated successfully.
# 18  Optimization terminated successfully.
# 7   Optimization terminated successfully.
# 5   Optimization terminated successfully.
# 21  Optimization terminated successfully.
# 22  Optimization terminated successfully.
# 23  Optimization terminated successfully.
# 4   Optimization terminated successfully.
# 25  Optimization terminated successfully.
# 27  Optimization terminated successfully.
# 15  Optimization terminated successfully.
#
#                                                     x  \
# 12  [2.4265867234939114, 2.3067428500434612, 0.001...
# 26  [2.4982202452139672, 2.184297394719601, 0.0010...
# 20  [1.4964068366133134, 2.499993991197181, 0.001,...
# 17  [1.5452456465333801, 2.497421713983464, 0.0010...
# 6   [0.6410959975169201, 2.5, 0.051572231534570405...
# 19  [0.5146866567040341, 2.499988984556288, 0.0577...
# 13  [2.451984410529043, 1.9839351478691323, 0.0018...
# 24  [2.2349421776212464, 2.4352560868124997, 0.001...
# 3   [0.001, 2.4999996724880154, 0.4913144416962407...
# 10  [0.011758559962771007, 2.4997509773055997, 0.8...
# 1   [2.4992352562062927, 1.1518814776956239, 0.004...
# 16  [2.499751199846359, 1.7097322538395168, 0.0010...
# 9   [0.1707142272974848, 2.499997745004289, 0.5332...
# 0   [2.4618353123415044, 2.119511858171072, 0.0051...
# 8   [2.3303922663549246, 2.2828743163666187, 0.006...
# 14  [0.001, 2.5, 0.7073657008486602, 0.17274466314...
# 29  [0.001, 2.4999999027752304, 0.7897854592323527...
# 2   [2.430307325309726, 0.9848237539998876, 0.0040...
# 28  [0.001, 2.499999238870042, 0.001, 0.1852570453...
# 11  [0.16985578481780628, 0.37070573734984524, 2.5...
# 18  [0.046798697025914174, 0.4125830175981795, 2.1...
# 7   [0.026860513120372742, 0.3085986248534267, 2.1...
# 5   [0.14678281066046917, 0.12010447904454669, 0.3...
# 21  [0.3572816701139079, 0.043280110996078786, 0.0...
# 22  [0.03189838724296005, 0.2909921723168637, 2.17...
# 23  [0.001, 0.05917121880215748, 1.694186055664344...
# 4   [0.1142988366779866, 0.26401670128551913, 1.27...
# 25  [0.001, 0.22661939544469223, 2.162813676895863...
# 27  [0.2210346436104782, 0.46324882345298857, 0.00...
# 15  [0.001, 0.3622760907889919, 2.5, 0.05457338690...
#
#                                         final_simplex
# 12  ([[2.4265867234939114, 2.3067428500434612, 0.0...
# 26  ([[2.4982202452139672, 2.184297394719601, 0.00...
# 20  ([[1.4964068366133134, 2.499993991197181, 0.00...
# 17  ([[1.5452456465333801, 2.497421713983464, 0.00...
# 6   ([[0.6410959975169201, 2.5, 0.0515722315345704...
# 19  ([[0.5146866567040341, 2.499988984556288, 0.05...
# 13  ([[2.451984410529043, 1.9839351478691323, 0.00...
# 24  ([[2.2349421776212464, 2.4352560868124997, 0.0...
# 3   ([[0.001, 2.4999996724880154, 0.49131444169624...
# 10  ([[0.011758559962771007, 2.4997509773055997, 0...
# 1   ([[2.4992352562062927, 1.1518814776956239, 0.0...
# 16  ([[2.499751199846359, 1.7097322538395168, 0.00...
# 9   ([[0.1707142272974848, 2.499997745004289, 0.53...
# 0   ([[2.4618353123415044, 2.119511858171072, 0.00...
# 8   ([[2.3303922663549246, 2.2828743163666187, 0.0...
# 14  ([[0.001, 2.5, 0.7073657008486602, 0.172744663...
# 29  ([[0.001, 2.4999999027752304, 0.78978545923235...
# 2   ([[2.430307325309726, 0.9848237539998876, 0.00...
# 28  ([[0.001, 2.499999238870042, 0.001, 0.18525704...
# 11  ([[0.16985578481780628, 0.37070573734984524, 2...
# 18  ([[0.046798697025914174, 0.4125830175981795, 2...
# 7   ([[0.026860513120372742, 0.3085986248534267, 2...
# 5   ([[0.14678281066046917, 0.12010447904454669, 0...
# 21  ([[0.3572816701139079, 0.043280110996078786, 0...
# 22  ([[0.03189838724296005, 0.2909921723168637, 2....
# 23  ([[0.001, 0.05917121880215748, 1.6941860556643...
# 4   ([[0.1142988366779866, 0.26401670128551913, 1....
# 25  ([[0.001, 0.22661939544469223, 2.1628136768958...
# 27  ([[0.2210346436104782, 0.46324882345298857, 0....
# 15  ([[0.001, 0.3622760907889919, 2.5, 0.054573386...
