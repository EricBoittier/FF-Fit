# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from ff_energy.ffe.utils import read_from_pickle
import jax.numpy as jnp
from ff_energy.ffe.plot import plot_energy_MSE, plot_ff_fit
from ff_energy.ffe.structure import atom_key_pairs
from ff_energy.ffe.potential import LJ, akp_indx
from ff_energy.ffe.ff import FF
from ff_energy.ffe.ff_fit import LJ_bound, load_ff, fit_func, fit_repeat
from ff_energy.ffe.data import pairs_data
from ff_energy.ffe.utils import pickle_output, read_from_pickle, str2int

# %%
sig_bound = (0.05, 2.5)
ep_bound = (0.001, 0.5)
LJ_bound = ((sig_bound), (sig_bound), (ep_bound), (ep_bound))
DE_bound = ((sig_bound), (sig_bound), (ep_bound), (ep_bound), 
            (1, 8), (6, 20))

# %%
#  example
# ffpkl = "ECOL_pbe0dz_FOE.ff.pkl"

# %%
# Parameters
ffpkl = "ECOL_pbe0dz_FOE.ff.pkl"

# %% [markdown]
# #  LJ fit

# %%
_c = next(read_from_pickle(f"ff/{ffpkl}"))
_c
# Out:
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# FF: LJ water_cluster ECOL Exact first_order_energy (jax_coloumb: False)

# %%
# _c.targets

# %%
fit_repeat(_c, 
           1, 
           f"{ffpkl}_LJ",
           bounds = LJ_bound,
           loss="jax",
           quiet='true'
          )

# %%
pd.DataFrame(_c.opt_results).sort_values("fun")
# Out:
#             fun  nit  nfev  status  success  \
# 5     38.730198  738  1256       0     True
# 6     50.981689  778  1337       0     True
# 3     51.031322  439   783       0     True
# 0    133.068710  246   435       0     True
# 1    419.112213  237   455       0     True
# 2    524.201721  273   503       0     True
# 4  13098.618164   40    63       0     True
#
#                                  message  \
# 5  Optimization terminated successfully.
# 6  Optimization terminated successfully.
# 3  Optimization terminated successfully.
# 0  Optimization terminated successfully.
# 1  Optimization terminated successfully.
# 2  Optimization terminated successfully.
# 4  Optimization terminated successfully.
#
#                                                    x  \
# 5  [0.6230585214075479, 2.5, 0.001, 0.00669026869...
# 6  [0.07309580953686798, 2.4999999955887686, 0.00...
# 3  [0.05027231543080456, 2.3384433258326114, 0.5,...
# 0  [0.05000000000000006, 1.8526818428200764, 0.00...
# 1  [1.7357291970644244, 1.4382805704320516, 0.001...
# 2  [1.7528566157770311, 1.1628845794457825, 0.002...
# 4              [0.0500000000000001, 2.5, 0.5, 0.001]
#
#                                        final_simplex
# 5  ([[0.6230585214075479, 2.5, 0.001, 0.006690268...
# 6  ([[0.07309580953686798, 2.4999999955887686, 0....
# 3  ([[0.05027231543080456, 2.3384433258326114, 0....
# 0  ([[0.05000000000000006, 1.8526818428200764, 0....
# 1  ([[1.7357291970644244, 1.4382805704320516, 0.0...
# 2  ([[1.7528566157770311, 1.1628845794457825, 0.0...
# 4  ([[0.0500000000000001, 2.5, 0.5, 0.001], [0.05...

# %% [markdown]
# #  DE fit

# %%
_c = next(read_from_pickle(f"ff/{ffpkl}"))

# %%
fit_repeat(_c, 
           30, 
           "test",
           bounds = DE_bound,
           loss="jax_de",
           quiet='true'
          )
# Out:
# /home/boittier/Documents/phd/ff_energy/ff_energy/ffe/ff_fit.py:174: OptimizeWarning: Unknown solver options: pgtol
#   res = minimize(

# %%
pd.DataFrame(_c.opt_results).sort_values("fun")
# Out:
#              fun   nit  nfev  status  success  \
# 29     19.671652   952  1547       0     True
# 1      19.836388  1325  2104       0     True
# 27     20.202728  1152  1860       0     True
# 8      20.284485  1821  2900       0     True
# 9      23.174736  1035  1702       0     True
# 4      24.980696   896  1485       0     True
# 13     25.182016   715  1172       0     True
# 18     26.827951  1056  1697       0     True
# 20     28.218256  1072  1715       0     True
# 28     28.551628  1043  1701       0     True
# 14     28.806337   646  1085       0     True
# 26     28.879677  1626  2587       0     True
# 12     29.437759  1140  1833       0     True
# 0      32.099705   749  1229       0     True
# 22     33.243885  1002  1615       0     True
# 5      33.669273   803  1314       0     True
# 16     36.336956  1787  2832       0     True
# 17     40.676594   465   816       0     True
# 10     40.739456  1319  2141       0     True
# 11     45.497150  1011  1651       0     True
# 23     52.759991  1033  1651       0     True
# 19     58.335194   979  1591       0     True
# 7      58.335220  1058  1704       0     True
# 15     80.136086   767  1270       0     True
# 21  21446.074219    39   185       0     True
# 6   21446.074219    47   202       0     True
# 24  21446.074219    36   186       0     True
# 25  21446.074219    43   203       0     True
# 2   21446.074219    56   215       0     True
# 3   21446.074219    42   201       0     True
#
#                                   message  \
# 29  Optimization terminated successfully.
# 1   Optimization terminated successfully.
# 27  Optimization terminated successfully.
# 8   Optimization terminated successfully.
# 9   Optimization terminated successfully.
# 4   Optimization terminated successfully.
# 13  Optimization terminated successfully.
# 18  Optimization terminated successfully.
# 20  Optimization terminated successfully.
# 28  Optimization terminated successfully.
# 14  Optimization terminated successfully.
# 26  Optimization terminated successfully.
# 12  Optimization terminated successfully.
# 0   Optimization terminated successfully.
# 22  Optimization terminated successfully.
# 5   Optimization terminated successfully.
# 16  Optimization terminated successfully.
# 17  Optimization terminated successfully.
# 10  Optimization terminated successfully.
# 11  Optimization terminated successfully.
# 23  Optimization terminated successfully.
# 19  Optimization terminated successfully.
# 7   Optimization terminated successfully.
# 15  Optimization terminated successfully.
# 21  Optimization terminated successfully.
# 6   Optimization terminated successfully.
# 24  Optimization terminated successfully.
# 25  Optimization terminated successfully.
# 2   Optimization terminated successfully.
# 3   Optimization terminated successfully.
#
#                                                     x  \
# 29  [0.6653266372764883, 2.3459944247666242, 0.086...
# 1   [0.5118895894942155, 2.4825686084273384, 0.199...
# 27  [0.5329849860051136, 2.257329953774849, 0.1512...
# 8   [0.5566183204265102, 2.1917176787903783, 0.135...
# 9   [0.20465138984816195, 2.4998123633250766, 0.33...
# 4   [0.05, 2.4619405102028584, 0.4971020798921285,...
# 13  [2.2325477912981517, 1.9516247879633826, 0.001...
# 18  [2.3309190000124778, 1.7653686133787878, 0.001...
# 20  [0.5646644786806222, 2.36776030279944, 0.48875...
# 28  [2.022797267512657, 1.791625607393129, 0.00110...
# 14  [0.49809636724711215, 2.270667221686753, 0.197...
# 26  [2.5, 1.7469408956657586, 0.001000040498863384...
# 12  [2.488618450885174, 2.1538006646571914, 0.0017...
# 0   [2.388561154563314, 1.6136863527282737, 0.0010...
# 22  [2.4559151886594837, 1.6280962136916597, 0.001...
# 5   [0.05060067679390582, 2.499999995827019, 0.066...
# 16  [0.901004836569445, 2.272757687396843, 0.17064...
# 17  [0.3162949404404063, 2.0729018646199417, 0.449...
# 10  [1.3934587521233686, 2.0897983882705162, 0.031...
# 11  [1.6104145960942002, 2.035783059547793, 0.0138...
# 23  [2.499992130805242, 1.5179571111637449, 0.0047...
# 19  [2.5, 1.7980622575251064, 0.003760789813191276...
# 7   [2.5, 1.797255747173881, 0.0037721625105643685...
# 15  [2.3145889568333065, 1.371991599008013, 0.0029...
# 21  [0.06478376751090126, 0.15571706039468092, 0.4...
# 6   [0.05, 0.4460064530739076, 0.2600825316107169,...
# 24  [0.1306094675751599, 0.3679966596992631, 0.378...
# 25  [0.14872957342496684, 0.14410324308416889, 0.1...
# 2   [0.05, 0.38061998797264396, 0.4382264333790707...
# 3   [0.08426992893096816, 0.422342297048115, 0.188...
#
#                                         final_simplex
# 29  ([[0.6653266372764883, 2.3459944247666242, 0.0...
# 1   ([[0.5118895894942155, 2.4825686084273384, 0.1...
# 27  ([[0.5329849860051136, 2.257329953774849, 0.15...
# 8   ([[0.5566183204265102, 2.1917176787903783, 0.1...
# 9   ([[0.20465138984816195, 2.4998123633250766, 0....
# 4   ([[0.05, 2.4619405102028584, 0.497102079892128...
# 13  ([[2.2325477912981517, 1.9516247879633826, 0.0...
# 18  ([[2.3309190000124778, 1.7653686133787878, 0.0...
# 20  ([[0.5646644786806222, 2.36776030279944, 0.488...
# 28  ([[2.022797267512657, 1.791625607393129, 0.001...
# 14  ([[0.49809636724711215, 2.270667221686753, 0.1...
# 26  ([[2.5, 1.7469408956657586, 0.0010000404988633...
# 12  ([[2.488618450885174, 2.1538006646571914, 0.00...
# 0   ([[2.388561154563314, 1.6136863527282737, 0.00...
# 22  ([[2.4559151886594837, 1.6280962136916597, 0.0...
# 5   ([[0.05060067679390582, 2.499999995827019, 0.0...
# 16  ([[0.901004836569445, 2.272757687396843, 0.170...
# 17  ([[0.3162949404404063, 2.0729018646199417, 0.4...
# 10  ([[1.3934587521233686, 2.0897983882705162, 0.0...
# 11  ([[1.6104145960942002, 2.035783059547793, 0.01...
# 23  ([[2.499992130805242, 1.5179571111637449, 0.00...
# 19  ([[2.5, 1.7980622575251064, 0.0037607898131912...
# 7   ([[2.5, 1.797255747173881, 0.00377216251056436...
# 15  ([[2.3145889568333065, 1.371991599008013, 0.00...
# 21  ([[0.06478376751090126, 0.15571706039468092, 0...
# 6   ([[0.05, 0.4460064530739076, 0.260082531610716...
# 24  ([[0.1306094675751599, 0.3679966596992631, 0.3...
# 25  ([[0.14872957342496684, 0.14410324308416889, 0...
# 2   ([[0.05, 0.38061998797264396, 0.43822643337907...
# 3   ([[0.08426992893096816, 0.422342297048115, 0.1...
