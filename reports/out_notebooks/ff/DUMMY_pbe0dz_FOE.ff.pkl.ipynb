# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from ff_energy.ffe.utils import read_from_pickle
import jax.numpy as jnp
from ff_energy.ffe.plot import plot_energy_MSE, plot_ff_fit
from ff_energy.ffe.structure import atom_key_pairs
from ff_energy.ffe.potential import LJ, akp_indx
from ff_energy.ffe.ff import FF
from ff_energy.ffe.ff_fit import LJ_bound, load_ff, fit_func, fit_repeat
from ff_energy.ffe.data import pairs_data
from ff_energy.ffe.utils import pickle_output, read_from_pickle, str2int

# %%
sig_bound = (0.05, 2.5)
ep_bound = (0.001, 0.5)
LJ_bound = ((sig_bound), (sig_bound), (ep_bound), (ep_bound))
DE_bound = ((sig_bound), (sig_bound), (ep_bound), (ep_bound), 
            (1, 8), (6, 20))

# %%
#  example
# ffpkl = "ECOL_pbe0dz_FOE.ff.pkl"

# %%
# Parameters
ffpkl = "DUMMY_pbe0dz_FOE.ff.pkl"

# %% [markdown]
# #  LJ fit

# %%
_c = next(read_from_pickle(f"ff/{ffpkl}"))
_c
# Out:
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# FF: LJ water_cluster DUMMY Exact first_order_energy (jax_coloumb: False)

# %%
# _c.targets

# %%
fit_repeat(_c, 
           30, 
           f"{ffpkl}_LJ",
           bounds = LJ_bound,
           loss="jax",
           # quiet='true'
          )
# Out:
# /home/boittier/Documents/phd/ff_energy/ff_energy/ffe/ff_fit.py:174: OptimizeWarning: Unknown solver options: pgtol
#   res = minimize(
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.1671497666394728, 1.7103326683203894, 0.2976118658750058, 0.34266368557078253]
# final_loss_fn:  65.22830963134766
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 65.22830963134766
#              x: [ 3.357e-01  1.709e+00  5.000e-01  2.888e-01]
#            nit: 474
#           nfev: 826
#  final_simplex: (array([[ 3.357e-01,  1.709e+00,  5.000e-01,  2.888e-01],
#                        [ 3.357e-01,  1.709e+00,  5.000e-01,  2.888e-01],
#                        ...,
#                        [ 3.357e-01,  1.709e+00,  5.000e-01,  2.888e-01],
#                        [ 3.357e-01,  1.709e+00,  5.000e-01,  2.888e-01]]), array([ 6.523e+01,  6.523e+01,  6.523e+01,  6.523e+01,
#                         6.523e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.2782949017202019, 0.7340829355133957, 0.48383277493721966, 0.4690679918622933]
# final_loss_fn:  67.38020324707031
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 67.38020324707031
#              x: [ 7.808e-01  1.632e+00  2.889e-03  5.000e-01]
#            nit: 465
#           nfev: 804
#  final_simplex: (array([[ 7.808e-01,  1.632e+00,  2.889e-03,  5.000e-01],
#                        [ 7.808e-01,  1.632e+00,  2.889e-03,  5.000e-01],
#                        ...,
#                        [ 7.808e-01,  1.632e+00,  2.889e-03,  5.000e-01],
#                        [ 7.808e-01,  1.632e+00,  2.889e-03,  5.000e-01]]), array([ 6.738e+01,  6.738e+01,  6.738e+01,  6.738e+01,
#                         6.738e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [2.0087363860930147, 0.23746277163713603, 0.06657612363597781, 0.2980602608526436]
# final_loss_fn:  127.9439468383789
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 127.9439468383789
#              x: [ 1.789e+00  5.000e-02  1.000e-03  5.000e-01]
#            nit: 170
#           nfev: 336
#  final_simplex: (array([[ 1.789e+00,  5.000e-02,  1.000e-03,  5.000e-01],
#                        [ 1.789e+00,  5.000e-02,  1.000e-03,  5.000e-01],
#                        ...,
#                        [ 1.789e+00,  5.000e-02,  1.000e-03,  5.000e-01],
#                        [ 1.789e+00,  5.000e-02,  1.000e-03,  5.000e-01]]), array([ 1.279e+02,  1.279e+02,  1.279e+02,  1.279e+02,
#                         1.279e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [2.1481042174361376, 2.3465910908905814, 0.2540116725870331, 0.33363431277327565]
# final_loss_fn:  69.62406921386719
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 69.62406921386719
#              x: [ 5.000e-02  1.698e+00  5.000e-01  4.759e-01]
#            nit: 196
#           nfev: 367
#  final_simplex: (array([[ 5.000e-02,  1.698e+00,  5.000e-01,  4.759e-01],
#                        [ 5.000e-02,  1.698e+00,  5.000e-01,  4.759e-01],
#                        ...,
#                        [ 5.000e-02,  1.698e+00,  5.000e-01,  4.759e-01],
#                        [ 5.000e-02,  1.698e+00,  5.000e-01,  4.759e-01]]), array([ 6.962e+01,  6.962e+01,  6.962e+01,  6.962e+01,
#                         6.962e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.5198534424513742, 0.5473287101022304, 0.4128359350077242, 0.0036807770802714974]
# final_loss_fn:  229.85655212402344
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 229.85655212402344
#              x: [ 9.152e-02  5.000e-02  1.000e-03  4.808e-03]
#            nit: 54
#           nfev: 157
#  final_simplex: (array([[ 9.152e-02,  5.000e-02,  1.000e-03,  4.808e-03],
#                        [ 9.152e-02,  5.000e-02,  1.000e-03,  4.808e-03],
#                        ...,
#                        [ 9.152e-02,  5.000e-02,  1.000e-03,  4.808e-03],
#                        [ 9.152e-02,  5.000e-02,  1.000e-03,  4.808e-03]]), array([ 2.299e+02,  2.299e+02,  2.299e+02,  2.299e+02,
#                         2.299e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.1733567208874402, 0.20715554367762867, 0.2751556238040847, 0.11123968785879797]
# final_loss_fn:  229.8565673828125
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 229.8565673828125
#              x: [ 5.000e-02  5.000e-02  2.785e-01  2.856e-01]
#            nit: 42
#           nfev: 143
#  final_simplex: (array([[ 5.000e-02,  5.000e-02,  2.785e-01,  2.856e-01],
#                        [ 5.000e-02,  5.000e-02,  2.785e-01,  2.856e-01],
#                        ...,
#                        [ 5.000e-02,  5.000e-02,  2.785e-01,  2.856e-01],
#                        [ 5.000e-02,  5.000e-02,  2.785e-01,  2.856e-01]]), array([ 2.299e+02,  2.299e+02,  2.299e+02,  2.299e+02,
#                         2.299e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.8546679343048535, 1.969946775040465, 0.01766399368918201, 0.4906629709406176]
# final_loss_fn:  70.23519134521484
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 70.23519134521484
#              x: [ 1.217e+00  1.080e+00  4.981e-02  4.812e-01]
#            nit: 224
#           nfev: 426
#  final_simplex: (array([[ 1.217e+00,  1.080e+00,  4.981e-02,  4.812e-01],
#                        [ 1.217e+00,  1.080e+00,  4.981e-02,  4.812e-01],
#                        ...,
#                        [ 1.217e+00,  1.080e+00,  4.981e-02,  4.812e-01],
#                        [ 1.217e+00,  1.080e+00,  4.981e-02,  4.812e-01]]), array([ 7.024e+01,  7.024e+01,  7.024e+01,  7.024e+01,
#                         7.024e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [2.4982125236953885, 2.149477564484428, 0.17270290295423255, 0.12770233938019687]
# final_loss_fn:  127.94132232666016
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 127.94132232666016
#              x: [ 1.789e+00  5.000e-02  1.000e-03  4.964e-01]
#            nit: 110
#           nfev: 219
#  final_simplex: (array([[ 1.789e+00,  5.000e-02,  1.000e-03,  4.964e-01],
#                        [ 1.789e+00,  5.000e-02,  1.000e-03,  4.964e-01],
#                        ...,
#                        [ 1.789e+00,  5.000e-02,  1.000e-03,  4.964e-01],
#                        [ 1.789e+00,  5.000e-02,  1.000e-03,  4.964e-01]]), array([ 1.279e+02,  1.279e+02,  1.279e+02,  1.279e+02,
#                         1.279e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [2.144881734309973, 0.1977159802777409, 0.43446404978134706, 0.23756424403328139]
# final_loss_fn:  229.8565673828125
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 229.8565673828125
#              x: [ 5.000e-02  5.000e-02  4.842e-01  1.379e-01]
#            nit: 42
#           nfev: 140
#  final_simplex: (array([[ 5.000e-02,  5.000e-02,  4.842e-01,  1.379e-01],
#                        [ 5.000e-02,  5.000e-02,  4.842e-01,  1.379e-01],
#                        ...,
#                        [ 5.000e-02,  5.000e-02,  4.842e-01,  1.379e-01],
#                        [ 5.000e-02,  5.000e-02,  4.842e-01,  1.379e-01]]), array([ 2.299e+02,  2.299e+02,  2.299e+02,  2.299e+02,
#                         2.299e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.05335013747995414, 2.2212560914178, 0.2069864092784016, 0.2969267459083528]
# final_loss_fn:  229.85655212402344
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 229.85655212402344
#              x: [ 5.000e-02  5.000e-02  1.603e-01  2.731e-01]
#            nit: 48
#           nfev: 147
#  final_simplex: (array([[ 5.000e-02,  5.000e-02,  1.603e-01,  2.731e-01],
#                        [ 5.000e-02,  5.000e-02,  1.603e-01,  2.731e-01],
#                        ...,
#                        [ 5.000e-02,  5.000e-02,  1.603e-01,  2.731e-01],
#                        [ 5.000e-02,  5.000e-02,  1.603e-01,  2.731e-01]]), array([ 2.299e+02,  2.299e+02,  2.299e+02,  2.299e+02,
#                         2.299e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.6547555145683628, 0.49251899556190676, 0.08266196443502277, 0.05567941032689692]
# final_loss_fn:  229.85653686523438
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 229.85653686523438
#              x: [ 5.000e-02  5.000e-02  2.284e-01  1.114e-01]
#            nit: 46
#           nfev: 139
#  final_simplex: (array([[ 5.000e-02,  5.000e-02,  2.284e-01,  1.114e-01],
#                        [ 5.000e-02,  5.000e-02,  2.284e-01,  1.114e-01],
#                        ...,
#                        [ 5.000e-02,  5.000e-02,  2.284e-01,  1.114e-01],
#                        [ 5.000e-02,  5.000e-02,  2.284e-01,  1.114e-01]]), array([ 2.299e+02,  2.299e+02,  2.299e+02,  2.299e+02,
#                         2.299e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.670866514244239, 1.4870783144436355, 0.39508043149606015, 0.15662839159902706]
# final_loss_fn:  65.2284927368164
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 65.2284927368164
#              x: [ 3.368e-01  1.709e+00  4.998e-01  2.881e-01]
#            nit: 257
#           nfev: 448
#  final_simplex: (array([[ 3.368e-01,  1.709e+00,  4.998e-01,  2.881e-01],
#                        [ 3.368e-01,  1.709e+00,  4.998e-01,  2.881e-01],
#                        ...,
#                        [ 3.368e-01,  1.709e+00,  4.998e-01,  2.881e-01],
#                        [ 3.368e-01,  1.709e+00,  4.998e-01,  2.881e-01]]), array([ 6.523e+01,  6.523e+01,  6.523e+01,  6.523e+01,
#                         6.523e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.5436270866999137, 1.2928300239161281, 0.3381560685021655, 0.06265901554490517]
# final_loss_fn:  229.85655212402344
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 229.85655212402344
#              x: [ 5.177e-02  5.618e-02  1.174e-01  1.936e-01]
#            nit: 50
#           nfev: 156
#  final_simplex: (array([[ 5.177e-02,  5.618e-02,  1.174e-01,  1.936e-01],
#                        [ 5.177e-02,  5.618e-02,  1.174e-01,  1.936e-01],
#                        ...,
#                        [ 5.177e-02,  5.618e-02,  1.174e-01,  1.936e-01],
#                        [ 5.177e-02,  5.618e-02,  1.174e-01,  1.936e-01]]), array([ 2.299e+02,  2.299e+02,  2.299e+02,  2.299e+02,
#                         2.299e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [2.3326459775949306, 1.0815139505645852, 0.2305759633879432, 0.07304931300811139]
# final_loss_fn:  71.74200439453125
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 71.74200439453125
#              x: [ 1.118e+00  1.248e+00  1.678e-01  6.266e-02]
#            nit: 137
#           nfev: 267
#  final_simplex: (array([[ 1.118e+00,  1.248e+00,  1.678e-01,  6.266e-02],
#                        [ 1.118e+00,  1.248e+00,  1.678e-01,  6.266e-02],
#                        ...,
#                        [ 1.118e+00,  1.248e+00,  1.678e-01,  6.266e-02],
#                        [ 1.118e+00,  1.248e+00,  1.678e-01,  6.266e-02]]), array([ 7.174e+01,  7.174e+01,  7.174e+01,  7.174e+01,
#                         7.174e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.5913506661930894, 1.445468840559171, 0.17131283985698834, 0.05381845157580232]
# final_loss_fn:  71.76911926269531
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 71.76911926269531
#              x: [ 1.121e+00  1.248e+00  1.616e-01  6.066e-02]
#            nit: 220
#           nfev: 423
#  final_simplex: (array([[ 1.121e+00,  1.248e+00,  1.616e-01,  6.066e-02],
#                        [ 1.121e+00,  1.248e+00,  1.616e-01,  6.066e-02],
#                        ...,
#                        [ 1.121e+00,  1.248e+00,  1.616e-01,  6.066e-02],
#                        [ 1.121e+00,  1.248e+00,  1.616e-01,  6.066e-02]]), array([ 7.177e+01,  7.177e+01,  7.177e+01,  7.177e+01,
#                         7.177e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.5205815230657722, 0.09867920286357221, 0.028484475059137614, 0.2140832914520617]
# final_loss_fn:  127.27082061767578
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 127.27082061767578
#              x: [ 1.783e+00  5.000e-02  1.000e-03  1.000e-03]
#            nit: 191
#           nfev: 366
#  final_simplex: (array([[ 1.783e+00,  5.000e-02,  1.000e-03,  1.000e-03],
#                        [ 1.783e+00,  5.000e-02,  1.000e-03,  1.000e-03],
#                        ...,
#                        [ 1.783e+00,  5.000e-02,  1.000e-03,  1.000e-03],
#                        [ 1.783e+00,  5.000e-02,  1.000e-03,  1.000e-03]]), array([ 1.273e+02,  1.273e+02,  1.273e+02,  1.273e+02,
#                         1.273e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.541415960623789, 1.927112105850693, 0.48571778150226147, 0.10500512444929223]
# final_loss_fn:  229.8565673828125
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 229.8565673828125
#              x: [ 5.000e-02  5.000e-02  4.868e-01  2.160e-01]
#            nit: 33
#           nfev: 127
#  final_simplex: (array([[ 5.000e-02,  5.000e-02,  4.868e-01,  2.160e-01],
#                        [ 5.000e-02,  5.000e-02,  4.868e-01,  2.160e-01],
#                        ...,
#                        [ 5.000e-02,  5.000e-02,  4.868e-01,  2.160e-01],
#                        [ 5.000e-02,  5.000e-02,  4.868e-01,  2.160e-01]]), array([ 2.299e+02,  2.299e+02,  2.299e+02,  2.299e+02,
#                         2.299e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.1959111670341234, 1.7347832407846726, 0.151470141909274, 0.13631033494018988]
# final_loss_fn:  71.6882553100586
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 71.6882553100586
#              x: [ 1.115e+00  1.240e+00  1.711e-01  7.456e-02]
#            nit: 139
#           nfev: 274
#  final_simplex: (array([[ 1.115e+00,  1.240e+00,  1.711e-01,  7.456e-02],
#                        [ 1.115e+00,  1.240e+00,  1.711e-01,  7.456e-02],
#                        ...,
#                        [ 1.115e+00,  1.240e+00,  1.711e-01,  7.456e-02],
#                        [ 1.115e+00,  1.240e+00,  1.711e-01,  7.456e-02]]), array([ 7.169e+01,  7.169e+01,  7.169e+01,  7.169e+01,
#                         7.169e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.6495876122600717, 1.485021567811654, 0.0786293612236742, 0.3030174773156092]
# final_loss_fn:  70.68161010742188
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 70.68161010742188
#              x: [ 1.167e+00  1.142e+00  9.135e-02  2.387e-01]
#            nit: 224
#           nfev: 426
#  final_simplex: (array([[ 1.167e+00,  1.142e+00,  9.135e-02,  2.387e-01],
#                        [ 1.167e+00,  1.142e+00,  9.135e-02,  2.387e-01],
#                        ...,
#                        [ 1.167e+00,  1.142e+00,  9.135e-02,  2.387e-01],
#                        [ 1.167e+00,  1.142e+00,  9.135e-02,  2.387e-01]]), array([ 7.068e+01,  7.068e+01,  7.068e+01,  7.068e+01,
#                         7.068e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [2.050294692117074, 0.9737220410986234, 0.43871867181506674, 0.468079793434013]
# final_loss_fn:  65.22817993164062
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 65.22817993164062
#              x: [ 3.363e-01  1.709e+00  5.000e-01  2.884e-01]
#            nit: 231
#           nfev: 444
#  final_simplex: (array([[ 3.363e-01,  1.709e+00,  5.000e-01,  2.884e-01],
#                        [ 3.363e-01,  1.709e+00,  5.000e-01,  2.884e-01],
#                        ...,
#                        [ 3.363e-01,  1.709e+00,  5.000e-01,  2.884e-01],
#                        [ 3.363e-01,  1.709e+00,  5.000e-01,  2.884e-01]]), array([ 6.523e+01,  6.523e+01,  6.523e+01,  6.523e+01,
#                         6.523e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [2.237006221511835, 2.0038993262756555, 0.4680607686574491, 0.4623532218531597]
# final_loss_fn:  65.22817993164062
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 65.22817993164062
#              x: [ 3.365e-01  1.709e+00  5.000e-01  2.882e-01]
#            nit: 243
#           nfev: 462
#  final_simplex: (array([[ 3.365e-01,  1.709e+00,  5.000e-01,  2.882e-01],
#                        [ 3.365e-01,  1.709e+00,  5.000e-01,  2.882e-01],
#                        ...,
#                        [ 3.365e-01,  1.709e+00,  5.000e-01,  2.882e-01],
#                        [ 3.365e-01,  1.709e+00,  5.000e-01,  2.882e-01]]), array([ 6.523e+01,  6.523e+01,  6.523e+01,  6.523e+01,
#                         6.523e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.24674920690366886, 1.7337202242011445, 0.1002094342917323, 0.4821461364955938]
# final_loss_fn:  65.22818756103516
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 65.22818756103516
#              x: [ 3.363e-01  1.709e+00  5.000e-01  2.881e-01]
#            nit: 339
#           nfev: 589
#  final_simplex: (array([[ 3.363e-01,  1.709e+00,  5.000e-01,  2.881e-01],
#                        [ 3.363e-01,  1.709e+00,  5.000e-01,  2.881e-01],
#                        ...,
#                        [ 3.363e-01,  1.709e+00,  5.000e-01,  2.881e-01],
#                        [ 3.363e-01,  1.709e+00,  5.000e-01,  2.881e-01]]), array([ 6.523e+01,  6.523e+01,  6.523e+01,  6.523e+01,
#                         6.523e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [2.223063751032765, 1.9532918379183428, 0.13876314549336968, 0.13049617121890092]
# final_loss_fn:  65.2281723022461
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 65.2281723022461
#              x: [ 3.363e-01  1.709e+00  5.000e-01  2.882e-01]
#            nit: 280
#           nfev: 508
#  final_simplex: (array([[ 3.363e-01,  1.709e+00,  5.000e-01,  2.882e-01],
#                        [ 3.363e-01,  1.709e+00,  5.000e-01,  2.882e-01],
#                        ...,
#                        [ 3.363e-01,  1.709e+00,  5.000e-01,  2.882e-01],
#                        [ 3.363e-01,  1.709e+00,  5.000e-01,  2.882e-01]]), array([ 6.523e+01,  6.523e+01,  6.523e+01,  6.523e+01,
#                         6.523e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.3345650084307016, 1.4178615076609171, 0.3900495648216329, 0.15989177225097959]
# final_loss_fn:  229.85655212402344
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 229.85655212402344
#              x: [ 6.466e-02  5.000e-02  1.000e-03  1.090e-01]
#            nit: 56
#           nfev: 159
#  final_simplex: (array([[ 6.466e-02,  5.000e-02,  1.000e-03,  1.090e-01],
#                        [ 6.466e-02,  5.000e-02,  1.000e-03,  1.090e-01],
#                        ...,
#                        [ 6.466e-02,  5.000e-02,  1.000e-03,  1.090e-01],
#                        [ 6.466e-02,  5.000e-02,  1.000e-03,  1.090e-01]]), array([ 2.299e+02,  2.299e+02,  2.299e+02,  2.299e+02,
#                         2.299e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.7274823882509904, 1.6039899104145274, 0.00839331594824533, 0.2524865726168372]
# final_loss_fn:  65.24304962158203
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 65.24304962158203
#              x: [ 3.376e-01  1.710e+00  4.950e-01  2.845e-01]
#            nit: 332
#           nfev: 592
#  final_simplex: (array([[ 3.376e-01,  1.710e+00,  4.950e-01,  2.845e-01],
#                        [ 3.376e-01,  1.710e+00,  4.950e-01,  2.845e-01],
#                        ...,
#                        [ 3.376e-01,  1.710e+00,  4.950e-01,  2.845e-01],
#                        [ 3.376e-01,  1.710e+00,  4.950e-01,  2.845e-01]]), array([ 6.524e+01,  6.524e+01,  6.524e+01,  6.524e+01,
#                         6.524e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.5502270074734533, 1.0908590893024943, 0.4942601187893032, 0.35132288983603643]
# final_loss_fn:  229.8565673828125
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 229.8565673828125
#              x: [ 5.000e-02  5.000e-02  4.069e-01  5.000e-01]
#            nit: 55
#           nfev: 161
#  final_simplex: (array([[ 5.000e-02,  5.000e-02,  4.069e-01,  5.000e-01],
#                        [ 5.000e-02,  5.000e-02,  4.069e-01,  5.000e-01],
#                        ...,
#                        [ 5.000e-02,  5.000e-02,  4.069e-01,  5.000e-01],
#                        [ 5.000e-02,  5.000e-02,  4.069e-01,  5.000e-01]]), array([ 2.299e+02,  2.299e+02,  2.299e+02,  2.299e+02,
#                         2.299e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.8559814214448203, 1.2034124159733315, 0.04787514699654721, 0.14181201543786442]
# final_loss_fn:  66.64361572265625
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 66.64361572265625
#              x: [ 5.701e-01  1.652e+00  3.143e-02  4.304e-01]
#            nit: 234
#           nfev: 491
#  final_simplex: (array([[ 5.701e-01,  1.652e+00,  3.143e-02,  4.304e-01],
#                        [ 5.701e-01,  1.652e+00,  3.143e-02,  4.304e-01],
#                        ...,
#                        [ 5.701e-01,  1.652e+00,  3.143e-02,  4.304e-01],
#                        [ 5.701e-01,  1.652e+00,  3.143e-02,  4.304e-01]]), array([ 6.664e+01,  6.664e+01,  6.664e+01,  6.664e+01,
#                         6.664e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [0.15128687982733424, 0.5911128918452925, 0.11958007885179056, 0.21675022526033746]
# final_loss_fn:  229.8565673828125
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 229.8565673828125
#              x: [ 5.000e-02  5.990e-02  2.083e-01  5.000e-01]
#            nit: 49
#           nfev: 153
#  final_simplex: (array([[ 5.000e-02,  5.990e-02,  2.083e-01,  5.000e-01],
#                        [ 5.000e-02,  5.990e-02,  2.083e-01,  5.000e-01],
#                        ...,
#                        [ 5.000e-02,  5.990e-02,  2.083e-01,  5.000e-01],
#                        [ 5.000e-02,  5.990e-02,  2.083e-01,  5.000e-01]]), array([ 2.299e+02,  2.299e+02,  2.299e+02,  2.299e+02,
#                         2.299e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.6802095238349783, 0.8432583675587056, 0.06899663130436307, 0.29419053388065175]
# final_loss_fn:  70.21940612792969
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 70.21940612792969
#              x: [ 1.220e+00  1.077e+00  4.811e-02  4.993e-01]
#            nit: 245
#           nfev: 456
#  final_simplex: (array([[ 1.220e+00,  1.077e+00,  4.811e-02,  4.993e-01],
#                        [ 1.220e+00,  1.077e+00,  4.811e-02,  4.993e-01],
#                        ...,
#                        [ 1.220e+00,  1.077e+00,  4.811e-02,  4.993e-01],
#                        [ 1.220e+00,  1.077e+00,  4.811e-02,  4.993e-01]]), array([ 7.022e+01,  7.022e+01,  7.022e+01,  7.022e+01,
#                         7.022e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax
# bounds: ((0.05, 2.5), (0.05, 2.5), (0.001, 0.5), (0.001, 0.5))
# maxfev: 10000
# initial guess: [1.481403911790649, 1.3098611653573498, 0.2540806101159951, 0.4735316720340968]
# final_loss_fn:  70.53795623779297
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 70.53795623779297
#              x: [ 1.178e+00  1.129e+00  7.700e-02  2.770e-01]
#            nit: 169
#           nfev: 323
#  final_simplex: (array([[ 1.178e+00,  1.129e+00,  7.700e-02,  2.770e-01],
#                        [ 1.178e+00,  1.129e+00,  7.700e-02,  2.770e-01],
#                        ...,
#                        [ 1.178e+00,  1.129e+00,  7.700e-02,  2.770e-01],
#                        [ 1.178e+00,  1.129e+00,  7.700e-02,  2.770e-01]]), array([ 7.054e+01,  7.054e+01,  7.054e+01,  7.054e+01,
#                         7.054e+01]))

# %%
pd.DataFrame(_c.opt_results).sort_values("fun")
# Out:
#            fun  nit  nfev  status  success  \
# 22   65.228172  280   508       0     True
# 20   65.228180  243   462       0     True
# 19   65.228180  231   444       0     True
# 21   65.228188  339   589       0     True
# 0    65.228310  474   826       0     True
# 11   65.228493  257   448       0     True
# 24   65.243050  332   592       0     True
# 26   66.643616  234   491       0     True
# 1    67.380203  465   804       0     True
# 3    69.624069  196   367       0     True
# 28   70.219406  245   456       0     True
# 6    70.235191  224   426       0     True
# 29   70.537956  169   323       0     True
# 18   70.681610  224   426       0     True
# 17   71.688255  139   274       0     True
# 13   71.742004  137   267       0     True
# 14   71.769119  220   423       0     True
# 15  127.270821  191   366       0     True
# 7   127.941322  110   219       0     True
# 2   127.943947  170   336       0     True
# 10  229.856537   46   139       0     True
# 9   229.856552   48   147       0     True
# 12  229.856552   50   156       0     True
# 23  229.856552   56   159       0     True
# 4   229.856552   54   157       0     True
# 8   229.856567   42   140       0     True
# 5   229.856567   42   143       0     True
# 25  229.856567   55   161       0     True
# 27  229.856567   49   153       0     True
# 16  229.856567   33   127       0     True
#
#                                   message  \
# 22  Optimization terminated successfully.
# 20  Optimization terminated successfully.
# 19  Optimization terminated successfully.
# 21  Optimization terminated successfully.
# 0   Optimization terminated successfully.
# 11  Optimization terminated successfully.
# 24  Optimization terminated successfully.
# 26  Optimization terminated successfully.
# 1   Optimization terminated successfully.
# 3   Optimization terminated successfully.
# 28  Optimization terminated successfully.
# 6   Optimization terminated successfully.
# 29  Optimization terminated successfully.
# 18  Optimization terminated successfully.
# 17  Optimization terminated successfully.
# 13  Optimization terminated successfully.
# 14  Optimization terminated successfully.
# 15  Optimization terminated successfully.
# 7   Optimization terminated successfully.
# 2   Optimization terminated successfully.
# 10  Optimization terminated successfully.
# 9   Optimization terminated successfully.
# 12  Optimization terminated successfully.
# 23  Optimization terminated successfully.
# 4   Optimization terminated successfully.
# 8   Optimization terminated successfully.
# 5   Optimization terminated successfully.
# 25  Optimization terminated successfully.
# 27  Optimization terminated successfully.
# 16  Optimization terminated successfully.
#
#                                                     x  \
# 22  [0.3363452600797677, 1.709114313940315, 0.5, 0...
# 20  [0.33648858058818926, 1.7090973503773785, 0.49...
# 19  [0.3362767210061065, 1.7091070979536633, 0.5, ...
# 21  [0.3363487655537259, 1.7091294459893662, 0.499...
# 0   [0.33565377288562814, 1.7091447820572285, 0.49...
# 11  [0.3368255596118912, 1.7090673782548786, 0.499...
# 24  [0.33764139134135523, 1.7095730318473303, 0.49...
# 26  [0.5701086566819031, 1.6524222136838609, 0.031...
# 1   [0.780839035094927, 1.6320160108850708, 0.0028...
# 3   [0.05000000000000037, 1.6978744089111641, 0.5,...
# 28  [1.2204277271404274, 1.0769136334027984, 0.048...
# 6   [1.21739356030941, 1.080316558754427, 0.049807...
# 29  [1.178388400968582, 1.128777374263247, 0.07700...
# 18  [1.1668000173033186, 1.141879572917557, 0.0913...
# 17  [1.1151542948661501, 1.240205897516959, 0.1710...
# 13  [1.1178349111432087, 1.2484447212668788, 0.167...
# 14  [1.1211178800556927, 1.2479561880022914, 0.161...
# 15  [1.7826744006663173, 0.050000000000000044, 0.0...
# 7   [1.788597076044033, 0.05000000000000007, 0.001...
# 2                [1.78863126363021, 0.05, 0.001, 0.5]
# 10  [0.050000000000000044, 0.05, 0.228410536397314...
# 9   [0.05, 0.05000000000000002, 0.1603007696952133...
# 12  [0.05177057936131134, 0.05617908830531859, 0.1...
# 23  [0.06465926446237341, 0.05, 0.001, 0.109031362...
# 4   [0.09151846484894544, 0.05, 0.001, 0.004808197...
# 8   [0.050000000000000044, 0.05, 0.484207571810370...
# 5   [0.05000000000000002, 0.05, 0.2785376304307052...
# 25              [0.05, 0.05, 0.4069314238166195, 0.5]
# 27  [0.05, 0.059897745160685134, 0.208335722508555...
# 16  [0.05, 0.05, 0.48681004345158163, 0.2160085986...
#
#                                         final_simplex
# 22  ([[0.3363452600797677, 1.709114313940315, 0.5,...
# 20  ([[0.33648858058818926, 1.7090973503773785, 0....
# 19  ([[0.3362767210061065, 1.7091070979536633, 0.5...
# 21  ([[0.3363487655537259, 1.7091294459893662, 0.4...
# 0   ([[0.33565377288562814, 1.7091447820572285, 0....
# 11  ([[0.3368255596118912, 1.7090673782548786, 0.4...
# 24  ([[0.33764139134135523, 1.7095730318473303, 0....
# 26  ([[0.5701086566819031, 1.6524222136838609, 0.0...
# 1   ([[0.780839035094927, 1.6320160108850708, 0.00...
# 3   ([[0.05000000000000037, 1.6978744089111641, 0....
# 28  ([[1.2204277271404274, 1.0769136334027984, 0.0...
# 6   ([[1.21739356030941, 1.080316558754427, 0.0498...
# 29  ([[1.178388400968582, 1.128777374263247, 0.077...
# 18  ([[1.1668000173033186, 1.141879572917557, 0.09...
# 17  ([[1.1151542948661501, 1.240205897516959, 0.17...
# 13  ([[1.1178349111432087, 1.2484447212668788, 0.1...
# 14  ([[1.1211178800556927, 1.2479561880022914, 0.1...
# 15  ([[1.7826744006663173, 0.050000000000000044, 0...
# 7   ([[1.788597076044033, 0.05000000000000007, 0.0...
# 2   ([[1.78863126363021, 0.05, 0.001, 0.5], [1.788...
# 10  ([[0.050000000000000044, 0.05, 0.2284105363973...
# 9   ([[0.05, 0.05000000000000002, 0.16030076969521...
# 12  ([[0.05177057936131134, 0.05617908830531859, 0...
# 23  ([[0.06465926446237341, 0.05, 0.001, 0.1090313...
# 4   ([[0.09151846484894544, 0.05, 0.001, 0.0048081...
# 8   ([[0.050000000000000044, 0.05, 0.4842075718103...
# 5   ([[0.05000000000000002, 0.05, 0.27853763043070...
# 25  ([[0.05, 0.05, 0.4069314238166195, 0.5], [0.05...
# 27  ([[0.05, 0.059897745160685134, 0.2083357225085...
# 16  ([[0.05, 0.05, 0.48681004345158163, 0.21600859...

# %% [markdown]
# #  DE fit

# %%
_c = next(read_from_pickle(f"ff/{ffpkl}"))

# %%
fit_repeat(_c, 
           30, 
           "test",
           bounds = DE_bound,
           loss="jax_de",
           quiet='true'
          )
# Out:
# /home/boittier/Documents/phd/ff_energy/ff_energy/ffe/ff_fit.py:174: OptimizeWarning: Unknown solver options: pgtol
#   res = minimize(

# %%
pd.DataFrame(_c.opt_results).sort_values("fun")
# Out:
#            fun   nit  nfev  status  success  \
# 22   64.006554  1529  2446       0     True
# 18   64.146347   716  1191       0     True
# 19   64.238991  1377  2211       0     True
# 4    64.252182   700  1156       0     True
# 27   64.278114  1093  1794       0     True
# 26   64.435455   890  1479       0     True
# 11   64.454987  1524  2418       0     True
# 25   64.479630   834  1392       0     True
# 20   64.629883  1200  1924       0     True
# 16   64.702591   469   806       0     True
# 2    64.773666  1216  1938       0     True
# 7    64.918037   813  1340       0     True
# 15   65.168953   797  1287       0     True
# 8    65.169815   847  1361       0     True
# 1    65.519447   871  1418       0     True
# 12   65.530800   982  1602       0     True
# 24   67.384033   749  1259       0     True
# 23   72.953453   611   997       0     True
# 5    72.958702   763  1275       0     True
# 17   74.276329   291   552       0     True
# 13   87.629227   531   891       0     True
# 14   92.817909  1015  1637       0     True
# 0   229.856552    64   220       0     True
# 28  229.856552    37   194       0     True
# 10  229.856552    53   218       0     True
# 9   229.856552    53   218       0     True
# 6   229.856552    53   212       0     True
# 3   229.856552    56   213       0     True
# 21  229.856552    55   213       0     True
# 29  229.856552    45   199       0     True
#
#                                   message  \
# 22  Optimization terminated successfully.
# 18  Optimization terminated successfully.
# 19  Optimization terminated successfully.
# 4   Optimization terminated successfully.
# 27  Optimization terminated successfully.
# 26  Optimization terminated successfully.
# 11  Optimization terminated successfully.
# 25  Optimization terminated successfully.
# 20  Optimization terminated successfully.
# 16  Optimization terminated successfully.
# 2   Optimization terminated successfully.
# 7   Optimization terminated successfully.
# 15  Optimization terminated successfully.
# 8   Optimization terminated successfully.
# 1   Optimization terminated successfully.
# 12  Optimization terminated successfully.
# 24  Optimization terminated successfully.
# 23  Optimization terminated successfully.
# 5   Optimization terminated successfully.
# 17  Optimization terminated successfully.
# 13  Optimization terminated successfully.
# 14  Optimization terminated successfully.
# 0   Optimization terminated successfully.
# 28  Optimization terminated successfully.
# 10  Optimization terminated successfully.
# 9   Optimization terminated successfully.
# 6   Optimization terminated successfully.
# 3   Optimization terminated successfully.
# 21  Optimization terminated successfully.
# 29  Optimization terminated successfully.
#
#                                                     x  \
# 22  [0.7661736777352766, 1.793422267153345, 0.0072...
# 18  [0.708550206108238, 1.870398196740937, 0.01867...
# 19  [0.6402074680623937, 1.7583959918779957, 0.015...
# 4   [0.8074746717510015, 1.863499031260523, 0.0093...
# 27  [0.5136862024350111, 1.8655855487626287, 0.079...
# 26  [1.582311573045965, 1.2398737678604863, 0.0050...
# 11  [1.6454901773588768, 1.1996559959219373, 0.003...
# 25  [1.6455885810505417, 1.195172891091278, 0.0031...
# 20  [0.31876743449820355, 1.9887934439092754, 0.44...
# 16  [0.5924055876414647, 1.7204697771019293, 0.018...
# 2   [0.40822731952380464, 2.0713449182211923, 0.20...
# 7   [1.8215083667524623, 1.0606594119846302, 0.001...
# 15  [0.3735703280165673, 1.622507194842727, 0.5, 0...
# 8   [0.37388300479181164, 1.6222147775942897, 0.49...
# 1   [0.714954444062945, 1.6602451058330483, 0.0072...
# 12  [1.6751482234813322, 1.0912759205422753, 0.002...
# 24  [0.8306940926987035, 1.751436975127381, 0.0100...
# 23  [0.27909265870547073, 1.8769737665717587, 0.49...
# 5   [0.27436302453646455, 1.8761993591861155, 0.49...
# 17  [1.0216467291286855, 1.139065343605943, 0.4076...
# 13  [1.4176058795742892, 1.6152139389419995, 0.062...
# 14  [2.5, 1.856325496629803, 0.0010001813067751792...
# 0   [0.10937911496922434, 0.40025641046795474, 0.4...
# 28  [0.15927566528050063, 0.22678656907157702, 0.4...
# 10  [0.05, 0.30452598002771203, 0.1884932101769452...
# 9   [0.3262242635797783, 0.057294502745139975, 0.0...
# 6   [0.3072128638733487, 0.05, 0.001, 0.2428670651...
# 3   [0.061849395575203026, 0.3592739973241268, 0.4...
# 21  [0.05, 0.32172301536091785, 0.3181365960554814...
# 29  [0.08167868562021616, 0.21707942091356047, 0.1...
#
#                                         final_simplex
# 22  ([[0.7661736777352766, 1.793422267153345, 0.00...
# 18  ([[0.708550206108238, 1.870398196740937, 0.018...
# 19  ([[0.6402074680623937, 1.7583959918779957, 0.0...
# 4   ([[0.8074746717510015, 1.863499031260523, 0.00...
# 27  ([[0.5136862024350111, 1.8655855487626287, 0.0...
# 26  ([[1.582311573045965, 1.2398737678604863, 0.00...
# 11  ([[1.6454901773588768, 1.1996559959219373, 0.0...
# 25  ([[1.6455885810505417, 1.195172891091278, 0.00...
# 20  ([[0.31876743449820355, 1.9887934439092754, 0....
# 16  ([[0.5924055876414647, 1.7204697771019293, 0.0...
# 2   ([[0.40822731952380464, 2.0713449182211923, 0....
# 7   ([[1.8215083667524623, 1.0606594119846302, 0.0...
# 15  ([[0.3735703280165673, 1.622507194842727, 0.5,...
# 8   ([[0.37388300479181164, 1.6222147775942897, 0....
# 1   ([[0.714954444062945, 1.6602451058330483, 0.00...
# 12  ([[1.6751482234813322, 1.0912759205422753, 0.0...
# 24  ([[0.8306940926987035, 1.751436975127381, 0.01...
# 23  ([[0.27909265870547073, 1.8769737665717587, 0....
# 5   ([[0.27436302453646455, 1.8761993591861155, 0....
# 17  ([[1.0216467291286855, 1.139065343605943, 0.40...
# 13  ([[1.4176058795742892, 1.6152139389419995, 0.0...
# 14  ([[2.5, 1.856325496629803, 0.00100018130677517...
# 0   ([[0.10937911496922434, 0.40025641046795474, 0...
# 28  ([[0.15927566528050063, 0.22678656907157702, 0...
# 10  ([[0.05, 0.30452598002771203, 0.18849321017694...
# 9   ([[0.3262242635797783, 0.057294502745139975, 0...
# 6   ([[0.3072128638733487, 0.05, 0.001, 0.24286706...
# 3   ([[0.061849395575203026, 0.3592739973241268, 0...
# 21  ([[0.05, 0.32172301536091785, 0.31813659605548...
# 29  ([[0.08167868562021616, 0.21707942091356047, 0...
