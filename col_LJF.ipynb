# %% [markdown]
# #  Ideas for fitting code:
#
# - pickle all FF objects

# %%
# %load_ext autoreload
# %autoreload 2

from ff_energy.cli import load_config_maker, load_all_theory, charmm_jobs

# from ff_energy.structure import
from ff_energy.potential import FF, LJ
import numpy as np
from ff_energy.data import Data, plot_ecol, plot_intE, plot_LJintE
import matplotlib.pyplot as plt
import pickle
from pathlib import Path
import pandas as pd
from ff_energy.utils import pickle_output, read_from_pickle
from ff_energy.data import Data

sig_bound = (0.05, 4.0)
ep_bound = (0.00001, 1.0)
LJ_bound = [(sig_bound), (sig_bound), (ep_bound), (ep_bound)]
# Out:
# atom_key_pairs [('CG331', 'CG331'), ('CG331', 'HGA3'), ('CG331', 'HGP1'), ('CG331', 'HT'), ('CG331', 'OG311'), ('CG331', 'OT'), ('HGA3', 'HGA3'), ('HGA3', 'HGP1'), ('HGA3', 'HT'), ('HGA3', 'OG311'), ('HGA3', 'OT'), ('HGP1', 'HGP1'), ('HGP1', 'HT'), ('HGP1', 'OG311'), ('HGP1', 'OT'), ('HT', 'HT'), ('HT', 'OG311'), ('HT', 'OT'), ('OG311', 'OG311'), ('OG311', 'OT'), ('OT', 'OT')]
# 0 ('CG331', 'CG331')
# 1 ('CG331', 'HGA3')
# 2 ('CG331', 'HGP1')
# 3 ('CG331', 'HT')
# 4 ('CG331', 'OG311')
# 5 ('CG331', 'OT')
# 6 ('HGA3', 'HGA3')
# 7 ('HGA3', 'HGP1')
# 8 ('HGA3', 'HT')
# 9 ('HGA3', 'OG311')
# 10 ('HGA3', 'OT')
# 11 ('HGP1', 'HGP1')
# 12 ('HGP1', 'HT')
# 13 ('HGP1', 'OG311')
# 14 ('HGP1', 'OT')
# 15 ('HT', 'HT')
# 16 ('HT', 'OG311')
# 17 ('HT', 'OT')
# 18 ('OG311', 'OG311')
# 19 ('OG311', 'OT')
# 20 ('OT', 'OT')

# %%
FUNC = LJ
BOUNDS = LJ_bound
ff_name = "pbe0dz_ecol"
structure = "water_cluster"
pk = "pickles/water_cluster/pbe0dz/pbe0_dz.mdcm"


#########################################################

ff_pkls = Path("pickles/ff")
ff_pickles = ff_pkls.glob("*.pkl")
ff_pickles = [_.name for _ in ff_pickles]
struct_dist_pkls = Path("pickles/structures")
struct_dist_pickles = struct_dist_pkls.glob("*.pkl")
struct_dist_pickles = [_.name for _ in struct_dist_pickles]


pickled_ff = (ff_pkls / f"{ff_name}.pkl").exists()
pickled_dists = (struct_dist_pkls / f"{structure}.pkl").exists()
pickled_ff = False

if pickled_ff:
    print("Pickled FF exists!, loading: ", ff_pkls / f"{ff_name}.pkl")
    try:
        ff = next(read_from_pickle(ff_pkls / f"{ff_name}.pkl"))
    except StopIteration:
        print("Pickle read failed.")
        pickled_ff = False

if not pickled_ff:
    if pickled_dists:
        print("loading pickled distances/structure")
        structures, dists = next(
            read_from_pickle(f"pickles/structures/{structure}.pkl")
        )
    else:
        print("No pickled distances/structure information, calculating:")
        CMS = load_config_maker("pbe0dz", structure, "mdcm")
        jobs = charmm_jobs(CMS)
        dists = {_.name.split(".")[0]: _.distances for _ in jobs[0].structures}
        structures = [_ for _ in jobs[0].structures]
        pickle_output((structures, dists), name=f"structures/{structure}")

    s = structures[0]
    data_ = Data(pk)
    ff = FF(data_.data, dists, FUNC, BOUNDS, s, elec="ECOL")

# d = ff.data_save.sample(200)
# ff.data = d.copy()
args = [1.7682, 0.2245, -0.1521, -0.0460]
# Out:
# loading pickled distances/structure
# loading pickles from  pickles/water_cluster/pbe0dz/pbe0_dz.mdcm
# [('HT', 'HT'), ('HT', 'OT'), ('OT', 'OT')]
# 0 ('HT', 'HT') ('HT', 'HT')
# 1 ('HT', 'OT') ('HT', 'OT')
# 2 ('OT', 'OT') ('OT', 'OT')

# %%
print(len(ff.dists["test0"][15]))
print(len(ff.dists["test0"][17]))
print(len(ff.dists["test0"][20]))
# Out:
# 190
# 380
# 190

# %%
# ff.data = ff.data_save
ff.data
# Out:
#                ECOL      KEY     TOTAL       ELEC       VDW      KEY  \
# test467 -113.436686  test467  21.39109  -81.32190  14.82881  test467
# test263         NaN  test263  19.20382 -122.03878  20.54380  test263
# test35          NaN   test35  22.25853 -100.65197  11.05221   test35
# test223         NaN  test223  22.62790  -61.61795   6.72946  test223
# test254         NaN  test254  22.63732 -124.82730  21.85417  test254
# ...             ...      ...       ...        ...       ...      ...
# test100 -120.244324  test100  22.94489 -100.52188  19.45476  test100
# test304         NaN  test304  20.88239 -105.35181  17.28253  test304
# test327         NaN  test327  19.07727 -157.43693  31.12436  test327
# test185 -114.232038  test185  23.27487  -91.75524  11.20177  test185
# test66          NaN   test66  24.24590 -111.11872  14.43453   test66
#
#             M_ENERGY      KEY  n_monomers     C_ENERGY  n_pairs       intE  \
# test467 -1527.154217  test467          20 -1527.236629      190 -51.714066
# test263 -1527.156016  test263          20 -1527.258259      190 -64.157783
# test35  -1527.143158   test35          20 -1527.258584      189 -72.430230
# test223 -1527.147556  test223          20 -1527.203106      190 -34.857221
# test254 -1527.135568  test254          20 -1527.237145      188 -63.739697
# ...              ...      ...         ...          ...      ...        ...
# test100 -1527.141372  test100          20 -1527.210157      190 -43.162995
# test304 -1527.150985  test304          20 -1527.239633      189 -55.626955
# test327 -1527.154084  test327          20 -1527.300559      190 -91.913853
# test185 -1527.144999  test185          20 -1527.232387      190 -54.835874
# test66  -1527.133226   test66          20 -1527.251024      190 -73.918366
#
#             P_intE
# test467 -50.297664
# test263 -66.601357
# test35  -65.790457
# test223 -39.243367
# test254 -57.830990
# ...            ...
# test100 -42.125801
# test304 -54.710834
# test327 -79.340573
# test185 -54.451833
# test66  -68.441739
#
# [500 rows x 13 columns]

# %%
for i in range(1):
    # d = ff.data_save.sample(100)
    # ff.data = d.copy()
    print(len(ff.data))
    _ = ff.LJ_performace(ff.eval_func(args))
    print(_.keys())
    print(len(_.keys()))
    # _["nb_intE"] = _["NBONDS"]
    plot_intE(_)
    print(_["SE"].mean())
_
# Out:
# 500
# Index(['ECOL', 'KEY', 'TOTAL', 'ELEC', 'VDW', 'KEY', 'M_ENERGY', 'KEY',
#        'n_monomers', 'C_ENERGY', 'n_pairs', 'intE', 'P_intE', 'LJ',
#        'VDW_ERROR', 'VDW_SE', 'nb_intE', 'SE'],
#       dtype='object')
# 18
# 1964040.984426641
#                ECOL      KEY     TOTAL       ELEC       VDW      KEY  \
# test467 -113.436686  test467  21.39109  -81.32190  14.82881  test467
# test263         NaN  test263  19.20382 -122.03878  20.54380  test263
# test35          NaN   test35  22.25853 -100.65197  11.05221   test35
# test223         NaN  test223  22.62790  -61.61795   6.72946  test223
# test254         NaN  test254  22.63732 -124.82730  21.85417  test254
# ...             ...      ...       ...        ...       ...      ...
# test100 -120.244324  test100  22.94489 -100.52188  19.45476  test100
# test304         NaN  test304  20.88239 -105.35181  17.28253  test304
# test327         NaN  test327  19.07727 -157.43693  31.12436  test327
# test185 -114.232038  test185  23.27487  -91.75524  11.20177  test185
# test66          NaN   test66  24.24590 -111.11872  14.43453   test66
#
#             M_ENERGY      KEY  n_monomers     C_ENERGY  n_pairs       intE  \
# test467 -1527.154217  test467          20 -1527.236629      190 -51.714066
# test263 -1527.156016  test263          20 -1527.258259      190 -64.157783
# test35  -1527.143158   test35          20 -1527.258584      189 -72.430230
# test223 -1527.147556  test223          20 -1527.203106      190 -34.857221
# test254 -1527.135568  test254          20 -1527.237145      188 -63.739697
# ...              ...      ...         ...          ...      ...        ...
# test100 -1527.141372  test100          20 -1527.210157      190 -43.162995
# test304 -1527.150985  test304          20 -1527.239633      189 -55.626955
# test327 -1527.154084  test327          20 -1527.300559      190 -91.913853
# test185 -1527.144999  test185          20 -1527.232387      190 -54.835874
# test66  -1527.133226   test66          20 -1527.251024      190 -73.918366
#
#             P_intE           LJ    VDW_ERROR        VDW_SE    nb_intE  \
# test467 -50.297664   832.552732  -817.723922  6.686724e+05  -66.49309
# test263 -66.601357  1825.169285 -1804.625485  3.256673e+06 -101.49498
# test35  -65.790457  1225.646245 -1214.594035  1.475239e+06  -89.59976
# test223 -39.243367   540.155143  -533.425683  2.845430e+05  -54.88849
# test254 -57.830990   939.509853  -917.655683  8.420920e+05 -102.97313
# ...            ...          ...          ...           ...        ...
# test100 -42.125801   738.242443  -718.787683  5.166557e+05  -81.06712
# test304 -54.710834   806.843518  -789.560988  6.234066e+05  -88.06928
# test327 -79.340573  1617.443464 -1586.319104  2.516408e+06 -126.31257
# test185 -54.451833  1451.639668 -1440.437898  2.074861e+06  -80.55347
# test66  -68.441739   973.465745  -959.031215  9.197409e+05  -96.68419
#
#                    SE
# test467  5.941791e+05
# test263           NaN
# test35            NaN
# test223           NaN
# test254           NaN
# ...               ...
# test100  4.371340e+05
# test304           NaN
# test327           NaN
# test185  1.938342e+06
# test66            NaN
#
# [500 rows x 18 columns]

# %%
_["VDW_ERROR"].mean()
# Out:
# -1172.1573968698467

# %%
# ff.data = ff.data_save.dropna()
# d

# %%
ff.opt_results, ff.opt_results_df = [], []

for i in range(10):
    d = ff.data_save.dropna()
    # d = d[d["ECOL"] < -40]
    d = d.sample(100)
    ff.data = d.copy()
    ff.fit_repeat(1, bounds=LJ_bound)
pickle_output(ff, "ff/pbe0dz_ecol")
# Out:
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.05, 4.0), (0.05, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [2.4529503354176128, 0.7742418170303464, 0.9373820133758267, 0.7865087154308569]
# final_loss_fn:  5563.055817584901
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 5563.055817584901
#              x: [ 5.000e-02  5.000e-02  1.000e+00  1.000e-05]
#            nit: 100
#           nfev: 147
#  final_simplex: (array([[ 5.000e-02,  5.000e-02,  1.000e+00,  1.000e-05],
#                        [ 5.000e-02,  5.000e-02,  1.000e+00,  1.000e-05],
#                        ...,
#                        [ 5.000e-02,  5.000e-02,  1.000e+00,  1.000e-05],
#                        [ 5.000e-02,  5.000e-02,  1.000e+00,  1.000e-05]]), array([ 5.563e+03,  5.563e+03,  5.563e+03,  5.563e+03,
#                         5.563e+03]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Set optimized parameters to FF object, use FF.opt_parm to get the optimized parameters
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.05, 4.0), (0.05, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [3.7815187933046346, 1.3807278582079126, 0.6415737866660306, 0.18345233123022622]
# final_loss_fn:  20.25724495250401
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 20.25724495250401
#              x: [ 5.000e-02  3.039e+00  7.470e-03  3.170e-04]
#            nit: 2652
#           nfev: 4351
#  final_simplex: (array([[ 5.000e-02,  3.039e+00,  7.470e-03,  3.170e-04],
#                        [ 5.000e-02,  3.039e+00,  7.470e-03,  3.170e-04],
#                        ...,
#                        [ 5.000e-02,  3.039e+00,  7.470e-03,  3.170e-04],
#                        [ 5.000e-02,  3.039e+00,  7.470e-03,  3.170e-04]]), array([ 2.026e+01,  2.026e+01,  2.026e+01,  2.026e+01,
#                         2.026e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Set optimized parameters to FF object, use FF.opt_parm to get the optimized parameters
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.05, 4.0), (0.05, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [0.8352336571561505, 3.6732499845751043, 0.13260383611890988, 0.4999514235871992]
# final_loss_fn:  770.0955555029267
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 770.0955555029267
#              x: [ 2.962e+00  5.000e-02  1.000e-05  1.000e+00]
#            nit: 472
#           nfev: 790
#  final_simplex: (array([[ 2.962e+00,  5.000e-02,  1.000e-05,  1.000e+00],
#                        [ 2.962e+00,  5.000e-02,  1.000e-05,  1.000e+00],
#                        ...,
#                        [ 2.962e+00,  5.000e-02,  1.000e-05,  1.000e+00],
#                        [ 2.962e+00,  5.000e-02,  1.000e-05,  1.000e+00]]), array([ 7.701e+02,  7.701e+02,  7.701e+02,  7.701e+02,
#                         7.701e+02]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Set optimized parameters to FF object, use FF.opt_parm to get the optimized parameters
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.05, 4.0), (0.05, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [1.0405813791285274, 0.5089012575989278, 0.7101153616562156, 0.02140156093228069]
# final_loss_fn:  5691.406399421994
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 5691.406399421994
#              x: [ 5.000e-02  5.000e-02  1.000e-05  1.000e-05]
#            nit: 76
#           nfev: 122
#  final_simplex: (array([[ 5.000e-02,  5.000e-02,  1.000e-05,  1.000e-05],
#                        [ 5.000e-02,  5.000e-02,  1.000e-05,  1.000e-05],
#                        ...,
#                        [ 5.000e-02,  5.000e-02,  1.000e-05,  1.000e-05],
#                        [ 5.000e-02,  5.000e-02,  1.000e-05,  1.000e-05]]), array([ 5.691e+03,  5.691e+03,  5.691e+03,  5.691e+03,
#                         5.691e+03]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Set optimized parameters to FF object, use FF.opt_parm to get the optimized parameters
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.05, 4.0), (0.05, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [2.1055123972485443, 3.062317857141076, 0.23219908184057214, 0.7325471590700082]
# final_loss_fn:  5714.170302949776
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 5714.170302949776
#              x: [ 5.000e-02  5.000e-02  1.000e-05  1.000e-05]
#            nit: 60
#           nfev: 91
#  final_simplex: (array([[ 5.000e-02,  5.000e-02,  1.000e-05,  1.000e-05],
#                        [ 5.000e-02,  5.000e-02,  1.000e-05,  1.000e-05],
#                        ...,
#                        [ 5.000e-02,  5.000e-02,  1.000e-05,  1.000e-05],
#                        [ 5.000e-02,  5.000e-02,  1.000e-05,  1.000e-05]]), array([ 5.714e+03,  5.714e+03,  5.714e+03,  5.714e+03,
#                         5.714e+03]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Set optimized parameters to FF object, use FF.opt_parm to get the optimized parameters
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.05, 4.0), (0.05, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [1.2903680503865649, 3.4615636992826038, 0.9267288904870423, 0.6729021514037027]
# final_loss_fn:  19.513950791684707
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 19.513950791684707
#              x: [ 5.000e-02  3.228e+00  4.083e-03  1.500e-04]
#            nit: 3429
#           nfev: 5664
#  final_simplex: (array([[ 5.000e-02,  3.228e+00,  4.083e-03,  1.500e-04],
#                        [ 5.000e-02,  3.228e+00,  4.083e-03,  1.500e-04],
#                        ...,
#                        [ 5.000e-02,  3.228e+00,  4.083e-03,  1.500e-04],
#                        [ 5.000e-02,  3.228e+00,  4.083e-03,  1.500e-04]]), array([ 1.951e+01,  1.951e+01,  1.951e+01,  1.951e+01,
#                         1.951e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Set optimized parameters to FF object, use FF.opt_parm to get the optimized parameters
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.05, 4.0), (0.05, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [0.07881017081387108, 0.3525377483878334, 0.8378085676127509, 0.8381378297254075]
# final_loss_fn:  5560.530718067338
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 5560.530718067338
#              x: [ 5.000e-02  5.000e-02  1.000e+00  1.000e-05]
#            nit: 53
#           nfev: 78
#  final_simplex: (array([[ 5.000e-02,  5.000e-02,  1.000e+00,  1.000e-05],
#                        [ 5.000e-02,  5.000e-02,  1.000e+00,  1.000e-05],
#                        ...,
#                        [ 5.000e-02,  5.000e-02,  1.000e+00,  1.000e-05],
#                        [ 5.000e-02,  5.000e-02,  1.000e+00,  1.000e-05]]), array([ 5.561e+03,  5.561e+03,  5.561e+03,  5.561e+03,
#                         5.561e+03]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Set optimized parameters to FF object, use FF.opt_parm to get the optimized parameters
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.05, 4.0), (0.05, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [2.7137569193588433, 2.8360692920211403, 0.6511833700892743, 0.9522484622752622]
# final_loss_fn:  19.503188278933735
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 19.503188278933735
#              x: [ 5.000e-02  2.520e+00  6.186e-02  3.287e-03]
#            nit: 647
#           nfev: 1100
#  final_simplex: (array([[ 5.000e-02,  2.520e+00,  6.186e-02,  3.287e-03],
#                        [ 5.000e-02,  2.520e+00,  6.186e-02,  3.287e-03],
#                        ...,
#                        [ 5.000e-02,  2.520e+00,  6.186e-02,  3.287e-03],
#                        [ 5.000e-02,  2.520e+00,  6.186e-02,  3.287e-03]]), array([ 1.950e+01,  1.950e+01,  1.950e+01,  1.950e+01,
#                         1.950e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Set optimized parameters to FF object, use FF.opt_parm to get the optimized parameters
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.05, 4.0), (0.05, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [2.3308222376753918, 1.2847042734025962, 0.2783057470629683, 0.4496217998656676]
# final_loss_fn:  19.44260285568236
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 19.44260285568236
#              x: [ 5.000e-02  4.000e+00  5.033e-04  1.075e-05]
#            nit: 5305
#           nfev: 8721
#  final_simplex: (array([[ 5.000e-02,  4.000e+00,  5.033e-04,  1.075e-05],
#                        [ 5.000e-02,  4.000e+00,  5.034e-04,  1.075e-05],
#                        ...,
#                        [ 5.000e-02,  4.000e+00,  5.034e-04,  1.075e-05],
#                        [ 5.000e-02,  4.000e+00,  5.034e-04,  1.075e-05]]), array([ 1.944e+01,  1.944e+01,  1.944e+01,  1.944e+01,
#                         1.944e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Set optimized parameters to FF object, use FF.opt_parm to get the optimized parameters
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.05, 4.0), (0.05, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [3.1285980939231397, 1.8849843333940601, 0.3996249740142898, 0.7382428508846632]
# final_loss_fn:  20.057027668140865
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 20.057027668140865
#              x: [ 5.000e-02  4.000e+00  3.878e-04  1.099e-05]
#            nit: 4092
#           nfev: 6676
#  final_simplex: (array([[ 5.000e-02,  4.000e+00,  3.878e-04,  1.099e-05],
#                        [ 5.000e-02,  4.000e+00,  3.879e-04,  1.099e-05],
#                        ...,
#                        [ 5.000e-02,  4.000e+00,  3.878e-04,  1.099e-05],
#                        [ 5.000e-02,  4.000e+00,  3.878e-04,  1.099e-05]]), array([ 2.006e+01,  2.006e+01,  2.006e+01,  2.006e+01,
#                         2.006e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Set optimized parameters to FF object, use FF.opt_parm to get the optimized parameters
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# ---------------------------------------------------------------------------
# PicklingError                             Traceback (most recent call last)
# Cell In[33], line 9
#       7     ff.data = d.copy()
#       8     ff.fit_repeat(1, bounds=LJ_bound)
# ----> 9 pickle_output(ff, "ff/pbe0dz_ecol")
#
# File ~/Documents/phd/ff_energy/ff_energy/utils.py:12, in pickle_output(output, name)
#      10 pickle_path.parents[0].mkdir(parents=True, exist_ok=True)
#      11 with open(pickle_path, 'wb') as handle:
# ---> 12     pickle.dump(output, handle,
#      13                 protocol=pickle.HIGHEST_PROTOCOL)
#
# PicklingError: Can't pickle <function LJ at 0x7f26b2385b80>: it's not the same object as ff_energy.potential.LJ

# %%
pd.DataFrame(ff.opt_results)
# Out:
#             fun   nit  nfev  status  success  \
# 0     94.809071   119   219       0     True
# 1   5374.279809    41    67       0     True
# 2     22.871527   404   682       0     True
# 3     20.962515  2719  4487       0     True
# 4     94.809071   695  1159       0     True
# ..          ...   ...   ...     ...      ...
# 95    21.038704  3888  6392       0     True
# 96  5591.492347    34    56       0     True
# 97    21.050103  3542  5832       0     True
# 98  5591.492250    57    88       0     True
# 99  5591.492347    33    52       0     True
#
#                                   message  \
# 0   Optimization terminated successfully.
# 1   Optimization terminated successfully.
# 2   Optimization terminated successfully.
# 3   Optimization terminated successfully.
# 4   Optimization terminated successfully.
# ..                                    ...
# 95  Optimization terminated successfully.
# 96  Optimization terminated successfully.
# 97  Optimization terminated successfully.
# 98  Optimization terminated successfully.
# 99  Optimization terminated successfully.
#
#                                                     x  \
# 0   [2.5748653360448657, 0.7695376694099813, 1.000...
# 1   [0.05000000000000002, 0.05000000000000002, 1.0...
# 2   [0.05000000000000001, 2.0588148532573323, 1.00...
# 3   [0.050000000005096246, 3.0167985210359785, 0.0...
# 4   [2.574865222435305, 0.7695376893979486, 1.0000...
# ..                                                ...
# 95  [0.483896304403413, 3.9999990564050925, 2.9461...
# 96  [0.05000000000000002, 0.05000000000000002, 1.0...
# 97  [0.0500000000000001, 4.0, 0.000337597783375017...
# 98  [0.05, 0.05000000000000021, 1.0000000000000023...
# 99  [0.05000000000000002, 0.05000000000000002, 1.0...
#
#                                         final_simplex
# 0   ([[2.5748653360448657, 0.7695376694099813, 1.0...
# 1   ([[0.05000000000000002, 0.05000000000000002, 1...
# 2   ([[0.05000000000000001, 2.0588148532573323, 1....
# 3   ([[0.050000000005096246, 3.0167985210359785, 0...
# 4   ([[2.574865222435305, 0.7695376893979486, 1.00...
# ..                                                ...
# 95  ([[0.483896304403413, 3.9999990564050925, 2.94...
# 96  ([[0.05000000000000002, 0.05000000000000002, 1...
# 97  ([[0.0500000000000001, 4.0, 0.0003375977833750...
# 98  ([[0.05, 0.05000000000000021, 1.00000000000000...
# 99  ([[0.05000000000000002, 0.05000000000000002, 1...
#
# [100 rows x 8 columns]

# %%
print(len(ff.data))
# plot_intE(ff.get_best_df())
# Out:
# 100

# %%
results = pd.DataFrame(ff.opt_results)
best_func = results.sort_values("fun")[:10]
best_func
# Out:
#           fun   nit   nfev  status  success  \
# 35  19.000282  1919   3146       0     True
# 38  19.000282   899   1499       0     True
# 39  19.415310  1533   2545       0     True
# 31  19.428249  1317   2169       0     True
# 10  19.555742  6101  10000       1    False
# 19  19.560546  5636   9220       0     True
# 76  19.605841   994   1678       0     True
# 72  19.666737  1787   2956       0     True
# 73  19.831367  2118   3504       0     True
# 64  20.248954  3299   5417       0     True
#
#                                               message  \
# 35              Optimization terminated successfully.
# 38              Optimization terminated successfully.
# 39              Optimization terminated successfully.
# 31              Optimization terminated successfully.
# 10  Maximum number of function evaluations has bee...
# 19              Optimization terminated successfully.
# 76              Optimization terminated successfully.
# 72              Optimization terminated successfully.
# 73              Optimization terminated successfully.
# 64              Optimization terminated successfully.
#
#                                                     x  \
# 35  [1.1688245967467719, 2.228942247561765, 1.0000...
# 38  [1.1688245588762665, 2.2289422172939286, 1.000...
# 39  [0.07079070930960127, 2.530358737608696, 0.041...
# 31  [0.05000000000032233, 2.562995809690322, 0.045...
# 10  [0.2725351260150719, 3.9401407477711388, 8.943...
# 19  [0.05000000157984729, 4.0, 0.00027673993034830...
# 76  [1.2093336514091215, 2.316220286908931, 1.0000...
# 72  [1.19538582555858, 2.539361644939886, 1.000000...
# 73  [0.05000000000121298, 2.801408054744151, 0.023...
# 64  [0.2210142106959431, 3.1725625290553916, 0.001...
#
#                                         final_simplex
# 35  ([[1.1688245967467719, 2.228942247561765, 1.00...
# 38  ([[1.1688245588762665, 2.2289422172939286, 1.0...
# 39  ([[0.07079070930960127, 2.530358737608696, 0.0...
# 31  ([[0.05000000000032233, 2.562995809690322, 0.0...
# 10  ([[0.2725351260150719, 3.9401407477711388, 8.9...
# 19  ([[0.05000000157984729, 4.0, 0.000276739930348...
# 76  ([[1.2093336514091215, 2.316220286908931, 1.00...
# 72  ([[1.19538582555858, 2.539361644939886, 1.0000...
# 73  ([[0.05000000000121298, 2.801408054744151, 0.0...
# 64  ([[0.2210142106959431, 3.1725625290553916, 0.0...

# %%
x = best_func["x"]
values = []

for _ in x:
    epsig = ["$\sigma$", "$\epsilon$"]
    names = []
    for es in epsig:
        for at in ff.atom_types:
            names.append(at + es)
    values.append({names[i]: _[i] for i in range(len(_))})


values = pd.DataFrame(values)
values["rmse"] = best_func["fun"]

# values.plot("rmse")

# %%
test_ = []
train_ = []
args_ = []
dfs_ = []

for res, data in zip(ff.opt_results, ff.opt_results_df):
    if res["fun"] < 20:
        test_keys = [_ for _ in list(ff.data_save.index) if _ not in data.index]
        test_df = ff.data_save.query("index in @test_keys")
        ff.data = test_df.dropna().copy()
        test_len = len(ff.data)
        test_res = ff.LJ_performace(ff.eval_func(res.x))

        # fig, ax = plt.subplots(1,3,figsize=(15,15))
        fig, ax = plt.subplot_mosaic([[0, 1], [2, 2]], figsize=(10, 7))

        plot_LJintE(test_res, ax=ax[0])

        ff.data = ff.data_save.query("index not in @test_keys").dropna().copy()
        train_len = len(ff.data)
        train_res = ff.LJ_performace(ff.eval_func(res.x))
        plot_LJintE(train_res, ax=ax[1])
        print(
            "{:.1f} ({}) {:.1f} ({})".format(
                test_res["SE"].mean(), test_len, train_res["SE"].mean(), train_len
            )
        )

        res = res.x
        x = np.arange(0.1, 5, 0.05)
        y = LJ(res[0] * 2, res[2], x)
        ax[2].plot(x, y, c="grey")
        y = LJ(res[1] * 2, res[3], x)
        ax[2].plot(x, y, c="firebrick")
        y = LJ(res[1] + res[1], np.sqrt(res[3] * res[2]), x)
        ax[2].plot(x, y, c="k")

        ax[2].axhline(0, c="k")
        ax[2].set_ylim(-1, 1)
        plt.show()

    test_.append(test_res["SE"].mean())
    train_.append(train_res["SE"].mean())
    args_.append(res)
    dfs_.append(test_res)
# Out:
# 26.7 (18) 19.6 (100)
# 26.7 (18) 19.6 (100)
# 27.0 (18) 19.4 (100)
# 28.1 (18) 19.0 (100)
# 28.1 (18) 19.0 (100)
# 27.1 (18) 19.4 (100)
# 24.6 (18) 19.7 (100)
# 24.9 (18) 19.8 (100)
# 24.8 (18) 19.6 (100)

# %%
# for _ in best_func.iterrows():
#     i, _ = _
#     # print(_)
#     res = _["x"]
#     fun = _["fun"]
#     plt.title(f"{fun} {res}")
#     x = np.arange(0.1,5,0.05)
#     y = LJ(res[0]*2,res[2],x)
#     plt.plot(x, y, c="grey")
#     y = LJ(res[1]*2,res[3],x)
#     plt.plot(x, y, c="firebrick")
#     y = LJ(res[1]+res[1],np.sqrt(res[3]*res[2]),x)
#     plt.plot(x, y, c="k")


#     plt.axhline(0,c="k")
#     plt.ylim(-1,1)
#     plt.show()

# %%
df = pd.DataFrame({"test": test_, "train": train_, "args": args_, "df": dfs_})

# %%
best = df[df["train"] < 35]
# best["test"] = np.sqrt(best["test"])
# best["train"] = np.sqrt(best["train"])
best
# Out:
#          test      train                                               args  \
# 0   25.416309  26.507449  [0.5034362263464525, 2.055311696715542, 0.0028...
# 3   24.618123  26.679160  [1.0797728771126858, 2.0538225742127643, 1.000...
# 5   24.645220  26.722080  [0.6141949734244336, 2.0720173552800727, 0.000...
# 8   24.618123  26.679160  [1.079773090487658, 2.0538210705069204, 1e-05,...
# 9   24.951449  27.107474  [0.5, 1.9877123349914758, 1.0000000000000003e-...
# 13  24.341779  27.929212  [0.5, 1.9657947176660302, 1.0000000000000341e-...
# 16  24.341779  27.929212  [0.5, 1.9657948300415828, 1.0000000000000016e-...
# 17  25.156794  28.093869  [0.6258432366956577, 3.8232148246761435, 2.643...
# 19  24.477932  27.465470  [0.9634967999409443, 1.9632706069085946, 2.380...
# 20  24.385674  27.340309  [0.5422799060961985, 2.064181479237102, 0.0015...
# 22  25.777421  25.742381  [1.130482412970847, 2.011984249361957, 1e-05, ...
# 23  25.807098  25.810700  [0.5028990649686664, 2.037158382169866, 0.0019...
# 26  26.266345  26.753496  [0.5, 3.8262734096638518, 5.180038765950062e-0...
# 32  27.722625  23.741005  [0.5097662719500708, 2.0691180274447185, 0.000...
# 34  27.710793  23.731878  [0.5789633533308591, 2.064795247172892, 0.0003...
# 39  28.366294  24.472547  [0.5000732305113004, 3.8538060574070823, 2.546...
# 42  27.564080  24.243133  [0.6445524911005538, 1.975386711748607, 0.0004...
# 46  27.517389  24.216051  [1.0908203687989249, 1.9649266993145522, 1.000...
# 53  27.790730  24.177612  [0.5000026492605245, 2.3409317671246135, 0.000...
# 55  27.453994  24.041159  [0.5032514433145867, 2.1135637728591394, 0.000...
# 56  27.862410  24.278046  [0.5, 2.023878860827947, 1.000000000000065e-05...
# 57  27.454577  24.041694  [0.5, 2.11377068110563, 0.0008492926024039074,...
# 58  28.344211  24.524733  [0.5, 3.857622403944023, 2.3009445532754616e-0...
# 59  27.450548  24.038023  [0.5228551186808689, 2.1122971058899167, 0.000...
# 60  27.502080  24.052887  [0.5, 2.089946430397567, 0.000579438249701848,...
# 62  28.086123  24.851571  [0.5, 3.828657948307578, 5.19172322124738e-05,...
# 63  28.096944  24.848037  [0.5367174798657881, 3.7348714137127237, 5.382...
# 65  27.184643  24.215457  [1.1658892594689663, 2.061057376179781, 1.0000...
# 66  28.086158  24.851592  [0.5034715071796126, 3.8286516645877917, 5.092...
# 67  27.184644  24.215457  [1.1658895387567072, 2.061057210790246, 1.0000...
# 75  24.631779  26.753862  [0.5000945153242984, 2.0937192427259337, 0.001...
# 76  24.589139  26.698691  [1.0222235716927077, 2.069595217084019, 1.7135...
# 84  22.625140  28.827728  [0.5, 2.1008446190526677, 0.001924304541088469...
# 85  22.641923  28.729552  [1.088607528967967, 2.0140508739360468, 1.0000...
# 87  22.698769  28.778899  [0.5, 2.034012867769502, 0.0014857500869991298...
# 88  23.130961  29.690481  [0.531279638197178, 3.836878026144355, 3.56512...
# 89  22.641930  28.729567  [1.0882223212342028, 2.0140613452984355, 1.003...
# 90  23.129673  29.691215  [0.7792950812243203, 3.809135601138634, 1.0000...
# 91  22.698772  28.778899  [0.5, 2.0340126928860167, 0.001485747975225625...
# 92  29.531668  23.575408  [0.5, 3.836664990230304, 3.878636510168248e-05...
# 94  29.445657  23.058143  [0.5, 1.9723173226156998, 1.0000000000000003e-...
#
#                                                    df
# 0                  ECOL      KEY     TOTAL       E...
# 3                  ECOL      KEY     TOTAL       E...
# 5                  ECOL      KEY     TOTAL       E...
# 8                  ECOL      KEY     TOTAL       E...
# 9                  ECOL      KEY     TOTAL       E...
# 13                ECOL      KEY     TOTAL       EL...
# 16                ECOL      KEY     TOTAL       EL...
# 17                ECOL      KEY     TOTAL       EL...
# 19                ECOL      KEY     TOTAL       EL...
# 20                ECOL      KEY     TOTAL       EL...
# 22                 ECOL      KEY     TOTAL       E...
# 23                 ECOL      KEY     TOTAL       E...
# 26                 ECOL      KEY     TOTAL       E...
# 32                 ECOL      KEY     TOTAL       E...
# 34                 ECOL      KEY     TOTAL       E...
# 39                 ECOL      KEY     TOTAL       E...
# 42                 ECOL      KEY     TOTAL       E...
# 46                 ECOL      KEY     TOTAL       E...
# 53                 ECOL      KEY     TOTAL       E...
# 55                 ECOL      KEY     TOTAL       E...
# 56                 ECOL      KEY     TOTAL       E...
# 57                 ECOL      KEY     TOTAL       E...
# 58                 ECOL      KEY     TOTAL       E...
# 59                 ECOL      KEY     TOTAL       E...
# 60                 ECOL      KEY     TOTAL       E...
# 62                ECOL      KEY     TOTAL       EL...
# 63                ECOL      KEY     TOTAL       EL...
# 65                ECOL      KEY     TOTAL       EL...
# 66                ECOL      KEY     TOTAL       EL...
# 67                ECOL      KEY     TOTAL       EL...
# 75                ECOL      KEY     TOTAL       EL...
# 76                ECOL      KEY     TOTAL       EL...
# 84                ECOL      KEY     TOTAL       EL...
# 85                ECOL      KEY     TOTAL       EL...
# 87                ECOL      KEY     TOTAL       EL...
# 88                ECOL      KEY     TOTAL       EL...
# 89                ECOL      KEY     TOTAL       EL...
# 90                ECOL      KEY     TOTAL       EL...
# 91                ECOL      KEY     TOTAL       EL...
# 92                ECOL      KEY     TOTAL       EL...
# 94                ECOL      KEY     TOTAL       EL...

# %%
best.iloc[0]["df"]
# Out:
#                ECOL      KEY     TOTAL       ELEC       VDW      KEY  \
# test467 -113.436686  test467  21.39109  -81.32190  14.82881  test467
# test263  -16.820533  test263  19.20382 -122.03878  20.54380  test263
# test35   -25.924214   test35  22.25853 -100.65197  11.05221   test35
# test254   -1.846755  test254  22.63732 -124.82730  21.85417  test254
# test478   -8.347594  test478  20.57061 -137.04099  17.44172  test478
# ...             ...      ...       ...        ...       ...      ...
# test191         NaN      NaN  21.63254 -110.06365  20.86924  test191
# test285         NaN      NaN  21.83160 -110.69072  22.43307  test285
# test204         NaN      NaN  17.66112 -129.14115  28.88785  test204
# test486         NaN      NaN  26.64222 -110.79449  25.86481  test486
# test288         NaN      NaN  21.66717 -120.27062  16.90015  test288
#
#             M_ENERGY      KEY  n_monomers     C_ENERGY  n_pairs       intE  \
# test467 -1527.154217  test467          20 -1527.236629      190 -51.714066
# test263 -1527.156016  test263          20 -1527.258259      190 -64.157783
# test35  -1527.143158   test35          20 -1527.258584      189 -72.430230
# test254 -1527.135568  test254          20 -1527.237145      188 -63.739697
# test478 -1527.139702  test478          20 -1527.283906      190 -90.488888
# ...              ...      ...         ...          ...      ...        ...
# test191 -1527.149787  test191          20 -1527.249170      190 -62.362955
# test285 -1527.147466  test285          20 -1527.242580      190 -59.684113
# test204 -1527.157200  test204          20 -1527.272753      190 -72.510080
# test486 -1527.123959  test486          20 -1527.198832      190 -46.983584
# test288 -1527.141466  test288          20 -1527.249875      190 -68.026508
#
#             P_intE         LJ  VDW_ERROR       VDW_SE    nb_intE          SE
# test467 -50.297664  40.255371 -25.426561   646.509989 -41.066529  113.370035
# test263 -66.601357  53.149059 -32.605259  1063.102928 -68.889721   22.391236
# test35  -65.790457  35.329966 -24.277756   589.409453 -65.322004   50.526886
# test254 -57.830990  53.337429 -31.483259   991.195579 -71.489871   60.065209
# test478 -80.561487  47.238588 -29.796868   887.853365 -89.802402    0.471264
# ...            ...        ...        ...          ...        ...         ...
# test191 -62.290388  50.888888 -30.019648   901.179269 -59.174762   10.164575
# test285 -58.592499  53.616376 -31.183306   972.398582 -57.074344    6.810896
# test204 -65.943128  63.417300 -34.529450  1192.282932 -65.723850   46.052921
# test486 -46.456197  58.367343 -32.502533  1056.414625 -52.427147   29.632379
# test288 -67.286499  44.895456 -27.995306   783.737162 -75.375164   54.002739
#
# [300 rows x 18 columns]

# %%
plt.scatter(best["test"], best["train"])
plt.xlabel("Test", fontsize=20)
plt.ylabel("Train", fontsize=20)
# Out:
# Text(0, 0.5, 'Train')

# %%
import matplotlib as mpl
import matplotlib.lines as mlines
import matplotlib.patches as mpatches
import matplotlib.path as mpath
import matplotlib.pyplot as plt

# # Prepare the data for the PathPatch below.
# Path = mpath.Path
# codes, verts = zip(*[
#     (Path.MOVETO, [0.018, -0.11]),
#     (Path.CURVE4, [-0.031, -0.051]),
#     (Path.CURVE4, [-0.115, 0.073]),
#     (Path.CURVE4, [-0.03, 0.073]),
#     (Path.LINETO, [-0.011, 0.039]),
#     (Path.CURVE4, [0.043, 0.121]),
#     (Path.CURVE4, [0.075, -0.005]),
#     (Path.CURVE4, [0.035, -0.027]),
#     (Path.CLOSEPOLY, [0.018, -0.11])])

# artists = [
#     mpatches.Circle((0, 0), 0.1, ec="none"),
#     mpatches.Rectangle((-0.025, -0.05), 0.05, 0.1, ec="none"),
#     mpatches.Wedge((0, 0), 0.1, 30, 270, ec="none"),
#     mpatches.RegularPolygon((0, 0), 5, radius=0.1),
#     mpatches.Ellipse((0, 0), 0.2, 0.1),
#     mpatches.Arrow(-0.05, -0.05, 0.1, 0.1, width=0.1),
#     mpatches.PathPatch(mpath.Path(verts, codes), ec="none"),
#     mpatches.FancyBboxPatch((-0.025, -0.05), 0.05, 0.1, ec="none",
#                             boxstyle=mpatches.BoxStyle("Round", pad=0.02)),
#     mlines.Line2D([-0.06, 0.0, 0.1], [0.05, -0.05, 0.05], lw=5),
# ]

# axs = plt.figure(figsize=(6, 6), layout="constrained").subplots(3, 3)
# for i, (ax, artist) in enumerate(zip(axs.flat, artists)):
#     artist.set(color=mpl.colormaps["hsv"](i / len(artists)))
#     ax.add_artist(artist)
#     ax.set(title=type(artist).__name__,
#            aspect=1, xlim=(-.2, .2), ylim=(-.2, .2))
#     ax.set_axis_off()
# plt.show()

# %%
import seaborn as sns
import matplotlib as mpl

# cmap = sns.color_palette("icefire", as_cmap=True)
# # cmap()
# # cmap = mpl.cm.cool
# norm = mpl.colors.Normalize(vmin=5, vmax=10)

# plt.colorbar(mpl.cm.ScalarMappable(norm=norm, cmap=cmap),
#              cax=ax, orientation='horizontal', label='Some Units')

# %%
# sns.choose_diverging_palette(as_cmap=True)

# %%
# cmap1 = sns.cubehelix_palette(start=.5, rot=-.99, as_cmap=True)
# cmap2 = sns.cubehelix_palette(start=.2, rot=-.99, as_cmap=True)
# cmap1 = sns.color_palette("Blues", as_cmap=True)
# cmap2 = sns.color_palette("Reds", as_cmap=True)
cmap1 = sns.color_palette("light:seagreen", as_cmap=True)
cmap2 = sns.color_palette("dark:blueviolet", as_cmap=True)


fig, ax = plt.subplots(
    1, 3, figsize=(4.5, 4), gridspec_kw={"width_ratios": [3.5, 0.25, 0.25]}
)

plt.subplots_adjust(wspace=0.25)

quarters = [
    (360, 90),
    (90, 180),
    (180, 270),
    (270, 360),
]


def plot_circle(x, y, ax, res):
    # print(res)
    size = 0.2
    quarters = [
        (90, 180),
        (0, 90),
        (180, 270),
        (270, 0),
    ]
    for i, (a, b) in enumerate(quarters):
        move = 0.0
        if i == 1:
            wedge = mpatches.Wedge((x, y), size, a, b)
        elif i == 0:
            wedge = mpatches.Wedge((x, y), size, a, b)
        elif i == 2:
            wedge = mpatches.Wedge((x, y + move), size, a, b)
        else:
            wedge = mpatches.Wedge((x, y + move), size, a, b)
        # wedge.set(color=mpl.colormaps["hsv"](i / 4))
        if i == 0 or i == 1:
            # print(res[i])
            cval = norm2(res[i])
            cmap = cmap2
        else:
            # print(res[i],np.log(res[i]))
            cval = norm1(np.log(res[i]))
            cmap = cmap1
        wedge.set(color=cmap(cval))
        if x < 27:
            wedge.set(alpha=1)
        ax.add_artist(wedge)
        # ax.set(aspect=1, xlim=(-.2, .2), ylim=(-.2, .2))
    return ax


norm1 = mpl.colors.Normalize(vmin=-11, vmax=-1)
norm2 = mpl.colors.Normalize(vmin=0.5, vmax=4)


# plt.scatter(best["test"], best["train"])
ax[0].set_xlabel("Train MSE [kcal/mol]", fontsize=20)
ax[0].set_ylabel("Test MSE [kcal/mol]", fontsize=20)
# plt.colorbar(cmap)
# plt.gca().set_axis_off()
minlim = min([best["test"].min(), best["train"].min()]) - 0.5
maxlim = max([best["test"].max(), best["train"].max()]) + 0.5

plt.colorbar(
    mpl.cm.ScalarMappable(norm=norm2, cmap=cmap2),
    cax=ax[1],
    orientation="vertical",
    label="",
)
plt.colorbar(
    mpl.cm.ScalarMappable(norm=norm1, cmap=cmap1),
    cax=ax[2],
    orientation="vertical",
    label="",
)

for x, y, res in zip(best["train"], best["test"], best["args"]):
    ax[0] = plot_circle(x, y, ax[0], res)

ax[0].set_xlim(minlim, maxlim)
ax[0].set_ylim(minlim, maxlim)
# ax[0].set_ylim(25, 29.5)
ax[0].plot(ax[0].get_xlim(), ax[0].get_ylim(), ls="--", c=".3", alpha=0.5)
# ax[0].grid()
ax[0].set_aspect(1)
plt.savefig("test.pdf", bbox_inches="tight")
plt.show()

# %%
from scipy.stats import bootstrap

rng = np.random.default_rng()


def boot_strap(best_res):
    data = (best_res["SE"],)  # samples must be in a sequence
    res = bootstrap(
        data, np.mean, confidence_level=0.95, random_state=rng, n_resamples=99999
    )
    print([np.sqrt(_) for _ in [data[0].mean(), *res.confidence_interval]])
    print()
    # plt.hist(data)
    # fig, ax = plt.subplots()
    # ax.hist(res.bootstrap_distribution, bins=10)
    # ax.set_title('Bootstrap Distribution')
    # ax.set_xlabel('statistic value')
    # ax.set_ylabel('frequency')
    # plt.show()


for i in range(len(best)):
    print(i, best.iloc[i]["args"])
    best_res = best.iloc[i]["df"]
    boot_strap(best_res)
# Out:
# 0 [2.18863786e+00 5.01979202e-01 1.16221449e-02 1.22542465e-03]
# [5.258061222834217, 4.928240162017293, 5.635217518595031]
#
# 1 [2.05267978e+00 5.00000000e-01 2.92584087e-02 7.26318017e-04]
# [5.250615725798329, 4.919723098726593, 5.629031679447502]
#
# 2 [2.05216402e+00 5.05536295e-01 2.93561785e-02 6.86727574e-04]
# [5.250552365419344, 4.918093328179624, 5.631758994170619]
#
# 3 [2.25556410e+00 5.00000000e-01 7.70712169e-03 1.22067537e-03]
# [5.265355813602289, 4.931998169601272, 5.645641353337261]
#
# 4 [3.82891951e+00 5.50109668e-01 1.05486861e-05 2.31341006e-05]
# [5.318294417937005, 4.984492116330265, 5.702409263123657]
#
# 5 [3.31948549e+00 5.00000000e-01 6.80701626e-05 1.78830950e-05]
# [5.2640102539490705, 4.935025932065009, 5.634261667303115]
#
# 6 [2.14903312e+00 5.00000000e-01 1.66227038e-02 1.00000000e-05]
# [5.193120434580334, 4.870002152641806, 5.56438119335041]
#
# 7 [2.14967099e+00 5.06719922e-01 1.65505576e-02 1.00000000e-05]
# [5.192891077974372, 4.8684860741072695, 5.565759008970995]
#
# 8 [2.14903247e+00 5.00000000e-01 1.66227715e-02 1.00000000e-05]
# [5.193120135217938, 4.87031213407963, 5.562412735518132]
#
# 9 [2.14907843e+00 5.00755104e-01 1.66173338e-02 1.00000000e-05]
# [5.19308187754049, 4.87054982822073, 5.562175586516091]
#
# 10 [2.03729663e+00 8.99782929e-01 3.35742409e-02 1.00000000e-05]
# [5.21820866919735, 4.886723540157217, 5.597831263813462]
#
# 11 [2.03729647e+00 8.99782877e-01 3.35742782e-02 1.00000000e-05]
# [5.218208569045281, 4.885006899608655, 5.598432692556525]
#
# 12 [2.03729640e+00 8.99782689e-01 3.35742975e-02 1.00000000e-05]
# [5.218208698500302, 4.88405407531821, 5.600453454664772]
#
# 13 [3.87272508e+00 5.00000000e-01 1.00000000e-05 1.50426229e-05]
# [5.287440067733616, 4.9546932982441865, 5.663399636798086]
#
# 14 [2.03407664e+00 5.00001362e-01 3.32131981e-02 1.40756168e-03]
# [5.055471802164623, 4.7190402682572365, 5.441210817364099]
#
# 15 [2.37846532e+00 5.00307788e-01 3.81212641e-03 1.35703692e-03]
# [5.099082890323011, 4.763801465697535, 5.48435864725888]
#
# 16 [2.08328126e+00 6.35831920e-01 2.38960886e-02 1.74432513e-04]
# [5.01382864913357, 4.701855453721479, 5.368002999124172]
#
# 17 [2.08512678e+00 1.00370524e+00 2.31715508e-02 1.00000000e-05]
# [5.009932832629857, 4.696885832329761, 5.362838078315093]
#
# 18 [2.09247128e+00 6.07212263e-01 2.24798878e-02 2.30373953e-04]
# [5.0147992771124255, 4.699753996041875, 5.371606136881456]
#
# 19 [2.02632023e+00 5.00000000e-01 3.78111570e-02 1.00000000e-05]
# [5.110602666660246, 4.768018209274944, 5.496386239029981]
#
# 20 [3.86011142e+00 5.00000000e-01 1.00000000e-05 2.16246853e-05]
# [5.146483175845061, 4.8076910484843545, 5.529466024244343]
#
# 21 [2.40119105e+00 5.00000000e-01 3.48922435e-03 7.53323172e-04]
# [5.108347920003258, 4.776411019802928, 5.493225594835618]
#
# 22 [1.93462640e+00 5.00000000e-01 7.48569162e-02 1.00000000e-05]
# [5.200980164285728, 4.862744673190004, 5.583557565624685]
#
# 23 [1.93469762e+00 5.02282737e-01 7.48079176e-02 1.00000000e-05]
# [5.200852818550796, 4.8625018805420925, 5.588646103198913]
#
# 24 [3.84919382e+00 5.00000000e-01 1.00000000e-05 3.00850423e-05]
# [5.158008266541204, 4.826173489373676, 5.5392079077455]
#
# 25 [2.21155480e+00 1.03528020e+00 1.02883503e-02 1.21842681e-05]
# [5.13430208662332, 4.798211657179254, 5.511495563392539]
#
# 26 [2.46087208e+00 5.03777743e-01 2.56936527e-03 6.43596665e-04]
# [5.167826610019207, 4.8340795178933345, 5.5436642857632785]
#
# 27 [3.88299449e+00 5.00000000e-01 1.00000000e-05 1.00000000e-05]
# [5.239859000367323, 4.900596252811563, 5.628763260719957]
#
# 28 [3.84385966e+00 5.00000000e-01 1.00000000e-05 3.54541106e-05]
# [5.215543025554336, 4.885882515853944, 5.588997702214996]
#
# 29 [2.50294285e+00 1.15437997e+00 1.90064370e-03 1.00000000e-05]
# [5.1821812998248005, 4.853104014405764, 5.554559483587788]
#
# 30 [2.50294229e+00 1.15438011e+00 1.90064899e-03 1.00000000e-05]
# [5.1821812636185465, 4.850544767935294, 5.555236464950366]
#
# 31 [2.50294239e+00 1.15438000e+00 1.90064815e-03 1.00000000e-05]
# [5.182181257804608, 4.852666613870709, 5.555160776843181]
#
# 32 [2.17372616e+00 5.00000003e-01 1.35879083e-02 4.65992690e-04]
# [5.133687448318783, 4.8043198184297, 5.513697143186122]
#
# 33 [2.17372466e+00 5.00080210e-01 1.35879861e-02 4.65653882e-04]
# [5.133687362908964, 4.805614572597848, 5.515874110702015]
#
# 34 [2.16971535e+00 5.64213813e-01 1.38998062e-02 2.60208708e-04]
# [5.133115603226463, 4.799443434375566, 5.51318137673196]
#
# 35 [2.17372497e+00 5.00000000e-01 1.35880115e-02 4.65991184e-04]
# [5.133687379268087, 4.7998538623698055, 5.51512777551041]
#
# 36 [2.15732822e+00 9.49127507e-01 1.49077951e-02 1.02411793e-05]
# [5.131785992394209, 4.802863541629382, 5.5143782358806925]

# %%
# Out:
# 27.64720782307286 24.257214295913368 31.681689168314147
