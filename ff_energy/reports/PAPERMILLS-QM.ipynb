# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from ff_energy.ffe.utils import read_from_pickle
import jax.numpy as jnp
from ff_energy.ffe.plot import plot_energy_MSE, plot_ff_fit
from ff_energy.ffe.structure import atom_key_pairs
from ff_energy.ffe.potential import LJ, akp_indx
from ff_energy.ffe.ff import FF
from ff_energy.ffe.ff_fit import LJ_bound, load_ff, fit_func, fit_repeat
from ff_energy.ffe.data import pairs_data
from ff_energy.ffe.utils import pickle_output, read_from_pickle, str2int

# %%
dataname = "water_cluster/pbe0dz/pbe0_dz.pc"

# %%
papermill_job = """papermill templates/qm_template.ipynb out_notebooks/qm/{logkey}.ipynb -k pycharmm -p dataname {dataname}

jupyter nbconvert --to webpdf --no-input out_notebooks/qm/{logkey}.ipynb 
mv out_notebooks/qm/{logkey}.ipynb out_pdfs/qm
"""

# %%
pm = papermill_job.format(dataname = dataname, logkey="test")

# %%
print(pm)
# Out:
# papermill templates/qm_template.ipynb out_notebooks/qm/test.ipynb -k pycharmm -p dataname water_cluster/pbe0dz/pbe0_dz.pc
#
# jupyter nbconvert --to webpdf --no-input out_notebooks/qm/test.ipynb
# mv out_notebooks/qm/test.ipynb out_pdfs/qm

# %% [markdown]
# # Generating FF objects

# %%
pair_eel_epol_path = "/home/boittier/homeb/pair-eel-epol"
files = list(Path(pair_eel_epol_path).glob("*.dat"))


pair_eel_epol = np.zeros((500,190))
pair_eel_epol.shape
for i in range(len(files)):
    fi = files[i]
    IDX = str2int(fi.name.split("-")[0])
    with open(fi) as f:
        for j, line in enumerate(f.readlines()):
            # print(j, line)
            a,b,E = line.split()
            pair_eel_epol[i,j] = float(E)

# %%
template_ff = next(read_from_pickle("ff/template.ff.pkl"))
# Out:
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
epol = """0 ,  -197.91065793953868
1 ,  -113.95976054505049
2 ,  -160.48478234183463
3 ,  -118.66284499444076
4 ,  -155.77380844422976
5 ,  -150.9995541705951
6 ,  -173.07424212891974
7 ,  -147.23694082382673
8 ,  -140.81293018069294
9 ,  -158.39180721962555
10 ,  -118.69328213099783
11 ,  -160.47184707947005
12 ,  -156.8234077096035
13 ,  -177.00109227393148
14 ,  -173.74116087929457
15 ,  -163.6634882042585
16 ,  -167.55432640034167
17 ,  -178.41306176129993
18 ,  -198.13771741862425
19 ,  -188.25358101682917
20 ,  -193.8544635663619
21 ,  -174.95623313674884
22 ,  -184.7888507989962
23 ,  -141.37639308994395
24 ,  -171.31522554651104
25 ,  -178.14050819168887
26 ,  -117.52904769388255
27 ,  -101.5691221575036
28 ,  -63.32306409695244
29 ,  -124.35656966687516
30 ,  -131.3454553505461
31 ,  -146.44465836118442
32 ,  -125.55640845955148
33 ,  -187.24746843835274
34 ,  -134.03816310896852
35 ,  -151.46381961675218
36 ,  -157.44014713750357
37 ,  -133.19432916720757
38 ,  -118.44675167746216
39 ,  -130.41899497944866
40 ,  -96.71962169598366
41 ,  -140.25823254566004
42 ,  -132.00782359284898
43 ,  -140.3666066008538
44 ,  -94.6945180935851
45 ,  -104.35787694081864
46 ,  -98.55605235390595
47 ,  -103.75579795474555
48 ,  -158.6029659742619
49 ,  -156.2075621992442
50 ,  -137.29242209817735
51 ,  -157.38867195795083
52 ,  -143.9587665773125
53 ,  -160.49270041316544
54 ,  -139.08578473091603
55 ,  -127.32256583556921
56 ,  -133.52154280028606
57 ,  -129.41801720247426
58 ,  -163.74855783048332
59 ,  -162.57353843841216
60 ,  -220.7106384897253
61 ,  -162.31533332880616
62 ,  -146.99186841898728
63 ,  -122.25799053811981
64 ,  -104.13337147993839
65 ,  -222.82863109624273
66 ,  -148.6798506977639
67 ,  -139.0026072939859
68 ,  -191.54216558892787
69 ,  -111.74711484742922
70 ,  -114.34141607914923
71 ,  -134.26584566451405
72 ,  -111.61147067502075
73 ,  -68.74539274039216
74 ,  -125.23712106570335
75 ,  -119.72667684459184
76 ,  -105.68142509224414
77 ,  -114.0079285241558
78 ,  -166.62518541586059
79 ,  -138.31552392610888
80 ,  -113.6338729704916
81 ,  -103.55039008081674
82 ,  -74.05014723602753
83 ,  -161.0464137539695
84 ,  -169.16727957022107
85 ,  -116.72034605589631
86 ,  -154.6530140654059
87 ,  -141.92759194648076
88 ,  -150.50258823950628
89 ,  -89.75511878476112
90 ,  -152.1632764230551
91 ,  -127.14255104592746
92 ,  -113.4417478133013
93 ,  -149.76383676877262
94 ,  -132.40553107818423
95 ,  -139.87832074936503
96 ,  -184.42649320021619
97 ,  -149.53282071826797
98 ,  -125.01340104365532
99 ,  -121.01651200622626
100 ,  -131.23403732702712
101 ,  -135.33980489815647
102 ,  -122.25457535247075
103 ,  -121.73708932333814
104 ,  -124.52892877852035
105 ,  -142.63868841911435
106 ,  -113.46730455520016
107 ,  -138.4834628053034
108 ,  -116.6604899368394
109 ,  -122.83959012347547
110 ,  -132.83305771413333
111 ,  -118.04514728433566
112 ,  -146.26036074190165
113 ,  -152.04025326197026
114 ,  -99.29683014669214
115 ,  -93.61570550553861
116 ,  -97.759998903551
117 ,  -92.54654182313033
118 ,  -148.05985471245475
119 ,  -171.74064617484493
120 ,  -158.37824648524085
121 ,  -163.9310858529523
122 ,  -133.1519393580275
123 ,  -104.48857602519008
124 ,  -100.09295420076245
125 ,  -134.1732050853578
126 ,  -181.36676117532465
127 ,  -136.01644247482957
128 ,  -163.06759485102845
129 ,  -103.55941073931717
130 ,  -176.19926601928893
131 ,  -112.50942640698553
132 ,  -164.52351684809835
133 ,  -98.38262119107118
134 ,  -192.03803808751383
135 ,  -117.40146061983016
136 ,  -203.52585087896162
137 ,  -150.67198570743201
138 ,  -168.57885299017664
139 ,  -191.37468962908642
140 ,  -182.49952656105646
141 ,  -177.96610283612003
142 ,  -152.49099413924128
143 ,  -149.0694070084556
144 ,  -160.03356428336957
145 ,  -161.00494295899097
146 ,  -175.84450793580197
147 ,  -172.60024775475978
148 ,  -140.46179406155252
149 ,  -180.09731736283342
150 ,  -187.61653019298308
151 ,  -212.6295443454816
152 ,  -154.54364412162647
153 ,  -161.94330866961997
154 ,  -162.7163161628733
155 ,  -152.84155970078672
156 ,  -116.71036513154354
157 ,  -129.36509726253942
158 ,  -131.9660601103589
159 ,  -136.63475265426
160 ,  -116.11973810721798
161 ,  -120.38774694113881
162 ,  -119.5202555186028
163 ,  -141.01055881472715
164 ,  -144.46128774131853
165 ,  -108.45322350362545
166 ,  -146.38659946548148
167 ,  -121.06569186828209
168 ,  -164.8425426551654
169 ,  -128.3106393840857
170 ,  -140.87884225104986
171 ,  -109.04465637034687
172 ,  -149.31692824135405
173 ,  -140.97284721324667
174 ,  -185.84721412962716
175 ,  -87.16690444094921
176 ,  -127.11971131891337
177 ,  -121.78875579526465
178 ,  -94.62579184077792
179 ,  -154.06856694334144
180 ,  -126.58305521132652
181 ,  -150.22552911952684
182 ,  -168.9872567263872
183 ,  -146.08914023728988
184 ,  -130.00968245670916
185 ,  -123.92680806290872
186 ,  -171.00487635718318
187 ,  -162.99128642290083
188 ,  -154.30408030724868
189 ,  -129.72560135969874
190 ,  -174.91585469743524
191 ,  -168.12091414916665
192 ,  -173.1714795800777
193 ,  -136.90591807673655
194 ,  -117.24349630702164
195 ,  -139.76560238970288
196 ,  -183.22006543282674
197 ,  -225.18751748735028
198 ,  -175.77731894697334
199 ,  -218.8560233769574
200 ,  -166.59707730045
201 ,  -154.71269723938303
202 ,  -162.61343196658177
203 ,  -166.94470006504375
204 ,  -201.97669876824668
205 ,  -172.60312365739762
206 ,  -135.73204577207756
207 ,  -218.2251354879628
208 ,  -145.16193060664017
209 ,  -166.50854141806855
210 ,  -92.66225206815697
211 ,  -95.03843853880736
212 ,  -168.58600880897836
213 ,  -178.42290507292356
214 ,  -154.38200313859699
215 ,  -127.3921018102241
216 ,  -154.9799789440253
217 ,  -143.91576674004492
218 ,  -126.51182445596
219 ,  -147.31188922237382
220 ,  -106.25931199910556
221 ,  -142.32985958471508
222 ,  -134.8855906905134
223 ,  -92.19348208733852
224 ,  -122.75770761171715
225 ,  -116.47760240592594
226 ,  -136.68437207076178
227 ,  -96.41595648459817
228 ,  -110.02308776374457
229 ,  -109.08382077012801
230 ,  -147.28641607322268
231 ,  -131.8719714683869
232 ,  -163.90524036234868
233 ,  -135.4888825472675
234 ,  -182.2260314401159
235 ,  -182.318235939479
236 ,  -176.6586109856553
237 ,  -210.6920690681493
238 ,  -184.13776271166273
239 ,  -194.52038982551454
240 ,  -129.56962967308854
241 ,  -187.40306469387977
242 ,  -178.25452476092588
243 ,  -177.08518455402404
244 ,  -164.56639157545314
245 ,  -151.70448425218103
246 ,  -213.59999280136256
247 ,  -188.89162388807958
248 ,  -152.1115179005135
249 ,  -148.91438382750053
250 ,  -135.94602189890406
251 ,  -129.2290004182587
252 ,  -181.35211175591652
253 ,  -150.2589028964324
254 ,  -176.47573952190288
255 ,  -114.4861089496999
256 ,  -139.45749085410586
257 ,  -85.59112786458763
258 ,  -111.75937953590896
259 ,  -120.77943530585628
260 ,  -145.09305898578808
261 ,  -127.37196837199764
262 ,  -132.24922436328137
263 ,  -172.95483097197533
264 ,  -171.6842750465584
265 ,  -141.74045229473543
266 ,  -128.6187340094404
267 ,  -115.22677126772948
268 ,  -87.49417582960405
269 ,  -119.00553833026392
270 ,  -145.16487233643483
271 ,  -146.89606594628503
272 ,  -165.8117198517518
273 ,  -165.72081372915596
274 ,  -192.78226672266567
275 ,  -186.8984327704939
276 ,  -146.8536188822844
277 ,  -153.3096171660629
278 ,  -116.03441374016784
279 ,  -179.87700384667718
280 ,  -155.86022229319852
281 ,  -112.68389636873628
282 ,  -158.68828839172923
283 ,  -153.15095405538023
284 ,  -137.08986862090384
285 ,  -164.72905065241426
286 ,  -172.03191175685788
287 ,  -130.56491035884576
288 ,  -157.85752914137015
289 ,  -154.5103234341981
290 ,  -115.23777602651654
291 ,  -150.6393340220742
292 ,  -101.66707383279366
293 ,  -157.072003313081
294 ,  -172.64148560018393
295 ,  -122.95268390362006
296 ,  -137.1125311856307
297 ,  -115.27341295705114
298 ,  -147.51364068946347
299 ,  -144.28838249935387
300 ,  -182.95079217869116
301 ,  -186.46028919370892
302 ,  -137.68904142665755
303 ,  -155.547663597629
304 ,  -135.1218083439805
305 ,  -169.60661693494816
306 ,  -150.65642705608224
307 ,  -151.21653451844318
308 ,  -162.8781011200412
309 ,  -150.40664423433495
310 ,  -146.70664618073587
311 ,  -144.5989112202992
312 ,  -117.4091005965672
313 ,  -174.50071438273164
314 ,  -173.04620244688482
315 ,  -136.35113255166135
316 ,  -153.6376103643359
317 ,  -154.26892049663815
318 ,  -170.01896492852148
319 ,  -141.6948895126982
320 ,  -129.7262870826985
321 ,  -125.18534684805631
322 ,  -148.19078947284842
323 ,  -113.81954853803276
324 ,  -135.5309002309315
325 ,  -144.54521767599255
326 ,  -198.347633419013
327 ,  -221.69789553692615
328 ,  -153.9779542096772
329 ,  -128.5921658709472
330 ,  -127.45796992908281
331 ,  -162.14254046008992
332 ,  -190.326381123613
333 ,  -181.9829186951046
334 ,  -159.68036428404403
335 ,  -164.29356678331757
336 ,  -165.70373801832085
337 ,  -93.24609645938135
338 ,  -133.43030278529997
339 ,  -132.3356772099623
340 ,  -79.777396965206
341 ,  -108.11844161579167
342 ,  -152.77540131413681
343 ,  -92.19029200598075
344 ,  -224.08284340817588
345 ,  -145.73178570714322
346 ,  -176.8137443814284
347 ,  -136.37914194933904
348 ,  -145.89992399826727
349 ,  -133.70047283531107
350 ,  -190.00703133341156
351 ,  -129.20949851604306
352 ,  -210.02878233716982
353 ,  -158.20855604061086
354 ,  -173.73164063821497
355 ,  -127.59354427806704
356 ,  -118.43041095261565
357 ,  -130.59115386817282
358 ,  -119.98755794469713
359 ,  -138.08287575396685
360 ,  -145.54611259544504
361 ,  -183.51568992824684
362 ,  -159.6846957227436
363 ,  -139.65678192416138
364 ,  -160.71230532928982
365 ,  -161.46381162021714
366 ,  -151.1265198420425
367 ,  -158.45731309016028
368 ,  -136.11102729281572
369 ,  -163.4007809673061
370 ,  -186.8974025328093
371 ,  -144.56136557125194
372 ,  -154.82524093265778
373 ,  -135.75022395986264
374 ,  -171.36304630929985
375 ,  -151.07585008987124
376 ,  -147.1596234922252
377 ,  -159.57705818539142
378 ,  -143.86093696685725
379 ,  -146.08066993212094
380 ,  -169.5226108717697
381 ,  -151.2936853180194
382 ,  -172.52198500342178
383 ,  -142.86226075130875
384 ,  -126.23424385181063
385 ,  -145.6186316739386
386 ,  -130.9282196913256
387 ,  -115.88637024893355
388 ,  -167.12805248949857
389 ,  -183.96276417630537
390 ,  -185.64589801962302
391 ,  -174.56399702263144
392 ,  -149.5067572086489
393 ,  -178.1888065466192
394 ,  -203.42501518068133
395 ,  -171.8512163911251
396 ,  -188.1692223647881
397 ,  -163.06443294479655
398 ,  -154.9605484335649
399 ,  -165.43211942530488
400 ,  -134.70896639165218
401 ,  -132.93053582445026
402 ,  -156.22766220581585
403 ,  -189.64617366341614
404 ,  -153.60101898447243
405 ,  -137.97833722336344
406 ,  -173.0666789717097
407 ,  -138.0286098201197
408 ,  -128.0769781876476
409 ,  -164.4485752883095
410 ,  -187.35269959266455
411 ,  -169.4455468314607
412 ,  -169.12828241470055
413 ,  -193.7461669574241
414 ,  -210.55900661036668
415 ,  -167.6866453905028
416 ,  -176.4117992922177
417 ,  -224.88894431205094
418 ,  -150.3837476574898
419 ,  -181.86284382043837
420 ,  -110.15165030287531
421 ,  -129.94622762695093
422 ,  -171.36603113943565
423 ,  -150.31053006001036
424 ,  -146.9040494907478
425 ,  -172.38834874944396
426 ,  -138.13516572924362
427 ,  -188.63251158512765
428 ,  -135.83725630553306
429 ,  -138.5639441727243
430 ,  -141.16270563236534
431 ,  -129.16516936630873
432 ,  -133.02327636904528
433 ,  -167.88587839249647
434 ,  -207.4458341999899
435 ,  -134.7782213317515
436 ,  -201.75974102341593
437 ,  -165.526856874407
438 ,  -165.34550067988462
439 ,  -146.26241790101832
440 ,  -157.3818750086686
441 ,  -173.419303887717
442 ,  -144.85829830210997
443 ,  -125.2272886359566
444 ,  -145.4509004028357
445 ,  -126.29849746737422
446 ,  -134.53774903375447
447 ,  -178.05464801001472
448 ,  -148.0808633603926
449 ,  -192.45222092695712
450 ,  -196.5152445133216
451 ,  -120.87186996251448
452 ,  -148.07570325389446
453 ,  -129.71429157094838
454 ,  -100.02675798486555
455 ,  -109.82438281173248
456 ,  -143.79180766832258
457 ,  -110.90499964204433
458 ,  -121.0903204044003
459 ,  -80.91582382197416
460 ,  -128.0610416314565
461 ,  -108.26132659009966
462 ,  -133.53743335683583
463 ,  -140.61833835469196
464 ,  -147.08798713251397
465 ,  -120.4668444702327
466 ,  -124.8655282550199
467 ,  -124.55768281149106
468 ,  -182.32435106558088
469 ,  -184.1076853517829
470 ,  -115.19343752392219
471 ,  -144.69687203558945
472 ,  -164.4978536092102
473 ,  -176.067067800297
474 ,  -136.8737724386799
475 ,  -188.70717124123934
476 ,  -95.01626104656552
477 ,  -177.39960493781564
478 ,  -186.09571371022167
479 ,  -184.84918725081738
480 ,  -168.4735024191577
481 ,  -167.77741720196985
482 ,  -170.25925082611033
483 ,  -154.64134931099312
484 ,  -149.36906767363558
485 ,  -153.58562733913467
486 ,  -168.3041350722371
487 ,  -177.77162454707175
488 ,  -122.04998839818906
489 ,  -201.6326593357404
490 ,  -169.58193634637348
491 ,  -150.81916099895923
492 ,  -159.3010712255848
493 ,  -156.25635440123125
494 ,  -157.79941150176913
495 ,  -175.80632021987057
496 ,  -138.41012605502584
497 ,  -178.9292131789199
498 ,  -171.90337621167242
499 ,  -176.12406452564676"""
epol_data = [float(_.split(",")[1]) for _ in epol.split("\n")]
# epol_data

# %%
first_order_energy = """7.640822312169947
-5.902675987018749
-6.037152396045854
-4.570214471819514
-12.251941741814242
7.304728365422202
18.29076174429756
10.72935496010793
-2.5118579710916125
6.600795332866156
-3.238907636758919
29.00248067643463
5.73452873777264
10.959869559712917
-0.7428700581068808
8.695036150715646
19.58156993384515
20.074269536597726
15.936627148729807
36.509910978498056
35.4923349701155
21.096131183199702
48.09945817875741
14.178987932788939
8.336955652693359
10.064278255228833
0.1874171239341945
4.413197483640748
5.944498928822997
17.18684796308074
1.9025981080862557
16.326083308598513
2.0234844816148367
11.735260735277775
-12.48761892471163
-9.228796270679437
18.919773095507832
-6.771217931295426
23.691126629232592
5.575962867757317
3.4832886897054003
9.973438101808876
20.33059937392939
-2.443072077632701
7.363092393697632
2.8630759001468533
3.3757477485149736
11.440206409802352
13.574728378933035
13.72467377454131
-0.1313537965699332
-2.6486086001035387
12.50044314738896
18.02432636889657
4.058545760077274
-0.5850456534496682
-11.51519090517341
14.05312421642213
12.884562213766744
29.16528223517449
9.919662861842562
31.19547849553594
5.057662134146705
30.5876405059762
8.483134862399808
1.465110930606622
-7.06680746005341
11.837785742482133
23.662281022812472
4.7754763337995305
-1.1696891984142397
14.518528035818642
12.157843182756185
1.595977214421474
4.82130234611716
2.141990460569782
-6.550232941402386
3.1470532401679634
2.7783156860322227
-4.137235949668557
-6.929295661775147
-6.45097920375123
-15.466213733564588
2.048705844410227
4.345043240600023
9.4438848679684
-16.084612832772162
13.701204292907246
25.902064065560833
-1.6191744199470748
1.8344419827510472
24.40252476543653
9.85624267605908
8.186622267939878
-15.070479906132398
-10.511833508569683
15.267871983314114
-2.7984552259293114
-9.681613253741352
-9.068808903552553
21.239707357940762
4.651076910981265
15.68152453190058
-1.1111455137892656
32.88285798627112
35.55652943998168
-6.997763031940237
0.11865927970392581
-12.743374340038718
-16.17069345213969
4.839678584690149
2.95718336984681
18.182011341279104
32.87566930068913
8.197818856755884
0.9693463832978875
16.2818628416376
17.359236925651093
25.85806918855284
10.541726051782542
11.473967925473875
15.236831976557315
27.555919364999887
9.89243390820711
23.290460953934215
0.499466790200951
20.17413710365971
7.8197796041614565
-3.928250572478793
16.685653513980608
9.842055314640122
-5.435474415993057
3.517820724674471
-2.8747051564917507
-8.11849764354477
-2.6793061124642352
8.0307805421764
0.5536926442968225
15.078950531154144
11.87474686617519
30.07907256944448
1.6314289268286597
11.014533604143786
-0.3267534682786312
1.8928654361102077
17.564584630764276
24.69140452299683
6.920982855829546
-8.524084059780762
23.355766178597985
18.3203297395723
26.20510777864337
9.06238471273083
-3.431259432705502
37.165004321299165
17.521880352044935
6.901594883731278
19.182909402466432
22.4684613241825
18.746664881748618
22.688304811870946
20.617584743193493
-2.8126846935035985
4.087454305429344
4.734104696968291
1.6310655987374403
0.985667528162064
0.07167344157817347
2.4119625423081223
7.467395950880249
23.998812657307962
0.5297850983491059
13.933361084968997
11.08378460770939
8.070512308118742
6.183599489376601
7.20097745578525
18.848507158726893
5.866864774449927
3.739997794135436
18.83825503453134
8.15290160333776
33.027072401092944
7.659633665227902
-0.5906040065817681
-3.4433607646811026
10.181476504509527
3.538200098405415
8.600045712653866
8.317090522733613
12.538192360280565
16.401398438590647
21.8704549023759
9.407771823629416
1.437023229890573
17.532345892122997
21.771196019206858
8.395102813918784
8.924138164047156
20.46188721898662
19.432371462677022
2.9890801155378073
14.124012392635848
12.250220985187626
18.220737711289306
28.03894226956781
4.965159896007464
27.746032520625583
11.913052805157944
11.463022717094965
-0.0036813469800772085
6.311570256825975
-1.1709467899985466
21.65598057411893
23.882886746026262
-4.239271938656781
-7.707216516316324
-13.08512999077138
-9.01339235004186
0.26166994297529894
5.935107809988798
-2.8096957401666223
-5.154122764353221
5.361595153549815
-4.071024099488286
-0.357070458597712
10.038220736230683
13.490984416224975
-1.150625962617295
-3.898333618988362
30.66181934194452
14.357987204950103
6.5023587381657215
-1.1834575089677708
3.9290551020233004
20.377994787625997
-2.3722896368949273
21.12289791356431
-3.991045696106632
28.403505693187142
14.459245772662488
17.442654583407755
37.688708100047165
18.69058931744596
5.656172320682218
16.978457088235924
13.407588470326754
8.765737642901211
4.771551387487053
9.97617341542033
13.448774176011964
3.4401193642289027
9.877609875437717
13.062478404898817
15.096662738992752
18.21859639820245
5.024237402807731
-18.108400589606298
-5.229070989109884
-0.1660286519437516
9.03520420259416
16.15994590937388
28.921615978055794
16.16331563517219
34.37010738822203
7.842945434090575
-6.945475742249108
4.79910018262885
6.065362962785202
19.923136829749286
18.298205199026345
7.7948177797680405
15.006863121645795
19.5384733366052
25.43790723315762
0.331837675603877
-10.528563789445968
-16.15138611547535
-0.6096587078835993
27.3763092119368
14.129267784424911
-0.03627996200111744
31.54939935842149
22.362065713161922
-8.18765176005931
21.650892790264738
6.474705776260477
22.628527255693253
5.442345268286435
2.3059162657302736
-2.5548473899682813
20.03199428589441
-0.8949890838845989
-1.4513085456807788
1.9410980731692429
-6.4177336266828435
12.441637540719803
-7.549850570073468
-1.0508399086799385
4.193033527139308
-2.7651755121199955
-2.3992855959851696
1.4959823254579017
10.07361459190102
6.253624965691307
20.420951763942696
15.204459704014617
5.721087045574144
12.26109547335154
31.466250400413774
-1.3135734800608094
4.059876142997976
-15.075799868790602
-0.8676933632449322
7.109731554510007
2.8004175736616737
-3.190294352733768
23.674016014446046
2.5298020438133824
-8.682079899829802
16.198327965445568
-12.851880892680834
20.28581295636809
5.045053272532196
4.802166946887938
14.433748305811214
28.151727307523043
19.12471511556238
-7.071699272430877
-9.322688065520568
-1.2835132664642084
5.8591837450954545
31.52672794336842
24.28007708547426
27.705677198505864
1.1970557017712813
17.602091875672116
2.3696146891755823
32.98121275382799
8.167512972946254
-5.6646226140878015
0.3688242131884564
-3.103702815080054
9.09315689853514
13.264963411666633
4.758517827392439
24.718432736310582
12.480322997951875
-8.833450307039916
31.56235673893371
18.917328443941315
25.011641807448587
41.01891177632287
11.329534196262516
18.203938906761138
-2.1695541280941075
-9.464261041861144
0.5294215196509039
16.681288432411428
13.847272182524827
-8.562136610340536
9.191138611787123
25.51393759835793
18.782303780048895
25.288148647126217
14.449930583142562
16.08696153793548
10.61992634446824
-17.629559220120328
2.9915791088871866
48.0294874843907
20.86866584030359
23.62779617722826
10.4275432990892
35.24678725165313
-8.176977635597686
17.239292067172887
11.426641914510974
20.319059599945174
5.2597697562711465
20.476045652202128
18.323500293698984
-3.985148738412925
-5.848356257605407
8.384610228208196
-10.912367720472734
-2.9672842014576117
-5.72885843679915
16.763409530005042
9.85114930711042
11.451335353245723
4.581758198934258
2.676713745252122
-6.937116751424344
23.649517417365463
4.324125651817251
31.741012575712045
11.666469884191562
3.381290414129732
10.380797796688993
2.050016836995771
8.193323127666341
11.946062815443849
14.304823724494906
7.170920630327636
6.371994084742608
6.965018018906489
8.884659284199147
4.2461570357228435
20.985111894229124
26.960097554510728
36.199927449902596
23.325345021390614
-0.2976247296246436
-3.8082290949753794
-2.228023891658215
6.586116631199488
8.448749476861915
-3.953891048543896
14.498885294957025
-7.2447632464466505
18.78568975826691
41.607186341867866
41.19894348983468
12.980687502965003
19.193010862008105
0.2973206383431189
14.415840880350002
9.889864570709264
-1.4325884949717902
14.235637103140956
-9.288988861706201
-2.704205499781721
24.949135777251282
27.868144483102864
-11.561401455540093
29.75713247554641
11.192721381512872
2.8407195574698
4.089924998764749
3.750813296132307
5.021726549397969
-1.9373748710421037
17.76538446052482
17.88694854447084
-15.365572195841377
-11.077371084632029
20.135378353743516
12.035428008088115
14.708179218816143
18.610261203082423
4.557819716609941
6.041081232852716
7.069174550832172
-3.337658237460435
-1.1907772188767982
18.52715366044901
-0.540818597664416
4.8015904541008245
4.348840865394361
19.40699648547041
3.5315087139913617
16.988875125686004
14.570080825274387
6.956375456324784
28.275547476445418
4.547853925048257
14.181958123124158
25.203033199687308
20.66148536819327
-4.1866006137713745
10.034159934324071
6.307727764990466
11.130035067721794
-3.419545964165872
16.289175084023917
-10.127129164284854
21.646769864748254
-1.107364142047771
23.03589799511549
6.833198171510659
6.067315772310409
4.76122170302096
2.063941209665666
-1.947361433386326
10.016973202769623
34.38702736522568
3.795072731573863
20.23254311250608
23.442095040808184
19.1245558537505
20.540942116857895
6.1623941248496905
-6.054554614399111
9.763130059952946
-1.7184626708515593
2.169630997806556
31.25020447452683
15.363398440470993
11.649577956907017"""
first_order_energy = [float(_) for _ in first_order_energy.split("\n")]

# %%
template_ff.data["first_order_energy"] = first_order_energy

# %%
template_ff.data["epol_mike"] = epol_data

# %%
#  add pair pol. data
template_ff.data["epol_pairs"] = pair_eel_epol.sum(axis=1)
template_ff.data
# Out:
#                ECOL      KEY     TOTAL      ELEC       VDW      KEY  \
# test0   -173.022645    test0  24.14023 -86.50353  20.41138    test0
# test1   -105.096240    test1  25.25058 -55.44306   8.97296    test1
# test2   -144.567121    test2  24.75756 -76.78875  14.41942    test2
# test3   -105.558619    test3  21.75948 -60.46748   5.74741    test3
# test4   -141.957058    test4  21.69034 -77.22292  12.55821    test4
# ...             ...      ...       ...       ...       ...      ...
# test495 -156.403481  test495  24.92171 -83.61850  17.54292  test495
# test496 -126.839243  test496  15.65968 -71.27947  12.74644  test496
# test497 -160.377711  test497  20.65947 -76.28248  24.76786  test497
# test498 -154.210967  test498  21.38907 -73.28759  20.35679  test498
# test499 -155.884825  test499  19.75572 -77.85868  21.20638  test499
#
#             M_ENERGY      KEY  n_monomers     C_ENERGY  ...          intE  \
# test0   -1527.133263    test0          20 -1527.276175  ... -1.916733e+06
# test1   -1527.135387    test1          20 -1527.221635  ... -1.916697e+06
# test2   -1527.140946    test2          20 -1527.260418  ... -1.916718e+06
# test3   -1527.151295    test3          20 -1527.247454  ... -1.916703e+06
# test4   -1527.150321    test4          20 -1527.270835  ... -1.916719e+06
# ...              ...      ...         ...          ...  ...           ...
# test495 -1527.129876  test495          20 -1527.255655  ... -1.916722e+06
# test496 -1527.168887  test496          20 -1527.264530  ... -1.916703e+06
# test497 -1527.154064  test497          20 -1527.248923  ... -1.916702e+06
# test498 -1527.150078  test498          20 -1527.257280  ... -1.916710e+06
# test499 -1527.154292  test499          20 -1527.269832  ... -1.916715e+06
#
#             P_intE        m_E_tot      p_m_E_tot  C_ENERGY_kcalmol  DUMMY  \
# test0   -77.478222  958362.266640 -958281.958385    -958370.381547      0
# test1   -53.285800  958360.933743 -958282.584949    -958336.157791      0
# test2   -70.885989  958357.445616 -958285.865741    -958360.493844      0
# test3   -58.662892  958350.951437 -958292.985598    -958352.359334      0
# test4   -73.371184  958351.562845 -958292.418135    -958367.030618      0
# ...            ...            ...            ...               ...    ...
# test495 -72.611238  958364.391623 -958280.758013    -958357.505436      0
# test496 -61.118914  958339.912612 -958304.589688    -958363.074582      0
# test497 -57.960443  958349.213649 -958294.973785    -958353.280867      0
# test498 -65.470853  958351.715184 -958293.538913    -958358.525003      0
# test499 -67.209134  958349.071037 -958296.120980    -958366.401571      0
#
#            k   epol_mike  first_order_energy  epol_pairs
# test0      0 -197.910658            7.640822 -182.982917
# test1      1 -113.959761           -5.902676 -111.406093
# test2      2 -160.484782           -6.037152 -153.110225
# test3      3 -118.662845           -4.570214 -111.548989
# test4      4 -155.773808          -12.251942 -151.839749
# ...      ...         ...                 ...         ...
# test495  495 -175.806320           -1.718463 -166.329665
# test496  496 -138.410126            2.169631 -133.079412
# test497  497 -178.929213           31.250204 -170.886865
# test498  498 -171.903376           15.363398 -164.288222
# test499  499 -176.124065           11.649578 -166.179097
#
# [500 rows x 21 columns]

# %%
template_ff.bounds = LJ_bound

# %%
pickle_output(template_ff, name=f"ff/template.ff")

# %%
elec_data = {
    "pc": next(read_from_pickle("water_cluster_pbe0dz_pc.pkl")),
    "kmdcm": next(read_from_pickle("water_cluster_pbe0dz_kmdcm.pkl")),
    "mdcm": next(read_from_pickle("water_cluster_pbe0dz_mdcm.pkl"))
}

# %%
elec_keys = ["pc", "kmdcm", "mdcm"]
elec_theory_keys = ["ECOL", "epol_mike", "DUMMY", "epol_pairs"]

# %% [markdown]
# ##  model electrostatics

# %%
for typ in ["pairs", "clusters", "FOE"]:
    # loop through each electrostatic method
    for k in elec_keys:
        print(k, typ)
        data = elec_data[k]
        #  get a fresh template ff
        template_ff = next(read_from_pickle("ff/template.ff.pkl"))
        #  add the epol_pairs data
        template_ff.data["epol_pairs"] = pair_eel_epol.sum(axis=1)
        # add the ELEC column 
        template_ff.data["ELEC"] = data.data["ELEC"]
        
        if typ == "pairs":
            template_ff.intE = "P_intE"
        elif typ == "FOE":
            template_ff.intE = "first_order_energy"
        else:
            template_ff.intE = "intE"
                
        # add the jax data
        jax_data = next(read_from_pickle(f"jax_data_{k}.pkl"))
        template_ff.init_jax_col(jax_data)
        
        template_ff.intern = "harmonic"
        template_ff.elec = "ELEC"
        
        template_ff.set_intE()
        template_ff.set_targets()
        
        # verify
        print(template_ff)
        # pickle the ff
        pickle_output(template_ff, f"ff/{k}_pbe0dz_{typ}.ff")
# Out:
# pc pairs
# FF: LJ water_cluster ELEC harmonic P_intE (jax_coloumb: True)
# kmdcm pairs
# FF: LJ water_cluster ELEC harmonic P_intE (jax_coloumb: True)
# mdcm pairs
# FF: LJ water_cluster ELEC harmonic P_intE (jax_coloumb: True)
# pc clusters
# FF: LJ water_cluster ELEC harmonic intE (jax_coloumb: True)
# kmdcm clusters
# FF: LJ water_cluster ELEC harmonic intE (jax_coloumb: True)
# mdcm clusters
# FF: LJ water_cluster ELEC harmonic intE (jax_coloumb: True)
# pc FOE
# FF: LJ water_cluster ELEC harmonic first_order_energy (jax_coloumb: True)
# kmdcm FOE
# FF: LJ water_cluster ELEC harmonic first_order_energy (jax_coloumb: True)
# mdcm FOE
# FF: LJ water_cluster ELEC harmonic first_order_energy (jax_coloumb: True)

# %% [markdown]
# ##  theoretical electrostatics

# %%
for typ in ["pairs", "clusters", "FOE"]:
    # loop through each electrostatic method
    for k in elec_theory_keys:
        print(k, typ)
        #  get a fresh template ff
        template_ff = next(read_from_pickle("ff/template.ff.pkl"))
        
        if typ == "pairs":
            template_ff.intE = "P_intE"
        elif typ == "FOE":
            template_ff.intE = "first_order_energy"
        else:
            template_ff.intE = "intE"
        
        #  add the epol_pairs data
        template_ff.data["epol_pairs"] = pair_eel_epol.sum(axis=1)
        # set the keys
        template_ff.elec = k
        template_ff.intern = "Exact"
        template_ff.set_intE()
        template_ff.set_targets()
        # verify
        print(template_ff)
        # pickle the ff
        pickle_output(template_ff, f"ff/{k}_pbe0dz_{typ}")
# Out:
# ECOL pairs
# FF: LJ water_cluster ECOL Exact P_intE (jax_coloumb: False)
# epol_mike pairs
# FF: LJ water_cluster epol_mike Exact P_intE (jax_coloumb: False)
# DUMMY pairs
# FF: LJ water_cluster DUMMY Exact P_intE (jax_coloumb: False)
# epol_pairs pairs
# FF: LJ water_cluster epol_pairs Exact P_intE (jax_coloumb: False)
# ECOL clusters
# FF: LJ water_cluster ECOL Exact intE (jax_coloumb: False)
# epol_mike clusters
# FF: LJ water_cluster epol_mike Exact intE (jax_coloumb: False)
# DUMMY clusters
# FF: LJ water_cluster DUMMY Exact intE (jax_coloumb: False)
# epol_pairs clusters
# FF: LJ water_cluster epol_pairs Exact intE (jax_coloumb: False)
# ECOL FOE
# FF: LJ water_cluster ECOL Exact first_order_energy (jax_coloumb: False)
# epol_mike FOE
# FF: LJ water_cluster epol_mike Exact first_order_energy (jax_coloumb: False)
# DUMMY FOE
# FF: LJ water_cluster DUMMY Exact first_order_energy (jax_coloumb: False)
# epol_pairs FOE
# FF: LJ water_cluster epol_pairs Exact first_order_energy (jax_coloumb: False)

# %% [markdown]
# #  Testing FF fit

# %%
_c = next(read_from_pickle("ff/ECOL_pbe0dz_FOE.pkl"))
# _c.get_loss_coulomb([1])
print(_c)
# Out:
# FF: LJ water_cluster ECOL Exact first_order_energy (jax_coloumb: False)

# %%
_c.data
# Out:
#                ECOL      KEY     TOTAL      ELEC       VDW      KEY  \
# test0   -173.022645    test0  24.14023 -86.50353  20.41138    test0
# test1   -105.096240    test1  25.25058 -55.44306   8.97296    test1
# test2   -144.567121    test2  24.75756 -76.78875  14.41942    test2
# test3   -105.558619    test3  21.75948 -60.46748   5.74741    test3
# test4   -141.957058    test4  21.69034 -77.22292  12.55821    test4
# ...             ...      ...       ...       ...       ...      ...
# test495 -156.403481  test495  24.92171 -83.61850  17.54292  test495
# test496 -126.839243  test496  15.65968 -71.27947  12.74644  test496
# test497 -160.377711  test497  20.65947 -76.28248  24.76786  test497
# test498 -154.210967  test498  21.38907 -73.28759  20.35679  test498
# test499 -155.884825  test499  19.75572 -77.85868  21.20638  test499
#
#             M_ENERGY      KEY  n_monomers     C_ENERGY  ...          intE  \
# test0   -1527.133263    test0          20 -1527.276175  ... -1.916733e+06
# test1   -1527.135387    test1          20 -1527.221635  ... -1.916697e+06
# test2   -1527.140946    test2          20 -1527.260418  ... -1.916718e+06
# test3   -1527.151295    test3          20 -1527.247454  ... -1.916703e+06
# test4   -1527.150321    test4          20 -1527.270835  ... -1.916719e+06
# ...              ...      ...         ...          ...  ...           ...
# test495 -1527.129876  test495          20 -1527.255655  ... -1.916722e+06
# test496 -1527.168887  test496          20 -1527.264530  ... -1.916703e+06
# test497 -1527.154064  test497          20 -1527.248923  ... -1.916702e+06
# test498 -1527.150078  test498          20 -1527.257280  ... -1.916710e+06
# test499 -1527.154292  test499          20 -1527.269832  ... -1.916715e+06
#
#             P_intE        m_E_tot      p_m_E_tot  C_ENERGY_kcalmol  DUMMY  \
# test0   -77.478222  958362.266640 -958281.958385    -958370.381547      0
# test1   -53.285800  958360.933743 -958282.584949    -958336.157791      0
# test2   -70.885989  958357.445616 -958285.865741    -958360.493844      0
# test3   -58.662892  958350.951437 -958292.985598    -958352.359334      0
# test4   -73.371184  958351.562845 -958292.418135    -958367.030618      0
# ...            ...            ...            ...               ...    ...
# test495 -72.611238  958364.391623 -958280.758013    -958357.505436      0
# test496 -61.118914  958339.912612 -958304.589688    -958363.074582      0
# test497 -57.960443  958349.213649 -958294.973785    -958353.280867      0
# test498 -65.470853  958351.715184 -958293.538913    -958358.525003      0
# test499 -67.209134  958349.071037 -958296.120980    -958366.401571      0
#
#            k   epol_mike  first_order_energy  epol_pairs
# test0      0 -197.910658            7.640822 -182.982917
# test1      1 -113.959761           -5.902676 -111.406093
# test2      2 -160.484782           -6.037152 -153.110225
# test3      3 -118.662845           -4.570214 -111.548989
# test4      4 -155.773808          -12.251942 -151.839749
# ...      ...         ...                 ...         ...
# test495  495 -175.806320           -1.718463 -166.329665
# test496  496 -138.410126            2.169631 -133.079412
# test497  497 -178.929213           31.250204 -170.886865
# test498  498 -171.903376           15.363398 -164.288222
# test499  499 -176.124065           11.649578 -166.179097
#
# [500 rows x 21 columns]

# %%
sig_bound = (0.005, 2.5)
ep_bound = (0.0001, 0.5)
LJ_bound = ((sig_bound), (sig_bound), (ep_bound), (ep_bound))
DE_bound = ((sig_bound), (sig_bound), (ep_bound), (ep_bound), 
            (1, 8), (6, 20))

# %%
fit_repeat(_c, 
           300, 
           "test",
           bounds = DE_bound,
           loss="jax_de",
           # quiet='true'
          )
# Out:
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [0.010620629560898875, 0.47624432653582127, 0.42806287869676096, 0.4300728072937307, 2.928706749701967, 19.97908290324093]
# /home/boittier/Documents/phd/ff_energy/ff_energy/ffe/ff_fit.py:174: OptimizeWarning: Unknown solver options: pgtol
#   res = minimize(
# final_loss_fn:  21446.07421875
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 21446.07421875
#              x: [ 1.138e-02  2.631e-01  4.449e-01  4.033e-01  3.594e+00
#                   1.997e+01]
#            nit: 37
#           nfev: 175
#  final_simplex: (array([[ 1.138e-02,  2.631e-01, ...,  3.594e+00,
#                          1.997e+01],
#                        [ 1.138e-02,  2.631e-01, ...,  3.594e+00,
#                          1.997e+01],
#                        ...,
#                        [ 1.138e-02,  2.631e-01, ...,  3.594e+00,
#                          1.997e+01],
#                        [ 1.138e-02,  2.631e-01, ...,  3.594e+00,
#                          1.997e+01]]), array([ 2.145e+04,  2.145e+04,  2.145e+04,  2.145e+04,
#                         2.145e+04,  2.145e+04,  2.145e+04]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [1.7419659109823018, 0.6557005593597124, 0.01076148847546954, 0.33201077002901935, 3.3443116475323564, 6.912663556013036]
# final_loss_fn:  19.26898956298828
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 19.26898956298828
#              x: [ 7.918e-01  2.445e+00  4.796e-02  4.009e-02  2.784e+00
#                   1.442e+01]
#            nit: 1088
#           nfev: 1771
#  final_simplex: (array([[ 7.918e-01,  2.445e+00, ...,  2.784e+00,
#                          1.442e+01],
#                        [ 7.918e-01,  2.445e+00, ...,  2.784e+00,
#                          1.442e+01],
#                        ...,
#                        [ 7.918e-01,  2.445e+00, ...,  2.784e+00,
#                          1.442e+01],
#                        [ 7.918e-01,  2.445e+00, ...,  2.784e+00,
#                          1.442e+01]]), array([ 1.927e+01,  1.927e+01,  1.927e+01,  1.927e+01,
#                         1.927e+01,  1.927e+01,  1.927e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [1.8391119247164862, 1.5435053685264453, 0.42880791389524703, 0.07368154786730101, 3.1176963515687808, 13.309832589477669]
# final_loss_fn:  19.523418426513672
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 19.523418426513672
#              x: [ 9.336e-01  2.227e+00  1.828e-02  5.392e-02  4.990e+00
#                   1.362e+01]
#            nit: 378
#           nfev: 706
#  final_simplex: (array([[ 9.336e-01,  2.227e+00, ...,  4.990e+00,
#                          1.362e+01],
#                        [ 9.336e-01,  2.227e+00, ...,  4.990e+00,
#                          1.362e+01],
#                        ...,
#                        [ 9.336e-01,  2.227e+00, ...,  4.990e+00,
#                          1.362e+01],
#                        [ 9.336e-01,  2.227e+00, ...,  4.990e+00,
#                          1.362e+01]]), array([ 1.952e+01,  1.952e+01,  1.952e+01,  1.952e+01,
#                         1.952e+01,  1.952e+01,  1.952e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [1.811245950110392, 0.7780425770139738, 0.18142417582457773, 0.34544454382767575, 3.517370557839203, 11.80691976316865]
# final_loss_fn:  23.53797149658203
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 23.53797149658203
#              x: [ 2.492e+00  1.804e+00  1.425e-04  4.138e-01  4.725e+00
#                   1.298e+01]
#            nit: 1122
#           nfev: 1812
#  final_simplex: (array([[ 2.492e+00,  1.804e+00, ...,  4.725e+00,
#                          1.298e+01],
#                        [ 2.492e+00,  1.804e+00, ...,  4.725e+00,
#                          1.298e+01],
#                        ...,
#                        [ 2.492e+00,  1.804e+00, ...,  4.725e+00,
#                          1.298e+01],
#                        [ 2.492e+00,  1.804e+00, ...,  4.725e+00,
#                          1.298e+01]]), array([ 2.354e+01,  2.354e+01,  2.354e+01,  2.354e+01,
#                         2.354e+01,  2.354e+01,  2.354e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [0.5006951127495387, 0.32837536614630214, 0.1622714536637651, 0.4703112393658211, 2.7490493468972144, 11.76810687573426]
# final_loss_fn:  21446.07421875
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 21446.07421875
#              x: [ 5.000e-03  2.852e-01  1.963e-01  4.940e-01  3.840e+00
#                   1.708e+01]
#            nit: 47
#           nfev: 216
#  final_simplex: (array([[ 5.000e-03,  2.852e-01, ...,  3.840e+00,
#                          1.708e+01],
#                        [ 5.000e-03,  2.852e-01, ...,  3.840e+00,
#                          1.708e+01],
#                        ...,
#                        [ 5.000e-03,  2.852e-01, ...,  3.840e+00,
#                          1.708e+01],
#                        [ 5.000e-03,  2.852e-01, ...,  3.840e+00,
#                          1.708e+01]]), array([ 2.145e+04,  2.145e+04,  2.145e+04,  2.145e+04,
#                         2.145e+04,  2.145e+04,  2.145e+04]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [2.295951373145113, 2.2366090382756814, 0.011656148039494196, 0.3385374599830736, 3.1645884241765385, 19.769369625978893]
# final_loss_fn:  25.69660186767578
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 25.69660186767578
#              x: [ 4.015e-01  2.496e+00  1.199e-02  3.915e-03  5.894e+00
#                   1.834e+01]
#            nit: 534
#           nfev: 942
#  final_simplex: (array([[ 4.015e-01,  2.496e+00, ...,  5.894e+00,
#                          1.834e+01],
#                        [ 4.015e-01,  2.496e+00, ...,  5.894e+00,
#                          1.834e+01],
#                        ...,
#                        [ 4.015e-01,  2.496e+00, ...,  5.894e+00,
#                          1.834e+01],
#                        [ 4.015e-01,  2.496e+00, ...,  5.894e+00,
#                          1.834e+01]]), array([ 2.570e+01,  2.570e+01,  2.570e+01,  2.570e+01,
#                         2.570e+01,  2.570e+01,  2.570e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [0.2718638190005642, 2.045050724230139, 0.4321825686260881, 0.2879762069904581, 3.372167986212114, 9.935042537555521]
# final_loss_fn:  20.6621150970459
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 20.6621150970459
#              x: [ 2.673e-01  2.500e+00  5.000e-01  4.178e-02  3.529e+00
#                   1.352e+01]
#            nit: 1077
#           nfev: 1743
#  final_simplex: (array([[ 2.673e-01,  2.500e+00, ...,  3.529e+00,
#                          1.352e+01],
#                        [ 2.673e-01,  2.500e+00, ...,  3.529e+00,
#                          1.352e+01],
#                        ...,
#                        [ 2.673e-01,  2.500e+00, ...,  3.529e+00,
#                          1.352e+01],
#                        [ 2.673e-01,  2.500e+00, ...,  3.529e+00,
#                          1.352e+01]]), array([ 2.066e+01,  2.066e+01,  2.066e+01,  2.066e+01,
#                         2.066e+01,  2.066e+01,  2.066e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [1.9999755217856496, 0.8187550692022723, 0.26257513444776054, 0.4964957541370469, 4.088288645632554, 7.211199946736235]
# final_loss_fn:  34.43484878540039
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 34.43484878540039
#              x: [ 8.712e-01  1.995e+00  2.990e-02  4.515e-01  7.999e+00
#                   8.000e+00]
#            nit: 1386
#           nfev: 2222
#  final_simplex: (array([[ 8.712e-01,  1.995e+00, ...,  7.999e+00,
#                          8.000e+00],
#                        [ 8.712e-01,  1.995e+00, ...,  7.999e+00,
#                          8.000e+00],
#                        ...,
#                        [ 8.712e-01,  1.995e+00, ...,  7.999e+00,
#                          8.000e+00],
#                        [ 8.712e-01,  1.995e+00, ...,  7.999e+00,
#                          8.000e+00]]), array([ 3.443e+01,  3.443e+01,  3.443e+01,  3.443e+01,
#                         3.443e+01,  3.443e+01,  3.443e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [0.10527633484601345, 1.6725528318765503, 0.02214954256524768, 0.3108573501668186, 2.119716833242804, 7.312152248213653]
# final_loss_fn:  21446.07421875
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 21446.07421875
#              x: [ 1.336e-01  1.051e-01  2.611e-02  3.047e-01  2.752e+00
#                   9.790e+00]
#            nit: 44
#           nfev: 197
#  final_simplex: (array([[ 1.336e-01,  1.051e-01, ...,  2.752e+00,
#                          9.790e+00],
#                        [ 1.336e-01,  1.051e-01, ...,  2.752e+00,
#                          9.790e+00],
#                        ...,
#                        [ 1.336e-01,  1.051e-01, ...,  2.752e+00,
#                          9.790e+00],
#                        [ 1.336e-01,  1.051e-01, ...,  2.752e+00,
#                          9.790e+00]]), array([ 2.145e+04,  2.145e+04,  2.145e+04,  2.145e+04,
#                         2.145e+04,  2.145e+04,  2.145e+04]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [2.437676223266508, 2.188304344113311, 0.4542640459460527, 0.25977009329722095, 3.0568619378437214, 12.594781833668932]
# final_loss_fn:  31.512985229492188
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 31.512985229492188
#              x: [ 1.120e+00  2.046e+00  2.228e-02  3.426e-01  7.887e+00
#                   7.560e+00]
#            nit: 1267
#           nfev: 2044
#  final_simplex: (array([[ 1.120e+00,  2.046e+00, ...,  7.887e+00,
#                          7.560e+00],
#                        [ 1.120e+00,  2.046e+00, ...,  7.887e+00,
#                          7.560e+00],
#                        ...,
#                        [ 1.120e+00,  2.046e+00, ...,  7.887e+00,
#                          7.560e+00],
#                        [ 1.120e+00,  2.046e+00, ...,  7.887e+00,
#                          7.560e+00]]), array([ 3.151e+01,  3.151e+01,  3.151e+01,  3.151e+01,
#                         3.151e+01,  3.151e+01,  3.151e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [1.1078581700093657, 0.16106947452730178, 0.4189976735895015, 0.04043536525827367, 7.826458039709584, 18.681037451681213]
# final_loss_fn:  23.419151306152344
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 23.419151306152344
#              x: [ 2.500e+00  1.720e+00  1.000e-04  3.788e-01  7.861e+00
#                   1.161e+01]
#            nit: 1308
#           nfev: 2108
#  final_simplex: (array([[ 2.500e+00,  1.720e+00, ...,  7.861e+00,
#                          1.161e+01],
#                        [ 2.500e+00,  1.720e+00, ...,  7.861e+00,
#                          1.161e+01],
#                        ...,
#                        [ 2.500e+00,  1.720e+00, ...,  7.861e+00,
#                          1.161e+01],
#                        [ 2.500e+00,  1.720e+00, ...,  7.861e+00,
#                          1.161e+01]]), array([ 2.342e+01,  2.342e+01,  2.342e+01,  2.342e+01,
#                         2.342e+01,  2.342e+01,  2.342e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [0.3269916391306869, 1.7751942919382004, 0.3323246905861163, 0.11470539313188532, 2.503047076547869, 11.237566141789642]
# final_loss_fn:  20.057348251342773
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 20.057348251342773
#              x: [ 4.013e-01  2.479e+00  2.789e-01  3.898e-02  3.666e+00
#                   1.349e+01]
#            nit: 497
#           nfev: 851
#  final_simplex: (array([[ 4.013e-01,  2.479e+00, ...,  3.666e+00,
#                          1.349e+01],
#                        [ 4.013e-01,  2.479e+00, ...,  3.666e+00,
#                          1.349e+01],
#                        ...,
#                        [ 4.013e-01,  2.479e+00, ...,  3.666e+00,
#                          1.349e+01],
#                        [ 4.013e-01,  2.479e+00, ...,  3.666e+00,
#                          1.349e+01]]), array([ 2.006e+01,  2.006e+01,  2.006e+01,  2.006e+01,
#                         2.006e+01,  2.006e+01,  2.006e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [1.8767260137619313, 1.1266573453222772, 0.05470232405581208, 0.253836328562936, 7.231730316804843, 17.19396266957245]
# final_loss_fn:  20.720556259155273
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 20.720556259155273
#              x: [ 2.305e+00  1.884e+00  1.000e-04  1.563e-01  5.612e+00
#                   1.396e+01]
#            nit: 1126
#           nfev: 1836
#  final_simplex: (array([[ 2.305e+00,  1.884e+00, ...,  5.612e+00,
#                          1.396e+01],
#                        [ 2.305e+00,  1.884e+00, ...,  5.612e+00,
#                          1.396e+01],
#                        ...,
#                        [ 2.305e+00,  1.884e+00, ...,  5.612e+00,
#                          1.396e+01],
#                        [ 2.305e+00,  1.884e+00, ...,  5.612e+00,
#                          1.396e+01]]), array([ 2.072e+01,  2.072e+01,  2.072e+01,  2.072e+01,
#                         2.072e+01,  2.072e+01,  2.072e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [1.2870632868451812, 2.272143385624032, 0.19528372238056066, 0.027905518946738723, 7.651898133864545, 19.34653350490573]
# final_loss_fn:  20.42869758605957
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 20.42869758605957
#              x: [ 3.933e-01  2.496e+00  2.914e-01  2.715e-02  4.392e+00
#                   1.334e+01]
#            nit: 437
#           nfev: 763
#  final_simplex: (array([[ 3.933e-01,  2.496e+00, ...,  4.392e+00,
#                          1.334e+01],
#                        [ 3.933e-01,  2.496e+00, ...,  4.392e+00,
#                          1.334e+01],
#                        ...,
#                        [ 3.933e-01,  2.496e+00, ...,  4.392e+00,
#                          1.334e+01],
#                        [ 3.933e-01,  2.496e+00, ...,  4.392e+00,
#                          1.334e+01]]), array([ 2.043e+01,  2.043e+01,  2.043e+01,  2.043e+01,
#                         2.043e+01,  2.043e+01,  2.043e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [2.37179304781311, 2.121383844674905, 0.0657297476233782, 0.2211217187559186, 5.889803724320878, 19.850997999845557]
# final_loss_fn:  33.95335388183594
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 33.95335388183594
#              x: [ 5.000e-03  2.500e+00  8.279e-02  2.810e-03  5.792e+00
#                   1.976e+01]
#            nit: 1546
#           nfev: 2507
#  final_simplex: (array([[ 5.000e-03,  2.500e+00, ...,  5.792e+00,
#                          1.976e+01],
#                        [ 5.000e-03,  2.500e+00, ...,  5.792e+00,
#                          1.976e+01],
#                        ...,
#                        [ 5.000e-03,  2.500e+00, ...,  5.792e+00,
#                          1.976e+01],
#                        [ 5.000e-03,  2.500e+00, ...,  5.792e+00,
#                          1.976e+01]]), array([ 3.395e+01,  3.395e+01,  3.395e+01,  3.395e+01,
#                         3.395e+01,  3.395e+01,  3.395e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [0.5823073249872537, 1.15472002813869, 0.27833051741191717, 0.4038218646374411, 2.982307433479172, 17.619946732000443]
# final_loss_fn:  21446.07421875
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 21446.07421875
#              x: [ 2.538e-01  5.000e-03  5.000e-01  5.000e-01  5.529e+00
#                   1.999e+01]
#            nit: 57
#           nfev: 216
#  final_simplex: (array([[ 2.538e-01,  5.000e-03, ...,  5.529e+00,
#                          1.999e+01],
#                        [ 2.538e-01,  5.000e-03, ...,  5.529e+00,
#                          1.999e+01],
#                        ...,
#                        [ 2.538e-01,  5.000e-03, ...,  5.529e+00,
#                          1.999e+01],
#                        [ 2.538e-01,  5.000e-03, ...,  5.529e+00,
#                          1.999e+01]]), array([ 2.145e+04,  2.145e+04,  2.145e+04,  2.145e+04,
#                         2.145e+04,  2.145e+04,  2.145e+04]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [0.021208847160113842, 0.6965656037129688, 0.04475436714817398, 0.3466001752208569, 5.251919466749353, 8.32548679156253]
# final_loss_fn:  21446.07421875
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 21446.07421875
#              x: [ 2.327e-02  3.312e-01  4.455e-02  3.520e-01  6.749e+00
#                   8.756e+00]
#            nit: 38
#           nfev: 183
#  final_simplex: (array([[ 2.327e-02,  3.312e-01, ...,  6.749e+00,
#                          8.756e+00],
#                        [ 2.327e-02,  3.312e-01, ...,  6.749e+00,
#                          8.756e+00],
#                        ...,
#                        [ 2.327e-02,  3.312e-01, ...,  6.749e+00,
#                          8.756e+00],
#                        [ 2.327e-02,  3.312e-01, ...,  6.749e+00,
#                          8.756e+00]]), array([ 2.145e+04,  2.145e+04,  2.145e+04,  2.145e+04,
#                         2.145e+04,  2.145e+04,  2.145e+04]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [2.2044201674803534, 0.5616143405059469, 0.29055624002588026, 0.34112319306915195, 2.3136563768580123, 7.488170567184491]
# final_loss_fn:  19.71646499633789
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 19.71646499633789
#              x: [ 1.122e+00  2.165e+00  3.427e-03  3.066e-02  7.956e+00
#                   1.364e+01]
#            nit: 1735
#           nfev: 2770
#  final_simplex: (array([[ 1.122e+00,  2.165e+00, ...,  7.956e+00,
#                          1.364e+01],
#                        [ 1.122e+00,  2.165e+00, ...,  7.956e+00,
#                          1.364e+01],
#                        ...,
#                        [ 1.122e+00,  2.165e+00, ...,  7.956e+00,
#                          1.364e+01],
#                        [ 1.122e+00,  2.165e+00, ...,  7.956e+00,
#                          1.364e+01]]), array([ 1.972e+01,  1.972e+01,  1.972e+01,  1.972e+01,
#                         1.972e+01,  1.972e+01,  1.972e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [0.392823189798375, 2.343100105088855, 0.36610493087342366, 0.0354992160025283, 6.938935253931567, 15.293234518420562]
# final_loss_fn:  20.404329299926758
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 20.404329299926758
#              x: [ 4.284e-01  2.330e+00  2.103e-01  4.661e-02  5.410e+00
#                   1.285e+01]
#            nit: 428
#           nfev: 754
#  final_simplex: (array([[ 4.284e-01,  2.330e+00, ...,  5.410e+00,
#                          1.285e+01],
#                        [ 4.284e-01,  2.330e+00, ...,  5.410e+00,
#                          1.285e+01],
#                        ...,
#                        [ 4.284e-01,  2.330e+00, ...,  5.410e+00,
#                          1.285e+01],
#                        [ 4.284e-01,  2.330e+00, ...,  5.410e+00,
#                          1.285e+01]]), array([ 2.040e+01,  2.040e+01,  2.040e+01,  2.040e+01,
#                         2.040e+01,  2.040e+01,  2.040e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [1.913403738506594, 2.1969594696324184, 0.28131814079538486, 0.12919225084549707, 7.993376152168321, 13.641030140009109]
# final_loss_fn:  26.59890365600586
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 26.59890365600586
#              x: [ 4.002e-01  2.104e+00  3.861e-01  2.792e-01  7.961e+00
#                   8.129e+00]
#            nit: 428
#           nfev: 760
#  final_simplex: (array([[ 4.002e-01,  2.104e+00, ...,  7.961e+00,
#                          8.129e+00],
#                        [ 4.002e-01,  2.104e+00, ...,  7.961e+00,
#                          8.129e+00],
#                        ...,
#                        [ 4.002e-01,  2.104e+00, ...,  7.961e+00,
#                          8.129e+00],
#                        [ 4.002e-01,  2.104e+00, ...,  7.961e+00,
#                          8.129e+00]]), array([ 2.660e+01,  2.660e+01,  2.660e+01,  2.660e+01,
#                         2.660e+01,  2.660e+01,  2.660e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [1.751720687069778, 2.2799428036090528, 0.2388131572365884, 0.4156676402443617, 1.8101390273794697, 14.847544387913135]
# final_loss_fn:  18.835317611694336
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 18.835317611694336
#              x: [ 1.093e+00  2.492e+00  1.037e-02  2.897e-02  1.965e+00
#                   1.576e+01]
#            nit: 1226
#           nfev: 1942
#  final_simplex: (array([[ 1.093e+00,  2.492e+00, ...,  1.965e+00,
#                          1.576e+01],
#                        [ 1.093e+00,  2.492e+00, ...,  1.965e+00,
#                          1.576e+01],
#                        ...,
#                        [ 1.093e+00,  2.492e+00, ...,  1.965e+00,
#                          1.576e+01],
#                        [ 1.093e+00,  2.492e+00, ...,  1.965e+00,
#                          1.576e+01]]), array([ 1.884e+01,  1.884e+01,  1.884e+01,  1.884e+01,
#                         1.884e+01,  1.884e+01,  1.884e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [2.31468094347125, 1.286303919767704, 0.23273911398119201, 0.17666580424002334, 6.085112348500324, 7.9646362802595005]
# final_loss_fn:  26.218042373657227
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 26.218042373657227
#              x: [ 6.312e-01  2.061e+00  1.123e-01  2.859e-01  7.912e+00
#                   8.459e+00]
#            nit: 501
#           nfev: 874
#  final_simplex: (array([[ 6.312e-01,  2.061e+00, ...,  7.912e+00,
#                          8.459e+00],
#                        [ 6.312e-01,  2.061e+00, ...,  7.912e+00,
#                          8.459e+00],
#                        ...,
#                        [ 6.312e-01,  2.061e+00, ...,  7.912e+00,
#                          8.459e+00],
#                        [ 6.312e-01,  2.061e+00, ...,  7.912e+00,
#                          8.459e+00]]), array([ 2.622e+01,  2.622e+01,  2.622e+01,  2.622e+01,
#                         2.622e+01,  2.622e+01,  2.622e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [2.4609884730013296, 2.2359488471889994, 0.38300423457004173, 0.07033623266216374, 3.4115550067139178, 13.000226667390223]
# final_loss_fn:  21.851882934570312
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 21.851882934570312
#              x: [ 2.464e-01  2.500e+00  4.642e-01  1.749e-02  7.149e+00
#                   1.213e+01]
#            nit: 1396
#           nfev: 2260
#  final_simplex: (array([[ 2.464e-01,  2.500e+00, ...,  7.149e+00,
#                          1.213e+01],
#                        [ 2.464e-01,  2.500e+00, ...,  7.149e+00,
#                          1.213e+01],
#                        ...,
#                        [ 2.464e-01,  2.500e+00, ...,  7.149e+00,
#                          1.213e+01],
#                        [ 2.464e-01,  2.500e+00, ...,  7.149e+00,
#                          1.213e+01]]), array([ 2.185e+01,  2.185e+01,  2.185e+01,  2.185e+01,
#                         2.185e+01,  2.185e+01,  2.185e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [0.6347293019693975, 1.569785971368889, 0.4732546833351717, 0.21751174866543302, 6.583446924187184, 6.574669033117464]
# final_loss_fn:  22.402511596679688
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 22.402511596679688
#              x: [ 5.107e-01  2.137e+00  2.131e-01  1.761e-01  7.812e+00
#                   8.938e+00]
#            nit: 394
#           nfev: 697
#  final_simplex: (array([[ 5.107e-01,  2.137e+00, ...,  7.812e+00,
#                          8.938e+00],
#                        [ 5.107e-01,  2.137e+00, ...,  7.812e+00,
#                          8.938e+00],
#                        ...,
#                        [ 5.107e-01,  2.137e+00, ...,  7.812e+00,
#                          8.938e+00],
#                        [ 5.107e-01,  2.137e+00, ...,  7.812e+00,
#                          8.938e+00]]), array([ 2.240e+01,  2.240e+01,  2.240e+01,  2.240e+01,
#                         2.240e+01,  2.240e+01,  2.240e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [1.6219809698745715, 0.24708014429210148, 0.1976138042515584, 0.2226920539517835, 6.180321580733201, 9.57663665518665]
# final_loss_fn:  23.32756805419922
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 23.32756805419922
#              x: [ 2.448e+00  1.764e+00  1.000e-04  1.842e-01  7.600e+00
#                   1.273e+01]
#            nit: 1771
#           nfev: 2854
#  final_simplex: (array([[ 2.448e+00,  1.764e+00, ...,  7.600e+00,
#                          1.273e+01],
#                        [ 2.448e+00,  1.764e+00, ...,  7.600e+00,
#                          1.273e+01],
#                        ...,
#                        [ 2.448e+00,  1.764e+00, ...,  7.600e+00,
#                          1.273e+01],
#                        [ 2.448e+00,  1.764e+00, ...,  7.600e+00,
#                          1.273e+01]]), array([ 2.333e+01,  2.333e+01,  2.333e+01,  2.333e+01,
#                         2.333e+01,  2.333e+01,  2.333e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [0.27335143090628855, 2.3482137241843155, 0.34152438611042935, 0.15996395651511633, 5.138382195064539, 16.035298232776363]
# final_loss_fn:  23.459184646606445
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 23.459184646606445
#              x: [ 3.426e-01  2.141e+00  4.703e-01  1.915e-01  8.000e+00
#                   8.762e+00]
#            nit: 401
#           nfev: 691
#  final_simplex: (array([[ 3.426e-01,  2.141e+00, ...,  8.000e+00,
#                          8.762e+00],
#                        [ 3.426e-01,  2.141e+00, ...,  8.000e+00,
#                          8.762e+00],
#                        ...,
#                        [ 3.426e-01,  2.141e+00, ...,  8.000e+00,
#                          8.762e+00],
#                        [ 3.426e-01,  2.141e+00, ...,  8.000e+00,
#                          8.762e+00]]), array([ 2.346e+01,  2.346e+01,  2.346e+01,  2.346e+01,
#                         2.346e+01,  2.346e+01,  2.346e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [0.4139988796778475, 0.9414442723532387, 0.2110007887711358, 0.013305063800116746, 7.887212871156966, 9.9894098704604]
# final_loss_fn:  21446.07421875
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 21446.07421875
#              x: [ 3.245e-01  5.000e-03  3.485e-01  1.766e-02  7.896e+00
#                   1.404e+01]
#            nit: 50
#           nfev: 212
#  final_simplex: (array([[ 3.245e-01,  5.000e-03, ...,  7.896e+00,
#                          1.404e+01],
#                        [ 3.245e-01,  5.000e-03, ...,  7.896e+00,
#                          1.404e+01],
#                        ...,
#                        [ 3.245e-01,  5.000e-03, ...,  7.896e+00,
#                          1.404e+01],
#                        [ 3.245e-01,  5.000e-03, ...,  7.896e+00,
#                          1.404e+01]]), array([ 2.145e+04,  2.145e+04,  2.145e+04,  2.145e+04,
#                         2.145e+04,  2.145e+04,  2.145e+04]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [1.803153964057412, 2.4331077968996757, 0.1325637027170039, 0.38965570213277556, 7.927721036951549, 18.08322312936893]
# final_loss_fn:  29.028379440307617
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 29.028379440307617
#              x: [ 5.972e-01  2.306e+00  3.912e-01  2.028e-01  8.000e+00
#                   6.000e+00]
#            nit: 683
#           nfev: 1118
#  final_simplex: (array([[ 5.972e-01,  2.306e+00, ...,  8.000e+00,
#                          6.000e+00],
#                        [ 5.972e-01,  2.306e+00, ...,  8.000e+00,
#                          6.000e+00],
#                        ...,
#                        [ 5.972e-01,  2.306e+00, ...,  8.000e+00,
#                          6.000e+00],
#                        [ 5.972e-01,  2.306e+00, ...,  8.000e+00,
#                          6.000e+00]]), array([ 2.903e+01,  2.903e+01,  2.903e+01,  2.903e+01,
#                         2.903e+01,  2.903e+01,  2.903e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [2.447896247835465, 2.1830733478127957, 0.385998540792415, 0.3357102971103967, 7.744814559261431, 13.362880375104934]
# final_loss_fn:  31.0426025390625
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 31.0426025390625
#              x: [ 5.368e-01  2.351e+00  5.000e-01  2.126e-01  7.598e+00
#                   6.000e+00]
#            nit: 1464
#           nfev: 2304
#  final_simplex: (array([[ 5.368e-01,  2.351e+00, ...,  7.598e+00,
#                          6.000e+00],
#                        [ 5.368e-01,  2.351e+00, ...,  7.598e+00,
#                          6.000e+00],
#                        ...,
#                        [ 5.368e-01,  2.351e+00, ...,  7.598e+00,
#                          6.000e+00],
#                        [ 5.368e-01,  2.351e+00, ...,  7.598e+00,
#                          6.000e+00]]), array([ 3.104e+01,  3.104e+01,  3.104e+01,  3.104e+01,
#                         3.104e+01,  3.104e+01,  3.104e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [0.03798599755683839, 0.6014664129221227, 0.06704524368108897, 0.3933471210193306, 5.7323927648101565, 11.441096995863541]
# final_loss_fn:  21446.07421875
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 21446.07421875
#              x: [ 3.973e-02  4.020e-01  6.991e-02  3.880e-01  6.748e+00
#                   1.189e+01]
#            nit: 39
#           nfev: 190
#  final_simplex: (array([[ 3.973e-02,  4.020e-01, ...,  6.748e+00,
#                          1.189e+01],
#                        [ 3.973e-02,  4.020e-01, ...,  6.748e+00,
#                          1.189e+01],
#                        ...,
#                        [ 3.973e-02,  4.020e-01, ...,  6.748e+00,
#                          1.189e+01],
#                        [ 3.973e-02,  4.020e-01, ...,  6.748e+00,
#                          1.189e+01]]), array([ 2.145e+04,  2.145e+04,  2.145e+04,  2.145e+04,
#                         2.145e+04,  2.145e+04,  2.145e+04]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [2.0225554157632, 1.5841446870268865, 0.38654104390754945, 0.23962056906773413, 1.2549009198214915, 17.764492878887935]
# final_loss_fn:  19.48059844970703
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 19.48059844970703
#              x: [ 7.877e-01  2.327e+00  4.547e-02  4.882e-02  3.975e+00
#                   1.375e+01]
#            nit: 1587
#           nfev: 2497
#  final_simplex: (array([[ 7.877e-01,  2.327e+00, ...,  3.975e+00,
#                          1.375e+01],
#                        [ 7.877e-01,  2.327e+00, ...,  3.975e+00,
#                          1.375e+01],
#                        ...,
#                        [ 7.877e-01,  2.327e+00, ...,  3.975e+00,
#                          1.375e+01],
#                        [ 7.877e-01,  2.327e+00, ...,  3.975e+00,
#                          1.375e+01]]), array([ 1.948e+01,  1.948e+01,  1.948e+01,  1.948e+01,
#                         1.948e+01,  1.948e+01,  1.948e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [0.5719350975067767, 1.5176585516006387, 0.17815024949983885, 0.24032982871888678, 7.894365313874889, 15.4447674592102]
# final_loss_fn:  24.579111099243164
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 24.579111099243164
#              x: [ 5.115e-01  2.121e+00  2.476e-01  2.408e-01  7.836e+00
#                   8.199e+00]
#            nit: 366
#           nfev: 661
#  final_simplex: (array([[ 5.115e-01,  2.121e+00, ...,  7.836e+00,
#                          8.199e+00],
#                        [ 5.115e-01,  2.121e+00, ...,  7.836e+00,
#                          8.199e+00],
#                        ...,
#                        [ 5.115e-01,  2.121e+00, ...,  7.836e+00,
#                          8.199e+00],
#                        [ 5.115e-01,  2.121e+00, ...,  7.836e+00,
#                          8.199e+00]]), array([ 2.458e+01,  2.458e+01,  2.458e+01,  2.458e+01,
#                         2.458e+01,  2.458e+01,  2.458e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [0.011138489249566976, 1.0945036020773646, 0.29469724886318616, 0.33411749454353834, 3.8947895651530917, 10.246072244878826]
# final_loss_fn:  21446.07421875
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 21446.07421875
#              x: [ 1.186e-02  2.144e-01  3.642e-01  3.590e-01  4.994e+00
#                   1.051e+01]
#            nit: 43
#           nfev: 203
#  final_simplex: (array([[ 1.186e-02,  2.144e-01, ...,  4.994e+00,
#                          1.051e+01],
#                        [ 1.186e-02,  2.144e-01, ...,  4.994e+00,
#                          1.051e+01],
#                        ...,
#                        [ 1.186e-02,  2.144e-01, ...,  4.994e+00,
#                          1.051e+01],
#                        [ 1.186e-02,  2.144e-01, ...,  4.994e+00,
#                          1.051e+01]]), array([ 2.145e+04,  2.145e+04,  2.145e+04,  2.145e+04,
#                         2.145e+04,  2.145e+04,  2.145e+04]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [1.9738644437867687, 2.1562713354865224, 0.488316995296269, 0.18075394184139515, 6.841176978509239, 18.888195598553217]
# final_loss_fn:  20.88182830810547
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 20.88182830810547
#              x: [ 3.472e-01  2.276e+00  4.969e-01  6.944e-02  7.666e+00
#                   1.006e+01]
#            nit: 442
#           nfev: 757
#  final_simplex: (array([[ 3.472e-01,  2.276e+00, ...,  7.666e+00,
#                          1.006e+01],
#                        [ 3.472e-01,  2.276e+00, ...,  7.666e+00,
#                          1.006e+01],
#                        ...,
#                        [ 3.472e-01,  2.276e+00, ...,  7.666e+00,
#                          1.006e+01],
#                        [ 3.472e-01,  2.276e+00, ...,  7.666e+00,
#                          1.006e+01]]), array([ 2.088e+01,  2.088e+01,  2.088e+01,  2.088e+01,
#                         2.088e+01,  2.088e+01,  2.088e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [0.2800730270324018, 1.2015663794412452, 0.06970567472255838, 0.2456930543848938, 2.0790957413571136, 14.201082444778795]
# final_loss_fn:  21446.07421875
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 21446.07421875
#              x: [ 2.069e-01  1.700e-01  9.348e-02  1.826e-01  4.151e+00
#                   1.957e+01]
#            nit: 61
#           nfev: 220
#  final_simplex: (array([[ 2.069e-01,  1.700e-01, ...,  4.151e+00,
#                          1.957e+01],
#                        [ 2.069e-01,  1.700e-01, ...,  4.151e+00,
#                          1.957e+01],
#                        ...,
#                        [ 2.069e-01,  1.700e-01, ...,  4.151e+00,
#                          1.957e+01],
#                        [ 2.069e-01,  1.700e-01, ...,  4.151e+00,
#                          1.957e+01]]), array([ 2.145e+04,  2.145e+04,  2.145e+04,  2.145e+04,
#                         2.145e+04,  2.145e+04,  2.145e+04]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [1.1296949814752124, 0.2686988378994273, 0.03379822986032336, 0.22787439659289402, 1.02428290695751, 19.759086104790104]
# final_loss_fn:  21446.07421875
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 21446.07421875
#              x: [ 8.455e-02  1.967e-01  1.590e-02  4.420e-01  3.012e+00
#                   1.981e+01]
#            nit: 60
#           nfev: 220
#  final_simplex: (array([[ 8.455e-02,  1.967e-01, ...,  3.012e+00,
#                          1.981e+01],
#                        [ 8.455e-02,  1.967e-01, ...,  3.012e+00,
#                          1.981e+01],
#                        ...,
#                        [ 8.455e-02,  1.967e-01, ...,  3.012e+00,
#                          1.981e+01],
#                        [ 8.455e-02,  1.967e-01, ...,  3.012e+00,
#                          1.981e+01]]), array([ 2.145e+04,  2.145e+04,  2.145e+04,  2.145e+04,
#                         2.145e+04,  2.145e+04,  2.145e+04]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [0.45127143565019473, 1.7446231012891784, 0.498001673282656, 0.2613546668614738, 7.8002263338516915, 16.49728308855431]
# final_loss_fn:  20.85611343383789
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 20.85611343383789
#              x: [ 3.481e-01  2.289e+00  4.899e-01  6.616e-02  7.270e+00
#                   1.042e+01]
#            nit: 844
#           nfev: 1384
#  final_simplex: (array([[ 3.481e-01,  2.289e+00, ...,  7.270e+00,
#                          1.042e+01],
#                        [ 3.481e-01,  2.289e+00, ...,  7.270e+00,
#                          1.042e+01],
#                        ...,
#                        [ 3.481e-01,  2.289e+00, ...,  7.270e+00,
#                          1.042e+01],
#                        [ 3.481e-01,  2.289e+00, ...,  7.270e+00,
#                          1.042e+01]]), array([ 2.086e+01,  2.086e+01,  2.086e+01,  2.086e+01,
#                         2.086e+01,  2.086e+01,  2.086e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [2.402663221205264, 1.9845692629188978, 0.17431260931793077, 0.05747627129085658, 3.668048497036141, 14.354925260886882]
# final_loss_fn:  28.0299129486084
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 28.0299129486084
#              x: [ 5.510e-01  2.363e+00  4.998e-01  1.627e-01  8.000e+00
#                   6.000e+00]
#            nit: 1092
#           nfev: 1746
#  final_simplex: (array([[ 5.510e-01,  2.363e+00, ...,  8.000e+00,
#                          6.000e+00],
#                        [ 5.510e-01,  2.363e+00, ...,  8.000e+00,
#                          6.000e+00],
#                        ...,
#                        [ 5.510e-01,  2.363e+00, ...,  8.000e+00,
#                          6.000e+00],
#                        [ 5.510e-01,  2.363e+00, ...,  8.000e+00,
#                          6.000e+00]]), array([ 2.803e+01,  2.803e+01,  2.803e+01,  2.803e+01,
#                         2.803e+01,  2.803e+01,  2.803e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [0.2452835640417704, 1.434386129867151, 0.023325398806250692, 0.4468522340308949, 2.0892677005798133, 13.818124301085366]
# final_loss_fn:  21446.07421875
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 21446.07421875
#              x: [ 3.017e-01  9.895e-02  5.532e-02  4.935e-01  5.510e+00
#                   1.929e+01]
#            nit: 61
#           nfev: 226
#  final_simplex: (array([[ 3.017e-01,  9.895e-02, ...,  5.510e+00,
#                          1.929e+01],
#                        [ 3.017e-01,  9.895e-02, ...,  5.510e+00,
#                          1.929e+01],
#                        ...,
#                        [ 3.017e-01,  9.895e-02, ...,  5.510e+00,
#                          1.929e+01],
#                        [ 3.017e-01,  9.895e-02, ...,  5.510e+00,
#                          1.929e+01]]), array([ 2.145e+04,  2.145e+04,  2.145e+04,  2.145e+04,
#                         2.145e+04,  2.145e+04,  2.145e+04]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [1.307697249035137, 0.09934237431993065, 0.37119022278175695, 0.28794638590231647, 3.990048519084511, 15.40333354154884]
# final_loss_fn:  47.15435028076172
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 47.15435028076172
#              x: [ 1.935e+00  1.921e+00  1.059e-02  5.000e-01  7.910e+00
#                   6.025e+00]
#            nit: 1071
#           nfev: 1762
#  final_simplex: (array([[ 1.935e+00,  1.921e+00, ...,  7.910e+00,
#                          6.025e+00],
#                        [ 1.935e+00,  1.921e+00, ...,  7.910e+00,
#                          6.025e+00],
#                        ...,
#                        [ 1.935e+00,  1.921e+00, ...,  7.910e+00,
#                          6.025e+00],
#                        [ 1.935e+00,  1.921e+00, ...,  7.910e+00,
#                          6.025e+00]]), array([ 4.715e+01,  4.715e+01,  4.715e+01,  4.715e+01,
#                         4.715e+01,  4.715e+01,  4.715e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [1.3901667551555372, 1.7289782478910636, 0.43541523649361275, 0.252273425287114, 7.400310823465951, 11.866123298679135]
# final_loss_fn:  35.46787643432617
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 35.46787643432617
#              x: [ 3.502e-01  2.061e+00  3.762e-01  4.287e-01  7.457e+00
#                   8.289e+00]
#            nit: 481
#           nfev: 817
#  final_simplex: (array([[ 3.502e-01,  2.061e+00, ...,  7.457e+00,
#                          8.289e+00],
#                        [ 3.502e-01,  2.061e+00, ...,  7.457e+00,
#                          8.289e+00],
#                        ...,
#                        [ 3.502e-01,  2.061e+00, ...,  7.457e+00,
#                          8.289e+00],
#                        [ 3.502e-01,  2.061e+00, ...,  7.457e+00,
#                          8.289e+00]]), array([ 3.547e+01,  3.547e+01,  3.547e+01,  3.547e+01,
#                         3.547e+01,  3.547e+01,  3.547e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [0.5769336501663711, 2.2192118662977482, 0.05163272680913922, 0.29903314730190295, 1.6842969597197033, 12.290206711562472]
# final_loss_fn:  23.84255599975586
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 23.84255599975586
#              x: [ 3.112e-01  2.478e+00  9.479e-02  1.817e-02  3.134e+00
#                   1.671e+01]
#            nit: 1024
#           nfev: 1677
#  final_simplex: (array([[ 3.112e-01,  2.478e+00, ...,  3.134e+00,
#                          1.671e+01],
#                        [ 3.112e-01,  2.478e+00, ...,  3.134e+00,
#                          1.671e+01],
#                        ...,
#                        [ 3.112e-01,  2.478e+00, ...,  3.134e+00,
#                          1.671e+01],
# ...
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [2.176023370509256, 2.259234578322785, 0.07975030648127437, 0.2772306031590101, 1.6400053133581949, 14.984454834980134]
# final_loss_fn:  19.352039337158203
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 19.352039337158203
#              x: [ 7.220e-01  2.464e+00  6.430e-02  3.670e-02  2.920e+00
#                   1.432e+01]
#            nit: 986
#           nfev: 1629
#  final_simplex: (array([[ 7.220e-01,  2.464e+00, ...,  2.920e+00,
#                          1.432e+01],
#                        [ 7.220e-01,  2.464e+00, ...,  2.920e+00,
#                          1.432e+01],
#                        ...,
#                        [ 7.220e-01,  2.464e+00, ...,  2.920e+00,
#                          1.432e+01],
#                        [ 7.220e-01,  2.464e+00, ...,  2.920e+00,
#                          1.432e+01]]), array([ 1.935e+01,  1.935e+01,  1.935e+01,  1.935e+01,
#                         1.935e+01,  1.935e+01,  1.935e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [1.7739399462636571, 0.226191622960837, 0.052286037305372075, 0.34161075883948333, 3.9047697615005106, 19.702838549768508]
# final_loss_fn:  37.46304702758789
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 37.46304702758789
#              x: [ 8.968e-01  1.980e+00  2.393e-02  5.000e-01  7.981e+00
#                   8.022e+00]
#            nit: 1295
#           nfev: 2116
#  final_simplex: (array([[ 8.968e-01,  1.980e+00, ...,  7.981e+00,
#                          8.022e+00],
#                        [ 8.968e-01,  1.980e+00, ...,  7.981e+00,
#                          8.022e+00],
#                        ...,
#                        [ 8.968e-01,  1.980e+00, ...,  7.981e+00,
#                          8.022e+00],
#                        [ 8.968e-01,  1.980e+00, ...,  7.981e+00,
#                          8.022e+00]]), array([ 3.746e+01,  3.746e+01,  3.746e+01,  3.746e+01,
#                         3.746e+01,  3.746e+01,  3.746e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [0.7800128202670289, 1.9669723598168256, 0.43962454541450113, 0.37406755848774975, 6.620256798240784, 13.273629240085045]
# final_loss_fn:  22.691490173339844
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 22.691490173339844
#              x: [ 3.824e-01  2.369e+00  4.990e-01  1.137e-01  3.912e+00
#                   1.166e+01]
#            nit: 1079
#           nfev: 1757
#  final_simplex: (array([[ 3.824e-01,  2.369e+00, ...,  3.912e+00,
#                          1.166e+01],
#                        [ 3.824e-01,  2.369e+00, ...,  3.912e+00,
#                          1.166e+01],
#                        ...,
#                        [ 3.824e-01,  2.369e+00, ...,  3.912e+00,
#                          1.166e+01],
#                        [ 3.824e-01,  2.369e+00, ...,  3.912e+00,
#                          1.166e+01]]), array([ 2.269e+01,  2.269e+01,  2.269e+01,  2.269e+01,
#                         2.269e+01,  2.269e+01,  2.269e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [2.4679694383439017, 0.10705056181872054, 0.46254581230853725, 0.396558509218251, 6.175077431999119, 13.984492321665517]
# final_loss_fn:  92.67816162109375
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 92.67816162109375
#              x: [ 2.253e+00  1.852e+00  1.404e-02  1.568e-01  8.000e+00
#                   6.000e+00]
#            nit: 956
#           nfev: 1572
#  final_simplex: (array([[ 2.253e+00,  1.852e+00, ...,  8.000e+00,
#                          6.000e+00],
#                        [ 2.253e+00,  1.852e+00, ...,  8.000e+00,
#                          6.000e+00],
#                        ...,
#                        [ 2.253e+00,  1.852e+00, ...,  8.000e+00,
#                          6.000e+00],
#                        [ 2.253e+00,  1.852e+00, ...,  8.000e+00,
#                          6.000e+00]]), array([ 9.268e+01,  9.268e+01,  9.268e+01,  9.268e+01,
#                         9.268e+01,  9.268e+01,  9.268e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [1.5069883639543489, 2.094488095052324, 0.4784948509921713, 0.45322975764842854, 4.759824700577607, 7.571218635538132]
# final_loss_fn:  25.15372085571289
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 25.15372085571289
#              x: [ 7.272e-01  2.089e+00  7.264e-02  2.441e-01  5.616e+00
#                   1.080e+01]
#            nit: 1290
#           nfev: 2045
#  final_simplex: (array([[ 7.272e-01,  2.089e+00, ...,  5.616e+00,
#                          1.080e+01],
#                        [ 7.272e-01,  2.089e+00, ...,  5.616e+00,
#                          1.080e+01],
#                        ...,
#                        [ 7.272e-01,  2.089e+00, ...,  5.616e+00,
#                          1.080e+01],
#                        [ 7.272e-01,  2.089e+00, ...,  5.616e+00,
#                          1.080e+01]]), array([ 2.515e+01,  2.515e+01,  2.515e+01,  2.515e+01,
#                         2.515e+01,  2.515e+01,  2.515e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [0.9396310566199422, 0.46846320741266273, 0.15231810026901346, 0.42346630514070216, 5.7070495362138685, 9.436465604286813]
# final_loss_fn:  21446.07421875
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 21446.07421875
#              x: [ 5.000e-03  4.442e-01  1.735e-01  5.000e-01  8.000e+00
#                   1.013e+01]
#            nit: 43
#           nfev: 190
#  final_simplex: (array([[ 5.000e-03,  4.442e-01, ...,  8.000e+00,
#                          1.013e+01],
#                        [ 5.000e-03,  4.442e-01, ...,  8.000e+00,
#                          1.013e+01],
#                        ...,
#                        [ 5.000e-03,  4.442e-01, ...,  8.000e+00,
#                          1.013e+01],
#                        [ 5.000e-03,  4.442e-01, ...,  8.000e+00,
#                          1.013e+01]]), array([ 2.145e+04,  2.145e+04,  2.145e+04,  2.145e+04,
#                         2.145e+04,  2.145e+04,  2.145e+04]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [0.0690722954084922, 1.2374926347222448, 0.10120703359093013, 0.47113389159571617, 4.1796866655033496, 11.276470419224884]
# final_loss_fn:  21446.07421875
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 21446.07421875
#              x: [ 7.357e-02  2.424e-01  1.251e-01  5.000e-01  5.359e+00
#                   1.157e+01]
#            nit: 44
#           nfev: 204
#  final_simplex: (array([[ 7.357e-02,  2.424e-01, ...,  5.359e+00,
#                          1.157e+01],
#                        [ 7.357e-02,  2.424e-01, ...,  5.359e+00,
#                          1.157e+01],
#                        ...,
#                        [ 7.357e-02,  2.424e-01, ...,  5.359e+00,
#                          1.157e+01],
#                        [ 7.357e-02,  2.424e-01, ...,  5.359e+00,
#                          1.157e+01]]), array([ 2.145e+04,  2.145e+04,  2.145e+04,  2.145e+04,
#                         2.145e+04,  2.145e+04,  2.145e+04]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [0.8878189816971435, 0.8182614368356763, 0.09834324487760368, 0.3992592041769419, 5.989133000022388, 9.888609116134335]
# final_loss_fn:  21446.07421875
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 21446.07421875
#              x: [ 5.000e-03  4.359e-01  1.229e-01  4.952e-01  8.000e+00
#                   1.963e+01]
#            nit: 49
#           nfev: 198
#  final_simplex: (array([[ 5.000e-03,  4.359e-01, ...,  8.000e+00,
#                          1.963e+01],
#                        [ 5.000e-03,  4.359e-01, ...,  8.000e+00,
#                          1.963e+01],
#                        ...,
#                        [ 5.000e-03,  4.359e-01, ...,  8.000e+00,
#                          1.963e+01],
#                        [ 5.000e-03,  4.359e-01, ...,  8.000e+00,
#                          1.963e+01]]), array([ 2.145e+04,  2.145e+04,  2.145e+04,  2.145e+04,
#                         2.145e+04,  2.145e+04,  2.145e+04]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [2.2623963475987003, 0.3622225339841173, 0.31230024404271856, 0.1883166686099582, 1.147162112256649, 7.8016850924589525]
# final_loss_fn:  19.580156326293945
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 19.580156326293945
#              x: [ 1.712e+00  2.190e+00  1.041e-04  1.316e-02  7.835e+00
#                   1.605e+01]
#            nit: 3404
#           nfev: 5288
#  final_simplex: (array([[ 1.712e+00,  2.190e+00, ...,  7.835e+00,
#                          1.605e+01],
#                        [ 1.712e+00,  2.190e+00, ...,  7.835e+00,
#                          1.605e+01],
#                        ...,
#                        [ 1.712e+00,  2.190e+00, ...,  7.835e+00,
#                          1.605e+01],
#                        [ 1.712e+00,  2.190e+00, ...,  7.835e+00,
#                          1.605e+01]]), array([ 1.958e+01,  1.958e+01,  1.958e+01,  1.958e+01,
#                         1.958e+01,  1.958e+01,  1.958e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [1.5024655278613581, 0.6654924093452659, 0.00017969916471208882, 0.36461122439076205, 6.162871300074354, 6.901101123838293]
# final_loss_fn:  22.636682510375977
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 22.636682510375977
#              x: [ 2.420e+00  1.753e+00  1.000e-04  2.935e-01  7.638e+00
#                   1.216e+01]
#            nit: 695
#           nfev: 1143
#  final_simplex: (array([[ 2.420e+00,  1.753e+00, ...,  7.638e+00,
#                          1.216e+01],
#                        [ 2.420e+00,  1.753e+00, ...,  7.638e+00,
#                          1.216e+01],
#                        ...,
#                        [ 2.420e+00,  1.753e+00, ...,  7.638e+00,
#                          1.216e+01],
#                        [ 2.420e+00,  1.753e+00, ...,  7.638e+00,
#                          1.216e+01]]), array([ 2.264e+01,  2.264e+01,  2.264e+01,  2.264e+01,
#                         2.264e+01,  2.264e+01,  2.264e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [1.2637126073184357, 0.09968050330428542, 0.0711841141433669, 0.33778535545595, 4.167454644126941, 19.04978210068043]
# final_loss_fn:  140.09823608398438
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 140.09823608398438
#              x: [ 2.378e+00  9.007e-01  6.551e-04  3.440e-01  3.214e+00
#                   1.731e+01]
#            nit: 936
#           nfev: 1544
#  final_simplex: (array([[ 2.378e+00,  9.007e-01, ...,  3.214e+00,
#                          1.731e+01],
#                        [ 2.378e+00,  9.007e-01, ...,  3.214e+00,
#                          1.731e+01],
#                        ...,
#                        [ 2.378e+00,  9.007e-01, ...,  3.214e+00,
#                          1.731e+01],
#                        [ 2.378e+00,  9.007e-01, ...,  3.214e+00,
#                          1.731e+01]]), array([ 1.401e+02,  1.401e+02,  1.401e+02,  1.401e+02,
#                         1.401e+02,  1.401e+02,  1.401e+02]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [1.9944734212340534, 1.8443542397321178, 0.002877047131542582, 0.12381946415110297, 6.240952044685996, 15.09348118742252]
# final_loss_fn:  20.64673614501953
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 20.64673614501953
#              x: [ 1.318e+00  2.015e+00  3.215e-03  1.175e-01  6.874e+00
#                   1.237e+01]
#            nit: 294
#           nfev: 532
#  final_simplex: (array([[ 1.318e+00,  2.015e+00, ...,  6.874e+00,
#                          1.237e+01],
#                        [ 1.318e+00,  2.015e+00, ...,  6.874e+00,
#                          1.237e+01],
#                        ...,
#                        [ 1.318e+00,  2.015e+00, ...,  6.874e+00,
#                          1.237e+01],
#                        [ 1.318e+00,  2.015e+00, ...,  6.874e+00,
#                          1.237e+01]]), array([ 2.065e+01,  2.065e+01,  2.065e+01,  2.065e+01,
#                         2.065e+01,  2.065e+01,  2.065e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [1.7484098068975484, 0.7573875985491112, 0.06871939510732869, 0.3747589097786048, 4.556719101843628, 15.39694305665386]
# final_loss_fn:  19.535032272338867
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 19.535032272338867
#              x: [ 1.307e+00  2.201e+00  1.272e-03  2.398e-02  6.693e+00
#                   1.489e+01]
#            nit: 1070
#           nfev: 1745
#  final_simplex: (array([[ 1.307e+00,  2.201e+00, ...,  6.693e+00,
#                          1.489e+01],
#                        [ 1.307e+00,  2.201e+00, ...,  6.693e+00,
#                          1.489e+01],
#                        ...,
#                        [ 1.307e+00,  2.201e+00, ...,  6.693e+00,
#                          1.489e+01],
#                        [ 1.307e+00,  2.201e+00, ...,  6.693e+00,
#                          1.489e+01]]), array([ 1.954e+01,  1.954e+01,  1.954e+01,  1.954e+01,
#                         1.954e+01,  1.954e+01,  1.954e+01]))
# Optimizing LJ parameters...
# function: get_loss_jax_de
# bounds: ((0.005, 2.5), (0.005, 2.5), (0.0001, 0.5), (0.0001, 0.5), (1, 8), (6, 20))
# maxfev: 10000
# initial guess: [1.1555190270339255, 0.5565369594135895, 0.30576403596755897, 0.250645203451756, 4.675520821556214, 13.422129116220692]
# final_loss_fn:  18.844017028808594
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 18.844017028808594
#              x: [ 2.340e+00  2.179e+00  1.000e-04  8.684e-02  1.551e+00
#                   1.671e+01]
#            nit: 1954
#           nfev: 3094
#  final_simplex: (array([[ 2.340e+00,  2.179e+00, ...,  1.551e+00,
#                          1.671e+01],
#                        [ 2.340e+00,  2.179e+00, ...,  1.551e+00,
#                          1.671e+01],
#                        ...,
#                        [ 2.340e+00,  2.179e+00, ...,  1.551e+00,
#                          1.671e+01],
#                        [ 2.340e+00,  2.179e+00, ...,  1.551e+00,
#                          1.671e+01]]), array([ 1.884e+01,  1.884e+01,  1.884e+01,  1.884e+01,
#                         1.884e+01,  1.884e+01,  1.884e+01]))

# %%
FIT = _c.eval_jax_de(_c.get_best_parm())
TARGETS = _c.targets
_c.data["TARGET"] = TARGETS
_c.data["FIT"] = FIT
_c.data["RESIDUALS"] = TARGETS - FIT

# %%
# plt.hist(TARGETS)
plt.hist(_c.data[_c.intE])
plt.hist(_c.data[_c.elec])
plt.hist(_c.data[_c.intE] - _c.data[_c.elec])
plt.hist(TARGETS - FIT)
# Out:
# (array([ 11.,  27.,  71., 107., 122.,  86.,  47.,  22.,   5.,   2.]),
#  array([-11.32063293,  -8.69663429,  -6.0726347 ,  -3.44863582,
#          -0.82463682,   1.79936218,   4.4233613 ,   7.04736042,
#           9.67135906,  12.29535866,  14.9193573 ]),
#  <BarContainer object of 10 artists>)

# %%
_c.data[["ECOL", "intE"]].describe()
# Out:
#              ECOL          intE
# count  500.000000  5.000000e+02
# mean  -133.827185 -1.916703e+06
# std     24.856582  1.322415e+01
# min   -200.733503 -1.916746e+06
# 25%   -151.116341 -1.916712e+06
# 50%   -133.880791 -1.916704e+06
# 75%   -117.043617 -1.916694e+06
# max    -59.273033 -1.916668e+06

# %%
_c.data["fit_intE"] = _c.data[_c.elec] + _c.data["FIT"]

# %%
pd.DataFrame(_c.opt_results).sort_values("fun")[:10]#.hist("fun")
# Out:
#            fun   nit  nfev  status  success  \
# 217  18.556486   884  1458       0     True
# 298  18.577574   560   962       0     True
# 98   18.577579  1110  1767       0     True
# 17   18.611160   783  1333       0     True
# 216  18.710497  1464  2324       0     True
# 50   18.835318  1226  1942       0     True
# 329  18.844017  1954  3094       0     True
# 148  18.854841   680  1141       0     True
# 308  18.920633  1009  1640       0     True
# 81   19.128391  1223  1949       0     True
#
#                                    message  \
# 217  Optimization terminated successfully.
# 298  Optimization terminated successfully.
# 98   Optimization terminated successfully.
# 17   Optimization terminated successfully.
# 216  Optimization terminated successfully.
# 50   Optimization terminated successfully.
# 329  Optimization terminated successfully.
# 148  Optimization terminated successfully.
# 308  Optimization terminated successfully.
# 81   Optimization terminated successfully.
#
#                                                      x  \
# 217  [1.6468541685281495, 2.417191710843558, 0.0008...
# 298  [1.4209545630011098, 2.4998980022495934, 0.002...
# 98   [1.8456039985183563, 2.2770995739069475, 0.000...
# 17   [1.5387066043093602, 2.39389013489824, 0.00249...
# 216  [1.188179003535509, 2.4667511425168707, 0.0071...
# 50   [1.093257021896827, 2.4918992894480754, 0.0103...
# 329  [2.3399488812250677, 2.1790444432753335, 0.000...
# 148  [2.1257194842416913, 2.139959431814974, 0.0001...
# 308  [1.0531668611000171, 2.4249069784445787, 0.013...
# 81   [0.8554257551596074, 2.499947751689964, 0.0361...
#
#                                          final_simplex
# 217  ([[1.6468541685281495, 2.417191710843558, 0.00...
# 298  ([[1.4209545630011098, 2.4998980022495934, 0.0...
# 98   ([[1.8456039985183563, 2.2770995739069475, 0.0...
# 17   ([[1.5387066043093602, 2.39389013489824, 0.002...
# 216  ([[1.188179003535509, 2.4667511425168707, 0.00...
# 50   ([[1.093257021896827, 2.4918992894480754, 0.01...
# 329  ([[2.3399488812250677, 2.1790444432753335, 0.0...
# 148  ([[2.1257194842416913, 2.139959431814974, 0.00...
# 308  ([[1.0531668611000171, 2.4249069784445787, 0.0...
# 81   ([[0.8554257551596074, 2.499947751689964, 0.03...

# %%
for _ in list(pd.DataFrame(_c.opt_results).sort_values("fun").x):
    print(_[4], _[5])
# Out:
# 1.4068166775224504 17.10129637367106
# 1.3556955172067215 16.76068479556445
# 1.7547710649989041 16.498347433325208
# 1.4923025355164397 16.0
# 1.7879111274370607 15.907573360533036
# 1.965427927248565 15.763958559149419
# 1.550716084585547 16.706753206848617
# 2.3200839277353005 16.229960066979285
# 2.360170520332067 15.15379164016859
# 2.278559476468234 14.853655899074985
# 1.8671548859572045 15.211018420768276
# 1.6873187482733547 15.304123534437977
# 1.0004581311271736 17.206406810265037
# 2.784495364049459 14.416939846637229
# 3.961351929249951 15.662688412845903
# 3.4086935210140443 14.100868139470297
# 2.9195313816648287 14.321053346868304
# 2.8757026896390814 14.180729257911194
# 2.346489172522422 18.36828216800344
# 2.8284904354411506 14.325009319367862
# 2.287191273159793 18.44048455007828
# 6.319729816493629 15.917318729955372
# 6.490646890391808 15.618972989107249
# 3.9748232763266405 13.74897925258485
# 4.990488680609019 13.615605832555019
# 6.692610278589348 14.88854262685198
# 7.834828865061892 16.05495932186649
# 3.2452708330445876 13.77941663270603
# 6.161529785896354 14.35009797718207
# 3.4562356825353806 14.437122672896058
# 3.359494351680129 14.544417176392635
# 3.641202503155653 14.004476469390564
# 3.496121198875646 13.646511645903463
# 5.431087686445245 13.427027815269199
# 6.122584495669555 13.479384404148544
# 5.435892793566667 13.467000435306577
# 7.955521334091934 13.639695707389318
# 3.318879521970084 13.612184755117958
# 6.2926590387579235 16.20356269155781
# 7.562985603399549 13.826810360774289
# 7.9632043011026 14.842232911069797
# 7.480531534797393 14.772249714000385
# 7.8950239147544 12.413749941689387
# 1.6803934753918224 15.912623762368227
# 3.2933559986052763 14.964746403238909
# 7.509840607279333 11.951070567230317
# 2.9529154020786987 13.31307419816433
# 3.6658246058240533 13.490960242858444
# 6.901096362251844 11.826400610410127
# 6.9140600881913095 11.550503918058965
# 5.449827754252947 13.284711779119235
# 7.999548669731276 10.889599854230646
# 3.614694084233818 12.979975338492942
# 6.04790457138559 13.703754516839034
# 3.6404307459627896 13.187903051370988
# 7.094990234330549 11.668824969345415
# 7.999965781924407 11.041232193670652
# 6.2924735427777225 11.51518119983497
# 6.838528576466842 11.789195961069318
# 6.132318079400546 11.786662002777035
# 3.668091987423771 12.954070652990282
# 3.9791014842838184 12.769840323256636
# 6.732220038342259 11.474894596631083
# 6.19331607121504 11.808720868571172
# 4.496114805400688 12.321239799531902
# 6.712131777917781 11.073122874548622
# 5.709707627353263 12.227950589275551
# 4.021836296147477 13.712236775580486
# 2.938041209291028 15.518889485718377
# 3.101047821835436 13.559823891187186
# 5.410381502224595 12.849860119266566
# 4.392068950296388 13.343602143071603
# 7.999981825808766 10.228333720520508
# 7.9667540870724585 10.150351203082714
# 4.369623556608669 12.537394185227518
# 6.173058749760763 11.361027858637254
# 3.338689202225925 13.65970236543886
# 7.5424200102913845 10.696866185166718
# 4.764863614052802 12.117243907068985
# 7.934715810378119 9.928703780916562
# 6.873778952688053 12.366014653417777
# 4.663201955461741 12.366517549155306
# 3.343333260150491 14.529873119745247
# 3.528955795533476 13.515239247257572
# 7.165254101340354 10.487199763537127
# 7.14613187141107 15.411269102622297
# 5.612017634592805 13.95997480674135
# 5.530413107933184 12.132462018622457
# 4.55513171729358 12.84742831869201
# 7.998137917977991 11.861515892755891
# 4.0773017184352724 13.59266818256521
# 7.5467399987162125 10.048422517563512
# 7.98235601712218 10.17779296675517
# 7.998652933716954 10.098378330413272
# 6.826849660956753 10.75555272906822
# 7.2696873340011035 10.42317852400917
# 7.6661478543552235 10.055950687430421
# 5.9160457647576346 10.865728963839192
# 4.295817035241795 11.887981742211466
# 7.1778206987871735 10.872612381797772
# 7.896326110063551 14.12705656573698
# 5.01683577739492 12.825065876702043
# 3.8587857521947493 13.062625731176487
# 4.975624086297713 13.816460431707313
# 7.273231416280881 10.083575375427916
# 6.670778873341993 10.042552021983104
# 6.895938048445106 10.019575280135957
# 7.666957781728207 11.067544694353415
# 4.43681620410571 16.585212277159187
# 6.724510652721995 11.821741613200555
# 7.999957720329929 8.616442212402387
# 7.999939859664449 8.324271150549936
# 7.148856888194677 12.131410613288313
# 6.038898948727953 11.299730803483765
# 7.846937630897202 11.468954837382007
# 7.811598251563306 8.938300805845643
# 2.7993206906214594 14.785618193118996
# 7.196462676873944 11.85482879093997
# 5.318121134786413 12.853975067179672
# 7.638371379893581 12.15867839022215
# 6.495002378430849 10.001609940609423
# 3.911850100925542 11.658303756882805
# 1.7681467640288775 14.61622966926894
# 5.741262096940879 12.661459033198756
# 7.585852144341261 12.75742611570119
# 4.981649549136751 14.814294135125653
# 7.998684292502558 8.000054111723713
# 1.9932007069063373 16.13725313069289
# 2.5709666382828127 13.1668976839258
# 7.960620504017655 7.867159425365746
# 6.440481924870687 11.037906682188733
# 1.5649027258978063 14.686839655587484
# 7.599766405212771 12.726172921351054
# 7.35277103449556 11.902362139854322
# 7.861126874403499 11.608505433684451
# 8.0 11.612396376197005
# 7.9999550260060275 8.762067551665254
# 4.725037036310451 12.982232859588743
# 3.9799868084610797 13.36657074005567
# 3.0879995159751097 13.576074247625176
# 1.3684797916105595 15.126255937423636
# 5.898450358586983 10.012851126225057
# 3.1556971222558237 13.437467237066347
# 7.999861227876217 7.525951156776824
# 3.133547765400453 16.708905541497035
# 7.999981168424489 7.144552186660069
# 7.6106355641991215 9.885729703501763
# 2.009988900147232 14.47499298274957
# 7.216424944778213 11.338584265163258
# 7.755248786948426 11.146886600817364
# 7.998650684615993 8.021278018511868
# 7.976247951372903 8.425219230620101
# 8.0 10.0
# 7.835659528638861 8.198819987250385
# 7.999981459734645 6.945385779657851
# 5.616303867245229 10.796015188272529
# 7.939516201668659 10.0
# 4.805610926579165 12.541885263222735
# 7.353473025147871 10.848432606568313
# 5.893572925715852 18.33925861810272
# 7.999969507009343 14.876801090213714
# 7.911723795333669 8.458554540092635
# 7.960742848938384 8.129374233776163
# 6.319806539243315 10.901436263634704
# 6.366433835002569 10.902377015888135
# 5.1312753771828366 11.802057893830117
# 7.999842545314667 7.999683754447066
# 7.999992689268691 6.000137576671992
# 8.0 6.0
# 7.999978220887795 6.0
# 7.999994208939139 6.0
# 7.999985136725107 6.0
# 7.9984369011662455 6.0
# 5.317696227227131 13.380962999283021
# 5.230825088821476 10.287881716078068
# 7.231123188354891 10.0
# 7.997021312120192 10.021953474084114
# 1.0028703518602096 14.468768920105475
# 7.999996206033965 6.0
# 7.95387120923351 10.880623069376956
# 7.780320518902266 6.0
# 5.3843437376363585 11.063554374229247
# 7.917741462731843 6.0
# 7.59812676591271 6.0
# 7.9968882664352545 7.022241647168858
# 7.8865508257692 7.559583609859425
# 7.87032425620953 7.955793751975129
# 7.964403703797504 7.82904733919921
# 5.791914741745718 19.76235643598485
# 7.999978330227649 11.770535222222485
# 7.9992582964922505 7.999724799063072
# 7.562086950281383 6.066845977551637
# 7.999954319695375 10.45985299671097
# 1.112495487100349 13.800122887626411
# 8.0 7.623925075879697
# 7.457008304298711 8.289095003516483
# 7.999962245588474 10.583176867059802
# 7.999764755957104 8.22302736794446
# 7.966500873392695 7.966294639632707
# 7.980699559966165 8.022028477082065
# 3.0847867844440993 11.243991503635009
# 7.999999025182412 6.0
# 7.779540995212264 8.059476408863855
# 1.2512429917166281 13.988940179257948
# 7.8244594154873255 7.450609270391354
# 7.97536818637786 7.4027248480661365
# 8.0 7.392816805004239
# 3.08413661952276 12.596250870316336
# 7.6204535601042975 7.584240036301685
# 4.406348629122929 10.940861442103508
# 6.614125371588237 12.541585105770416
# 7.7577546317901405 6.0
# 8.0 6.0
# 5.654685704288568 9.196541612509685
# 7.969828442109751 7.115003985045835
# 5.922915507947593 10.130474251053961
# 7.977659811669023 6.0
# 4.219811027010389 14.830066480899703
# 7.9098554366346345 6.024674555099797
# 5.371372954540848 9.813534367639216
# 1.8394225344046549 13.378643562714188
# 2.012979415582608 13.15803894222189
# 1.9318006846070177 19.99996009315094
# 8.0 10.454563557363006
# 8.0 13.45092828371465
# 4.616174553771333 17.874040882074837
# 7.999994135388146 6.0
# 7.9999989638177045 19.853804550736164
# 7.99999604005969 20.0
# 7.656675131143008 6.0
# 7.9999856046404965 6.0
# 7.93932229840129 14.58591775297996
# 1.628028989990827 15.664164372874822
# 4.45066299955211 17.579959955279058
# 2.8233108972942844 13.671277548666115
# 3.213689448541442 17.310150980290494
# 7.999989489897649 15.999999559304658
# 7.209744170204556 9.240621741572783
# 7.2252567335199 7.225159560300084
# 7.034983302203944 7.03491563944904
# 6.929648019670747 7.286407325067503
# 8.0 8.898857650063356
# 1.9407032504452602 16.966602418965287
# 7.222695989443171 13.078461018774732
# 8.0 12.945135822455146
# 8.0 19.63385713817231
# 6.879487922765541 11.246473474463983
# 8.0 12.096140377643998
# 7.151896857094382 15.323086337624652
# 6.4190401026379025 15.812048473374709
# 3.125455653163046 19.603829087055104
# 8.0 8.930237138160752
# 5.359416127109178 11.569693454045762
# 4.118235248914113 17.892566805756303
# 7.101123973096989 19.97551521302608
# 8.0 20.0
# 5.703546871098138 16.694036043144344
# 5.11532606405053 12.739829522652016
# 5.005823901616551 14.58411155718455
# 6.442951693824893 10.593685221300284
# 2.894085368204327 17.491868654806126
# 7.8387242773632835 19.735622559692224
# 3.06237229651655 15.421058318829179
# 6.720322348236653 15.625940735868038
# 3.260126108949608 19.868151749332604
# 7.660251048594484 10.921089975050588
# 7.188935488715076 14.479076649680632
# 8.0 10.126482880855313
# 8.0 15.445956328416422
# 7.89629263579949 14.035638313592152
# 7.081951598165826 11.474368974776944
# 8.0 20.0
# 7.563058691005776 19.055145747023992
# 1.903641850582512 6.958043882252278
# 7.98125905705451 11.585450290341306
# 4.104299588569413 19.48737494411644
# 8.0 15.332584217456493
# 4.010148271694518 10.520325775231473
# 3.13567840616151 7.927518542645267
# 7.982205804202403 19.83194133300715
# 3.254904701701947 18.16253444769492
# 7.951151149760854 18.66674006567024
# 4.134522051712006 12.248891560260756
# 7.260696321010052 7.207378396926053
# 7.696846862014432 15.761651270485114
# 4.208633039771556 19.016734158670957
# 6.652543599922064 20.0
# 3.4188244528342517 20.0
# 7.291692631003073 13.432150616468281
# 4.928769657392019 19.270751651711493
# 5.181293666249688 17.54515753286615
# 7.028098905517595 10.44846630184557
# 8.0 15.440751828631264
# 8.0 16.856844972808062
# 3.418353158910146 20.0
# 7.266893097813211 8.20492483104542
# 7.963281815642603 15.41181674765863
# 3.594445182157358 19.97036744625801
# 5.81956375922862 20.0
# 8.0 13.449546716144575
# 3.840042953446188 17.077678141529795
# 5.436509603118148 19.87940844813615
# 7.358847123364862 15.033815200764987
# 6.162747584306803 19.633524857441564
# 2.161783053491747 20.0
# 7.522601593491139 10.525266833275854
# 3.1977059214510852 20.0
# 2.7515974427408594 9.789783259478192
# 8.0 20.0
# 3.14177397192994 8.868018179459604
# 5.509816246269805 19.28543833768537
# 5.5285715981182255 19.987491523445193
# 7.003845673580292 18.974153845161347
# 7.036194466987784 19.886954481290374
# 3.2526931119257174 20.0
# 3.0120617372610603 19.80549364089417
# 4.15052164316299 19.565115357620165
# 4.994105940873013 10.512501746925444
# 7.567235433412729 12.714583964380417
# 2.861702106663712 20.0
# 6.74755312960713 11.88524383397457
# 3.7618006138171385 20.0
# 7.540154243204576 20.0
# 6.748878611052756 8.755893901928829
# 7.394916271748274 17.93584059391715
# 7.171197026770692 11.644778861335256
# 5.412588358006701 14.577357652562114
# 8.0 13.410342701547922
# 7.750761548680895 8.323568793428747
# 1.849656624077603 8.730608189665139

# %%
plot_energy_MSE(_c.data, 
                # "intE",
                "first_order_energy",
                "fit_intE", 
                elec="ELEC",
                # xlabel="Target", 
                # ylabel="Fit",
                s=5)
# Out:
# 8.766496143960714e-228
# (<Axes: xlabel='NBOND energy\n(kcal/mol)', ylabel='CCSD(T) interaction energy\n(kcal/mol)'>,
#  <matplotlib.colorbar.Colorbar at 0x7f2e3e7eff70>,
#  {'MSE': 18.556486523701924,
#   'RMSE': 4.30772405380172,
#   'R': 0.9358880019096528,
#   'RS': 0.9373579254317016,
#   'n': 500,
#   'slope': 0.9306394685358357,
#   'intercept': 0.6901895751346743})

# %%
plot_energy_MSE(_c.data, 
                "TARGET", 
                "FIT", 
                elec=_c.elec,
                xlabel="Target", 
                ylabel="Fit",
                s=5)
# Out:
# 0.0
# (<Axes: xlabel='Target', ylabel='Fit'>,
#  <matplotlib.colorbar.Colorbar at 0x7f2e130246a0>,
#  {'MSE': 18.556484,
#   'RMSE': 4.307724,
#   'R': 0.9906469336027084,
#   'RS': 0.9901446965787862,
#   'n': 500,
#   'slope': 0.9737679155659219,
#   'intercept': 3.804583913549749})

# %% [markdown]
# #  Make the bash files for generating reports

# %%
# paths =

# %%
# for p in paths:
#     if n_dyna > 1:
#         path = str(p)
#         logkey = "_".join(path[path.find("sim"):].split("/")[:-1])
#         print(logkey, n_dyna)

        
#         pm = papermill_job.format(path=path,
#                     logkey=logkey,
#                     NSAVC=nsavc,
#                     dt=dt)
        
#         with open(f"in_scripts/{logkey}_pm.sh", "w") as f:
#             f.write(pm)

# %% [markdown]
# #  FF

# %%
# ?FF
# Out:
# Init signature:
# FF(
#     data,
#     dists,
#     func,
#     bounds,
#     structure,
#     nobj=4,
#     elec='ELEC',
#     intern='Exact',
#     intE='intE',
#     pairs=False,
# )
# Docstring:      <no docstring>
# File:           ~/Documents/phd/ff_energy/ff_energy/ffe/ff.py
# Type:           type
# Subclasses:

# %%
structures, dists = next(read_from_pickle(f"water_cluster.pkl"))

# %%
# structures
# dists = {_.name.split(".")[0]: _.distances for _ in structures}
# dists

# %%
len(dists.keys())
# Out:
# 500

# %%
from ff_energy.ffe.cli import load_config_maker, charmm_jobs
from ff_energy.ffe.utils import pickle_output
structure = "water_cluster"

# print("No pickled distances/structure information, calculating:")
# CMS = load_config_maker("pbe0dz", structure, "pc")
# jobs = charmm_jobs(CMS)
# dists = {_.name.split(".")[0]: _.distances for _ in jobs[0].structures}
# structures = [_ for _ in jobs[0].structures]

pickle_output((structures, dists), name=f"structures/{structure}")

# %%
template_ff = FF(data_.data,
  dists,
  LJ,
  None,
  structures[0],
  )

# %%
# dists

# %%
pickle_output(template_ff, name=f"ff/template.ff")

# %%
template_ff
# Out:
# FF: LJ water_cluster ELEC Exact intE (jax_coloumb: False)
