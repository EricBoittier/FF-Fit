# %%
import os
import sys
import numpy as np
import pandas as pd

import pycharmm
import pycharmm.generate as gen
import pycharmm.ic as ic
import pycharmm.coor as coor
import pycharmm.energy as energy
import pycharmm.dynamics as dyn
import pycharmm.nbonds as nbonds
import pycharmm.minimize as minimize
import pycharmm.crystal as crystal
import pycharmm.select as select
import pycharmm.image as image
import pycharmm.psf as psf
import pycharmm.param as param
import pycharmm.read as read
import pycharmm.write as write
import pycharmm.settings as settings
import pycharmm.cons_harm as cons_harm
import pycharmm.cons_fix as cons_fix
import pycharmm.shake as shake
import pycharmm.scalar as scalar

# %%
pycharmm.__file__
# Out:
# '/home/boittier/Documents/CHARMM/PhysNet_PyCHARMM/v0/physnet_pycharmm_c47a2/tool/pycharmm/pycharmm/__init__.py'

# %%
pycharmm.lingo.charmm_script('bomlev 0')
pycharmm.lingo.charmm_script("stream dcm/dcm_toppar.str")

read.sequence_string("DCM " * 254)
gen.new_segment(
    seg_name='DCM',
    setup_ic=True)

# Print current coordinates
pos = coor.get_positions().to_numpy(dtype=np.float32)
print("current pos:", pos.shape)

read.pdb('dcm/dcm_box.pdb')

crystal.define_cubic(30)
crystal.build(12)

pycharmm.NonBondedScript(**{'cutnb': 16,
                  'ctofnb': 14,
                  'ctonnb': 12,
                  'atom': True,
                  'vatom': True,
                  'eps': 1,
                  'fswitch': True,
                  'vfswitch': True,
                  'cdie': True})
# Out:
#
#  CHARMM>     bomlev 0
#
#
#  CHARMM>     stream dcm/dcm_toppar.str
#  VOPEN> Attempting to open::dcm/dcm_toppar.str::
#  OPNLGU> Unit 99 opened for READONLY access to dcm/dcm_toppar.str
#
#                     INPUT STREAM SWITCHING TO UNIT    99
#  RDTITL> * TOPPAR STREAM FILE GENERATED BY
#  RDTITL> * CHARMM GENERAL FORCE FIELD (CGENFF) PROGRAM VERSION 2.5.1
#  RDTITL> * FOR USE WITH CGENFF VERSION 4.6
#  RDTITL> *
#  Parameter: IN1 <- "" <empty>
#
#  CHARMM>
#
#  CHARMM>    read rtf card !append
#  MAINIO> Residue topology file being read from unit  99.
#  RDTITL> * TOPOLOGIES GENERATED BY
#  RDTITL> * CHARMM GENERAL FORCE FIELD (CGENFF) PROGRAM VERSION 2.5.1
#  RDTITL> *
#
#  CHARMM>
#
#  CHARMM>    read param card !flex append
#
#           PARAMETER FILE BEING READ FROM UNIT 99
#  RDTITL> * PARAMETERS GENERATED BY ANALOGY BY
#  RDTITL> * CHARMM GENERAL FORCE FIELD (CGENFF) PROGRAM VERSION 2.5.1
#  RDTITL> *
#  PARMIO> NONBOND, HBOND lists and IMAGE atoms cleared.
#
#  CHARMM>    RETURN
#  VCLOSE: Closing unit   99 with status "KEEP"
#
#                     RETURNING TO INPUT STREAM    90
#
#
#           RESIDUE SEQUENCE --   254 RESIDUES
#           DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM
#           DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM
#           DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM
#           DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM
#           DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM
#           DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM
#           DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM
#           DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM
#           DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM
#           DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM
#           DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM
#           DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM
#           DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM DCM
#  NO PATCHING WILL BE DONE ON THE FIRST RESIDUE
#  NO PATCHING WILL BE DONE ON THE LAST  RESIDUE
#  GENPSF> Segment   1 has been generated. Its identifier is DCM.
#  PSFSUM> PSF modified: NONBOND lists and IMAGE atoms cleared.
#  PSFSUM> Summary of the structure file counters :
#          Number of segments      =        1   Number of residues   =      254
#          Number of atoms         =     1270   Number of groups     =      254
#          Number of bonds         =     1016   Number of angles     =     1524
#          Number of dihedrals     =        0   Number of impropers  =        0
#          Number of cross-terms   =        0
#          Number of HB acceptors  =        0   Number of HB donors  =        0
#          Number of NB exclusions =        0   Total charge =    0.00000
#  QXFORM> Expanded format used.
#          More than 4 character atom type used.
# current pos: (1270, 3)
#
#  CHARMM>     read coor pdb -
#  CHARMM>     name dcm/dcm_box.pdb
#  VOPEN> Attempting to open::dcm/dcm_box.pdb::
#   read CHARMM-pdb format
#           SPATIAL COORDINATES BEING READ FROM UNIT 91
#  TITLE>  *
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#  Crystal Parameters : Crystal Type = CUBI
#            A     =   30.00000 B    =   30.00000 C     =   30.00000
#            Alpha =   90.00000 Beta =   90.00000 Gamma =   90.00000
#  XBUILD> Building all transformations with a minimum atom-atom
#          contact distance of less than   12.00 Angstroms.
#
#  Range of Grid Search for Transformation     1 :
#  Lattice Vector A    -2 TO     2
#  Lattice Vector B    -2 TO     2
#  Lattice Vector C    -2 TO     2
#
#
#  The number of transformations generated =    26
#
#
#  Number  Symop   A   B   C   Distance
#
#       1      1  -1  -1  -1    10.3391
#       2      1  -1   0  -1     5.6847
#       3      1  -1   1  -1    10.5488
#       4      1   0  -1  -1     7.7679
#       5      1   0   0  -1     2.1642
#       6      1   0   1  -1     5.6233
#       7      1  -1  -1   0     7.6084
#       8      1  -1   0   0     3.5479
#       9      1  -1   1   0     5.4397
#      10      1   0  -1   0     2.2200
#      11      1   0   1   0     2.2200
#      12      1  -1  -1   1    10.2692
#      13      1  -1   0   1     5.3309
#      14      1  -1   1   1     9.2085
#      15      1   0  -1   1     5.6233
#      16      1   0   0   1     2.1642
#      17      1   0   1   1     7.7679
#      18      1   1   1   1    10.3391
#      19      1   1   0   1     5.6847
#      20      1   1  -1   1    10.5488
#      21      1   1   1   0     7.6084
#      22      1   1   0   0     3.5479
#      23      1   1  -1   0     5.4397
#      24      1   1   1  -1    10.2692
#      25      1   1   0  -1     5.3309
#      26      1   1  -1  -1     9.2085
#                      THERE ARE NO ROTATIONS FOR THIS TRANSFORMATION SET
#     26 Transformations have been processed.

# %%
xyz = coor.get_positions() 
xyz
# Out:
#            x       y       z
# 0      0.432  22.059  14.756
# 1     -0.002  20.319  14.579
# 2      2.213  22.334  14.772
# 3      0.012  22.429  15.719
# 4     -0.001  22.618  13.895
# ...      ...     ...     ...
# 1265  15.881  12.596  15.744
# 1266  17.107  11.625  16.638
# 1267  15.925  14.344  16.178
# 1268  14.870  12.198  15.992
# 1269  16.086  12.500  14.653
#
# [1270 rows x 3 columns]

# %%
minimize.run_abnr(**{'nstep': 10000,
                     'tolenr': 1e-6,
                     'tolgrd': 1e-3})
# Out:
#  <MKIMAT2>: updating the image atom lists and remapping
#  Transformation   Atoms  Groups  Residues  Min-Distance
#     1  C001 has      25       5       5        2.05
#     2  C002 has     180      36      36        1.23
#     3  C003 has      25       5       5        4.28
#     4  C004 has     195      39      39        1.49
#     5  C005 has     660     132     132        0.00
#     6  C006 has     265      53      53        1.05
#     7  C007 has     160      32      32        2.05
#     8  C008 has     640     128     128        0.00
#     9  C009 has     230      46      46        1.55
#    10  C010 has     610     122     122        0.00
#    12  C012 has      25       5       5        3.31
#    13  C013 has     175      35      35        0.63
#    14  C014 has      70      14      14        6.35
#  Total of 4530 atoms and  906 groups and  906 residues were included
#
#
#  NONBOND OPTION FLAGS:
#      ELEC     VDW      ATOMs    CDIElec  FSHIft   VATOm    VFSWIt
#      BYGRoup  NOEXtnd  NOEWald
#  CUTNB  = 14.000 CTEXNB =999.000 CTONNB = 10.000 CTOFNB = 12.000
#  CGONNB =  0.000 CGOFNB = 10.000
#  WMIN   =  1.500 WRNMXD =  0.500 E14FAC =  1.000 EPS    =  1.000
#  NBXMOD =      5
#  There are        0 atom  pairs and        0 atom  exclusions.
#  There are        0 group pairs and        0 group exclusions.
#  <MAKINB> with mode   5 found   2540 exclusions and      0 interactions(1-4)
#  <MAKGRP> found      0 group exclusions.
#  <MAKGRP> found      0 image group exclusions.
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR   364936 ATOM PAIRS AND        0 GROUP PAIRS
#
#  General atom nonbond list generation found:
#    208400 ATOM PAIRS WERE FOUND FOR ATOM LIST
#      8903 GROUP PAIRS REQUIRED ATOM SEARCHES
#
#  SPACE FOR   538488 ATOM PAIRS AND        0 GROUP PAIRS
#
#  Image nonbond list generation found:
#    133469 ATOM PAIRS WERE FOUND FOR ATOM LIST
#         0 ATOM PAIRS WERE FOUND FOR ATOM SELF LIST
#     10673 GROUP PAIRS REQUIRED ATOM SEARCHES
#
#  PRNHBD: CUToff Hydrogen Bond  distance =    4.5000   Angle =   90.0000
#          CuT switching ON HB dist. =     3.5000  OFf HB dist. =    4.0000
#          CuT switching ON Hb Angle =    50.0000  OFf Hb Angle =   70.0000
#          ACCEptor antecedents included
#          All hydrogen bonds for each hydrogen will be found
#          Hydrogen bonds between excluded atoms will be kept
#
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#  HBEDIT-deletions:       0 due to duplications,          0 due to best-option,
#                          0 due to fixed atoms,           0 due to exclusions
#  HBEDIT: currently     0 hydrogen bonds present
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#                          0 primary donor to image acceptor hbonds found
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#                          0 image donor to primary acceptor hbonds found
#                          0 unique image hbonds found
#  HBEDIT-deletions:       0 due to duplications,          0 due to best-option,
#                          0 due to fixed atoms,           0 due to exclusions
#  HBEDIT: currently     0 hydrogen bonds present
#
#
#  ABNER> An energy minimization has been requested.
#
#  EIGRNG =    0.0005000   MINDIM =            5
#  NPRINT =           10   NSTEP  =        10000
#  PSTRCT =    0.0000000   SDSTP  =    0.0200000
#  STPLIM =    1.0000000   STRICT =    0.1000000
#  TOLFUN =    0.0000010   TOLGRD =    0.0010000
#  TOLITR =          100   TOLSTP =    0.0000000
#  FMEM   =    0.0000000
# MINI MIN: Cycle      ENERgy      Delta-E         GRMS    Step-size
# MINI INTERN:          BONDs       ANGLes       UREY-b    DIHEdrals    IMPRopers
# MINI EXTERN:        VDWaals         ELEC       HBONds          ASP         USER
# MINI IMAGES:        IMNBvdw       IMELec       IMHBnd       RXNField    EXTElec
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>        0 5373523363.6          0.0 2068168666.9          0.0
# MINI INTERN>       22.58180    134.04666      1.40342      0.00000      0.00000
# MINI EXTERN>    23309.56638      3.62216      0.00000      0.00000      0.00000
# MINI IMAGES>   5373499879.0         13.4          0.0          0.0          0.0
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>       10  111266124.1 5262257239.5   28171668.2          0.0
# MINI INTERN>       25.57481    134.97226      1.40316      0.00000      0.00000
# MINI EXTERN>    23323.15610      3.63796      0.00000      0.00000      0.00000
# MINI IMAGES>   111242624.10        11.27         0.00         0.00         0.00
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>       20   5236530.10 106029594.02    974583.73         0.04
# MINI INTERN>       36.22729    139.93282      1.39802      0.00000      0.00000
# MINI EXTERN>    23397.51371      3.64875      0.00000      0.00000      0.00000
# MINI IMAGES>   5212942.1161       9.2626       0.0000       0.0000       0.0000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>       30  171030.7984 5065499.3009   22166.0248       0.0373
# MINI INTERN>      155.32264    190.94742      1.47566      0.00000      0.00000
# MINI EXTERN>    23530.08406      3.85686      0.00000      0.00000      0.00000
# MINI IMAGES>   147143.34396      5.76781      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>       40  28545.67749 142485.12093    291.28702      0.10048
# MINI INTERN>      967.21412    492.58997      2.17392      0.00000      0.00000
# MINI EXTERN>    20998.39010      2.82785      0.00000      0.00000      0.00000
# MINI IMAGES>     6078.90273      3.57881      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
#  UPDECI: Image update at step        50
#
#  <MKIMAT2>: updating the image atom lists and remapping
#  Transformation   Atoms  Groups  Residues  Min-Distance
#     1  C001 has      25       5       5        1.90
#     2  C002 has     170      34      34        0.77
#     3  C003 has      25       5       5        3.95
#     4  C004 has     175      35      35        1.05
#     5  C005 has     670     134     134        0.00
#     6  C006 has     255      51      51        0.57
#     7  C007 has     150      30      30        1.78
#     8  C008 has     630     126     126        0.00
#     9  C009 has     235      47      47        1.51
#    10  C010 has     610     122     122        0.00
#    12  C012 has      25       5       5        3.24
#    13  C013 has     180      36      36        0.58
#    14  C014 has      70      14      14        6.33
#  Total of 4490 atoms and  898 groups and  898 residues were included
#
#  <MAKGRP> found      0 image group exclusions.
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#  HBEDIT-deletions:       0 due to duplications,          0 due to best-option,
#                          0 due to fixed atoms,           0 due to exclusions
#  HBEDIT: currently     0 hydrogen bonds present
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#                          0 primary donor to image acceptor hbonds found
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#                          0 image donor to primary acceptor hbonds found
#                          0 unique image hbonds found
#  HBEDIT-deletions:       0 due to duplications,          0 due to best-option,
#                          0 due to fixed atoms,           0 due to exclusions
#  HBEDIT: currently     0 hydrogen bonds present
#  UPDECI: Nonbond update at step        50
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR   364936 ATOM PAIRS AND        0 GROUP PAIRS
#
#  General atom nonbond list generation found:
#    208727 ATOM PAIRS WERE FOUND FOR ATOM LIST
#      8659 GROUP PAIRS REQUIRED ATOM SEARCHES
#
#  SPACE FOR   538488 ATOM PAIRS AND        0 GROUP PAIRS
#
#  Image nonbond list generation found:
#    133212 ATOM PAIRS WERE FOUND FOR ATOM LIST
#         0 ATOM PAIRS WERE FOUND FOR ATOM SELF LIST
#     10357 GROUP PAIRS REQUIRED ATOM SEARCHES
#
# MINI>       50   5040.22650  23505.45099     16.29068      3.47660
# MINI INTERN>      716.28775   1198.74164      3.57564      0.00000      0.00000
# MINI EXTERN>     2832.50170     -6.83815      0.00000      0.00000      0.00000
# MINI IMAGES>      290.83183      5.12610      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>       60   1911.78149   3128.44501      7.31608      2.99313
# MINI INTERN>      230.98333    565.91934      2.49609      0.00000      0.00000
# MINI EXTERN>     1063.16077     -5.37049      0.00000      0.00000      0.00000
# MINI IMAGES>       49.72979      4.86265      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>       70     89.97006   1821.81143      3.96762      1.73940
# MINI INTERN>       64.97251    182.38199      1.33361      0.00000      0.00000
# MINI EXTERN>      -74.58419     -4.62031      0.00000      0.00000      0.00000
# MINI IMAGES>      -83.18232      3.66877      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>       80   -621.43544    711.40550      3.15740      1.01082
# MINI INTERN>       26.86793    107.34588      1.15474      0.00000      0.00000
# MINI EXTERN>     -609.11197     -4.43350      0.00000      0.00000      0.00000
# MINI IMAGES>     -146.26193      3.00342      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>       90   -904.34317    282.90773      1.97704      0.35245
# MINI INTERN>       13.03637     92.03755      1.05961      0.00000      0.00000
# MINI EXTERN>     -828.32589     -4.96454      0.00000      0.00000      0.00000
# MINI IMAGES>     -179.86232      2.67606      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
#  UPDECI: Image update at step       100
#
#  <MKIMAT2>: updating the image atom lists and remapping
#  Transformation   Atoms  Groups  Residues  Min-Distance
#     1  C001 has      30       6       6        0.47
#     2  C002 has     195      39      39        0.30
#     3  C003 has      30       6       6        3.93
#     4  C004 has     185      37      37        0.00
#     5  C005 has     660     132     132        0.00
#     6  C006 has     250      50      50        0.00
#     7  C007 has     160      32      32        0.29
#     8  C008 has     620     124     124        0.00
#     9  C009 has     245      49      49        0.50
#    10  C010 has     625     125     125        0.00
#    12  C012 has      45       9       9        3.51
#    13  C013 has     190      38      38        0.00
#    14  C014 has      65      13      13        5.03
#  Total of 4570 atoms and  914 groups and  914 residues were included
#
#  <MAKGRP> found      0 image group exclusions.
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#  HBEDIT-deletions:       0 due to duplications,          0 due to best-option,
#                          0 due to fixed atoms,           0 due to exclusions
#  HBEDIT: currently     0 hydrogen bonds present
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#                          0 primary donor to image acceptor hbonds found
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#                          0 image donor to primary acceptor hbonds found
#                          0 unique image hbonds found
#  HBEDIT-deletions:       0 due to duplications,          0 due to best-option,
#                          0 due to fixed atoms,           0 due to exclusions
#  HBEDIT: currently     0 hydrogen bonds present
#  UPDECI: Nonbond update at step       100
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR   364936 ATOM PAIRS AND        0 GROUP PAIRS
#
#  General atom nonbond list generation found:
#    202027 ATOM PAIRS WERE FOUND FOR ATOM LIST
#      8642 GROUP PAIRS REQUIRED ATOM SEARCHES
#
#  SPACE FOR   538488 ATOM PAIRS AND        0 GROUP PAIRS
#
#  Image nonbond list generation found:
#    139638 ATOM PAIRS WERE FOUND FOR ATOM LIST
#         0 ATOM PAIRS WERE FOUND FOR ATOM SELF LIST
#     10731 GROUP PAIRS REQUIRED ATOM SEARCHES
#
# MINI>      100  -1112.53183    208.18866      2.46745      0.20482
# MINI INTERN>       12.21983     80.83902      1.02150      0.00000      0.00000
# MINI EXTERN>     -978.98795     -8.57410      0.00000      0.00000      0.00000
# MINI IMAGES>     -221.05976      2.00963      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      110  -1172.12203     59.59020      0.58106      0.07142
# MINI INTERN>        4.64239     74.94745      1.04033      0.00000      0.00000
# MINI EXTERN>    -1016.31112    -11.49001      0.00000      0.00000      0.00000
# MINI IMAGES>     -227.08823      2.13715      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      120  -1243.29851     71.17648      1.24466      0.11528
# MINI INTERN>        4.47678     76.64220      1.12692      0.00000      0.00000
# MINI EXTERN>    -1071.16888    -16.73383      0.00000      0.00000      0.00000
# MINI IMAGES>     -239.12224      1.48054      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      130  -1304.07047     60.77196      1.14537      0.11166
# MINI INTERN>        3.11103     73.51480      1.11848      0.00000      0.00000
# MINI EXTERN>    -1113.11783    -21.79281      0.00000      0.00000      0.00000
# MINI IMAGES>     -247.47205      0.56791      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      140  -1333.71067     29.64020      0.78193      0.06489
# MINI INTERN>        2.11344     70.94922      1.11073      0.00000      0.00000
# MINI EXTERN>    -1131.44750    -23.85810      0.00000      0.00000      0.00000
# MINI IMAGES>     -252.59946      0.02101      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
#  UPDECI: Image update at step       150
#
#  <MKIMAT2>: updating the image atom lists and remapping
#  Transformation   Atoms  Groups  Residues  Min-Distance
#     1  C001 has      35       7       7        0.59
#     2  C002 has     195      39      39        0.09
#     3  C003 has      30       6       6        3.83
#     4  C004 has     190      38      38        0.19
#     5  C005 has     660     132     132        0.00
#     6  C006 has     265      53      53        0.00
#     7  C007 has     160      32      32        0.30
#     8  C008 has     620     124     124        0.00
#     9  C009 has     240      48      48        0.49
#    10  C010 has     630     126     126        0.00
#    12  C012 has      50      10      10        3.54
#    13  C013 has     190      38      38        0.00
#    14  C014 has      65      13      13        4.86
#  Total of 4600 atoms and  920 groups and  920 residues were included
#
#  <MAKGRP> found      0 image group exclusions.
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#  HBEDIT-deletions:       0 due to duplications,          0 due to best-option,
#                          0 due to fixed atoms,           0 due to exclusions
#  HBEDIT: currently     0 hydrogen bonds present
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#                          0 primary donor to image acceptor hbonds found
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#                          0 image donor to primary acceptor hbonds found
#                          0 unique image hbonds found
#  HBEDIT-deletions:       0 due to duplications,          0 due to best-option,
#                          0 due to fixed atoms,           0 due to exclusions
#  HBEDIT: currently     0 hydrogen bonds present
#  UPDECI: Nonbond update at step       150
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR   364936 ATOM PAIRS AND        0 GROUP PAIRS
#
#  General atom nonbond list generation found:
#    200665 ATOM PAIRS WERE FOUND FOR ATOM LIST
#      8599 GROUP PAIRS REQUIRED ATOM SEARCHES
#
#  SPACE FOR   538488 ATOM PAIRS AND        0 GROUP PAIRS
#
#  Image nonbond list generation found:
#    140678 ATOM PAIRS WERE FOUND FOR ATOM LIST
#         0 ATOM PAIRS WERE FOUND FOR ATOM SELF LIST
#     10808 GROUP PAIRS REQUIRED ATOM SEARCHES
#
# MINI>      150  -1352.95206     19.24139      0.64878      0.06285
# MINI INTERN>        1.70412     71.69662      1.13027      0.00000      0.00000
# MINI EXTERN>    -1145.24381    -26.00437      0.00000      0.00000      0.00000
# MINI IMAGES>     -255.72174     -0.51316      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      160  -1393.39330     40.44124      1.29024      0.11272
# MINI INTERN>        2.62346     69.99084      1.15200      0.00000      0.00000
# MINI EXTERN>    -1165.64179    -34.10290      0.00000      0.00000      0.00000
# MINI IMAGES>     -264.52657     -2.88835      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      170  -1416.41970     23.02640      0.45074      0.03930
# MINI INTERN>        1.01803     69.72882      1.13689      0.00000      0.00000
# MINI EXTERN>    -1178.87577    -36.52498      0.00000      0.00000      0.00000
# MINI IMAGES>     -269.32655     -3.57614      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      180  -1421.61988      5.20018      0.23370      0.02284
# MINI INTERN>        0.79392     69.32288      1.09950      0.00000      0.00000
# MINI EXTERN>    -1182.90271    -36.61808      0.00000      0.00000      0.00000
# MINI IMAGES>     -269.76293     -3.55247      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      190  -1437.85607     16.23619      0.71235      0.06145
# MINI INTERN>        1.09498     69.94949      1.13033      0.00000      0.00000
# MINI EXTERN>    -1190.76957    -40.64571      0.00000      0.00000      0.00000
# MINI IMAGES>     -274.08935     -4.52625      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
#  UPDECI: Image update at step       200
#
#  <MKIMAT2>: updating the image atom lists and remapping
#  Transformation   Atoms  Groups  Residues  Min-Distance
#     1  C001 has      35       7       7        0.25
#     2  C002 has     195      39      39        0.00
#     3  C003 has      35       7       7        3.66
#     4  C004 has     185      37      37        0.19
#     5  C005 has     660     132     132        0.00
#     6  C006 has     270      54      54        0.00
#     7  C007 has     160      32      32        0.02
#     8  C008 has     635     127     127        0.00
#     9  C009 has     245      49      49        0.38
#    10  C010 has     620     124     124        0.00
#    12  C012 has      60      12      12        3.24
#    13  C013 has     195      39      39        0.00
#    14  C014 has      65      13      13        4.43
#  Total of 4630 atoms and  926 groups and  926 residues were included
#
#  <MAKGRP> found      0 image group exclusions.
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#  HBEDIT-deletions:       0 due to duplications,          0 due to best-option,
#                          0 due to fixed atoms,           0 due to exclusions
#  HBEDIT: currently     0 hydrogen bonds present
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#                          0 primary donor to image acceptor hbonds found
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#                          0 image donor to primary acceptor hbonds found
#                          0 unique image hbonds found
#  HBEDIT-deletions:       0 due to duplications,          0 due to best-option,
#                          0 due to fixed atoms,           0 due to exclusions
#  HBEDIT: currently     0 hydrogen bonds present
#  UPDECI: Nonbond update at step       200
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR   364936 ATOM PAIRS AND        0 GROUP PAIRS
#
#  General atom nonbond list generation found:
#    199472 ATOM PAIRS WERE FOUND FOR ATOM LIST
#      8524 GROUP PAIRS REQUIRED ATOM SEARCHES
#
#  SPACE FOR   538488 ATOM PAIRS AND        0 GROUP PAIRS
#
#  Image nonbond list generation found:
#    141724 ATOM PAIRS WERE FOUND FOR ATOM LIST
#         0 ATOM PAIRS WERE FOUND FOR ATOM SELF LIST
#     10838 GROUP PAIRS REQUIRED ATOM SEARCHES
#
# MINI>      200  -1446.88900      9.03293      0.45292      0.03968
# MINI INTERN>        0.70728     70.05840      1.12159      0.00000      0.00000
# MINI EXTERN>    -1195.75049    -42.18383      0.00000      0.00000      0.00000
# MINI IMAGES>     -275.88491     -4.95705      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      210  -1461.46886     14.57986      0.38779      0.03843
# MINI INTERN>        0.50574     69.33522      1.18303      0.00000      0.00000
# MINI EXTERN>    -1200.41891    -46.10227      0.00000      0.00000      0.00000
# MINI IMAGES>     -279.69195     -6.27972      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      220  -1470.94627      9.47741      0.49469      0.04136
# MINI INTERN>        0.71411     69.25519      1.11809      0.00000      0.00000
# MINI EXTERN>    -1203.30511    -49.65678      0.00000      0.00000      0.00000
# MINI IMAGES>     -281.52357     -7.54820      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      230  -1474.66026      3.71399      0.27520      0.02403
# MINI INTERN>        0.52622     68.86871      1.13255      0.00000      0.00000
# MINI EXTERN>    -1205.53437    -49.94893      0.00000      0.00000      0.00000
# MINI IMAGES>     -282.14834     -7.55609      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      240  -1477.48398      2.82372      0.25223      0.02328
# MINI INTERN>        0.50049     68.93757      1.12816      0.00000      0.00000
# MINI EXTERN>    -1207.23647    -50.57020      0.00000      0.00000      0.00000
# MINI IMAGES>     -282.49149     -7.75205      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
#  UPDECI: Image update at step       250
#
#  <MKIMAT2>: updating the image atom lists and remapping
#  Transformation   Atoms  Groups  Residues  Min-Distance
#     1  C001 has      35       7       7        0.21
#     2  C002 has     195      39      39        0.00
#     3  C003 has      35       7       7        3.56
#     4  C004 has     185      37      37        0.11
#     5  C005 has     665     133     133        0.00
#     6  C006 has     270      54      54        0.00
#     7  C007 has     155      31      31        0.00
#     8  C008 has     635     127     127        0.00
#     9  C009 has     245      49      49        0.39
#    10  C010 has     620     124     124        0.00
#    12  C012 has      60      12      12        3.25
#    13  C013 has     200      40      40        0.00
#    14  C014 has      65      13      13        4.26
#  Total of 4635 atoms and  927 groups and  927 residues were included
#
#  <MAKGRP> found      0 image group exclusions.
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#  HBEDIT-deletions:       0 due to duplications,          0 due to best-option,
#                          0 due to fixed atoms,           0 due to exclusions
#  HBEDIT: currently     0 hydrogen bonds present
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#                          0 primary donor to image acceptor hbonds found
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#                          0 image donor to primary acceptor hbonds found
#                          0 unique image hbonds found
#  HBEDIT-deletions:       0 due to duplications,          0 due to best-option,
#                          0 due to fixed atoms,           0 due to exclusions
#  HBEDIT: currently     0 hydrogen bonds present
#  UPDECI: Nonbond update at step       250
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR   364936 ATOM PAIRS AND        0 GROUP PAIRS
#
#  General atom nonbond list generation found:
#    198973 ATOM PAIRS WERE FOUND FOR ATOM LIST
#      8507 GROUP PAIRS REQUIRED ATOM SEARCHES
#
#  SPACE FOR   538488 ATOM PAIRS AND        0 GROUP PAIRS
#
#  Image nonbond list generation found:
#    141963 ATOM PAIRS WERE FOUND FOR ATOM LIST
#         0 ATOM PAIRS WERE FOUND FOR ATOM SELF LIST
#     10871 GROUP PAIRS REQUIRED ATOM SEARCHES
#
# MINI>      250  -1480.73760      3.25362      0.48902      0.03758
# MINI INTERN>        0.70831     68.63217      1.12884      0.00000      0.00000
# MINI EXTERN>    -1209.23773    -51.19708      0.00000      0.00000      0.00000
# MINI IMAGES>     -282.79237     -7.97973      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      260  -1485.16164      4.42404      0.34243      0.03640
# MINI INTERN>        0.44654     68.96810      1.14102      0.00000      0.00000
# MINI EXTERN>    -1211.09293    -52.91322      0.00000      0.00000      0.00000
# MINI IMAGES>     -283.16496     -8.54619      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      270  -1495.26135     10.09971      0.46081      0.04030
# MINI INTERN>        0.58954     68.90363      1.12662      0.00000      0.00000
# MINI EXTERN>    -1216.04924    -56.44842      0.00000      0.00000      0.00000
# MINI IMAGES>     -283.76195     -9.62154      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      280  -1501.34910      6.08775      0.45110      0.03331
# MINI INTERN>        0.60140     68.56541      1.13598      0.00000      0.00000
# MINI EXTERN>    -1218.53547    -57.93228      0.00000      0.00000      0.00000
# MINI IMAGES>     -285.09977    -10.08437      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      290  -1505.91956      4.57046      0.29998      0.01935
# MINI INTERN>        0.55138     68.66228      1.13191      0.00000      0.00000
# MINI EXTERN>    -1219.13816    -60.46109      0.00000      0.00000      0.00000
# MINI IMAGES>     -285.91017    -10.75571      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
#  UPDECI: Image update at step       300
#
#  <MKIMAT2>: updating the image atom lists and remapping
#  Transformation   Atoms  Groups  Residues  Min-Distance
#     1  C001 has      35       7       7        0.61
#     2  C002 has     180      36      36        0.00
#     3  C003 has      35       7       7        3.47
#     4  C004 has     180      36      36        0.00
#     5  C005 has     660     132     132        0.00
#     6  C006 has     270      54      54        0.00
#     7  C007 has     155      31      31        0.00
#     8  C008 has     640     128     128        0.00
#     9  C009 has     255      51      51        0.38
#    10  C010 has     630     126     126        0.00
#    12  C012 has      60      12      12        3.37
#    13  C013 has     205      41      41        0.00
#    14  C014 has      70      14      14        4.26
#  Total of 4645 atoms and  929 groups and  929 residues were included
#
#  <MAKGRP> found      0 image group exclusions.
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#  HBEDIT-deletions:       0 due to duplications,          0 due to best-option,
#                          0 due to fixed atoms,           0 due to exclusions
#  HBEDIT: currently     0 hydrogen bonds present
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#                          0 primary donor to image acceptor hbonds found
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#                          0 image donor to primary acceptor hbonds found
#                          0 unique image hbonds found
#  HBEDIT-deletions:       0 due to duplications,          0 due to best-option,
#                          0 due to fixed atoms,           0 due to exclusions
#  HBEDIT: currently     0 hydrogen bonds present
#  UPDECI: Nonbond update at step       300
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR   364936 ATOM PAIRS AND        0 GROUP PAIRS
#
#  General atom nonbond list generation found:
#    199051 ATOM PAIRS WERE FOUND FOR ATOM LIST
#      8498 GROUP PAIRS REQUIRED ATOM SEARCHES
#
#  SPACE FOR   538488 ATOM PAIRS AND        0 GROUP PAIRS
#
#  Image nonbond list generation found:
#    142109 ATOM PAIRS WERE FOUND FOR ATOM LIST
#         0 ATOM PAIRS WERE FOUND FOR ATOM SELF LIST
#     10872 GROUP PAIRS REQUIRED ATOM SEARCHES
#
# MINI>      300  -1511.38923      5.46967      0.38420      0.03124
# MINI INTERN>        0.49378     68.75032      1.12892      0.00000      0.00000
# MINI EXTERN>    -1220.87679    -62.66361      0.00000      0.00000      0.00000
# MINI IMAGES>     -286.99966    -11.22218      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      310  -1513.91335      2.52412      0.20469      0.01816
# MINI INTERN>        0.38633     68.49907      1.11797      0.00000      0.00000
# MINI EXTERN>    -1222.88981    -62.50527      0.00000      0.00000      0.00000
# MINI IMAGES>     -287.38186    -11.13979      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      320  -1517.53663      3.62328      0.36565      0.02931
# MINI INTERN>        0.45826     68.66286      1.11924      0.00000      0.00000
# MINI EXTERN>    -1226.09687    -62.89250      0.00000      0.00000      0.00000
# MINI IMAGES>     -287.82609    -10.96153      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      330  -1519.70564      2.16901      0.19237      0.01703
# MINI INTERN>        0.36100     68.53766      1.13080      0.00000      0.00000
# MINI EXTERN>    -1227.35508    -63.26865      0.00000      0.00000      0.00000
# MINI IMAGES>     -288.10828    -11.00309      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      340  -1520.44847      0.74283      0.11669      0.00990
# MINI INTERN>        0.33160     68.43699      1.13311      0.00000      0.00000
# MINI EXTERN>    -1227.69986    -63.41225      0.00000      0.00000      0.00000
# MINI IMAGES>     -288.19853    -11.03955      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
#  UPDECI: Image update at step       350
#
#  <MKIMAT2>: updating the image atom lists and remapping
#  Transformation   Atoms  Groups  Residues  Min-Distance
#     1  C001 has      30       6       6        0.61
#     2  C002 has     180      36      36        0.00
#     3  C003 has      35       7       7        3.48
#     4  C004 has     180      36      36        0.00
#     5  C005 has     660     132     132        0.00
#     6  C006 has     275      55      55        0.00
#     7  C007 has     155      31      31        0.00
#     8  C008 has     640     128     128        0.00
#     9  C009 has     255      51      51        0.37
#    10  C010 has     630     126     126        0.00
#    12  C012 has      55      11      11        3.38
#    13  C013 has     205      41      41        0.00
#    14  C014 has      70      14      14        4.25
#  Total of 4640 atoms and  928 groups and  928 residues were included
#
#  <MAKGRP> found      0 image group exclusions.
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#  HBEDIT-deletions:       0 due to duplications,          0 due to best-option,
#                          0 due to fixed atoms,           0 due to exclusions
#  HBEDIT: currently     0 hydrogen bonds present
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#                          0 primary donor to image acceptor hbonds found
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#                          0 image donor to primary acceptor hbonds found
#                          0 unique image hbonds found
#  HBEDIT-deletions:       0 due to duplications,          0 due to best-option,
#                          0 due to fixed atoms,           0 due to exclusions
#  HBEDIT: currently     0 hydrogen bonds present
#  UPDECI: Nonbond update at step       350
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR   364936 ATOM PAIRS AND        0 GROUP PAIRS
#
#  General atom nonbond list generation found:
#    199205 ATOM PAIRS WERE FOUND FOR ATOM LIST
#      8512 GROUP PAIRS REQUIRED ATOM SEARCHES
#
#  SPACE FOR   538488 ATOM PAIRS AND        0 GROUP PAIRS
#
#  Image nonbond list generation found:
#    142025 ATOM PAIRS WERE FOUND FOR ATOM LIST
#         0 ATOM PAIRS WERE FOUND FOR ATOM SELF LIST
#     10853 GROUP PAIRS REQUIRED ATOM SEARCHES
#
# MINI>      350  -1522.66090      2.21243      0.27777      0.02663
# MINI INTERN>        0.37897     68.76551      1.10640      0.00000      0.00000
# MINI EXTERN>    -1228.96796    -64.28304      0.00000      0.00000      0.00000
# MINI IMAGES>     -288.46938    -11.19140      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      360  -1532.12805      9.46715      0.36748      0.04299
# MINI INTERN>        0.54185     68.82598      1.09275      0.00000      0.00000
# MINI EXTERN>    -1233.59125    -67.51455      0.00000      0.00000      0.00000
# MINI IMAGES>     -289.67197    -11.81087      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      370  -1536.55932      4.43127      0.26104      0.02498
# MINI INTERN>        0.37927     68.63929      1.11717      0.00000      0.00000
# MINI EXTERN>    -1236.55266    -68.07315      0.00000      0.00000      0.00000
# MINI IMAGES>     -290.17668    -11.89256      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      380  -1540.96281      4.40349      0.34187      0.04033
# MINI INTERN>        0.36009     69.02730      1.11097      0.00000      0.00000
# MINI EXTERN>    -1239.35050    -69.35196      0.00000      0.00000      0.00000
# MINI IMAGES>     -290.47239    -12.28633      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      390  -1546.29614      5.33332      0.17949      0.02343
# MINI INTERN>        0.38822     68.56013      1.09621      0.00000      0.00000
# MINI EXTERN>    -1241.67343    -71.23155      0.00000      0.00000      0.00000
# MINI IMAGES>     -290.53209    -12.90363      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
#  UPDECI: Image update at step       400
#
#  <MKIMAT2>: updating the image atom lists and remapping
#  Transformation   Atoms  Groups  Residues  Min-Distance
#     1  C001 has      30       6       6        0.90
#     2  C002 has     185      37      37        0.00
#     3  C003 has      30       6       6        3.48
#     4  C004 has     175      35      35        0.00
#     5  C005 has     660     132     132        0.00
#     6  C006 has     270      54      54        0.00
#     7  C007 has     155      31      31        0.00
#     8  C008 has     640     128     128        0.00
#     9  C009 has     265      53      53        0.00
#    10  C010 has     630     126     126        0.00
#    12  C012 has      55      11      11        3.56
#    13  C013 has     205      41      41        0.00
#    14  C014 has      70      14      14        4.26
#  Total of 4640 atoms and  928 groups and  928 residues were included
#
#  <MAKGRP> found      0 image group exclusions.
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#  HBEDIT-deletions:       0 due to duplications,          0 due to best-option,
#                          0 due to fixed atoms,           0 due to exclusions
#  HBEDIT: currently     0 hydrogen bonds present
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#                          0 primary donor to image acceptor hbonds found
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#                          0 image donor to primary acceptor hbonds found
#                          0 unique image hbonds found
#  HBEDIT-deletions:       0 due to duplications,          0 due to best-option,
#                          0 due to fixed atoms,           0 due to exclusions
#  HBEDIT: currently     0 hydrogen bonds present
#  UPDECI: Nonbond update at step       400
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR   364936 ATOM PAIRS AND        0 GROUP PAIRS
#
#  General atom nonbond list generation found:
#    200037 ATOM PAIRS WERE FOUND FOR ATOM LIST
#      8549 GROUP PAIRS REQUIRED ATOM SEARCHES
#
#  SPACE FOR   538488 ATOM PAIRS AND        0 GROUP PAIRS
#
#  Image nonbond list generation found:
#    141281 ATOM PAIRS WERE FOUND FOR ATOM LIST
#         0 ATOM PAIRS WERE FOUND FOR ATOM SELF LIST
#     10813 GROUP PAIRS REQUIRED ATOM SEARCHES
#
# MINI>      400  -1549.83102      3.53488      0.22646      0.02270
# MINI INTERN>        0.32682     68.55634      1.11093      0.00000      0.00000
# MINI EXTERN>    -1243.91893    -71.63693      0.00000      0.00000      0.00000
# MINI IMAGES>     -291.38837    -12.88090      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      410  -1551.90607      2.07505      0.12840      0.01319
# MINI INTERN>        0.28948     68.47669      1.11940      0.00000      0.00000
# MINI EXTERN>    -1245.55268    -71.83657      0.00000      0.00000      0.00000
# MINI IMAGES>     -291.47100    -12.93139      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      420  -1555.72751      3.82144      0.24132      0.02129
# MINI INTERN>        0.32216     68.43339      1.11941      0.00000      0.00000
# MINI EXTERN>    -1247.54137    -73.01659      0.00000      0.00000      0.00000
# MINI IMAGES>     -291.76484    -13.27966      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      430  -1559.24851      3.52100      0.21490      0.02062
# MINI INTERN>        0.31701     68.48754      1.11727      0.00000      0.00000
# MINI EXTERN>    -1249.62721    -73.91446      0.00000      0.00000      0.00000
# MINI IMAGES>     -292.03517    -13.59349      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      440  -1561.56819      2.31968      0.38942      0.03329
# MINI INTERN>        0.42659     68.59517      1.12664      0.00000      0.00000
# MINI EXTERN>    -1250.66849    -74.85369      0.00000      0.00000      0.00000
# MINI IMAGES>     -292.22064    -13.97377      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
#  UPDECI: Image update at step       450
#
#  <MKIMAT2>: updating the image atom lists and remapping
#  Transformation   Atoms  Groups  Residues  Min-Distance
#     1  C001 has      30       6       6        1.22
#     2  C002 has     185      37      37        0.00
#     3  C003 has      35       7       7        3.28
#     4  C004 has     180      36      36        0.00
#     5  C005 has     665     133     133        0.00
#     6  C006 has     285      57      57        0.00
#     7  C007 has     155      31      31        0.00
#     8  C008 has     640     128     128        0.00
#     9  C009 has     265      53      53        0.22
#    10  C010 has     630     126     126        0.00
#    12  C012 has      55      11      11        3.69
#    13  C013 has     200      40      40        0.00
#    14  C014 has      70      14      14        4.25
#  Total of 4665 atoms and  933 groups and  933 residues were included
#
#  <MAKGRP> found      0 image group exclusions.
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#  HBEDIT-deletions:       0 due to duplications,          0 due to best-option,
#                          0 due to fixed atoms,           0 due to exclusions
#  HBEDIT: currently     0 hydrogen bonds present
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#                          0 primary donor to image acceptor hbonds found
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#                          0 image donor to primary acceptor hbonds found
#                          0 unique image hbonds found
#  HBEDIT-deletions:       0 due to duplications,          0 due to best-option,
#                          0 due to fixed atoms,           0 due to exclusions
#  HBEDIT: currently     0 hydrogen bonds present
#  UPDECI: Nonbond update at step       450
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR   364936 ATOM PAIRS AND        0 GROUP PAIRS
#
#  General atom nonbond list generation found:
#    200743 ATOM PAIRS WERE FOUND FOR ATOM LIST
#      8604 GROUP PAIRS REQUIRED ATOM SEARCHES
#
#  SPACE FOR   538488 ATOM PAIRS AND        0 GROUP PAIRS
#
#  Image nonbond list generation found:
#    140580 ATOM PAIRS WERE FOUND FOR ATOM LIST
#         0 ATOM PAIRS WERE FOUND FOR ATOM SELF LIST
#     10784 GROUP PAIRS REQUIRED ATOM SEARCHES
#
# MINI>      450  -1566.61616      5.04797      0.21384      0.01935
# MINI INTERN>        0.42447     68.49158      1.11270      0.00000      0.00000
# MINI EXTERN>    -1252.61331    -76.45600      0.00000      0.00000      0.00000
# MINI IMAGES>     -292.78175    -14.79384      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      460  -1571.30912      4.69296      0.21373      0.03123
# MINI INTERN>        0.27530     68.62729      1.14852      0.00000      0.00000
# MINI EXTERN>    -1254.39364    -77.71261      0.00000      0.00000      0.00000
# MINI IMAGES>     -293.58821    -15.66577      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      470  -1574.42404      3.11491      0.24825      0.02016
# MINI INTERN>        0.33293     68.41317      1.12295      0.00000      0.00000
# MINI EXTERN>    -1255.87577    -78.29778      0.00000      0.00000      0.00000
# MINI IMAGES>     -294.01856    -16.10098      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      480  -1575.87945      1.45541      0.27340      0.01953
# MINI INTERN>        0.33503     68.39266      1.12848      0.00000      0.00000
# MINI EXTERN>    -1257.16309    -78.26065      0.00000      0.00000      0.00000
# MINI IMAGES>     -294.25109    -16.06078      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      490  -1577.47960      1.60015      0.21248      0.01892
# MINI INTERN>        0.30376     68.56176      1.11984      0.00000      0.00000
# MINI EXTERN>    -1258.33783    -78.53267      0.00000      0.00000      0.00000
# MINI IMAGES>     -294.45856    -16.13592      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
#  UPDECI: Image update at step       500
#
#  <MKIMAT2>: updating the image atom lists and remapping
#  Transformation   Atoms  Groups  Residues  Min-Distance
#     1  C001 has      30       6       6        1.30
#     2  C002 has     185      37      37        0.00
#     3  C003 has      35       7       7        3.23
#     4  C004 has     180      36      36        0.00
#     5  C005 has     675     135     135        0.00
#     6  C006 has     285      57      57        0.00
#     7  C007 has     155      31      31        0.00
#     8  C008 has     650     130     130        0.00
#     9  C009 has     270      54      54        0.22
#    10  C010 has     625     125     125        0.00
#    12  C012 has      45       9       9        3.65
#    13  C013 has     200      40      40        0.00
#    14  C014 has      70      14      14        4.12
#  Total of 4675 atoms and  935 groups and  935 residues were included
#
#  <MAKGRP> found      0 image group exclusions.
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#  HBEDIT-deletions:       0 due to duplications,          0 due to best-option,
#                          0 due to fixed atoms,           0 due to exclusions
#  HBEDIT: currently     0 hydrogen bonds present
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#                          0 primary donor to image acceptor hbonds found
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#                          0 image donor to primary acceptor hbonds found
#                          0 unique image hbonds found
#  HBEDIT-deletions:       0 due to duplications,          0 due to best-option,
#                          0 due to fixed atoms,           0 due to exclusions
#  HBEDIT: currently     0 hydrogen bonds present
#  UPDECI: Nonbond update at step       500
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR   364936 ATOM PAIRS AND        0 GROUP PAIRS
#
#  General atom nonbond list generation found:
#    201296 ATOM PAIRS WERE FOUND FOR ATOM LIST
#      8627 GROUP PAIRS REQUIRED ATOM SEARCHES
#
#  SPACE FOR   538488 ATOM PAIRS AND        0 GROUP PAIRS
#
#  Image nonbond list generation found:
#    140217 ATOM PAIRS WERE FOUND FOR ATOM LIST
#         0 ATOM PAIRS WERE FOUND FOR ATOM SELF LIST
#     10805 GROUP PAIRS REQUIRED ATOM SEARCHES
#
# MINI>      500  -1579.32005      1.84046      0.19358      0.01832
# MINI INTERN>        0.28760     68.40984      1.12465      0.00000      0.00000
# MINI EXTERN>    -1259.39222    -78.86141      0.00000      0.00000      0.00000
# MINI IMAGES>     -294.64146    -16.24705      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      510  -1581.41609      2.09604      0.19346      0.01972
# MINI INTERN>        0.32646     68.41461      1.11133      0.00000      0.00000
# MINI EXTERN>    -1260.41271    -79.41215      0.00000      0.00000      0.00000
# MINI IMAGES>     -294.92850    -16.51513      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      520  -1583.22871      1.81261      0.24090      0.01910
# MINI INTERN>        0.31360     68.45354      1.11906      0.00000      0.00000
# MINI EXTERN>    -1261.79949    -79.43261      0.00000      0.00000      0.00000
# MINI IMAGES>     -295.22037    -16.66244      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>      530  -1584.28148      1.05277      0.17384      0.01850
# MINI INTERN>        0.28323     68.43131      1.11729      0.00000      0.00000
# MINI EXTERN>    -1262.41999    -79.52742      0.00000      0.00000      0.00000
# MINI IMAGES>     -295.38925    -16.77665      0.00000      0.00000      0.00000
# ...
#  HBEDIT: currently     0 hydrogen bonds present
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#                          0 primary donor to image acceptor hbonds found
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#                          0 image donor to primary acceptor hbonds found
#                          0 unique image hbonds found
#  HBEDIT-deletions:       0 due to duplications,          0 due to best-option,
#                          0 due to fixed atoms,           0 due to exclusions
#  HBEDIT: currently     0 hydrogen bonds present
#  UPDECI: Nonbond update at step      5850
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR   364936 ATOM PAIRS AND        0 GROUP PAIRS
#
#  General atom nonbond list generation found:
#    211138 ATOM PAIRS WERE FOUND FOR ATOM LIST
#      8941 GROUP PAIRS REQUIRED ATOM SEARCHES
#
#  SPACE FOR   538488 ATOM PAIRS AND        0 GROUP PAIRS
#
#  Image nonbond list generation found:
#    139342 ATOM PAIRS WERE FOUND FOR ATOM LIST
#         0 ATOM PAIRS WERE FOUND FOR ATOM SELF LIST
#     10409 GROUP PAIRS REQUIRED ATOM SEARCHES
#
# MINI>     5850  -1730.81334      0.02449      0.02874      0.00254
# MINI INTERN>        0.54845     68.49054      1.09125      0.00000      0.00000
# MINI EXTERN>    -1343.47049    -91.33443      0.00000      0.00000      0.00000
# MINI IMAGES>     -342.93648    -23.20220      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>     5860  -1730.82462      0.01128      0.02205      0.00148
# MINI INTERN>        0.54979     68.48921      1.09044      0.00000      0.00000
# MINI EXTERN>    -1343.47866    -91.33514      0.00000      0.00000      0.00000
# MINI IMAGES>     -342.94088    -23.19940      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>     5870  -1730.83510      0.01048      0.03214      0.00238
# MINI INTERN>        0.55118     68.48792      1.09088      0.00000      0.00000
# MINI EXTERN>    -1343.45153    -91.34735      0.00000      0.00000      0.00000
# MINI IMAGES>     -342.97182    -23.19438      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>     5880  -1730.84628      0.01117      0.01565      0.00139
# MINI INTERN>        0.54870     68.49007      1.09047      0.00000      0.00000
# MINI EXTERN>    -1343.47290    -91.33935      0.00000      0.00000      0.00000
# MINI IMAGES>     -342.96669    -23.19657      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>     5890  -1730.89789      0.05161      0.03894      0.00373
# MINI INTERN>        0.54691     68.48989      1.09064      0.00000      0.00000
# MINI EXTERN>    -1343.41059    -91.35036      0.00000      0.00000      0.00000
# MINI IMAGES>     -343.06863    -23.19574      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
#  UPDECI: Image update at step      5900
#
#  <MKIMAT2>: updating the image atom lists and remapping
#  Transformation   Atoms  Groups  Residues  Min-Distance
#     1  C001 has      20       4       4        1.57
#     2  C002 has     145      29      29        0.00
#     3  C003 has      20       4       4        1.43
#     4  C004 has     185      37      37        0.00
#     5  C005 has     730     146     146        0.00
#     6  C006 has     340      68      68        0.00
#     7  C007 has     180      36      36        0.00
#     8  C008 has     685     137     137        0.00
#     9  C009 has     270      54      54        0.00
#    10  C010 has     625     125     125        0.00
#    12  C012 has      30       6       6        3.01
#    13  C013 has     150      30      30        0.00
#    14  C014 has      45       9       9        3.02
#  Total of 4695 atoms and  939 groups and  939 residues were included
#
#  <MAKGRP> found      0 image group exclusions.
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#  HBEDIT-deletions:       0 due to duplications,          0 due to best-option,
#                          0 due to fixed atoms,           0 due to exclusions
#  HBEDIT: currently     0 hydrogen bonds present
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#                          0 primary donor to image acceptor hbonds found
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#                          0 image donor to primary acceptor hbonds found
#                          0 unique image hbonds found
#  HBEDIT-deletions:       0 due to duplications,          0 due to best-option,
#                          0 due to fixed atoms,           0 due to exclusions
#  HBEDIT: currently     0 hydrogen bonds present
#  UPDECI: Nonbond update at step      5900
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR   364936 ATOM PAIRS AND        0 GROUP PAIRS
#
#  General atom nonbond list generation found:
#    211221 ATOM PAIRS WERE FOUND FOR ATOM LIST
#      8949 GROUP PAIRS REQUIRED ATOM SEARCHES
#
#  SPACE FOR   538488 ATOM PAIRS AND        0 GROUP PAIRS
#
#  Image nonbond list generation found:
#    139317 ATOM PAIRS WERE FOUND FOR ATOM LIST
#         0 ATOM PAIRS WERE FOUND FOR ATOM SELF LIST
#     10387 GROUP PAIRS REQUIRED ATOM SEARCHES
#
# MINI>     5900  -1730.94620      0.04831      0.02896      0.00217
# MINI INTERN>        0.54804     68.48934      1.09062      0.00000      0.00000
# MINI EXTERN>    -1343.43342    -91.31965      0.00000      0.00000      0.00000
# MINI IMAGES>     -343.11885    -23.20228      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>     5910  -1730.96986      0.02366      0.02242      0.00210
# MINI INTERN>        0.54884     68.48766      1.08997      0.00000      0.00000
# MINI EXTERN>    -1343.40523    -91.29700      0.00000      0.00000      0.00000
# MINI IMAGES>     -343.18249    -23.21162      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>     5920  -1730.99909      0.02922      0.02148      0.00203
# MINI INTERN>        0.54822     68.49068      1.09040      0.00000      0.00000
# MINI EXTERN>    -1343.44338    -91.29003      0.00000      0.00000      0.00000
# MINI IMAGES>     -343.16076    -23.23422      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>     5930  -1731.07181      0.07273      0.05045      0.00547
# MINI INTERN>        0.54937     68.49904      1.08900      0.00000      0.00000
# MINI EXTERN>    -1343.42487    -91.25493      0.00000      0.00000      0.00000
# MINI IMAGES>     -343.21881    -23.31061      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>     5940  -1731.12556      0.05375      0.03117      0.00318
# MINI INTERN>        0.55018     68.48951      1.09288      0.00000      0.00000
# MINI EXTERN>    -1343.41813    -91.17752      0.00000      0.00000      0.00000
# MINI IMAGES>     -343.26951    -23.39297      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
#  UPDECI: Image update at step      5950
#
#  <MKIMAT2>: updating the image atom lists and remapping
#  Transformation   Atoms  Groups  Residues  Min-Distance
#     1  C001 has      20       4       4        1.54
#     2  C002 has     145      29      29        0.00
#     3  C003 has      20       4       4        1.42
#     4  C004 has     185      37      37        0.00
#     5  C005 has     730     146     146        0.00
#     6  C006 has     340      68      68        0.00
#     7  C007 has     180      36      36        0.00
#     8  C008 has     685     137     137        0.00
#     9  C009 has     270      54      54        0.00
#    10  C010 has     630     126     126        0.00
#    12  C012 has      30       6       6        3.02
#    13  C013 has     150      30      30        0.00
#    14  C014 has      45       9       9        2.96
#  Total of 4700 atoms and  940 groups and  940 residues were included
#
#  <MAKGRP> found      0 image group exclusions.
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#  HBEDIT-deletions:       0 due to duplications,          0 due to best-option,
#                          0 due to fixed atoms,           0 due to exclusions
#  HBEDIT: currently     0 hydrogen bonds present
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#                          0 primary donor to image acceptor hbonds found
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#                          0 image donor to primary acceptor hbonds found
#                          0 unique image hbonds found
#  HBEDIT-deletions:       0 due to duplications,          0 due to best-option,
#                          0 due to fixed atoms,           0 due to exclusions
#  HBEDIT: currently     0 hydrogen bonds present
#  UPDECI: Nonbond update at step      5950
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR   364936 ATOM PAIRS AND        0 GROUP PAIRS
#
#  General atom nonbond list generation found:
#    211348 ATOM PAIRS WERE FOUND FOR ATOM LIST
#      8951 GROUP PAIRS REQUIRED ATOM SEARCHES
#
#  SPACE FOR   538488 ATOM PAIRS AND        0 GROUP PAIRS
#
#  Image nonbond list generation found:
#    139269 ATOM PAIRS WERE FOUND FOR ATOM LIST
#         0 ATOM PAIRS WERE FOUND FOR ATOM SELF LIST
#     10392 GROUP PAIRS REQUIRED ATOM SEARCHES
#
# MINI>     5950  -1731.15413      0.02857      0.04878      0.00308
# MINI INTERN>        0.55389     68.49329      1.09016      0.00000      0.00000
# MINI EXTERN>    -1343.41566    -91.16997      0.00000      0.00000      0.00000
# MINI IMAGES>     -343.29843    -23.40741      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>     5960  -1731.18268      0.02855      0.02463      0.00179
# MINI INTERN>        0.55287     68.49185      1.09051      0.00000      0.00000
# MINI EXTERN>    -1343.44160    -91.18274      0.00000      0.00000      0.00000
# MINI IMAGES>     -343.30863    -23.38494      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>     5970  -1731.19170      0.00903      0.00805      0.00104
# MINI INTERN>        0.55197     68.49165      1.09055      0.00000      0.00000
# MINI EXTERN>    -1343.45224    -91.17053      0.00000      0.00000      0.00000
# MINI IMAGES>     -343.31069    -23.39240      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>     5980  -1731.21855      0.02684      0.03003      0.00280
# MINI INTERN>        0.55484     68.49671      1.09053      0.00000      0.00000
# MINI EXTERN>    -1343.46051    -91.14643      0.00000      0.00000      0.00000
# MINI IMAGES>     -343.34906    -23.40463      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>     5990  -1731.27413      0.05558      0.05059      0.00451
# MINI INTERN>        0.55407     68.49591      1.09042      0.00000      0.00000
# MINI EXTERN>    -1343.48317    -91.07124      0.00000      0.00000      0.00000
# MINI IMAGES>     -343.41837    -23.44174      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
#  UPDECI: Image update at step      6000
#
#  <MKIMAT2>: updating the image atom lists and remapping
#  Transformation   Atoms  Groups  Residues  Min-Distance
#     1  C001 has      20       4       4        1.53
#     2  C002 has     145      29      29        0.00
#     3  C003 has      20       4       4        1.42
#     4  C004 has     185      37      37        0.00
#     5  C005 has     730     146     146        0.00
#     6  C006 has     340      68      68        0.00
#     7  C007 has     180      36      36        0.00
#     8  C008 has     685     137     137        0.00
#     9  C009 has     270      54      54        0.00
#    10  C010 has     630     126     126        0.00
#    12  C012 has      30       6       6        3.03
#    13  C013 has     145      29      29        0.00
#    14  C014 has      45       9       9        2.93
#  Total of 4695 atoms and  939 groups and  939 residues were included
#
#  <MAKGRP> found      0 image group exclusions.
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#  HBEDIT-deletions:       0 due to duplications,          0 due to best-option,
#                          0 due to fixed atoms,           0 due to exclusions
#  HBEDIT: currently     0 hydrogen bonds present
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#                          0 primary donor to image acceptor hbonds found
#  HBFIND-exclusions:      0 due to distance cutoff,       0 due to angle cutoff
#                          0 image donor to primary acceptor hbonds found
#                          0 unique image hbonds found
#  HBEDIT-deletions:       0 due to duplications,          0 due to best-option,
#                          0 due to fixed atoms,           0 due to exclusions
#  HBEDIT: currently     0 hydrogen bonds present
#  UPDECI: Nonbond update at step      6000
#  Generating nonbond list with Exclusion mode = 5
#  == PRIMARY == SPACE FOR   364936 ATOM PAIRS AND        0 GROUP PAIRS
#
#  General atom nonbond list generation found:
#    211360 ATOM PAIRS WERE FOUND FOR ATOM LIST
#      8953 GROUP PAIRS REQUIRED ATOM SEARCHES
#
#  SPACE FOR   538488 ATOM PAIRS AND        0 GROUP PAIRS
#
#  Image nonbond list generation found:
#    139271 ATOM PAIRS WERE FOUND FOR ATOM LIST
#         0 ATOM PAIRS WERE FOUND FOR ATOM SELF LIST
#     10404 GROUP PAIRS REQUIRED ATOM SEARCHES
#
# MINI>     6000  -1731.29420      0.02007      0.01242      0.00157
# MINI INTERN>        0.55320     68.49003      1.08995      0.00000      0.00000
# MINI EXTERN>    -1343.52016    -91.08099      0.00000      0.00000      0.00000
# MINI IMAGES>     -343.38276    -23.44346      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>     6010  -1731.30677      0.01257      0.02284      0.00152
# MINI INTERN>        0.55382     68.49182      1.08984      0.00000      0.00000
# MINI EXTERN>    -1343.50777    -91.08441      0.00000      0.00000      0.00000
# MINI IMAGES>     -343.40332    -23.44675      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# MINI>     6020  -1731.30874      0.00197      0.00658      0.00053
# MINI INTERN>        0.55344     68.49213      1.08987      0.00000      0.00000
# MINI EXTERN>    -1343.51236    -91.08822      0.00000      0.00000      0.00000
# MINI IMAGES>     -343.39445    -23.44915      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
#
#  ABNER> Minimization exiting with function tolerance ( 0.0000010) satisfied.
#
# ABNR MIN: Cycle      ENERgy      Delta-E         GRMS    Step-size
# ABNR INTERN:          BONDs       ANGLes       UREY-b    DIHEdrals    IMPRopers
# ABNR EXTERN:        VDWaals         ELEC       HBONds          ASP         USER
# ABNR IMAGES:        IMNBvdw       IMELec       IMHBnd       RXNField    EXTElec
#  ----------       ---------    ---------    ---------    ---------    ---------
# ABNR>     6028  -1731.31781      0.00907      0.02732      0.00159
# ABNR INTERN>        0.55468     68.49341      1.08975      0.00000      0.00000
# ABNR EXTERN>    -1343.51087    -91.08858      0.00000      0.00000      0.00000
# ABNR IMAGES>     -343.39535    -23.46084      0.00000      0.00000      0.00000
#  ----------       ---------    ---------    ---------    ---------    ---------
# True

# %%
write.coor_pdb('test.pdb')
write.coor_pdb("dcm.pdb", title="Formic Acid Dimer with Water")
write.psf_card("fad_water.psf", title="Formic Acid Dimer with Water")
# Out:
#
#  CHARMM>     write name test.pdb -
#  CHARMM>     coor pdb
#  VOPEN> Attempting to open::test.pdb::
#  RDTITL>
#  RDTITL> No title read.
#   Write CHARMM-pdb format
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#
#  CHARMM>     write name dcm.pdb -
#  CHARMM>     coor pdb
#  VOPEN> Attempting to open::dcm.pdb::
#  RDTITL> * FORMIC ACID DIMER WITH WATER
#  RDTITL> *
#   Write CHARMM-pdb format
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
#
#
#  CHARMM>     write name fad_water.psf -
#  CHARMM>     psf card
#  VOPEN> Attempting to open::fad_water.psf::
#  RDTITL> * FORMIC ACID DIMER WITH WATER
#  RDTITL> *
#  VCLOSE: Closing unit   91 with status "KEEP"
#
#  CHARMM>
