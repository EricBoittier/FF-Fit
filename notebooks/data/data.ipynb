# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
from ff_energy.plotting.data_plots import DataPlots
import matplotlib.pyplot as plt
plt.set_loglevel("notset")

pkl_path = "/home/boittier/Documents/phd/ff_energy/pickles/dcm_pbe0dz_pc.pkl"
data = pd.read_pickle(pkl_path)

dataplot = DataPlots(data)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dataplot.data.describe()
# Out:
#            M_ENERGY  n_monomers      C_ENERGY        intE      P_intE  \
# count    201.000000       201.0    201.000000  201.000000  201.000000
# mean  -19187.348845        20.0 -19187.369408  -12.903388  -13.200988
# std        0.010286         0.0      0.012571    4.155822    4.237359
# min   -19187.374614        20.0 -19187.403082  -24.250399  -25.257264
# 25%   -19187.355706        20.0 -19187.378212  -15.953931  -16.112004
# 50%   -19187.349671        20.0 -19187.371210  -12.825383  -13.242955
# 75%   -19187.342966        20.0 -19187.362383  -10.035430  -10.346979
# max   -19187.313885        20.0 -19187.323216   -2.586429   -2.905018
#
#        C_ENERGY_kcalmol
# count      2.010000e+02
# mean      -1.204013e+07
# std        7.888463e+00
# min       -1.204015e+07
# 25%       -1.204014e+07
# 50%       -1.204013e+07
# 75%       -1.204013e+07
# max       -1.204010e+07

# %%
dataplot.energy_hist()
# Out:
# DEBUG:matplotlib.colorbar:locator: <matplotlib.ticker.AutoLocator object at 0x7ff89369b880>
# 2023-08-07 15:39:09 | DEBUG | colorbar:_get_ticker_locator_formatter:876 - locator: <matplotlib.ticker.AutoLocator object at 0x7ff89369b880>
# 3.1198171647492714e-191
# (<Figure size 800x600 with 3 Axes>, <Axes: >)
