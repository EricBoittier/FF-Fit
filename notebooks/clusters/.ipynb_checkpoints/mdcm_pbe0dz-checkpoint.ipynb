# %%
# %load_ext autoreload
# %autoreload 2

from ff_energy.structure import Structure
from ff_energy.job import Job
from ff_energy.plot import plot_energy_MSE
import pandas as pd

# s = Structure("/home/boittier/charmm/mix3/jobs/pdbs/mix0.pdb")

kwargs = {"m_nproc": 4, "m_memory": 480, "m_queue": "short", 
          "m_basis": "avdz", "m_method": "run,ks,pbe0",
          "chmpath": "/home/boittier/dev-release-dcm/build/cmake/charmm",
          "modules": "module load cmake/cmake-3.23.0-gcc-11.2.0-openmpi-4.1.3",
          "c_files": ["pbe0_dz.mdcm"],
          "c_dcm_command": f"open unit 11 card read name pbe0_dz.mdcm \nDCM IUDCM 11 TSHIFT XYZ 15",
          }

JOBDIR = "d3d/mdcm_pbe0dz"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from pathlib import Path
import os
PDBPATH = Path("/home/boittier/charmm/test/dimer3d/")
pdbs = [_ for _ in os.listdir(PDBPATH) if _.endswith("pdb")]

# %%
for p in pdbs:
    s_path = PDBPATH / p
    s = Structure(s_path)
    s.set_2body()
    ID = p.split(".")[0]
    j = Job(ID, f"/home/boittier/homeb/{JOBDIR}/{ID}", s, kwargs=kwargs)
    # j.generate_molpro()
    j.generate_charmm()

# %%
# for x in *; do cd $x; cd charmm; sbatch *.slurm; cd ../..; done
# for x in *; do cd $x/monomers; for y in *.sh; do sbatch $y; done ; cd ../..; done

# %%
mp = "/home/boittier/homeb/d3d/pbe0dz/{}/monomers"

for p in pdbs:
    s_path = PDBPATH / p
    s = Structure(s_path)
    s.set_2body()
    ID = p.split(".")[0]
    j = Job(ID, f"/home/boittier/homeb/{JOBDIR}/{ID}", s, kwargs=kwargs)
    j.generate_coloumb_interactions(monomers_path=Path(mp.format(ID)))
    j.generate_polarization(nch_per_monomer=(3, 3),
                           monomers_path=Path(mp.format(ID))
                           )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 10
#       8 j = Job(ID, f"/home/boittier/homeb/{JOBDIR}/{ID}", s, kwargs=kwargs)
#       9 j.generate_coloumb_interactions(monomers_path=Path(mp.format(ID)))
# ---> 10 j.generate_polarization(nch_per_monomer=(3, 3),
#      11                        monomers_path=mp.format(ID)
#      12                        )
#
# File ~/Documents/phd/ff_energy/ff_energy/job.py:138, in Job.generate_polarization(self, nch_per_monomer, monomers_path)
#     135     monomers_path = self.monomers_path
#     137 for monomer in monomers:
# --> 138     wfpath = monomers_path / f"{self.name}_{monomer}.molden"
#     139     copy(wfpath, self.polarization_path)
#     140     #  make a lattice file
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
# for x in *; do cd $x/coloumb; for y in *.sh; do sbatch $y; done ; cd ../..; done
# for x in *; do cd $x/polarization; for y in *.slurm; do sbatch $y; done ; cd ../..; done

# %%
# p_data = j.gather_data()

# %%
output = []
for p in pdbs:
    s_path = PDBPATH / p
    s = Structure(s_path)
    s.set_2body()
    ID = p.split(".")[0]
    j = Job(ID, f"/home/boittier/homeb/{JOBDIR}/{ID}", s, kwargs=kwargs)
    o = j.gather_data()
    output.append(o)

# %%
o = j.gather_data()

# %%
o["polarization"].sum()
# Out:
# QMMM        -152.069846
# KEY        17-1_117-1_2
# NOFIELD      -152.06976
# pol           -0.053645
# dtype: object

# %%
#  generate molpro jobs and wait
#  generate charmm jobs and wait
#  generate orbkit jobs

# %%
chm_df = pd.concat([_["charmm"] for _ in output])

# %%
ctot = pd.concat([_["coloumb_total"] for _ in output])

# %%
_ = pd.concat([_["polarization"].sum() for _ in output])

# %%
pol_df = pd.concat([_["pol_total"] for _ in output])

# %%
pol_df
# Out:
#            POL   KEY
# 7-3  -0.451832   7-3
# 3-1  -3.091648   3-1
# 8-2  -0.333524   8-2
# 3-3  -2.988207   3-3
# 9-3  -0.236082   9-3
# ...        ...   ...
# 6-2  -0.699853   6-2
# 20-1 -0.036185  20-1
# 7-2  -0.471351   7-2
# 19-1 -0.040975  19-1
# 17-1 -0.053645  17-1
#
# [104 rows x 2 columns]

# %%
#  convert molpro csv
converters = {i: lambda x: float(x.strip().replace("D","E")) * 627.503 * 10**(-3) for i in range(3,10)}
converters[0] = lambda x: x
converters[1] = lambda x: float(x.strip().replace("D","E"))
converters[2] = lambda x: float(x.strip().replace("D","E"))

#  read molpro csv
df = pd.read_csv("/home/boittier/pcbach/dimer3d/sapt.csv", converters=converters)
#  strip whitespace in column names
df = df.rename(columns=lambda x: x.strip())

# %%
df["KEY"] = df["KEYS"].apply(lambda x: x.strip())
df
# Out:
#       KEYS    RS     TS       ELST          EXCH         IND         EXIND  \
# 0    1-1    0.75  180.0 -62.373121  4.056921e+02 -318.197366  2.515914e+02
# 1    2-1    1.00  180.0 -61.080007  1.852532e+02 -111.370336  8.627128e+01
# 2    3-1    1.25  180.0 -36.211838  7.964523e+01  -39.555195  2.925575e+01
# 3    4-1    1.50  180.0 -20.247849  3.307793e+01  -14.405995  9.790059e+00
# 4    5-1    1.75  180.0 -11.790530  1.349713e+01   -5.513265  3.288282e+00
# ..     ...   ...    ...        ...           ...         ...           ...
# 107  12-5   3.50   90.0  -0.913704  2.024254e-02   -0.046512  2.525937e-03
# 108  13-5   4.25   90.0  -0.473149  1.119777e-03   -0.014520  1.380030e-04
# 109  14-5   5.00   90.0  -0.270115  5.359255e-05   -0.005766  9.085400e-06
# 110  15-5   7.00   90.0  -0.081262 -5.079888e-07   -0.000868  5.742869e-07
# 111  16-5   9.00   90.0  -0.032185 -2.521828e-08   -0.000208  1.139545e-08
#
#           DISP        EXDISP        ETOT   KEY
# 0   -35.614933 -4.037036e-01  240.694452   1-1
# 1   -20.122589  3.723402e+00   82.674903   2-1
# 2   -11.147753  2.685490e+00   24.671678   3-1
# 3    -6.174418  1.462394e+00    3.502116   4-1
# 4    -3.447615  7.158500e-01   -3.250147   5-1
# ..         ...           ...         ...   ...
# 107  -0.113131  2.312804e-03   -1.048266  12-5
# 108  -0.038197  1.642618e-04   -0.524445  13-5
# 109  -0.015719  1.147403e-05   -0.291525  14-5
# 110  -0.002505  1.499236e-07   -0.084635  15-5
# 111  -0.000623  3.783456e-09   -0.033016  16-5
#
# [112 rows x 11 columns]

# %%
pol_3d = pd.merge(df, pol_df, on="KEY")
pol_3d = pd.merge(pol_3d, ctot)
pol_3d = pd.merge(pol_3d, chm_df)
pol_3d
# Out:
#      KEYS    RS     TS       ELST          EXCH         IND         EXIND  \
# 0   1-1    0.75  180.0 -62.373121  4.056921e+02 -318.197366  2.515914e+02
# 1   2-1    1.00  180.0 -61.080007  1.852532e+02 -111.370336  8.627128e+01
# 2   3-1    1.25  180.0 -36.211838  7.964523e+01  -39.555195  2.925575e+01
# 3   4-1    1.50  180.0 -20.247849  3.307793e+01  -14.405995  9.790059e+00
# 4   5-1    1.75  180.0 -11.790530  1.349713e+01   -5.513265  3.288282e+00
# ..    ...   ...    ...        ...           ...         ...           ...
# 75  12-5   3.50   90.0  -0.913704  2.024254e-02   -0.046512  2.525937e-03
# 76  13-5   4.25   90.0  -0.473149  1.119777e-03   -0.014520  1.380030e-04
# 77  14-5   5.00   90.0  -0.270115  5.359255e-05   -0.005766  9.085400e-06
# 78  15-5   7.00   90.0  -0.081262 -5.079888e-07   -0.000868  5.742869e-07
# 79  16-5   9.00   90.0  -0.032185 -2.521828e-08   -0.000208  1.139545e-08
#
#          DISP        EXDISP        ETOT   KEY       POL       ECOL  \
# 0  -35.614933 -4.037036e-01  240.694452   1-1 -8.830861 -65.850672
# 1  -20.122589  3.723402e+00   82.674903   2-1 -5.055018 -61.354694
# 2  -11.147753  2.685490e+00   24.671678   3-1 -3.091648 -36.208831
# 3   -6.174418  1.462394e+00    3.502116   4-1 -1.860897 -20.171970
# 4   -3.447615  7.158500e-01   -3.250147   5-1 -1.137719 -11.571804
# ..        ...           ...         ...   ...       ...        ...
# 75  -0.113131  2.312804e-03   -1.048266  12-5 -0.108700  -0.842129
# 76  -0.038197  1.642618e-04   -0.524445  13-5 -0.065924  -0.434121
# 77  -0.015719  1.147403e-05   -0.291525  14-5 -0.044590  -0.247050
# 78  -0.002505  1.499236e-07   -0.084635  15-5 -0.020924  -0.074086
# 79  -0.000623  3.783456e-09   -0.033016  16-5 -0.012304  -0.029364
#
#           TOTAL     ELEC          VDW
# 0   56057.63258 -9.97701  11137.70216
# 1    1475.14004 -4.96886    477.46500
# 2     108.30195 -2.56552     55.36028
# 3      16.55908 -1.28707     10.23080
# 4      14.37659 -0.55886      2.08525
# ..          ...      ...          ...
# 75     15.71536  0.49770     -0.08670
# 76     15.60129  0.51638     -0.03643
# 77     15.55991  0.50037     -0.01640
# 78     15.60385  0.42553     -0.00283
# 79     15.54086  0.35817     -0.00072
#
# [80 rows x 16 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np

TS = list(set(df["TS"]))
TS.sort()
colors = plt.cm.plasma_r(np.linspace(0, 1, len(TS)))

ax = plt.figure().add_subplot()

for i, ts in enumerate(TS):
    tmp = pol_3d[pol_3d["TS"] == ts]
    tmp = tmp[tmp["RS"] > 0]
    # ax.plot(tmp["RS"], tmp["ETOT"] - tmp["ELST"], "-o",  c=colors[i])
    ax.plot(tmp["RS"], tmp["POL"], "-o",  c=colors[i])
    
plt.ylim(-.1,0)
# plt.yscale("log")
plt.axhline(0, c="k", linewidth=0.1)
plt.xlim(1,8)
# Out:
# (1.0, 8.0)

# %%
import matplotlib.pyplot as plt
import numpy as np

colors = plt.cm.plasma_r(np.linspace(0, 1, len(TS)))
TS = list(set(df["TS"]))
TS.sort()

ax = plt.figure().add_subplot()

for i, ts in enumerate(TS):
    tmp = pol_3d[pol_3d["TS"] == ts]
    tmp = tmp[tmp["RS"] > 0]
    # ax.plot(tmp["RS"], tmp["ETOT"] - tmp["ELST"], "-o",  c=colors[i])
    ax.plot(tmp["RS"], tmp["ECOL"], "-d",  c=colors[i])
    ax.plot(tmp["RS"], tmp["ELST"], "-d",  c=colors[i])
    ax.plot(tmp["RS"], tmp["ELEC"], "-x",  c=colors[i])
    ax.plot(tmp["RS"], tmp["ELEC"] + tmp["POL"], "--x",  c=colors[i])
    
plt.legend()
# plt.ylim(-10,0)
plt.axhline(0, c="k", linewidth=0.1)
# plt.xlim(1.5,3)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
j.kwargs
# Out:
# {'m_nproc': 4,
#  'm_memory': 480,
#  'm_queue': 'short',
#  'm_basis': 'avdz',
#  'm_method': 'run,ks,pbe0',
#  'chmpath': '/home/boittier/dev-release-dcm/build/cmake/charmm',
#  'modules': 'module load cmake/cmake-3.23.0-gcc-11.2.0-openmpi-4.1.3',
#  'c_files': ['pbe0_dz.pc'],
#  'c_dcm_command': 'open unit 11 card read name pbe0_dz.pc \nDCM IUDCM 11 TSHIFT XYZ 15'}

# %%
pol_3d["ELECpol"] = pol_3d["ELEC"] + pol_3d["POL"]

# %%
plot_energy_MSE(pol_3d, "ECOL", "ELST", 
                elec="ECOL", CMAP="plasma",
               xlabel="Coulomb integral [kcal/mol]",
               ylabel="SAPT-ELEC [kcal/mol]")

plt.savefig("sapt_vs_ci.pdf", bbox_inches="tight")

# %%
plot_energy_MSE(pol_3d, "ECOL", "ELEC", 
                elec="ECOL", CMAP="plasma",
               xlabel="Coulomb integral [kcal/mol]",
               ylabel="CHM-ELEC [kcal/mol]")
plt.savefig("chm_vs_ci.pdf", bbox_inches="tight")

# %%
plot_energy_MSE(pol_3d, "ECOL", "ELECpol", 
                elec="ECOL", CMAP="plasma",
               xlabel="Coulomb integral [kcal/mol]",
               ylabel="CHM-ELEC + POL [kcal/mol]")
plt.savefig("chm_pol_vs_ci.pdf", bbox_inches="tight")

# %%
pol_3d
# Out:
#      KEYS    RS     TS       ELST          EXCH         IND         EXIND  \
# 0   1-1    0.75  180.0 -62.373121  4.056921e+02 -318.197366  2.515914e+02
# 1   2-1    1.00  180.0 -61.080007  1.852532e+02 -111.370336  8.627128e+01
# 2   3-1    1.25  180.0 -36.211838  7.964523e+01  -39.555195  2.925575e+01
# 3   4-1    1.50  180.0 -20.247849  3.307793e+01  -14.405995  9.790059e+00
# 4   5-1    1.75  180.0 -11.790530  1.349713e+01   -5.513265  3.288282e+00
# ..    ...   ...    ...        ...           ...         ...           ...
# 75  12-5   3.50   90.0  -0.913704  2.024254e-02   -0.046512  2.525937e-03
# 76  13-5   4.25   90.0  -0.473149  1.119777e-03   -0.014520  1.380030e-04
# 77  14-5   5.00   90.0  -0.270115  5.359255e-05   -0.005766  9.085400e-06
# 78  15-5   7.00   90.0  -0.081262 -5.079888e-07   -0.000868  5.742869e-07
# 79  16-5   9.00   90.0  -0.032185 -2.521828e-08   -0.000208  1.139545e-08
#
#          DISP        EXDISP        ETOT   KEY        POL       ECOL  \
# 0  -35.614933 -4.037036e-01  240.694452   1-1 -17.551890 -61.301508
# 1  -20.122589  3.723402e+00   82.674903   2-1  -8.617284 -60.013564
# 2  -11.147753  2.685490e+00   24.671678   3-1  -4.685572 -36.182925
# 3   -6.174418  1.462394e+00    3.502116   4-1  -2.561838 -20.520058
# 4   -3.447615  7.158500e-01   -3.250147   5-1  -1.387239 -11.966885
# ..        ...           ...         ...   ...        ...        ...
# 75  -0.113131  2.312804e-03   -1.048266  12-5  -0.040499  -0.916508
# 76  -0.038197  1.642618e-04   -0.524445  13-5  -0.013901  -0.474694
# 77  -0.015719  1.147403e-05   -0.291525  14-5  -0.005636  -0.270469
# 78  -0.002505  1.499236e-07   -0.084635  15-5  -0.000855  -0.081184
# 79  -0.000623  3.783456e-09   -0.033016  16-5  -0.000206  -0.032198
#
#           TOTAL      ELEC          VDW           MSE    ELECpol
# 0   55966.19531 -63.31429  11137.70216  3.827764e+02 -80.866180
# 1    1459.81164 -28.09761    477.46500  5.428280e+02 -36.714894
# 2     102.77170 -16.94156     55.36028  2.118711e+02 -21.627132
# 3      15.55905 -11.13109     10.23080  4.660970e+01 -13.692928
# 4      14.77608  -7.69261      2.08525  8.334978e+00  -9.079849
# ..          ...       ...          ...           ...        ...
# 75     15.70353  -0.86105     -0.08670  2.237818e-04  -0.901549
# 76     15.56477  -0.45225     -0.03643  7.298781e-05  -0.466151
# 77     15.51919  -0.25896     -0.01640  3.448870e-05  -0.264596
# 78     15.57066  -0.07809     -0.00283  5.012296e-06  -0.078945
# 79     15.51574  -0.03105     -0.00072  8.867869e-07  -0.031256
#
# [80 rows x 18 columns]
