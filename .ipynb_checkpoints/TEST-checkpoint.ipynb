# %% [markdown]
# #  Ideas for fitting code:
#
# - pickle all FF objects

# %%
# %load_ext autoreload
# %autoreload 2

from ff_energy.cli import load_config_maker, load_all_theory, charmm_jobs
# from ff_energy.structure import
from ff_energy.potential import FF, LJ
import numpy as np
from ff_energy.data import Data, plot_ecol, plot_intE
import matplotlib.pyplot as plt
import pickle
from pathlib import Path
import pandas as pd 
from ff_energy.utils import *

sig_bound = (0.5, 4.0)
ep_bound = (0.00001, 1.0)
LJ_bound = [(sig_bound), (sig_bound), (ep_bound), (ep_bound)]
# Out:
# atom_key_pairs [('CG331', 'CG331'), ('CG331', 'HGA3'), ('CG331', 'HGP1'), ('CG331', 'HT'), ('CG331', 'OG311'), ('CG331', 'OT'), ('HGA3', 'HGA3'), ('HGA3', 'HGP1'), ('HGA3', 'HT'), ('HGA3', 'OG311'), ('HGA3', 'OT'), ('HGP1', 'HGP1'), ('HGP1', 'HT'), ('HGP1', 'OG311'), ('HGP1', 'OT'), ('HT', 'HT'), ('HT', 'OG311'), ('HT', 'OT'), ('OG311', 'OG311'), ('OG311', 'OT'), ('OT', 'OT')]
# 0 ('CG331', 'CG331')
# 1 ('CG331', 'HGA3')
# 2 ('CG331', 'HGP1')
# 3 ('CG331', 'HT')
# 4 ('CG331', 'OG311')
# 5 ('CG331', 'OT')
# 6 ('HGA3', 'HGA3')
# 7 ('HGA3', 'HGP1')
# 8 ('HGA3', 'HT')
# 9 ('HGA3', 'OG311')
# 10 ('HGA3', 'OT')
# 11 ('HGP1', 'HGP1')
# 12 ('HGP1', 'HT')
# 13 ('HGP1', 'OG311')
# 14 ('HGP1', 'OT')
# 15 ('HT', 'HT')
# 16 ('HT', 'OG311')
# 17 ('HT', 'OT')
# 18 ('OG311', 'OG311')
# 19 ('OG311', 'OT')
# 20 ('OT', 'OT')

# %%
FUNC = LJ
BOUNDS = LJ_bound
ff_name = "pbe0dz_mdcm"
structures = "water_cluster"
pk = "pickles/water_cluster/pbe0_dz.mdcm"

#########################################################

ff_pkls = Path("pickles/ff")
ff_pickles = ff_pkls.glob("*.pkl")
ff_pickles = [_.name for _ in ff_pickles]
struct_dist_pkls = Path("pickles/structures")
struct_dist_pickles = struct_dist_pkls.glob("*.pkl")
struct_dist_pickles = [_.name for _ in struct_dist_pickles]


pickled_ff = (ff_pkls/f"{ff_name}.pkl").exists()
pickled_dists = (struct_dist_pkls/f"{ff_name}.pkl").exists()


if pickled_ff:
    print("Pickled FF exists!, loading: ", ff_pkls/f"{ff_name}.pkl")
    ff = next(read_from_pickle(ff_pkls / f"{ff_name}.pkl"))
else:
    if pickled_dists:
        print("loading pickled distances/structure")
        structures, dists =  next(read_from_pickle(
            f"structures/{structures}.pkl"))
    else:
        print("No pickled distances/structure information, calculating:")
        CMS = load_config_maker("pbe0dz", "water_cluster", "mdcm")
        jobs = charmm_jobs(CMS)
        dists = {_.name.split(".")[0]: _.distances for _ in jobs[0].structures}
        structures = [_ for _ in jobs[0].structures]
        pickle_output((structures, dists), 
                      name=f"structures/{structures}.pkl")

    s = structures[0]
    data_ = p_data(pk)
    ff = FF(data_.data,dists,FUNC,BOUNDS,s)

# d = ff.data_save.sample(200)
# ff.data = d.copy()
args = [1.7682,0.2245,-0.1521,-0.0460]
# Out:
# ['pbe0_dz_mdcm.pkl']
# Pickled FF exists!, loading:  pickles/ff/pbe0_dz_mdcm.pkl

# %%
# pbe0_dz_mdcm.data

# %%
for i in range(1):
    # d = ff.data_save.sample(100)
    # ff.data = d.copy()
    print(len(ff.data))
    _ = ff.eval_func(args)
    plot_intE(_)
    print(_["SE"].mean())
# Out:
# 100
# 792.1525901515354

# %%
# ff.opt_results_df

# %%
for i in range(10):
    d = ff.data_save.sample(100)
    ff.data = d.copy()
    ff.fit_repeat(10, bounds=LJ_bound)
pickle_output(ff, "ff/pbe0_dz_mdcm")
# Out:
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [1.6998293848387473, 2.7458467619715705, 0.3560158931616747, 0.6733472198998177]
# final_loss_fn:  26.112949758320223
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 26.112949758320223
#              x: [ 2.044e+00  5.000e-01  2.731e-02  8.630e-03]
#            nit: 336
#           nfev: 585
#  final_simplex: (array([[ 2.044e+00,  5.000e-01,  2.731e-02,  8.630e-03],
#                        [ 2.044e+00,  5.000e-01,  2.731e-02,  8.630e-03],
#                        ...,
#                        [ 2.044e+00,  5.000e-01,  2.731e-02,  8.630e-03],
#                        [ 2.044e+00,  5.000e-01,  2.731e-02,  8.630e-03]]), array([ 2.611e+01,  2.611e+01,  2.611e+01,  2.611e+01,
#                         2.611e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [1.7110116827231006, 1.3400687914356668, 0.5553716844223654, 0.27534066603338275]
# final_loss_fn:  26.04829167227398
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 26.04829167227398
#              x: [ 1.982e+00  1.317e+00  3.956e-02  1.000e-05]
#            nit: 2495
#           nfev: 4085
#  final_simplex: (array([[ 1.982e+00,  1.317e+00,  3.956e-02,  1.000e-05],
#                        [ 1.982e+00,  1.317e+00,  3.956e-02,  1.000e-05],
#                        ...,
#                        [ 1.982e+00,  1.317e+00,  3.956e-02,  1.000e-05],
#                        [ 1.982e+00,  1.317e+00,  3.956e-02,  1.000e-05]]), array([ 2.605e+01,  2.605e+01,  2.605e+01,  2.605e+01,
#                         2.605e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [2.922768130534198, 3.7586928512069737, 0.7415578701257789, 0.08673755166142766]
# final_loss_fn:  26.048291672281263
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 26.048291672281263
#              x: [ 1.982e+00  1.317e+00  3.956e-02  1.000e-05]
#            nit: 607
#           nfev: 1023
#  final_simplex: (array([[ 1.982e+00,  1.317e+00,  3.956e-02,  1.000e-05],
#                        [ 1.982e+00,  1.317e+00,  3.956e-02,  1.000e-05],
#                        ...,
#                        [ 1.982e+00,  1.317e+00,  3.956e-02,  1.000e-05],
#                        [ 1.982e+00,  1.317e+00,  3.956e-02,  1.000e-05]]), array([ 2.605e+01,  2.605e+01,  2.605e+01,  2.605e+01,
#                         2.605e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [1.3032831125122222, 2.1901010267175183, 0.40077752917689075, 0.5251089632644504]
# final_loss_fn:  26.527846839467735
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 26.527846839467735
#              x: [ 2.384e+00  5.000e-01  3.181e-03  4.858e-03]
#            nit: 402
#           nfev: 695
#  final_simplex: (array([[ 2.384e+00,  5.000e-01,  3.181e-03,  4.858e-03],
#                        [ 2.384e+00,  5.000e-01,  3.181e-03,  4.857e-03],
#                        ...,
#                        [ 2.384e+00,  5.000e-01,  3.181e-03,  4.857e-03],
#                        [ 2.384e+00,  5.000e-01,  3.181e-03,  4.857e-03]]), array([ 2.653e+01,  2.653e+01,  2.653e+01,  2.653e+01,
#                         2.653e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [0.9568203140573779, 1.084504698387771, 0.8960724507975795, 0.47411333949440276]
# final_loss_fn:  26.048291672273123
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 26.048291672273123
#              x: [ 1.982e+00  1.317e+00  3.956e-02  1.000e-05]
#            nit: 570
#           nfev: 960
#  final_simplex: (array([[ 1.982e+00,  1.317e+00,  3.956e-02,  1.000e-05],
#                        [ 1.982e+00,  1.317e+00,  3.956e-02,  1.000e-05],
#                        ...,
#                        [ 1.982e+00,  1.317e+00,  3.956e-02,  1.000e-05],
#                        [ 1.982e+00,  1.317e+00,  3.956e-02,  1.000e-05]]), array([ 2.605e+01,  2.605e+01,  2.605e+01,  2.605e+01,
#                         2.605e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [2.9854763812422966, 3.4621772923774525, 0.5135642820929909, 0.031468070297403714]
# final_loss_fn:  26.11294975831973
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 26.11294975831973
#              x: [ 2.044e+00  5.000e-01  2.731e-02  8.630e-03]
#            nit: 491
#           nfev: 833
#  final_simplex: (array([[ 2.044e+00,  5.000e-01,  2.731e-02,  8.630e-03],
#                        [ 2.044e+00,  5.000e-01,  2.731e-02,  8.630e-03],
#                        ...,
#                        [ 2.044e+00,  5.000e-01,  2.731e-02,  8.630e-03],
#                        [ 2.044e+00,  5.000e-01,  2.731e-02,  8.630e-03]]), array([ 2.611e+01,  2.611e+01,  2.611e+01,  2.611e+01,
#                         2.611e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [2.7928129137872664, 1.0747492838533188, 0.5478815059618175, 0.31645722761337924]
# final_loss_fn:  72.53956003802789
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 72.53956003802789
#              x: [ 5.000e-01  2.649e+00  1.000e+00  1.000e-05]
#            nit: 321
#           nfev: 550
#  final_simplex: (array([[ 5.000e-01,  2.649e+00,  1.000e+00,  1.000e-05],
#                        [ 5.000e-01,  2.649e+00,  1.000e+00,  1.000e-05],
#                        ...,
#                        [ 5.000e-01,  2.649e+00,  1.000e+00,  1.000e-05],
#                        [ 5.000e-01,  2.649e+00,  1.000e+00,  1.000e-05]]), array([ 7.254e+01,  7.254e+01,  7.254e+01,  7.254e+01,
#                         7.254e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [1.2698524411668313, 1.3703581629220536, 0.9459301958364834, 0.36636997541527044]
# final_loss_fn:  28.64010868985854
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 28.64010868985854
#              x: [ 1.907e+00  5.000e-01  9.465e-02  1.000e-05]
#            nit: 298
#           nfev: 532
#  final_simplex: (array([[ 1.907e+00,  5.000e-01,  9.465e-02,  1.000e-05],
#                        [ 1.907e+00,  5.000e-01,  9.465e-02,  1.000e-05],
#                        ...,
#                        [ 1.907e+00,  5.000e-01,  9.465e-02,  1.000e-05],
#                        [ 1.907e+00,  5.000e-01,  9.465e-02,  1.000e-05]]), array([ 2.864e+01,  2.864e+01,  2.864e+01,  2.864e+01,
#                         2.864e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [0.6246848527700928, 1.6784481001168332, 0.6594547950396523, 0.8896174772947241]
# final_loss_fn:  1967.5434604443785
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 1967.5434604443785
#              x: [ 5.000e-01  5.000e-01  1.000e-05  1.000e-05]
#            nit: 34
#           nfev: 55
#  final_simplex: (array([[ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e-05],
#                        [ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e-05],
#                        ...,
#                        [ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e-05],
#                        [ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e-05]]), array([ 1.968e+03,  1.968e+03,  1.968e+03,  1.968e+03,
#                         1.968e+03]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [2.4983198064930945, 2.7602416253296957, 0.10157511801502782, 0.38994162846497726]
# final_loss_fn:  26.112949057641245
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 26.112949057641245
#              x: [ 2.044e+00  5.000e-01  2.731e-02  8.630e-03]
#            nit: 599
#           nfev: 995
#  final_simplex: (array([[ 2.044e+00,  5.000e-01,  2.731e-02,  8.630e-03],
#                        [ 2.044e+00,  5.000e-01,  2.731e-02,  8.630e-03],
#                        ...,
#                        [ 2.044e+00,  5.000e-01,  2.731e-02,  8.630e-03],
#                        [ 2.044e+00,  5.000e-01,  2.731e-02,  8.630e-03]]), array([ 2.611e+01,  2.611e+01,  2.611e+01,  2.611e+01,
#                         2.611e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Set optimized parameters to FF object, use FF.opt_parm to get the optimized parameters
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [2.853639850053943, 1.9655514626720867, 0.0034342547637196716, 0.49887631271973376]
# final_loss_fn:  25.86421707549943
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 25.86421707549943
#              x: [ 2.230e+00  5.000e-01  8.140e-03  3.825e-03]
#            nit: 886
#           nfev: 1464
#  final_simplex: (array([[ 2.230e+00,  5.000e-01,  8.140e-03,  3.825e-03],
#                        [ 2.230e+00,  5.000e-01,  8.140e-03,  3.825e-03],
#                        ...,
#                        [ 2.230e+00,  5.000e-01,  8.140e-03,  3.825e-03],
#                        [ 2.230e+00,  5.000e-01,  8.140e-03,  3.825e-03]]), array([ 2.586e+01,  2.586e+01,  2.586e+01,  2.586e+01,
#                         2.586e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [2.4440494236003287, 3.973961076297832, 0.056012855185618396, 0.5507654669174095]
# final_loss_fn:  1903.590366337325
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 1903.590366337325
#              x: [ 5.000e-01  5.000e-01  1.000e-05  1.000e-05]
#            nit: 38
#           nfev: 62
#  final_simplex: (array([[ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e-05],
#                        [ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e-05],
#                        ...,
#                        [ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e-05],
#                        [ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e-05]]), array([ 1.904e+03,  1.904e+03,  1.904e+03,  1.904e+03,
#                         1.904e+03]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [2.1007002203701055, 3.3302214692731504, 0.07844704440234429, 0.43271938402948035]
# final_loss_fn:  25.760847573776847
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 25.760847573776847
#              x: [ 2.124e+00  1.270e+00  1.504e-02  1.000e-05]
#            nit: 1847
#           nfev: 3020
#  final_simplex: (array([[ 2.124e+00,  1.270e+00,  1.504e-02,  1.000e-05],
#                        [ 2.124e+00,  1.270e+00,  1.504e-02,  1.000e-05],
#                        ...,
#                        [ 2.124e+00,  1.270e+00,  1.504e-02,  1.000e-05],
#                        [ 2.124e+00,  1.270e+00,  1.504e-02,  1.000e-05]]), array([ 2.576e+01,  2.576e+01,  2.576e+01,  2.576e+01,
#                         2.576e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [2.6172696874854156, 2.274632663042694, 0.9711230025736048, 0.32007837501793474]
# final_loss_fn:  1903.590366337325
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 1903.590366337325
#              x: [ 5.000e-01  5.000e-01  1.000e-05  1.000e-05]
#            nit: 46
#           nfev: 76
#  final_simplex: (array([[ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e-05],
#                        [ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e-05],
#                        ...,
#                        [ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e-05],
#                        [ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e-05]]), array([ 1.904e+03,  1.904e+03,  1.904e+03,  1.904e+03,
#                         1.904e+03]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [2.373211215100327, 0.977160031945944, 0.2131398098628908, 0.2706173362111423]
# final_loss_fn:  25.86421707550002
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 25.86421707550002
#              x: [ 2.230e+00  5.000e-01  8.140e-03  3.825e-03]
#            nit: 1177
#           nfev: 1965
#  final_simplex: (array([[ 2.230e+00,  5.000e-01,  8.140e-03,  3.825e-03],
#                        [ 2.230e+00,  5.000e-01,  8.140e-03,  3.825e-03],
#                        ...,
#                        [ 2.230e+00,  5.000e-01,  8.140e-03,  3.825e-03],
#                        [ 2.230e+00,  5.000e-01,  8.140e-03,  3.825e-03]]), array([ 2.586e+01,  2.586e+01,  2.586e+01,  2.586e+01,
#                         2.586e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [2.0664513053989326, 0.8719328055743389, 0.9436752408546777, 0.4646035748575947]
# final_loss_fn:  123.46933511690163
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 123.46933511690163
#              x: [ 1.699e+00  5.000e-01  1.000e+00  1.000e-05]
#            nit: 299
#           nfev: 503
#  final_simplex: (array([[ 1.699e+00,  5.000e-01,  1.000e+00,  1.000e-05],
#                        [ 1.699e+00,  5.000e-01,  1.000e+00,  1.000e-05],
#                        ...,
#                        [ 1.699e+00,  5.000e-01,  1.000e+00,  1.000e-05],
#                        [ 1.699e+00,  5.000e-01,  1.000e+00,  1.000e-05]]), array([ 1.235e+02,  1.235e+02,  1.235e+02,  1.235e+02,
#                         1.235e+02]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [2.2562838004073518, 3.2311295125101007, 0.9685740042540173, 0.8923187775637262]
# final_loss_fn:  52.18045126119264
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 52.18045126119264
#              x: [ 2.724e+00  5.000e-01  1.000e-05  1.000e+00]
#            nit: 588
#           nfev: 981
#  final_simplex: (array([[ 2.724e+00,  5.000e-01,  1.000e-05,  1.000e+00],
#                        [ 2.724e+00,  5.000e-01,  1.000e-05,  1.000e+00],
#                        ...,
#                        [ 2.724e+00,  5.000e-01,  1.000e-05,  1.000e+00],
#                        [ 2.724e+00,  5.000e-01,  1.000e-05,  1.000e+00]]), array([ 5.218e+01,  5.218e+01,  5.218e+01,  5.218e+01,
#                         5.218e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [3.6268651090403106, 3.6684511527773744, 0.6832591870199807, 0.40629807818325425]
# final_loss_fn:  123.46933507425182
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 123.46933507425182
#              x: [ 1.699e+00  5.000e-01  1.000e+00  1.000e-05]
#            nit: 149
#           nfev: 260
#  final_simplex: (array([[ 1.699e+00,  5.000e-01,  1.000e+00,  1.000e-05],
#                        [ 1.699e+00,  5.000e-01,  1.000e+00,  1.000e-05],
#                        ...,
#                        [ 1.699e+00,  5.000e-01,  1.000e+00,  1.000e-05],
#                        [ 1.699e+00,  5.000e-01,  1.000e+00,  1.000e-05]]), array([ 1.235e+02,  1.235e+02,  1.235e+02,  1.235e+02,
#                         1.235e+02]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [0.862388439177177, 2.177861774191451, 0.40411957583817315, 0.3463083234637166]
# final_loss_fn:  1903.590366337325
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 1903.590366337325
#              x: [ 5.000e-01  5.000e-01  1.000e-05  1.000e-05]
#            nit: 57
#           nfev: 92
#  final_simplex: (array([[ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e-05],
#                        [ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e-05],
#                        ...,
#                        [ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e-05],
#                        [ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e-05]]), array([ 1.904e+03,  1.904e+03,  1.904e+03,  1.904e+03,
#                         1.904e+03]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [0.8177034450958541, 1.493935978778501, 0.860931597198031, 0.15784027244338272]
# final_loss_fn:  53.14394201856025
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 53.14394201856025
#              x: [ 7.199e-01  2.478e+00  1.000e+00  1.000e-05]
#            nit: 622
#           nfev: 1040
#  final_simplex: (array([[ 7.199e-01,  2.478e+00,  1.000e+00,  1.000e-05],
#                        [ 7.199e-01,  2.478e+00,  1.000e+00,  1.000e-05],
#                        ...,
#                        [ 7.199e-01,  2.478e+00,  1.000e+00,  1.000e-05],
#                        [ 7.199e-01,  2.478e+00,  1.000e+00,  1.000e-05]]), array([ 5.314e+01,  5.314e+01,  5.314e+01,  5.314e+01,
#                         5.314e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Set optimized parameters to FF object, use FF.opt_parm to get the optimized parameters
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [0.8076216956737713, 3.461204884652796, 0.7077963843143178, 0.11770485349644236]
# final_loss_fn:  31.888092508981583
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 31.888092508981583
#              x: [ 3.797e+00  5.000e-01  1.000e-05  9.478e-05]
#            nit: 250
#           nfev: 440
#  final_simplex: (array([[ 3.797e+00,  5.000e-01,  1.000e-05,  9.478e-05],
#                        [ 3.797e+00,  5.000e-01,  1.000e-05,  9.478e-05],
#                        ...,
#                        [ 3.797e+00,  5.000e-01,  1.000e-05,  9.478e-05],
#                        [ 3.797e+00,  5.000e-01,  1.000e-05,  9.478e-05]]), array([ 3.189e+01,  3.189e+01,  3.189e+01,  3.189e+01,
#                         3.189e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [2.5472556679677725, 0.7870907948687407, 0.8299450739507427, 0.3947435720774985]
# final_loss_fn:  31.69607499610522
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 31.69607499610522
#              x: [ 1.932e+00  5.000e-01  7.596e-02  1.000e-05]
#            nit: 406
#           nfev: 699
#  final_simplex: (array([[ 1.932e+00,  5.000e-01,  7.596e-02,  1.000e-05],
#                        [ 1.932e+00,  5.000e-01,  7.596e-02,  1.000e-05],
#                        ...,
#                        [ 1.932e+00,  5.000e-01,  7.596e-02,  1.000e-05],
#                        [ 1.932e+00,  5.000e-01,  7.596e-02,  1.000e-05]]), array([ 3.170e+01,  3.170e+01,  3.170e+01,  3.170e+01,
#                         3.170e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [0.658964985792176, 3.0705558990950776, 0.29895986778777944, 0.45227735298535876]
# final_loss_fn:  2031.6592235296753
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 2031.6592235296753
#              x: [ 5.000e-01  5.000e-01  1.000e-05  1.000e-05]
#            nit: 52
#           nfev: 79
#  final_simplex: (array([[ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e-05],
#                        [ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e-05],
#                        ...,
#                        [ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e-05],
#                        [ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e-05]]), array([ 2.032e+03,  2.032e+03,  2.032e+03,  2.032e+03,
#                         2.032e+03]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [1.2449809257792825, 2.07897919656137, 0.5464557192945018, 0.8548703347548042]
# final_loss_fn:  30.930941070715004
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 30.930941070715004
#              x: [ 1.996e+00  1.207e+00  3.862e-02  1.000e-05]
#            nit: 467
#           nfev: 800
#  final_simplex: (array([[ 1.996e+00,  1.207e+00,  3.862e-02,  1.000e-05],
#                        [ 1.996e+00,  1.207e+00,  3.862e-02,  1.000e-05],
#                        ...,
#                        [ 1.996e+00,  1.207e+00,  3.862e-02,  1.000e-05],
#                        [ 1.996e+00,  1.207e+00,  3.862e-02,  1.000e-05]]), array([ 3.093e+01,  3.093e+01,  3.093e+01,  3.093e+01,
#                         3.093e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [3.326882943123145, 2.6155145599588248, 0.7505742854982859, 0.7323840481478787]
# final_loss_fn:  2192.650130574988
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 2192.650130574988
#              x: [ 5.000e-01  5.000e-01  1.000e+00  1.000e+00]
#            nit: 21
#           nfev: 34
#  final_simplex: (array([[ 5.000e-01,  5.000e-01,  1.000e+00,  1.000e+00],
#                        [ 5.000e-01,  5.000e-01,  1.000e+00,  1.000e+00],
#                        ...,
#                        [ 5.000e-01,  5.000e-01,  1.000e+00,  1.000e+00],
#                        [ 5.000e-01,  5.000e-01,  1.000e+00,  1.000e+00]]), array([ 2.193e+03,  2.193e+03,  2.193e+03,  2.193e+03,
#                         2.193e+03]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [2.9556615507363904, 2.867697334281122, 0.8000276471582809, 0.8061370742852152]
# final_loss_fn:  747.4760051143926
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 747.4760051143926
#              x: [ 1.664e+00  5.000e-01  1.000e+00  1.000e+00]
#            nit: 79
#           nfev: 154
#  final_simplex: (array([[ 1.664e+00,  5.000e-01,  1.000e+00,  1.000e+00],
#                        [ 1.664e+00,  5.000e-01,  1.000e+00,  1.000e+00],
#                        ...,
#                        [ 1.664e+00,  5.000e-01,  1.000e+00,  1.000e+00],
#                        [ 1.664e+00,  5.000e-01,  1.000e+00,  1.000e+00]]), array([ 7.475e+02,  7.475e+02,  7.475e+02,  7.475e+02,
#                         7.475e+02]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [0.8121840126899034, 3.9437107910491473, 0.5587804008966846, 0.07085645120305141]
# final_loss_fn:  31.514844837346637
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 31.514844837346637
#              x: [ 2.544e+00  5.037e-01  1.398e-03  2.312e-03]
#            nit: 590
#           nfev: 997
#  final_simplex: (array([[ 2.544e+00,  5.037e-01,  1.398e-03,  2.312e-03],
#                        [ 2.544e+00,  5.037e-01,  1.398e-03,  2.313e-03],
#                        ...,
#                        [ 2.544e+00,  5.037e-01,  1.398e-03,  2.312e-03],
#                        [ 2.544e+00,  5.037e-01,  1.398e-03,  2.312e-03]]), array([ 3.151e+01,  3.151e+01,  3.151e+01,  3.151e+01,
#                         3.151e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [3.0848850735987656, 3.9902303890337247, 0.8685452794858387, 0.09348109875038249]
# final_loss_fn:  547.2313635122995
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 547.2313635122995
#              x: [ 5.000e-01  2.872e+00  1.000e-05  1.000e-05]
#            nit: 128
#           nfev: 220
#  final_simplex: (array([[ 5.000e-01,  2.872e+00,  1.000e-05,  1.000e-05],
#                        [ 5.000e-01,  2.872e+00,  1.000e-05,  1.000e-05],
#                        ...,
#                        [ 5.000e-01,  2.872e+00,  1.000e-05,  1.000e-05],
#                        [ 5.000e-01,  2.872e+00,  1.000e-05,  1.000e-05]]), array([ 5.472e+02,  5.472e+02,  5.472e+02,  5.472e+02,
#                         5.472e+02]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [1.2968710497481128, 0.9956108319065375, 0.768176818378247, 0.48928515321496185]
# final_loss_fn:  30.930941070657074
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 30.930941070657074
#              x: [ 1.996e+00  1.207e+00  3.862e-02  1.000e-05]
#            nit: 2101
#           nfev: 3488
#  final_simplex: (array([[ 1.996e+00,  1.207e+00,  3.862e-02,  1.000e-05],
#                        [ 1.996e+00,  1.207e+00,  3.862e-02,  1.000e-05],
#                        ...,
#                        [ 1.996e+00,  1.207e+00,  3.862e-02,  1.000e-05],
#                        [ 1.996e+00,  1.207e+00,  3.862e-02,  1.000e-05]]), array([ 3.093e+01,  3.093e+01,  3.093e+01,  3.093e+01,
#                         3.093e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [1.88047486875021, 3.174271555388583, 0.9507563358431577, 0.8970348848727863]
# final_loss_fn:  53.38823736365678
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 53.38823736365678
#              x: [ 2.717e+00  5.000e-01  1.000e-05  1.000e+00]
#            nit: 551
#           nfev: 933
#  final_simplex: (array([[ 2.717e+00,  5.000e-01,  1.000e-05,  1.000e+00],
#                        [ 2.717e+00,  5.000e-01,  1.000e-05,  1.000e+00],
#                        ...,
#                        [ 2.717e+00,  5.000e-01,  1.000e-05,  1.000e+00],
#                        [ 2.717e+00,  5.000e-01,  1.000e-05,  1.000e+00]]), array([ 5.339e+01,  5.339e+01,  5.339e+01,  5.339e+01,
#                         5.339e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Set optimized parameters to FF object, use FF.opt_parm to get the optimized parameters
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [2.1540374571264578, 3.7198887796437123, 0.14220932184658774, 0.6312135903794325]
# final_loss_fn:  26.924527491122923
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 26.924527491122923
#              x: [ 2.192e+00  5.321e-01  1.014e-02  3.107e-03]
#            nit: 843
#           nfev: 1400
#  final_simplex: (array([[ 2.192e+00,  5.321e-01,  1.014e-02,  3.107e-03],
#                        [ 2.192e+00,  5.321e-01,  1.014e-02,  3.107e-03],
#                        ...,
#                        [ 2.192e+00,  5.321e-01,  1.014e-02,  3.107e-03],
#                        [ 2.192e+00,  5.321e-01,  1.014e-02,  3.107e-03]]), array([ 2.692e+01,  2.692e+01,  2.692e+01,  2.692e+01,
#                         2.692e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [2.533028108646598, 2.112599463403451, 0.7768086301364612, 0.7689541117875817]
# final_loss_fn:  2092.270069201386
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 2092.270069201386
#              x: [ 5.000e-01  5.000e-01  1.000e+00  1.000e+00]
#            nit: 18
#           nfev: 31
#  final_simplex: (array([[ 5.000e-01,  5.000e-01,  1.000e+00,  1.000e+00],
#                        [ 5.000e-01,  5.000e-01,  1.000e+00,  1.000e+00],
#                        ...,
#                        [ 5.000e-01,  5.000e-01,  1.000e+00,  1.000e+00],
#                        [ 5.000e-01,  5.000e-01,  1.000e+00,  1.000e+00]]), array([ 2.092e+03,  2.092e+03,  2.092e+03,  2.092e+03,
#                         2.092e+03]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [3.2773742999510764, 2.0582318146729253, 0.9325902290640079, 0.9874132885861583]
# final_loss_fn:  116.16825916301684
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 116.16825916301684
#              x: [ 1.699e+00  5.000e-01  1.000e+00  1.000e-05]
#            nit: 211
#           nfev: 363
#  final_simplex: (array([[ 1.699e+00,  5.000e-01,  1.000e+00,  1.000e-05],
#                        [ 1.699e+00,  5.000e-01,  1.000e+00,  1.000e-05],
#                        ...,
#                        [ 1.699e+00,  5.000e-01,  1.000e+00,  1.000e-05],
#                        [ 1.699e+00,  5.000e-01,  1.000e+00,  1.000e-05]]), array([ 1.162e+02,  1.162e+02,  1.162e+02,  1.162e+02,
#                         1.162e+02]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [1.0382926434273403, 2.862930556312801, 0.3168263733541287, 0.6876329835407226]
# final_loss_fn:  56.92095408498768
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 56.92095408498768
#              x: [ 2.719e+00  5.000e-01  1.000e-05  1.000e+00]
#            nit: 635
#           nfev: 1070
#  final_simplex: (array([[ 2.719e+00,  5.000e-01,  1.000e-05,  1.000e+00],
#                        [ 2.719e+00,  5.000e-01,  1.000e-05,  1.000e+00],
#                        ...,
#                        [ 2.719e+00,  5.000e-01,  1.000e-05,  1.000e+00],
#                        [ 2.719e+00,  5.000e-01,  1.000e-05,  1.000e+00]]), array([ 5.692e+01,  5.692e+01,  5.692e+01,  5.692e+01,
#                         5.692e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [2.1960698391348537, 1.7742345063632021, 0.6877479276744423, 0.8072805235803854]
# final_loss_fn:  2092.270069201386
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 2092.270069201386
#              x: [ 5.000e-01  5.000e-01  1.000e+00  1.000e+00]
#            nit: 21
#           nfev: 36
#  final_simplex: (array([[ 5.000e-01,  5.000e-01,  1.000e+00,  1.000e+00],
#                        [ 5.000e-01,  5.000e-01,  1.000e+00,  1.000e+00],
#                        ...,
#                        [ 5.000e-01,  5.000e-01,  1.000e+00,  1.000e+00],
#                        [ 5.000e-01,  5.000e-01,  1.000e+00,  1.000e+00]]), array([ 2.092e+03,  2.092e+03,  2.092e+03,  2.092e+03,
#                         2.092e+03]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [2.465584131803717, 2.7216673345210562, 0.28954735365542755, 0.07380649405727224]
# final_loss_fn:  26.934162998425514
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 26.934162998425514
#              x: [ 2.193e+00  5.000e-01  1.018e-02  4.093e-03]
#            nit: 808
#           nfev: 1349
#  final_simplex: (array([[ 2.193e+00,  5.000e-01,  1.018e-02,  4.093e-03],
#                        [ 2.193e+00,  5.000e-01,  1.018e-02,  4.093e-03],
#                        ...,
#                        [ 2.193e+00,  5.000e-01,  1.018e-02,  4.093e-03],
#                        [ 2.193e+00,  5.000e-01,  1.018e-02,  4.093e-03]]), array([ 2.693e+01,  2.693e+01,  2.693e+01,  2.693e+01,
#                         2.693e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [0.5359376889209404, 3.7609113889061097, 0.031283929690468906, 0.8045235856528475]
# final_loss_fn:  1935.2624395252058
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 1935.2624395252058
#              x: [ 5.000e-01  5.000e-01  1.000e-05  1.000e-05]
#            nit: 33
#           nfev: 53
#  final_simplex: (array([[ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e-05],
#                        [ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e-05],
#                        ...,
#                        [ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e-05],
#                        [ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e-05]]), array([ 1.935e+03,  1.935e+03,  1.935e+03,  1.935e+03,
#                         1.935e+03]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [1.35217552988609, 3.7304117558089214, 0.1268556702107373, 0.3864532456030111]
# final_loss_fn:  26.80809030793765
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 26.80809030793765
#              x: [ 2.098e+00  1.266e+00  1.767e-02  1.000e-05]
#            nit: 1468
#           nfev: 2433
#  final_simplex: (array([[ 2.098e+00,  1.266e+00,  1.767e-02,  1.000e-05],
#                        [ 2.098e+00,  1.266e+00,  1.767e-02,  1.000e-05],
#                        ...,
#                        [ 2.098e+00,  1.266e+00,  1.767e-02,  1.000e-05],
#                        [ 2.098e+00,  1.266e+00,  1.767e-02,  1.000e-05]]), array([ 2.681e+01,  2.681e+01,  2.681e+01,  2.681e+01,
#                         2.681e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [2.3995322683685116, 3.3820460598747966, 0.5992411378405302, 0.2370957706229393]
# final_loss_fn:  26.999812073787716
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 26.999812073787716
#              x: [ 2.547e+00  5.000e-01  1.391e-03  1.968e-03]
#            nit: 486
#           nfev: 817
#  final_simplex: (array([[ 2.547e+00,  5.000e-01,  1.391e-03,  1.968e-03],
#                        [ 2.547e+00,  5.000e-01,  1.391e-03,  1.969e-03],
#                        ...,
#                        [ 2.547e+00,  5.000e-01,  1.391e-03,  1.968e-03],
#                        [ 2.547e+00,  5.000e-01,  1.391e-03,  1.969e-03]]), array([ 2.700e+01,  2.700e+01,  2.700e+01,  2.700e+01,
#                         2.700e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [2.3619984763062463, 1.352433792877354, 0.08430281118235282, 0.9226229770708694]
# final_loss_fn:  26.820622365146534
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 26.820622365146534
#              x: [ 2.100e+00  1.110e+00  1.757e-02  3.087e-05]
#            nit: 711
#           nfev: 1188
#  final_simplex: (array([[ 2.100e+00,  1.110e+00,  1.757e-02,  3.087e-05],
#                        [ 2.100e+00,  1.110e+00,  1.757e-02,  3.087e-05],
#                        ...,
#                        [ 2.100e+00,  1.110e+00,  1.757e-02,  3.087e-05],
#                        [ 2.100e+00,  1.110e+00,  1.757e-02,  3.087e-05]]), array([ 2.682e+01,  2.682e+01,  2.682e+01,  2.682e+01,
#                         2.682e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Set optimized parameters to FF object, use FF.opt_parm to get the optimized parameters
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [3.9833376740819686, 2.9710834683786813, 0.9502922710094549, 0.8778154069763722]
# final_loss_fn:  64.1847145297008
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 64.1847145297008
#              x: [ 2.758e+00  5.000e-01  1.000e-05  7.861e-01]
#            nit: 585
#           nfev: 972
#  final_simplex: (array([[ 2.758e+00,  5.000e-01,  1.000e-05,  7.861e-01],
#                        [ 2.758e+00,  5.000e-01,  1.000e-05,  7.861e-01],
#                        ...,
#                        [ 2.758e+00,  5.000e-01,  1.000e-05,  7.861e-01],
#                        [ 2.758e+00,  5.000e-01,  1.000e-05,  7.861e-01]]), array([ 6.418e+01,  6.418e+01,  6.418e+01,  6.418e+01,
#                         6.418e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [2.424443223810364, 3.088309004584653, 0.03678816256908817, 0.3977202117725397]
# final_loss_fn:  21.0514972837184
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 21.0514972837184
#              x: [ 2.090e+00  5.000e-01  2.274e-02  1.117e-03]
#            nit: 328
#           nfev: 561
#  final_simplex: (array([[ 2.090e+00,  5.000e-01,  2.274e-02,  1.117e-03],
#                        [ 2.090e+00,  5.000e-01,  2.274e-02,  1.117e-03],
#                        ...,
#                        [ 2.090e+00,  5.000e-01,  2.274e-02,  1.117e-03],
#                        [ 2.090e+00,  5.000e-01,  2.274e-02,  1.117e-03]]), array([ 2.105e+01,  2.105e+01,  2.105e+01,  2.105e+01,
#                         2.105e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [1.5156239700528369, 0.6506553651304905, 0.5409174519446789, 0.13444041095619846]
# final_loss_fn:  21.040142340379838
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 21.040142340379838
#              x: [ 2.069e+00  1.056e+00  2.562e-02  1.000e-05]
#            nit: 630
#           nfev: 1075
#  final_simplex: (array([[ 2.069e+00,  1.056e+00,  2.562e-02,  1.000e-05],
#                        [ 2.069e+00,  1.056e+00,  2.562e-02,  1.000e-05],
#                        ...,
#                        [ 2.069e+00,  1.056e+00,  2.562e-02,  1.000e-05],
#                        [ 2.069e+00,  1.056e+00,  2.562e-02,  1.000e-05]]), array([ 2.104e+01,  2.104e+01,  2.104e+01,  2.104e+01,
#                         2.104e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [1.3827544678388792, 2.196498279173162, 0.9655651883361456, 0.32348204456495705]
# final_loss_fn:  21.051497283722327
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 21.051497283722327
#              x: [ 2.090e+00  5.000e-01  2.274e-02  1.117e-03]
#            nit: 494
#           nfev: 843
#  final_simplex: (array([[ 2.090e+00,  5.000e-01,  2.274e-02,  1.117e-03],
#                        [ 2.090e+00,  5.000e-01,  2.274e-02,  1.117e-03],
#                        ...,
#                        [ 2.090e+00,  5.000e-01,  2.274e-02,  1.117e-03],
#                        [ 2.090e+00,  5.000e-01,  2.274e-02,  1.117e-03]]), array([ 2.105e+01,  2.105e+01,  2.105e+01,  2.105e+01,
#                         2.105e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [1.2901889552524413, 0.9808203939414333, 0.23986131217928058, 0.8177019199681015]
# final_loss_fn:  21.81765033044623
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 21.81765033044623
#              x: [ 3.594e+00  5.020e-01  2.377e-05  4.529e-05]
#            nit: 920
#           nfev: 1554
#  final_simplex: (array([[ 3.594e+00,  5.020e-01,  2.377e-05,  4.529e-05],
#                        [ 3.594e+00,  5.020e-01,  2.377e-05,  4.529e-05],
#                        ...,
#                        [ 3.594e+00,  5.020e-01,  2.377e-05,  4.529e-05],
#                        [ 3.594e+00,  5.020e-01,  2.377e-05,  4.529e-05]]), array([ 2.182e+01,  2.182e+01,  2.182e+01,  2.182e+01,
#                         2.182e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [1.903315402116635, 0.8199716543328313, 0.8069987508506827, 0.290760945102485]
# final_loss_fn:  63.592880188389785
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 63.592880188389785
#              x: [ 2.779e+00  5.000e-01  1.000e-05  6.661e-01]
#            nit: 656
#           nfev: 1094
#  final_simplex: (array([[ 2.779e+00,  5.000e-01,  1.000e-05,  6.661e-01],
#                        [ 2.779e+00,  5.000e-01,  1.000e-05,  6.661e-01],
#                        ...,
#                        [ 2.779e+00,  5.000e-01,  1.000e-05,  6.661e-01],
#                        [ 2.779e+00,  5.000e-01,  1.000e-05,  6.661e-01]]), array([ 6.359e+01,  6.359e+01,  6.359e+01,  6.359e+01,
#                         6.359e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [1.1014379211412915, 3.8510978503918603, 0.18829518537823892, 0.19751142659097046]
# final_loss_fn:  21.051295843428438
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 21.051295843428438
#              x: [ 2.090e+00  5.049e-01  2.277e-02  1.068e-03]
#            nit: 498
#           nfev: 852
#  final_simplex: (array([[ 2.090e+00,  5.049e-01,  2.277e-02,  1.068e-03],
#                        [ 2.090e+00,  5.049e-01,  2.277e-02,  1.068e-03],
#                        ...,
#                        [ 2.090e+00,  5.049e-01,  2.277e-02,  1.068e-03],
#                        [ 2.090e+00,  5.049e-01,  2.277e-02,  1.068e-03]]), array([ 2.105e+01,  2.105e+01,  2.105e+01,  2.105e+01,
#                         2.105e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [1.989144723659035, 1.233059715636946, 0.8458013114036244, 0.19478169239393908]
# final_loss_fn:  65.58747665758251
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 65.58747665758251
#              x: [ 6.846e-01  2.512e+00  1.000e+00  1.000e-05]
#            nit: 599
#           nfev: 1004
#  final_simplex: (array([[ 6.846e-01,  2.512e+00,  1.000e+00,  1.000e-05],
#                        [ 6.846e-01,  2.512e+00,  1.000e+00,  1.000e-05],
#                        ...,
#                        [ 6.846e-01,  2.511e+00,  1.000e+00,  1.000e-05],
#                        [ 6.846e-01,  2.512e+00,  1.000e+00,  1.000e-05]]), array([ 6.559e+01,  6.559e+01,  6.559e+01,  6.559e+01,
#                         6.559e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [2.571274460181579, 1.1096096030580798, 0.051437316922587996, 0.6805948535299677]
# final_loss_fn:  21.04014234037743
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 21.04014234037743
#              x: [ 2.069e+00  1.056e+00  2.562e-02  1.000e-05]
#            nit: 737
#           nfev: 1234
#  final_simplex: (array([[ 2.069e+00,  1.056e+00,  2.562e-02,  1.000e-05],
#                        [ 2.069e+00,  1.056e+00,  2.562e-02,  1.000e-05],
#                        ...,
#                        [ 2.069e+00,  1.056e+00,  2.562e-02,  1.000e-05],
#                        [ 2.069e+00,  1.056e+00,  2.562e-02,  1.000e-05]]), array([ 2.104e+01,  2.104e+01,  2.104e+01,  2.104e+01,
#                         2.104e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [2.7419335500054425, 2.9710164724587673, 0.7205598849349416, 0.2461026016360617]
# final_loss_fn:  2081.8682898063157
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 2081.8682898063157
#              x: [ 5.000e-01  5.000e-01  1.000e+00  1.000e-05]
#            nit: 31
#           nfev: 50
# ...
#                         3.007e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [1.5577662343156846, 0.8016318332354493, 0.24113086994852395, 0.5923655140311831]
# final_loss_fn:  29.171436675219933
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 29.171436675219933
#              x: [ 1.959e+00  5.000e-01  6.171e-02  1.000e-05]
#            nit: 299
#           nfev: 510
#  final_simplex: (array([[ 1.959e+00,  5.000e-01,  6.171e-02,  1.000e-05],
#                        [ 1.959e+00,  5.000e-01,  6.171e-02,  1.000e-05],
#                        ...,
#                        [ 1.959e+00,  5.000e-01,  6.171e-02,  1.000e-05],
#                        [ 1.959e+00,  5.000e-01,  6.171e-02,  1.000e-05]]), array([ 2.917e+01,  2.917e+01,  2.917e+01,  2.917e+01,
#                         2.917e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [3.2884052064960656, 2.430832464020279, 0.9061144453317719, 0.3430618053661763]
# final_loss_fn:  2164.0760147972205
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 2164.0760147972205
#              x: [ 5.000e-01  5.000e-01  1.000e+00  1.000e-05]
#            nit: 29
#           nfev: 49
#  final_simplex: (array([[ 5.000e-01,  5.000e-01,  1.000e+00,  1.000e-05],
#                        [ 5.000e-01,  5.000e-01,  1.000e+00,  1.000e-05],
#                        ...,
#                        [ 5.000e-01,  5.000e-01,  1.000e+00,  1.000e-05],
#                        [ 5.000e-01,  5.000e-01,  1.000e+00,  1.000e-05]]), array([ 2.164e+03,  2.164e+03,  2.164e+03,  2.164e+03,
#                         2.164e+03]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [2.863536887271442, 3.0638818966143346, 0.807285380213757, 0.09656434331716407]
# final_loss_fn:  2164.0760147972205
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 2164.0760147972205
#              x: [ 5.000e-01  5.000e-01  1.000e+00  1.000e-05]
#            nit: 27
#           nfev: 47
#  final_simplex: (array([[ 5.000e-01,  5.000e-01,  1.000e+00,  1.000e-05],
#                        [ 5.000e-01,  5.000e-01,  1.000e+00,  1.000e-05],
#                        ...,
#                        [ 5.000e-01,  5.000e-01,  1.000e+00,  1.000e-05],
#                        [ 5.000e-01,  5.000e-01,  1.000e+00,  1.000e-05]]), array([ 2.164e+03,  2.164e+03,  2.164e+03,  2.164e+03,
#                         2.164e+03]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [2.303703841259645, 3.8655829848222165, 0.8820690614708593, 0.7547688684778611]
# final_loss_fn:  2217.270624424114
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 2217.270624424114
#              x: [ 5.000e-01  5.000e-01  1.000e-05  1.000e+00]
#            nit: 45
#           nfev: 73
#  final_simplex: (array([[ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e+00],
#                        [ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e+00],
#                        ...,
#                        [ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e+00],
#                        [ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e+00]]), array([ 2.217e+03,  2.217e+03,  2.217e+03,  2.217e+03,
#                         2.217e+03]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [3.0150947162237305, 0.5070081121205843, 0.6092785470449278, 0.517671598344785]
# final_loss_fn:  29.17143667521205
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 29.17143667521205
#              x: [ 1.959e+00  5.000e-01  6.171e-02  1.000e-05]
#            nit: 322
#           nfev: 546
#  final_simplex: (array([[ 1.959e+00,  5.000e-01,  6.171e-02,  1.000e-05],
#                        [ 1.959e+00,  5.000e-01,  6.171e-02,  1.000e-05],
#                        ...,
#                        [ 1.959e+00,  5.000e-01,  6.171e-02,  1.000e-05],
#                        [ 1.959e+00,  5.000e-01,  6.171e-02,  1.000e-05]]), array([ 2.917e+01,  2.917e+01,  2.917e+01,  2.917e+01,
#                         2.917e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [1.0683230855789105, 1.5387884417996105, 0.18857783960065333, 0.8905033439419192]
# final_loss_fn:  68.83540702285195
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 68.83540702285195
#              x: [ 2.716e+00  5.000e-01  1.000e-05  1.000e+00]
#            nit: 489
#           nfev: 819
#  final_simplex: (array([[ 2.716e+00,  5.000e-01,  1.000e-05,  1.000e+00],
#                        [ 2.716e+00,  5.000e-01,  1.000e-05,  1.000e+00],
#                        ...,
#                        [ 2.716e+00,  5.000e-01,  1.000e-05,  1.000e+00],
#                        [ 2.716e+00,  5.000e-01,  1.000e-05,  1.000e+00]]), array([ 6.884e+01,  6.884e+01,  6.884e+01,  6.884e+01,
#                         6.884e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Set optimized parameters to FF object, use FF.opt_parm to get the optimized parameters
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [1.312916142278235, 1.775119402453185, 0.19764792549061766, 0.11004746082586347]
# final_loss_fn:  52.74031979729381
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 52.74031979729381
#              x: [ 2.959e+00  5.008e-01  1.000e-05  1.449e-01]
#            nit: 956
#           nfev: 1572
#  final_simplex: (array([[ 2.959e+00,  5.008e-01,  1.000e-05,  1.449e-01],
#                        [ 2.959e+00,  5.008e-01,  1.000e-05,  1.449e-01],
#                        ...,
#                        [ 2.959e+00,  5.008e-01,  1.000e-05,  1.449e-01],
#                        [ 2.959e+00,  5.008e-01,  1.000e-05,  1.449e-01]]), array([ 5.274e+01,  5.274e+01,  5.274e+01,  5.274e+01,
#                         5.274e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [3.8601834175394556, 3.7811710189926195, 0.14192850810784038, 0.17001249194622212]
# final_loss_fn:  28.68630570792456
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 28.68630570792456
#              x: [ 3.105e+00  5.000e-01  1.189e-04  3.758e-04]
#            nit: 760
#           nfev: 1269
#  final_simplex: (array([[ 3.105e+00,  5.000e-01,  1.189e-04,  3.758e-04],
#                        [ 3.105e+00,  5.000e-01,  1.189e-04,  3.761e-04],
#                        ...,
#                        [ 3.105e+00,  5.000e-01,  1.189e-04,  3.756e-04],
#                        [ 3.105e+00,  5.000e-01,  1.189e-04,  3.756e-04]]), array([ 2.869e+01,  2.869e+01,  2.869e+01,  2.869e+01,
#                         2.869e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [1.0250653504274936, 1.2716250905300501, 0.06353777534256465, 0.4141460642478971]
# final_loss_fn:  27.469865757570812
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 27.469865757570812
#              x: [ 1.976e+00  1.114e+00  4.589e-02  1.000e-05]
#            nit: 451
#           nfev: 772
#  final_simplex: (array([[ 1.976e+00,  1.114e+00,  4.589e-02,  1.000e-05],
#                        [ 1.976e+00,  1.114e+00,  4.589e-02,  1.000e-05],
#                        ...,
#                        [ 1.976e+00,  1.114e+00,  4.589e-02,  1.000e-05],
#                        [ 1.976e+00,  1.114e+00,  4.589e-02,  1.000e-05]]), array([ 2.747e+01,  2.747e+01,  2.747e+01,  2.747e+01,
#                         2.747e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [3.4868189910914946, 2.831512255146741, 0.668594472803167, 0.5141031744839926]
# final_loss_fn:  2095.1502064052092
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 2095.1502064052092
#              x: [ 5.000e-01  5.000e-01  1.000e+00  1.000e+00]
#            nit: 21
#           nfev: 34
#  final_simplex: (array([[ 5.000e-01,  5.000e-01,  1.000e+00,  1.000e+00],
#                        [ 5.000e-01,  5.000e-01,  1.000e+00,  1.000e+00],
#                        ...,
#                        [ 5.000e-01,  5.000e-01,  1.000e+00,  1.000e+00],
#                        [ 5.000e-01,  5.000e-01,  1.000e+00,  1.000e+00]]), array([ 2.095e+03,  2.095e+03,  2.095e+03,  2.095e+03,
#                         2.095e+03]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [2.5745166739591006, 0.5161765815574161, 0.34516412983088846, 0.154453210204005]
# final_loss_fn:  27.469865757555297
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 27.469865757555297
#              x: [ 1.976e+00  1.114e+00  4.589e-02  1.000e-05]
#            nit: 503
#           nfev: 857
#  final_simplex: (array([[ 1.976e+00,  1.114e+00,  4.589e-02,  1.000e-05],
#                        [ 1.976e+00,  1.114e+00,  4.589e-02,  1.000e-05],
#                        ...,
#                        [ 1.976e+00,  1.114e+00,  4.589e-02,  1.000e-05],
#                        [ 1.976e+00,  1.114e+00,  4.589e-02,  1.000e-05]]), array([ 2.747e+01,  2.747e+01,  2.747e+01,  2.747e+01,
#                         2.747e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [3.4796569241085007, 2.9291420368341177, 0.6818013086379304, 0.11630764369866955]
# final_loss_fn:  1946.1542323265703
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 1946.1542323265703
#              x: [ 5.000e-01  5.000e-01  1.000e+00  1.000e-05]
#            nit: 30
#           nfev: 47
#  final_simplex: (array([[ 5.000e-01,  5.000e-01,  1.000e+00,  1.000e-05],
#                        [ 5.000e-01,  5.000e-01,  1.000e+00,  1.000e-05],
#                        ...,
#                        [ 5.000e-01,  5.000e-01,  1.000e+00,  1.000e-05],
#                        [ 5.000e-01,  5.000e-01,  1.000e+00,  1.000e-05]]), array([ 1.946e+03,  1.946e+03,  1.946e+03,  1.946e+03,
#                         1.946e+03]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [3.76731322975267, 3.9003653153307742, 0.6109654581026438, 0.3780450042553178]
# final_loss_fn:  1946.1542323265703
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 1946.1542323265703
#              x: [ 5.000e-01  5.000e-01  1.000e+00  1.000e-05]
#            nit: 36
#           nfev: 60
#  final_simplex: (array([[ 5.000e-01,  5.000e-01,  1.000e+00,  1.000e-05],
#                        [ 5.000e-01,  5.000e-01,  1.000e+00,  1.000e-05],
#                        ...,
#                        [ 5.000e-01,  5.000e-01,  1.000e+00,  1.000e-05],
#                        [ 5.000e-01,  5.000e-01,  1.000e+00,  1.000e-05]]), array([ 1.946e+03,  1.946e+03,  1.946e+03,  1.946e+03,
#                         1.946e+03]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [2.1113384332110545, 2.7382773531409192, 0.9408676427241507, 0.5632122720709869]
# final_loss_fn:  57.54225778309176
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 57.54225778309176
#              x: [ 2.709e+00  5.000e-01  1.000e-05  1.000e+00]
#            nit: 605
#           nfev: 989
#  final_simplex: (array([[ 2.709e+00,  5.000e-01,  1.000e-05,  1.000e+00],
#                        [ 2.709e+00,  5.000e-01,  1.000e-05,  1.000e+00],
#                        ...,
#                        [ 2.709e+00,  5.000e-01,  1.000e-05,  1.000e+00],
#                        [ 2.709e+00,  5.000e-01,  1.000e-05,  1.000e+00]]), array([ 5.754e+01,  5.754e+01,  5.754e+01,  5.754e+01,
#                         5.754e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [2.9171549547106697, 2.336009169887456, 0.418601655719901, 0.762811427740978]
# final_loss_fn:  1994.8113178671974
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 1994.8113178671974
#              x: [ 5.000e-01  5.000e-01  1.000e-05  1.000e+00]
#            nit: 28
#           nfev: 47
#  final_simplex: (array([[ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e+00],
#                        [ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e+00],
#                        ...,
#                        [ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e+00],
#                        [ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e+00]]), array([ 1.995e+03,  1.995e+03,  1.995e+03,  1.995e+03,
#                         1.995e+03]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [3.6929046331816893, 1.9409872951705192, 0.40010576005194254, 0.7974034680479286]
# final_loss_fn:  1946.1542323265703
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 1946.1542323265703
#              x: [ 5.000e-01  5.000e-01  1.000e+00  1.000e-05]
#            nit: 41
#           nfev: 64
#  final_simplex: (array([[ 5.000e-01,  5.000e-01,  1.000e+00,  1.000e-05],
#                        [ 5.000e-01,  5.000e-01,  1.000e+00,  1.000e-05],
#                        ...,
#                        [ 5.000e-01,  5.000e-01,  1.000e+00,  1.000e-05],
#                        [ 5.000e-01,  5.000e-01,  1.000e+00,  1.000e-05]]), array([ 1.946e+03,  1.946e+03,  1.946e+03,  1.946e+03,
#                         1.946e+03]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Set optimized parameters to FF object, use FF.opt_parm to get the optimized parameters
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [1.4113429372709163, 1.4392182973174266, 0.6112050953198014, 0.43606804288565876]

# %%
# ff.get_best_loss()

# %%
print(len(ff.data))
# plot_intE(ff.get_best_df())
# Out:
# 500

# %%
results = pd.DataFrame(ff.opt_results)
best_func = results.sort_values("fun")[:10]
best_func
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 2
#       1 results = pd.DataFrame(ff.opt_results)
# ----> 2 best_func = results.sort_values("fun")[:10]
#       3 best_func
#
# File ~/miniconda3/envs/pycharmm/lib/python3.8/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/pycharmm/lib/python3.8/site-packages/pandas/core/frame.py:6912, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6908 elif len(by):
#    6909     # len(by) == 1
#    6911     by = by[0]
# -> 6912     k = self._get_label_or_level_values(by, axis=axis)
#    6914     # need to rewrap column in Series to apply key function
#    6915     if key is not None:
#    6916         # error: Incompatible types in assignment (expression has type
#    6917         # "Series", variable has type "ndarray")
#
# File ~/miniconda3/envs/pycharmm/lib/python3.8/site-packages/pandas/core/generic.py:1850, in NDFrame._get_label_or_level_values(self, key, axis)
#    1844     values = (
#    1845         self.axes[axis]
#    1846         .get_level_values(key)  # type: ignore[assignment]
#    1847         ._values
#    1848     )
#    1849 else:
# -> 1850     raise KeyError(key)
#    1852 # Check for duplicates
#    1853 if values.ndim > 1:
#
# KeyError: 'fun'

# %%
x = best_func["x"]
values = []
for _ in x:
    epsig = ["$\sigma$","$\epsilon$"]
    names = []
    for es in epsig:
        for at in ff.atom_types:
            names.append(at+es)
    values.append({names[i]: _[i] for i in range(len(_))})
    
    
values = pd.DataFrame(values)
values["rmse"] = best_func["fun"]

values.plot("rmse")
# Out:
# <AxesSubplot:xlabel='rmse'>

# %%
test_ = []
train_ = []
args_ = []
dfs_ = []

for res, data in zip(ff.opt_results,ff.opt_results_df):
    test_keys = [_ for _ in list(ff.data_save.index) if _ not in data.index ]
    test_df = ff.data_save.query("index in @test_keys")
    ff.data = test_df.copy()
    test_len = len(ff.data)
    test_res = ff.eval_func(res.x)
    plot_intE(test_res)
    
    ff.data = ff.data_save.query("index not in @test_keys").copy()
    train_len = len(ff.data)
    train_res = ff.eval_func(res.x)
    plot_intE(train_res)
    print("{:.1f} ({}) {:.1f} ({})".format(test_res["SE"].mean(),
                                           test_len,
         train_res["SE"].mean(),
         train_len))
    test_.append(test_res["SE"].mean())
    train_.append(train_res["SE"].mean())
    args_.append(res.x)
    dfs_.append(test_res)

# %%
df = pd.DataFrame({"test": test_, "train": train_, "args": args_, "df": dfs_})

# %%
best = df[df["train"] < 35]
# best["test"] = np.sqrt(best["test"])
# best["train"] = np.sqrt(best["train"]) 
best
# Out:
#           test      train                                               args  \
# 1    27.917897  20.383867  [1.9839278082046399, 0.5, 0.051873723431355934...
# 2    28.716471  23.064137  [1.9859574332339243, 0.5007299854357377, 0.049...
# 3    28.228360  24.664879  [3.858973855340669, 0.5, 1.0000000000000585e-0...
# 8    25.623155  27.815861  [2.063931574308903, 0.5, 0.029288172335442703,...
# 11   28.075774  21.873808  [1.9338021894310695, 0.5, 0.07369873509472952,...
# 15   28.588004  22.870892  [3.731114413347504, 0.5, 1.3050831956394406e-0...
# 16   28.153430  22.466843  [2.448422468204365, 0.5, 0.0024074981360934227...
# 18   27.689097  21.686561  [1.9722512667923704, 0.8758834990755617, 0.050...
# 19   27.679939  21.680616  [1.9707758865234677, 0.9999077692025407, 0.050...
# 24   27.348354  24.042951  [1.9156042585132713, 0.5, 0.08787440863938215,...
# 27   27.348356  24.042951  [1.9156043026434435, 0.5, 0.08787438147609286,...
# 28   27.348342  24.042951  [1.9156044861464858, 0.5, 0.08787423434227115,...
# 29   26.316712  27.286549  [3.3631997834194425, 0.5, 5.111831638402604e-0...
# 30   27.130301  23.365277  [2.1061226163919153, 0.5, 0.022078048499581664...
# 32   27.257267  23.265230  [3.580797503850709, 0.5, 2.4757398806577917e-0...
# 35   26.822965  23.080708  [2.3890447300504842, 0.5052253579627444, 0.003...
# 38   27.130297  23.365277  [2.106121966410889, 0.5, 0.022078140512494626,...
# 41   28.042756  23.167865  [2.090689304274394, 0.5, 0.019709176378180045,...
# 42   28.915377  23.866790  [3.7784246726353947, 0.5003164007974226, 1.000...
# 43   28.042748  23.167865  [2.090689287637856, 0.5, 0.019709184547913518,...
# 51   27.503853  24.803642  [2.034770723532517, 0.5, 0.030359039027450505,...
# 52   27.392679  24.779974  [2.0012231018282742, 1.187772766723996, 0.0368...
# 53   27.797332  25.625222  [1.9352073216430035, 0.5, 0.07239558394715172,...
# 54   27.392679  24.779974  [2.001222062791615, 1.1877718267852104, 0.0368...
# 55   27.503856  24.803642  [2.0347712018949373, 0.5, 0.030358924808523827...
# 56   27.392682  24.779974  [2.001221884262888, 1.1877719039829464, 0.0368...
# 57   27.797337  25.625222  [1.9352069980191324, 0.5, 0.0723957681013353, ...
# 60   27.626973  25.898035  [1.9017964614852063, 0.5, 0.098605417714763, 3...
# 62   27.626334  25.897983  [1.901788621619823, 0.5032953946166249, 0.0986...
# 63   27.579847  25.895923  [1.9020214748779534, 0.6756232276434282, 0.097...
# 65   27.621003  25.897561  [1.9017300085687374, 0.531124846273904, 0.0985...
# 67   27.626981  25.898035  [1.9017962947880147, 0.5, 0.09860562025398976,...
# 71   27.186621  25.499845  [3.593823673957605, 0.5, 2.4633884556089e-05, ...
# 72   27.192332  25.500051  [3.6627461532683556, 0.5, 1.9582959916684416e-...
# 73   27.085516  25.497935  [3.0010299657282538, 0.5, 0.000220122673518478...
# 74   27.085517  25.497935  [3.0010311683388764, 0.5, 0.000220121589728246...
# 75   27.574622  25.882927  [2.2855793472797705, 0.5, 0.007352269406121158...
# 76   27.085517  25.497935  [3.001029706103477, 0.5, 0.0002201229053904161...
# 77   27.085463  25.497934  [3.0008479594074116, 0.5000840708521928, 0.000...
# 78   27.053272  25.495895  [2.9008874009143657, 0.6346489204411765, 0.000...
# 80   27.104881  22.448252  [1.9394231388224101, 0.5, 0.06913674381992072,...
# 81   27.050211  22.400499  [1.9320306284569309, 0.9743466792749813, 0.071...
# 86   26.594155  23.966968  [2.374877798506647, 0.5035912923505732, 0.0038...
# 87   27.104501  22.448006  [1.939396524256558, 0.5013552006263414, 0.0691...
# 88   26.932311  24.863037  [3.84843664468757, 0.5142996522956852, 1.00000...
# 90   27.163800  22.695070  [2.0278584288338344, 0.5, 0.037657619951356316...
# 91   27.163809  22.695070  [2.0278587369803347, 0.5, 0.03765755660401095,...
# 94   27.163816  22.695070  [2.0278589474786664, 0.5, 0.03765750586499082,...
# 98   27.163811  22.695070  [2.027858385303789, 0.5, 0.037657651868267944,...
# 101  27.975999  21.966714  [3.8644553617627775, 0.5561059903066362, 1.000...
# 105  27.973454  21.965140  [3.7671546464180956, 0.6758829613652539, 1.360...
# 107  27.490043  21.804354  [2.3829296187769504, 0.5, 0.003908559157522412...
#
#                                                     df
# 1                   ECOL      KEY     TOTAL       E...
# 2                   ECOL      KEY     TOTAL       E...
# 3                   ECOL      KEY     TOTAL       E...
# 8                   ECOL      KEY     TOTAL       E...
# 11                  ECOL      KEY     TOTAL       E...
# 15                  ECOL      KEY     TOTAL       E...
# 16                  ECOL      KEY     TOTAL       E...
# 18                  ECOL      KEY     TOTAL       E...
# 19                  ECOL      KEY     TOTAL       E...
# 24                  ECOL      KEY     TOTAL       E...
# 27                  ECOL      KEY     TOTAL       E...
# 28                  ECOL      KEY     TOTAL       E...
# 29                  ECOL      KEY     TOTAL       E...
# 30                  ECOL      KEY     TOTAL       E...
# 32                  ECOL      KEY     TOTAL       E...
# 35                  ECOL      KEY     TOTAL       E...
# 38                  ECOL      KEY     TOTAL       E...
# 41                  ECOL      KEY     TOTAL       E...
# 42                  ECOL      KEY     TOTAL       E...
# 43                  ECOL      KEY     TOTAL       E...
# 51                  ECOL      KEY     TOTAL       E...
# 52                  ECOL      KEY     TOTAL       E...
# 53                  ECOL      KEY     TOTAL       E...
# 54                  ECOL      KEY     TOTAL       E...
# 55                  ECOL      KEY     TOTAL       E...
# 56                  ECOL      KEY     TOTAL       E...
# 57                  ECOL      KEY     TOTAL       E...
# 60                  ECOL      KEY     TOTAL       E...
# 62                  ECOL      KEY     TOTAL       E...
# 63                  ECOL      KEY     TOTAL       E...
# 65                  ECOL      KEY     TOTAL       E...
# 67                  ECOL      KEY     TOTAL       E...
# 71                  ECOL      KEY     TOTAL       E...
# 72                  ECOL      KEY     TOTAL       E...
# 73                  ECOL      KEY     TOTAL       E...
# 74                  ECOL      KEY     TOTAL       E...
# 75                  ECOL      KEY     TOTAL       E...
# 76                  ECOL      KEY     TOTAL       E...
# 77                  ECOL      KEY     TOTAL       E...
# 78                  ECOL      KEY     TOTAL       E...
# 80                  ECOL      KEY     TOTAL       E...
# 81                  ECOL      KEY     TOTAL       E...
# 86                  ECOL      KEY     TOTAL       E...
# 87                  ECOL      KEY     TOTAL       E...
# 88                  ECOL      KEY     TOTAL       E...
# 90                  ECOL      KEY     TOTAL       E...
# 91                  ECOL      KEY     TOTAL       E...
# 94                  ECOL      KEY     TOTAL       E...
# 98                  ECOL      KEY     TOTAL       E...
# 101                 ECOL      KEY     TOTAL       E...
# 105                 ECOL      KEY     TOTAL       E...
# 107                 ECOL      KEY     TOTAL       E...

# %%
best.iloc[0]["df"]
# Out:
#                ECOL      KEY     TOTAL       ELEC       VDW      KEY  \
# test467 -113.436686  test467  21.39109  -81.32190  14.82881  test467
# test471 -127.463435  test471  21.36685  -93.42710  14.54395  test471
# test117  -87.465907  test117  23.93672  -59.12652   8.80992  test117
# test186 -155.938399  test186  21.62421 -115.09755  22.50911  test186
# test375 -136.608797  test375  18.96213 -113.72132  13.32872  test375
# ...             ...      ...       ...        ...       ...      ...
# test48          NaN      NaN  21.38249 -110.66179  20.01366   test48
# test381         NaN      NaN  22.34947 -104.26997  19.67678  test381
# test489         NaN      NaN  19.86517 -138.11558  32.25939  test489
# test304         NaN      NaN  20.88239 -105.35181  17.28253  test304
# test327         NaN      NaN  19.07727 -157.43693  31.12436  test327
#
#             M_ENERGY      KEY     C_ENERGY       intE     NBONDS         LJ  \
# test467 -1527.154217  test467 -1527.236629 -51.714066  -66.49309  40.844282
# test471 -1527.144137  test471 -1527.242885 -61.964509  -78.88315  40.933978
# test117 -1527.145615  test117 -1527.193103 -29.798988  -50.31660  29.307305
# test186 -1527.145607  test186 -1527.253079 -67.438908  -92.58844  51.554322
# test375 -1527.144874  test375 -1527.256065 -69.772736 -100.39260  39.473671
# ...              ...      ...          ...        ...        ...        ...
# test48  -1527.147549   test48 -1527.250885 -64.843945  -90.64813  47.187919
# test381 -1527.147167  test381 -1527.236541 -56.082083  -84.59319  47.794296
# test489 -1527.152482  test489 -1527.269339 -73.327986 -105.85619  67.662512
# test304 -1527.150985  test304 -1527.239633 -55.626955  -88.06928  44.206594
# test327 -1527.154084  test327 -1527.300559 -91.913853 -126.31257  68.701923
#
#          VDW_ERROR       VDW_SE    nb_intE          SE
# test467 -26.015472   676.804777 -40.477618  126.257758
# test471 -26.390028   696.433583 -52.493122   89.707180
# test117 -20.497385   420.142780 -29.819215    0.000409
# test186 -29.045212   843.624318 -63.543228   15.176322
# test375 -26.144951   683.558479 -74.247649   20.024841
# ...            ...          ...        ...         ...
# test48  -27.174259   738.440332 -63.473871    1.877102
# test381 -28.117516   790.594694 -56.475674    0.154914
# test489 -35.403122  1253.381031 -70.453068    8.265154
# test304 -26.924064   724.905216 -61.145216   30.451206
# test327 -37.577563  1412.073253 -88.735007   10.105065
#
# [400 rows x 16 columns]

# %%
plt.scatter(best["test"], best["train"])
plt.xlabel("Test", fontsize=20)
plt.ylabel("Train", fontsize=20)
# Out:
# Text(0, 0.5, 'Train')

# %%
import matplotlib as mpl
import matplotlib.lines as mlines
import matplotlib.patches as mpatches
import matplotlib.path as mpath
import matplotlib.pyplot as plt

# Prepare the data for the PathPatch below.
Path = mpath.Path
codes, verts = zip(*[
    (Path.MOVETO, [0.018, -0.11]),
    (Path.CURVE4, [-0.031, -0.051]),
    (Path.CURVE4, [-0.115, 0.073]),
    (Path.CURVE4, [-0.03, 0.073]),
    (Path.LINETO, [-0.011, 0.039]),
    (Path.CURVE4, [0.043, 0.121]),
    (Path.CURVE4, [0.075, -0.005]),
    (Path.CURVE4, [0.035, -0.027]),
    (Path.CLOSEPOLY, [0.018, -0.11])])

artists = [
    mpatches.Circle((0, 0), 0.1, ec="none"),
    mpatches.Rectangle((-0.025, -0.05), 0.05, 0.1, ec="none"),
    mpatches.Wedge((0, 0), 0.1, 30, 270, ec="none"),
    mpatches.RegularPolygon((0, 0), 5, radius=0.1),
    mpatches.Ellipse((0, 0), 0.2, 0.1),
    mpatches.Arrow(-0.05, -0.05, 0.1, 0.1, width=0.1),
    mpatches.PathPatch(mpath.Path(verts, codes), ec="none"),
    mpatches.FancyBboxPatch((-0.025, -0.05), 0.05, 0.1, ec="none",
                            boxstyle=mpatches.BoxStyle("Round", pad=0.02)),
    mlines.Line2D([-0.06, 0.0, 0.1], [0.05, -0.05, 0.05], lw=5),
]

axs = plt.figure(figsize=(6, 6), layout="constrained").subplots(3, 3)
for i, (ax, artist) in enumerate(zip(axs.flat, artists)):
    artist.set(color=mpl.colormaps["hsv"](i / len(artists)))
    ax.add_artist(artist)
    ax.set(title=type(artist).__name__,
           aspect=1, xlim=(-.2, .2), ylim=(-.2, .2))
    ax.set_axis_off()
plt.show()

# %%
import seaborn as sns
cmap = sns.color_palette("icefire", as_cmap=True)
# cmap()
# cmap = mpl.cm.cool
norm = mpl.colors.Normalize(vmin=5, vmax=10)

plt.colorbar(mpl.cm.ScalarMappable(norm=norm, cmap=cmap),
             cax=ax, orientation='horizontal', label='Some Units')

# %%
# sns.choose_diverging_palette(as_cmap=True)

# %%
# cmap1 = sns.cubehelix_palette(start=.5, rot=-.99, as_cmap=True)
# cmap2 = sns.cubehelix_palette(start=.2, rot=-.99, as_cmap=True)
# cmap1 = sns.color_palette("Blues", as_cmap=True)
# cmap2 = sns.color_palette("Reds", as_cmap=True)
cmap1 = sns.color_palette("light:seagreen", as_cmap=True)
cmap2 = sns.color_palette("dark:blueviolet", as_cmap=True)


fig, ax = plt.subplots(1,3,figsize=(4.5, 4), 
                       gridspec_kw={'width_ratios': [3.5, 0.25,0.25]})

plt.subplots_adjust(wspace=0.25)

quarters = [(360,90),(90,180),(180,270),(270,360),]

def plot_circle(x,y,ax,res):
    # print(res)
    size = 0.2
    quarters = [(90,180),(0,90),(180,270),(270,0),]
    for i, (a,b) in enumerate(quarters):
        move = 0.0
        if i == 1:
            wedge = mpatches.Wedge((x, y), size, a, b)
        elif i == 0:
            wedge = mpatches.Wedge((x, y), size, a, b)
        elif i == 2:
            wedge = mpatches.Wedge((x, y+move), size, a, b)
        else:
            wedge = mpatches.Wedge((x, y+move), size, a, b)
        # wedge.set(color=mpl.colormaps["hsv"](i / 4))
        if i == 0 or i == 1:
            # print(res[i])
            cval = norm2(res[i])
            cmap = cmap2
        else:
            # print(res[i],np.log(res[i]))
            cval = norm1(np.log(res[i]))
            cmap = cmap1
        wedge.set(color=cmap(cval))
        if x < 27:
            wedge.set(alpha=1)
        ax.add_artist(wedge)
        # ax.set(aspect=1, xlim=(-.2, .2), ylim=(-.2, .2))
    return ax
    
norm1 = mpl.colors.Normalize(vmin=-11, vmax=-1)
norm2 = mpl.colors.Normalize(vmin=0.5, vmax=4)


    
# plt.scatter(best["test"], best["train"])
ax[0].set_xlabel("Train MSE [kcal/mol]", fontsize=20)
ax[0].set_ylabel("Test MSE [kcal/mol]", fontsize=20)
# plt.colorbar(cmap)
# plt.gca().set_axis_off()
minlim = min([best["test"].min(),best["train"].min()]) - .5
maxlim = max([best["test"].max(),best["train"].max()]) + .5

plt.colorbar(mpl.cm.ScalarMappable(norm=norm2, cmap=cmap2),
             cax=ax[1], orientation='vertical', label='')
plt.colorbar(mpl.cm.ScalarMappable(norm=norm1, cmap=cmap1),
             cax=ax[2], orientation='vertical', label='')

for x,y,res in zip(best["train"], best["test"], best["args"]):
    ax[0] = plot_circle(x,y,ax[0],res)

ax[0].set_xlim(minlim, maxlim)
ax[0].set_ylim(minlim, maxlim)
# ax[0].set_ylim(25, 29.5)
ax[0].plot(ax[0].get_xlim(), ax[0].get_ylim(), ls="--", c=".3", alpha=0.5)
# ax[0].grid()
ax[0].set_aspect(1)
plt.savefig("test.pdf",bbox_inches="tight")
plt.show()

# %%
from scipy.stats import bootstrap
rng = np.random.default_rng()
best_res = best.iloc[0]["df"]

# %%
data = (best_res["SE"],)  # samples must be in a sequence
res = bootstrap(data, np.median, confidence_level=0.95,
                random_state=rng)

# %%
res
# Out:
# BootstrapResult(confidence_interval=ConfidenceInterval(low=10.281067592824375, high=15.217199855208536), standard_error=1.462264663646212)

# %%
plt.hist(data)
# Out:
# (array([271.,  59.,  34.,  13.,  10.,   5.,   4.,   0.,   3.,   1.]),
#  array([3.09346227e-04, 2.60686173e+01, 5.21369253e+01, 7.82052333e+01,
#         1.04273541e+02, 1.30341849e+02, 1.56410157e+02, 1.82478465e+02,
#         2.08546773e+02, 2.34615081e+02, 2.60683389e+02]),
#  <BarContainer object of 10 artists>)

# %%
fig, ax = plt.subplots()
ax.hist(res.bootstrap_distribution, bins=25)
ax.set_title('Bootstrap Distribution')
ax.set_xlabel('statistic value')
ax.set_ylabel('frequency')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [507], in <cell line: 2>()
#       1 fig, ax = plt.subplots()
# ----> 2 ax.hist(res.bootstrap_distribution, bins=25)
#       3 ax.set_title('Bootstrap Distribution')
#       4 ax.set_xlabel('statistic value')
#
# AttributeError: 'BootstrapResult' object has no attribute 'bootstrap_distribution'
