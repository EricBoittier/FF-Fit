# %% [markdown]
# #  Ideas for fitting code:
#
# - pickle all FF objects

# %%
# %load_ext autoreload
# %autoreload 2

from ff_energy.cli import load_config_maker, load_all_theory, charmm_jobs
# from ff_energy.structure import
from ff_energy.potential import FF, LJ
import numpy as np
from ff_energy.data import Data, plot_ecol, plot_intE, plot_LJintE
import matplotlib.pyplot as plt
import pickle
from pathlib import Path
import pandas as pd 
from ff_energy.utils import pickle_output,read_from_pickle
from ff_energy.data import Data

sig_bound = (0.5, 4.0)
ep_bound = (0.00001, 1.0)
LJ_bound = [(sig_bound), (sig_bound), (ep_bound), (ep_bound)]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
FUNC = LJ
BOUNDS = LJ_bound
ff_name = "pbe0dz_mdcm"
structure = "water_cluster"
pk = "pickles/water_cluster/pbe0dz/pbe0_dz.mdcm"



#########################################################

ff_pkls = Path("pickles/ff")
ff_pickles = ff_pkls.glob("*.pkl")
ff_pickles = [_.name for _ in ff_pickles]
struct_dist_pkls = Path("pickles/structures")
struct_dist_pickles = struct_dist_pkls.glob("*.pkl")
struct_dist_pickles = [_.name for _ in struct_dist_pickles]


pickled_ff = (ff_pkls/f"{ff_name}.pkl").exists()
pickled_dists = (struct_dist_pkls/f"{structure}.pkl").exists()


if pickled_ff:
    print("Pickled FF exists!, loading: ", ff_pkls/f"{ff_name}.pkl")
    try:
        ff = next(read_from_pickle(ff_pkls / f"{ff_name}.pkl"))
    except StopIteration:
        print("Pickle read failed.")
        pickled_ff = False
    
if not pickled_ff:
    if pickled_dists:
        print("loading pickled distances/structure")
        structures, dists =  next(read_from_pickle(
            f"pickles/structures/{structure}.pkl"))
    else:
        print("No pickled distances/structure information, calculating:")
        CMS = load_config_maker("pbe0dz", structure, "mdcm")
        jobs = charmm_jobs(CMS)
        dists = {_.name.split(".")[0]: _.distances for _ in jobs[0].structures}
        structures = [_ for _ in jobs[0].structures]
        pickle_output((structures, dists), 
                      name=f"structures/{structure}")

    s = structures[0]
    data_ = Data(pk)
    ff = FF(data_.data,dists,FUNC,BOUNDS,s)

# d = ff.data_save.sample(200)
# ff.data = d.copy()
args = [1.7682,0.2245,-0.1521,-0.0460]
# Out:
# loading pickled distances/structure
# loading pickles from  pickles/water_cluster/pbe0dz/pbe0_dz.mdcm
# [('HT', 'HT'), ('HT', 'OT'), ('OT', 'OT')]
# 0 ('HT', 'HT') ('HT', 'HT')
# 1 ('HT', 'OT') ('HT', 'OT')
# 2 ('OT', 'OT') ('OT', 'OT')

# %%
print(len(ff.dists["test0"][15]))
print(len(ff.dists["test0"][17]))
print(len(ff.dists["test0"][20]))
# Out:
# 190
# 380
# 190

# %%
# ff.data = ff.data_save
ff.data
# Out:
#                ECOL      KEY     TOTAL       ELEC       VDW      KEY  \
# test467 -113.436686  test467  21.39109  -81.32190  14.82881  test467
# test263  -16.820533  test263  19.20382 -122.03878  20.54380  test263
# test35   -25.924214   test35  22.25853 -100.65197  11.05221   test35
# test223    1.312603  test223  22.62790  -61.61795   6.72946  test223
# test254   -1.846755  test254  22.63732 -124.82730  21.85417  test254
# ...             ...      ...       ...        ...       ...      ...
# test64          NaN      NaN  20.64353  -66.68013  10.23596   test64
# test278         NaN      NaN  23.71745  -83.37680   7.66610  test278
# test204         NaN      NaN  17.66112 -129.14115  28.88785  test204
# test486         NaN      NaN  26.64222 -110.79449  25.86481  test486
# test288         NaN      NaN  21.66717 -120.27062  16.90015  test288
#
#             M_ENERGY      KEY  n_monomers     C_ENERGY  n_pairs       intE  \
# test467 -1527.154217  test467          20 -1527.236629      190 -51.714066
# test263 -1527.156016  test263          20 -1527.258259      190 -64.157783
# test35  -1527.143158   test35          20 -1527.258584      189 -72.430230
# test223 -1527.147556  test223          20 -1527.203106      190 -34.857221
# test254 -1527.135568  test254          20 -1527.237145      188 -63.739697
# ...              ...      ...         ...          ...      ...        ...
# test64  -1527.154680   test64          20 -1527.218444      190 -40.012616
# test278 -1527.143103  test278          20 -1527.219809      189 -48.133270
# test204 -1527.157200  test204          20 -1527.272753      190 -72.510080
# test486 -1527.123959  test486          20 -1527.198832      190 -46.983584
# test288 -1527.141466  test288          20 -1527.249875      190 -68.026508
#
#             P_intE
# test467 -50.297664
# test263 -66.601357
# test35  -65.790457
# test223 -39.243367
# test254 -57.830990
# ...            ...
# test64  -43.014397
# test278 -47.465430
# test204 -65.943128
# test486 -46.456197
# test288 -67.286499
#
# [500 rows x 13 columns]

# %%
for i in range(1):
    # d = ff.data_save.sample(100)
    # ff.data = d.copy()
    print(len(ff.data))
    _ = ff.LJ_performace(ff.eval_func(args))
    print(_.keys())
    print(len(_.keys()))
    # _["nb_intE"] = _["NBONDS"]
    plot_intE(_)
    print(_["SE"].mean())
_
# Out:
# 500
# Index(['ECOL', 'KEY', 'TOTAL', 'ELEC', 'VDW', 'KEY', 'M_ENERGY', 'KEY',
#        'n_monomers', 'C_ENERGY', 'n_pairs', 'intE', 'P_intE', 'LJ',
#        'VDW_ERROR', 'VDW_SE', 'nb_intE', 'SE'],
#       dtype='object')
# 18
# 1850458.1078806906
#                ECOL      KEY     TOTAL       ELEC       VDW      KEY  \
# test467 -113.436686  test467  21.39109  -81.32190  14.82881  test467
# test263  -16.820533  test263  19.20382 -122.03878  20.54380  test263
# test35   -25.924214   test35  22.25853 -100.65197  11.05221   test35
# test223    1.312603  test223  22.62790  -61.61795   6.72946  test223
# test254   -1.846755  test254  22.63732 -124.82730  21.85417  test254
# ...             ...      ...       ...        ...       ...      ...
# test64          NaN      NaN  20.64353  -66.68013  10.23596   test64
# test278         NaN      NaN  23.71745  -83.37680   7.66610  test278
# test204         NaN      NaN  17.66112 -129.14115  28.88785  test204
# test486         NaN      NaN  26.64222 -110.79449  25.86481  test486
# test288         NaN      NaN  21.66717 -120.27062  16.90015  test288
#
#             M_ENERGY      KEY  n_monomers     C_ENERGY  n_pairs       intE  \
# test467 -1527.154217  test467          20 -1527.236629      190 -51.714066
# test263 -1527.156016  test263          20 -1527.258259      190 -64.157783
# test35  -1527.143158   test35          20 -1527.258584      189 -72.430230
# test223 -1527.147556  test223          20 -1527.203106      190 -34.857221
# test254 -1527.135568  test254          20 -1527.237145      188 -63.739697
# ...              ...      ...         ...          ...      ...        ...
# test64  -1527.154680   test64          20 -1527.218444      190 -40.012616
# test278 -1527.143103  test278          20 -1527.219809      189 -48.133270
# test204 -1527.157200  test204          20 -1527.272753      190 -72.510080
# test486 -1527.123959  test486          20 -1527.198832      190 -46.983584
# test288 -1527.141466  test288          20 -1527.249875      190 -68.026508
#
#             P_intE           LJ    VDW_ERROR        VDW_SE    nb_intE  \
# test467 -50.297664   832.552732  -817.723922  6.686724e+05  -66.49309
# test263 -66.601357  1825.169285 -1804.625485  3.256673e+06 -101.49498
# test35  -65.790457  1225.646245 -1214.594035  1.475239e+06  -89.59976
# test223 -39.243367   540.155143  -533.425683  2.845430e+05  -54.88849
# test254 -57.830990   939.509853  -917.655683  8.420920e+05 -102.97313
# ...            ...          ...          ...           ...        ...
# test64  -43.014397   432.796433  -422.560473  1.785574e+05  -56.44417
# test278 -47.465430   893.218494  -885.552394  7.842030e+05  -75.71070
# test204 -65.943128  1237.830181 -1208.942331  1.461542e+06 -100.25330
# test486 -46.456197  1283.919224 -1258.054414  1.582701e+06  -84.92968
# test288 -67.286499  1144.865412 -1127.965262  1.272306e+06 -103.37047
#
#                    SE
# test467  6.447205e+05
# test263  3.123308e+06
# test35   1.433825e+06
# test223  2.635738e+05
# test254  7.716256e+05
# ...               ...
# test64   1.649407e+05
# test278  7.361210e+05
# test204  1.395231e+06
# test486  1.488664e+06
# test288  1.193821e+06
#
# [500 rows x 18 columns]

# %%
_["VDW_ERROR"].mean()
# Out:
# -1172.1573968698467

# %%
# plot_intE(_)

# %%
for i in range(10):
    d = ff.data_save.sample(250)
    ff.data = d.copy()
    ff.fit_repeat(10, bounds=LJ_bound)
pickle_output(ff, "ff/pbe0dz_mdcm")
# Out:
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [1.5915648450748567, 3.7071777611267454, 0.9331845141107322, 0.6106141858131832]
# final_loss_fn:  73.09749656507256
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 73.09749656507256
#              x: [ 2.642e+00  5.000e-01  1.000e-05  1.000e+00]
#            nit: 130
#           nfev: 232
#  final_simplex: (array([[ 2.642e+00,  5.000e-01,  1.000e-05,  1.000e+00],
#                        [ 2.642e+00,  5.000e-01,  1.000e-05,  1.000e+00],
#                        ...,
#                        [ 2.642e+00,  5.000e-01,  1.000e-05,  1.000e+00],
#                        [ 2.642e+00,  5.000e-01,  1.000e-05,  1.000e+00]]), array([ 7.310e+01,  7.310e+01,  7.310e+01,  7.310e+01,
#                         7.310e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [1.1071610904326115, 2.5357183122383047, 0.128731408030678, 0.34625241013100305]
# final_loss_fn:  26.679159873748585
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 26.679159873748585
#              x: [ 1.080e+00  2.054e+00  1.000e-05  2.771e-02]
#            nit: 4128
#           nfev: 6792
#  final_simplex: (array([[ 1.080e+00,  2.054e+00,  1.000e-05,  2.771e-02],
#                        [ 1.080e+00,  2.054e+00,  1.000e-05,  2.771e-02],
#                        ...,
#                        [ 1.080e+00,  2.054e+00,  1.000e-05,  2.771e-02],
#                        [ 1.080e+00,  2.054e+00,  1.000e-05,  2.771e-02]]), array([ 2.668e+01,  2.668e+01,  2.668e+01,  2.668e+01,
#                         2.668e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [1.6596082217883055, 2.9857688938674416, 0.758934770673698, 0.46002066417783294]
# final_loss_fn:  64.25771126388666
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 64.25771126388666
#              x: [ 5.000e-01  2.728e+00  9.509e-01  1.000e-05]
#            nit: 616
#           nfev: 1030
#  final_simplex: (array([[ 5.000e-01,  2.728e+00,  9.509e-01,  1.000e-05],
#                        [ 5.000e-01,  2.728e+00,  9.509e-01,  1.000e-05],
#                        ...,
#                        [ 5.000e-01,  2.728e+00,  9.509e-01,  1.000e-05],
#                        [ 5.000e-01,  2.728e+00,  9.509e-01,  1.000e-05]]), array([ 6.426e+01,  6.426e+01,  6.426e+01,  6.426e+01,
#                         6.426e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [2.946943266005774, 1.319890148074196, 0.8961404138048019, 0.25993115362642943]
# final_loss_fn:  26.722080010021003
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 26.722080010021003
#              x: [ 6.142e-01  2.072e+00  4.574e-04  2.497e-02]
#            nit: 580
#           nfev: 970
#  final_simplex: (array([[ 6.142e-01,  2.072e+00,  4.574e-04,  2.497e-02],
#                        [ 6.142e-01,  2.072e+00,  4.574e-04,  2.497e-02],
#                        ...,
#                        [ 6.142e-01,  2.072e+00,  4.574e-04,  2.497e-02],
#                        [ 6.142e-01,  2.072e+00,  4.574e-04,  2.497e-02]]), array([ 2.672e+01,  2.672e+01,  2.672e+01,  2.672e+01,
#                         2.672e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [2.299771843088855, 2.481915364384509, 0.3943589234536953, 0.6537644012320706]
# final_loss_fn:  2040.4488306661706
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 2040.4488306661706
#              x: [ 5.000e-01  5.000e-01  1.000e-05  1.000e+00]
#            nit: 32
#           nfev: 51
#  final_simplex: (array([[ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e+00],
#                        [ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e+00],
#                        ...,
#                        [ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e+00],
#                        [ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e+00]]), array([ 2.040e+03,  2.040e+03,  2.040e+03,  2.040e+03,
#                         2.040e+03]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [3.852401053993671, 3.8182774225673453, 0.689931524277934, 0.012263815383683832]
# final_loss_fn:  64.44310767686638
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 64.44310767686638
#              x: [ 5.000e-01  2.721e+00  1.000e+00  1.000e-05]
#            nit: 821
#           nfev: 1377
#  final_simplex: (array([[ 5.000e-01,  2.721e+00,  1.000e+00,  1.000e-05],
#                        [ 5.000e-01,  2.721e+00,  1.000e+00,  1.000e-05],
#                        ...,
#                        [ 5.000e-01,  2.721e+00,  1.000e+00,  1.000e-05],
#                        [ 5.000e-01,  2.721e+00,  1.000e+00,  1.000e-05]]), array([ 6.444e+01,  6.444e+01,  6.444e+01,  6.444e+01,
#                         6.444e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [3.630286926547369, 3.0289037908478798, 0.08877935488340624, 0.40153730910536833]
# final_loss_fn:  26.67915987016404
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 26.67915987016404
#              x: [ 1.080e+00  2.054e+00  1.000e-05  2.771e-02]
#            nit: 1595
#           nfev: 2643
#  final_simplex: (array([[ 1.080e+00,  2.054e+00,  1.000e-05,  2.771e-02],
#                        [ 1.080e+00,  2.054e+00,  1.000e-05,  2.771e-02],
#                        ...,
#                        [ 1.080e+00,  2.054e+00,  1.000e-05,  2.771e-02],
#                        [ 1.080e+00,  2.054e+00,  1.000e-05,  2.771e-02]]), array([ 2.668e+01,  2.668e+01,  2.668e+01,  2.668e+01,
#                         2.668e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [1.5172715404123212, 0.9792985441817434, 0.1837704473749557, 0.2615768193441963]
# final_loss_fn:  27.107473509313756
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 27.107473509313756
#              x: [ 5.000e-01  1.988e+00  1.000e-05  4.962e-02]
#            nit: 315
#           nfev: 537
#  final_simplex: (array([[ 5.000e-01,  1.988e+00,  1.000e-05,  4.962e-02],
#                        [ 5.000e-01,  1.988e+00,  1.000e-05,  4.962e-02],
#                        ...,
#                        [ 5.000e-01,  1.988e+00,  1.000e-05,  4.962e-02],
#                        [ 5.000e-01,  1.988e+00,  1.000e-05,  4.962e-02]]), array([ 2.711e+01,  2.711e+01,  2.711e+01,  2.711e+01,
#                         2.711e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [1.4810775434909145, 1.9444353443451154, 0.4601081843336588, 0.8687107270511217]
# final_loss_fn:  62.0815565681256
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 62.0815565681256
#              x: [ 2.488e+00  7.037e-01  1.000e-05  1.000e+00]
#            nit: 645
#           nfev: 1090
#  final_simplex: (array([[ 2.488e+00,  7.037e-01,  1.000e-05,  1.000e+00],
#                        [ 2.488e+00,  7.037e-01,  1.000e-05,  1.000e+00],
#                        ...,
#                        [ 2.488e+00,  7.037e-01,  1.000e-05,  1.000e+00],
#                        [ 2.488e+00,  7.037e-01,  1.000e-05,  1.000e+00]]), array([ 6.208e+01,  6.208e+01,  6.208e+01,  6.208e+01,
#                         6.208e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [3.6924913824357897, 0.9021663889319023, 0.14497087775165268, 0.025852356527615295]
# final_loss_fn:  2031.4446577344238
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 2031.4446577344238
#              x: [ 5.000e-01  5.000e-01  1.000e-05  1.000e-05]
#            nit: 27
#           nfev: 46
#  final_simplex: (array([[ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e-05],
#                        [ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e-05],
#                        ...,
#                        [ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e-05],
#                        [ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e-05]]), array([ 2.031e+03,  2.031e+03,  2.031e+03,  2.031e+03,
#                         2.031e+03]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Set optimized parameters to FF object, use FF.opt_parm to get the optimized parameters
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [3.6495242820330427, 1.7538116777457835, 0.275393975666746, 0.634893041052619]
# final_loss_fn:  54.92820614290551
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 54.92820614290551
#              x: [ 2.506e+00  6.908e-01  1.000e-05  9.280e-01]
#            nit: 626
#           nfev: 1053
#  final_simplex: (array([[ 2.506e+00,  6.908e-01,  1.000e-05,  9.280e-01],
#                        [ 2.506e+00,  6.908e-01,  1.000e-05,  9.280e-01],
#                        ...,
#                        [ 2.506e+00,  6.908e-01,  1.000e-05,  9.280e-01],
#                        [ 2.506e+00,  6.908e-01,  1.000e-05,  9.280e-01]]), array([ 5.493e+01,  5.493e+01,  5.493e+01,  5.493e+01,
#                         5.493e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [1.5905037518953475, 1.556913298100192, 0.537185137568866, 0.6137743318632829]
# final_loss_fn:  27.92921199245286
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 27.92921199245286
#              x: [ 5.000e-01  1.966e+00  1.000e-05  5.817e-02]
#            nit: 298
#           nfev: 514
#  final_simplex: (array([[ 5.000e-01,  1.966e+00,  1.000e-05,  5.817e-02],
#                        [ 5.000e-01,  1.966e+00,  1.000e-05,  5.817e-02],
#                        ...,
#                        [ 5.000e-01,  1.966e+00,  1.000e-05,  5.817e-02],
#                        [ 5.000e-01,  1.966e+00,  1.000e-05,  5.818e-02]]), array([ 2.793e+01,  2.793e+01,  2.793e+01,  2.793e+01,
#                         2.793e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [0.5178832495057314, 3.9368581010062864, 0.7060791086461858, 0.264047105911555]
# final_loss_fn:  58.347821971339584
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 58.347821971339584
#              x: [ 5.000e-01  2.735e+00  8.938e-01  1.000e-05]
#            nit: 560
#           nfev: 952
#  final_simplex: (array([[ 5.000e-01,  2.735e+00,  8.938e-01,  1.000e-05],
#                        [ 5.000e-01,  2.735e+00,  8.938e-01,  1.000e-05],
#                        ...,
#                        [ 5.000e-01,  2.735e+00,  8.938e-01,  1.000e-05],
#                        [ 5.000e-01,  2.735e+00,  8.938e-01,  1.000e-05]]), array([ 5.835e+01,  5.835e+01,  5.835e+01,  5.835e+01,
#                         5.835e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [0.9524475581011502, 3.263750091952305, 0.3598602687635476, 0.9951655134372939]
# final_loss_fn:  1935.7355815768622
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 1935.7355815768622
#              x: [ 5.000e-01  5.000e-01  1.000e-05  1.000e+00]
#            nit: 48
#           nfev: 74
#  final_simplex: (array([[ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e+00],
#                        [ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e+00],
#                        ...,
#                        [ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e+00],
#                        [ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e+00]]), array([ 1.936e+03,  1.936e+03,  1.936e+03,  1.936e+03,
#                         1.936e+03]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [2.182184140514305, 1.544144066967725, 0.29094542774473253, 0.6817677266016398]
# final_loss_fn:  27.92921199245503
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 27.92921199245503
#              x: [ 5.000e-01  1.966e+00  1.000e-05  5.817e-02]
#            nit: 282
#           nfev: 483
#  final_simplex: (array([[ 5.000e-01,  1.966e+00,  1.000e-05,  5.817e-02],
#                        [ 5.000e-01,  1.966e+00,  1.000e-05,  5.818e-02],
#                        ...,
#                        [ 5.000e-01,  1.966e+00,  1.000e-05,  5.818e-02],
#                        [ 5.000e-01,  1.966e+00,  1.000e-05,  5.818e-02]]), array([ 2.793e+01,  2.793e+01,  2.793e+01,  2.793e+01,
#                         2.793e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [2.08131354611744, 1.768434874750839, 0.714669526750918, 0.7010761459330866]
# final_loss_fn:  28.093868853286665
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 28.093868853286665
#              x: [ 6.258e-01  3.823e+00  2.643e-05  1.003e-05]
#            nit: 944
#           nfev: 1604
#  final_simplex: (array([[ 6.258e-01,  3.823e+00,  2.643e-05,  1.003e-05],
#                        [ 6.258e-01,  3.823e+00,  2.643e-05,  1.003e-05],
#                        ...,
#                        [ 6.258e-01,  3.823e+00,  2.643e-05,  1.003e-05],
#                        [ 6.258e-01,  3.823e+00,  2.643e-05,  1.003e-05]]), array([ 2.809e+01,  2.809e+01,  2.809e+01,  2.809e+01,
#                         2.809e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [0.7158291872260643, 2.665543295622519, 0.4524946149606758, 0.7459266037405461]
# final_loss_fn:  1927.0758743267027
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 1927.0758743267027
#              x: [ 5.000e-01  5.000e-01  1.000e-05  1.000e-05]
#            nit: 64
#           nfev: 95
#  final_simplex: (array([[ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e-05],
#                        [ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e-05],
#                        ...,
#                        [ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e-05],
#                        [ 5.000e-01,  5.000e-01,  1.000e-05,  1.000e-05]]), array([ 1.927e+03,  1.927e+03,  1.927e+03,  1.927e+03,
#                         1.927e+03]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [3.7757569001550655, 2.1765564409979774, 0.05835751968340142, 0.7124838543666061]
# final_loss_fn:  27.465469815051456
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 27.465469815051456
#              x: [ 9.635e-01  1.963e+00  2.381e-05  5.347e-02]
#            nit: 305
#           nfev: 523
#  final_simplex: (array([[ 9.635e-01,  1.963e+00,  2.381e-05,  5.347e-02],
#                        [ 9.635e-01,  1.963e+00,  2.381e-05,  5.347e-02],
#                        ...,
#                        [ 9.635e-01,  1.963e+00,  2.380e-05,  5.347e-02],
#                        [ 9.635e-01,  1.963e+00,  2.381e-05,  5.347e-02]]), array([ 2.747e+01,  2.747e+01,  2.747e+01,  2.747e+01,
#                         2.747e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [2.1072125387270972, 1.6704546869104675, 0.6860983942937668, 0.3873514432208237]
# final_loss_fn:  27.340309426338663
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 27.340309426338663
#              x: [ 5.423e-01  2.064e+00  1.561e-03  2.552e-02]
#            nit: 756
#           nfev: 1257
#  final_simplex: (array([[ 5.423e-01,  2.064e+00,  1.561e-03,  2.552e-02],
#                        [ 5.423e-01,  2.064e+00,  1.561e-03,  2.552e-02],
#                        ...,
#                        [ 5.423e-01,  2.064e+00,  1.561e-03,  2.552e-02],
#                        [ 5.423e-01,  2.064e+00,  1.561e-03,  2.552e-02]]), array([ 2.734e+01,  2.734e+01,  2.734e+01,  2.734e+01,
#                         2.734e+01]))
# Set optimized parameters to FF object, self.df["LJ"] is updated.
# Optimizing LJ parameters...
# function: LJ
# bounds: [(0.5, 4.0), (0.5, 4.0), (1e-05, 1.0), (1e-05, 1.0)]
# maxfev: 10000
# initial guess: [2.268548206039778, 1.5555383207665905, 0.9800450172353201, 0.6803066563533561]

# %%
# ff.get_best_loss()

# %%
print(len(ff.data))
# plot_intE(ff.get_best_df())
# Out:
# 200

# %%
results = pd.DataFrame(ff.opt_results)
best_func = results.sort_values("fun")[:10]
best_func
# Out:
#          fun  nit  nfev  status  success  \
# 0  26.507449  503   867       0     True
# 1  55.804414  680  1140       0     True
#
#                                  message  \
# 0  Optimization terminated successfully.
# 1  Optimization terminated successfully.
#
#                                                    x  \
# 0  [0.5034362263464525, 2.055311696715542, 0.0028...
# 1  [0.5000000001467252, 2.7198002463173006, 1.0, ...
#
#                                        final_simplex
# 0  ([[0.5034362263464525, 2.055311696715542, 0.00...
# 1  ([[0.5000000001467252, 2.7198002463173006, 1.0...

# %%
x = best_func["x"]
values = []

for _ in x:
    epsig = ["$\sigma$","$\epsilon$"]
    names = []
    for es in epsig:
        for at in ff.atom_types:
            names.append(at+es)
    values.append({names[i]: _[i] for i in range(len(_))})
    
    
values = pd.DataFrame(values)
values["rmse"] = best_func["fun"]

values.plot("rmse")
# Out:
# <AxesSubplot: xlabel='rmse'>

# %%
test_ = []
train_ = []
args_ = []
dfs_ = []

for res, data in zip(ff.opt_results,ff.opt_results_df):
    test_keys = [_ for _ in list(ff.data_save.index) if _ not in data.index ]
    test_df = ff.data_save.query("index in @test_keys")
    ff.data = test_df.copy()
    test_len = len(ff.data)
    test_res = ff.LJ_performace(ff.eval_func(res.x))
    plot_LJintE(test_res)
    
    ff.data = ff.data_save.query("index not in @test_keys").copy()
    train_len = len(ff.data)
    train_res = ff.LJ_performace(ff.eval_func(res.x))
    plot_LJintE(train_res)
    print("{:.1f} ({}) {:.1f} ({})".format(test_res["SE"].mean(),
                                           test_len,
         train_res["SE"].mean(),
         train_len))
    test_.append(test_res["SE"].mean())
    train_.append(train_res["SE"].mean())
    args_.append(res.x)
    dfs_.append(test_res)
# Out:
# 25.4 (300) 26.5 (200)
# 63.5 (300) 55.8 (200)

# %%
df = pd.DataFrame({"test": test_, "train": train_, "args": args_, "df": dfs_})

# %%
best = df[df["train"] < 35]
# best["test"] = np.sqrt(best["test"])
# best["train"] = np.sqrt(best["train"]) 
best

# %%
best.iloc[0]["df"]

# %%
plt.scatter(best["test"], best["train"])
plt.xlabel("Test", fontsize=20)
plt.ylabel("Train", fontsize=20)

# %%
import matplotlib as mpl
import matplotlib.lines as mlines
import matplotlib.patches as mpatches
import matplotlib.path as mpath
import matplotlib.pyplot as plt

# # Prepare the data for the PathPatch below.
# Path = mpath.Path
# codes, verts = zip(*[
#     (Path.MOVETO, [0.018, -0.11]),
#     (Path.CURVE4, [-0.031, -0.051]),
#     (Path.CURVE4, [-0.115, 0.073]),
#     (Path.CURVE4, [-0.03, 0.073]),
#     (Path.LINETO, [-0.011, 0.039]),
#     (Path.CURVE4, [0.043, 0.121]),
#     (Path.CURVE4, [0.075, -0.005]),
#     (Path.CURVE4, [0.035, -0.027]),
#     (Path.CLOSEPOLY, [0.018, -0.11])])

# artists = [
#     mpatches.Circle((0, 0), 0.1, ec="none"),
#     mpatches.Rectangle((-0.025, -0.05), 0.05, 0.1, ec="none"),
#     mpatches.Wedge((0, 0), 0.1, 30, 270, ec="none"),
#     mpatches.RegularPolygon((0, 0), 5, radius=0.1),
#     mpatches.Ellipse((0, 0), 0.2, 0.1),
#     mpatches.Arrow(-0.05, -0.05, 0.1, 0.1, width=0.1),
#     mpatches.PathPatch(mpath.Path(verts, codes), ec="none"),
#     mpatches.FancyBboxPatch((-0.025, -0.05), 0.05, 0.1, ec="none",
#                             boxstyle=mpatches.BoxStyle("Round", pad=0.02)),
#     mlines.Line2D([-0.06, 0.0, 0.1], [0.05, -0.05, 0.05], lw=5),
# ]

# axs = plt.figure(figsize=(6, 6), layout="constrained").subplots(3, 3)
# for i, (ax, artist) in enumerate(zip(axs.flat, artists)):
#     artist.set(color=mpl.colormaps["hsv"](i / len(artists)))
#     ax.add_artist(artist)
#     ax.set(title=type(artist).__name__,
#            aspect=1, xlim=(-.2, .2), ylim=(-.2, .2))
#     ax.set_axis_off()
# plt.show()

# %%
import seaborn as sns
import matplotlib as mpl
# cmap = sns.color_palette("icefire", as_cmap=True)
# # cmap()
# # cmap = mpl.cm.cool
# norm = mpl.colors.Normalize(vmin=5, vmax=10)

# plt.colorbar(mpl.cm.ScalarMappable(norm=norm, cmap=cmap),
#              cax=ax, orientation='horizontal', label='Some Units')

# %%
# sns.choose_diverging_palette(as_cmap=True)

# %%
# cmap1 = sns.cubehelix_palette(start=.5, rot=-.99, as_cmap=True)
# cmap2 = sns.cubehelix_palette(start=.2, rot=-.99, as_cmap=True)
# cmap1 = sns.color_palette("Blues", as_cmap=True)
# cmap2 = sns.color_palette("Reds", as_cmap=True)
cmap1 = sns.color_palette("light:seagreen", as_cmap=True)
cmap2 = sns.color_palette("dark:blueviolet", as_cmap=True)


fig, ax = plt.subplots(1,3,figsize=(4.5, 4), 
                       gridspec_kw={'width_ratios': [3.5, 0.25,0.25]})

plt.subplots_adjust(wspace=0.25)

quarters = [(360,90),(90,180),(180,270),(270,360),]

def plot_circle(x,y,ax,res):
    # print(res)
    size = 0.2
    quarters = [(90,180),(0,90),(180,270),(270,0),]
    for i, (a,b) in enumerate(quarters):
        move = 0.0
        if i == 1:
            wedge = mpatches.Wedge((x, y), size, a, b)
        elif i == 0:
            wedge = mpatches.Wedge((x, y), size, a, b)
        elif i == 2:
            wedge = mpatches.Wedge((x, y+move), size, a, b)
        else:
            wedge = mpatches.Wedge((x, y+move), size, a, b)
        # wedge.set(color=mpl.colormaps["hsv"](i / 4))
        if i == 0 or i == 1:
            # print(res[i])
            cval = norm2(res[i])
            cmap = cmap2
        else:
            # print(res[i],np.log(res[i]))
            cval = norm1(np.log(res[i]))
            cmap = cmap1
        wedge.set(color=cmap(cval))
        if x < 27:
            wedge.set(alpha=1)
        ax.add_artist(wedge)
        # ax.set(aspect=1, xlim=(-.2, .2), ylim=(-.2, .2))
    return ax
    
norm1 = mpl.colors.Normalize(vmin=-11, vmax=-1)
norm2 = mpl.colors.Normalize(vmin=0.5, vmax=4)


    
# plt.scatter(best["test"], best["train"])
ax[0].set_xlabel("Train MSE [kcal/mol]", fontsize=20)
ax[0].set_ylabel("Test MSE [kcal/mol]", fontsize=20)
# plt.colorbar(cmap)
# plt.gca().set_axis_off()
minlim = min([best["test"].min(),best["train"].min()]) - .5
maxlim = max([best["test"].max(),best["train"].max()]) + .5

plt.colorbar(mpl.cm.ScalarMappable(norm=norm2, cmap=cmap2),
             cax=ax[1], orientation='vertical', label='')
plt.colorbar(mpl.cm.ScalarMappable(norm=norm1, cmap=cmap1),
             cax=ax[2], orientation='vertical', label='')

for x,y,res in zip(best["train"], best["test"], best["args"]):
    ax[0] = plot_circle(x,y,ax[0],res)

ax[0].set_xlim(minlim, maxlim)
ax[0].set_ylim(minlim, maxlim)
# ax[0].set_ylim(25, 29.5)
ax[0].plot(ax[0].get_xlim(), ax[0].get_ylim(), ls="--", c=".3", alpha=0.5)
# ax[0].grid()
ax[0].set_aspect(1)
plt.savefig("test.pdf",bbox_inches="tight")
plt.show()

# %%
from scipy.stats import bootstrap
rng = np.random.default_rng()
def boot_strap(best_res):
    data = (best_res["SE"],)  # samples must be in a sequence
    res = bootstrap(data, np.mean, confidence_level=0.95,
                    random_state=rng,n_resamples=99999)
    print([np.sqrt(_) for _ in [data[0].mean(),*res.confidence_interval]])
    print()
    # plt.hist(data)
    # fig, ax = plt.subplots()
    # ax.hist(res.bootstrap_distribution, bins=10)
    # ax.set_title('Bootstrap Distribution')
    # ax.set_xlabel('statistic value')
    # ax.set_ylabel('frequency')
    # plt.show()
    
for i in range(len(best)):
    print(i, best.iloc[i]["args"])
    best_res = best.iloc[i]["df"]
    boot_strap(best_res)
# Out:
# 0 [2.18863786e+00 5.01979202e-01 1.16221449e-02 1.22542465e-03]
# [5.258061222834217, 4.928240162017293, 5.635217518595031]
#
# 1 [2.05267978e+00 5.00000000e-01 2.92584087e-02 7.26318017e-04]
# [5.250615725798329, 4.919723098726593, 5.629031679447502]
#
# 2 [2.05216402e+00 5.05536295e-01 2.93561785e-02 6.86727574e-04]
# [5.250552365419344, 4.918093328179624, 5.631758994170619]
#
# 3 [2.25556410e+00 5.00000000e-01 7.70712169e-03 1.22067537e-03]
# [5.265355813602289, 4.931998169601272, 5.645641353337261]
#
# 4 [3.82891951e+00 5.50109668e-01 1.05486861e-05 2.31341006e-05]
# [5.318294417937005, 4.984492116330265, 5.702409263123657]
#
# 5 [3.31948549e+00 5.00000000e-01 6.80701626e-05 1.78830950e-05]
# [5.2640102539490705, 4.935025932065009, 5.634261667303115]
#
# 6 [2.14903312e+00 5.00000000e-01 1.66227038e-02 1.00000000e-05]
# [5.193120434580334, 4.870002152641806, 5.56438119335041]
#
# 7 [2.14967099e+00 5.06719922e-01 1.65505576e-02 1.00000000e-05]
# [5.192891077974372, 4.8684860741072695, 5.565759008970995]
#
# 8 [2.14903247e+00 5.00000000e-01 1.66227715e-02 1.00000000e-05]
# [5.193120135217938, 4.87031213407963, 5.562412735518132]
#
# 9 [2.14907843e+00 5.00755104e-01 1.66173338e-02 1.00000000e-05]
# [5.19308187754049, 4.87054982822073, 5.562175586516091]
#
# 10 [2.03729663e+00 8.99782929e-01 3.35742409e-02 1.00000000e-05]
# [5.21820866919735, 4.886723540157217, 5.597831263813462]
#
# 11 [2.03729647e+00 8.99782877e-01 3.35742782e-02 1.00000000e-05]
# [5.218208569045281, 4.885006899608655, 5.598432692556525]
#
# 12 [2.03729640e+00 8.99782689e-01 3.35742975e-02 1.00000000e-05]
# [5.218208698500302, 4.88405407531821, 5.600453454664772]
#
# 13 [3.87272508e+00 5.00000000e-01 1.00000000e-05 1.50426229e-05]
# [5.287440067733616, 4.9546932982441865, 5.663399636798086]
#
# 14 [2.03407664e+00 5.00001362e-01 3.32131981e-02 1.40756168e-03]
# [5.055471802164623, 4.7190402682572365, 5.441210817364099]
#
# 15 [2.37846532e+00 5.00307788e-01 3.81212641e-03 1.35703692e-03]
# [5.099082890323011, 4.763801465697535, 5.48435864725888]
#
# 16 [2.08328126e+00 6.35831920e-01 2.38960886e-02 1.74432513e-04]
# [5.01382864913357, 4.701855453721479, 5.368002999124172]
#
# 17 [2.08512678e+00 1.00370524e+00 2.31715508e-02 1.00000000e-05]
# [5.009932832629857, 4.696885832329761, 5.362838078315093]
#
# 18 [2.09247128e+00 6.07212263e-01 2.24798878e-02 2.30373953e-04]
# [5.0147992771124255, 4.699753996041875, 5.371606136881456]
#
# 19 [2.02632023e+00 5.00000000e-01 3.78111570e-02 1.00000000e-05]
# [5.110602666660246, 4.768018209274944, 5.496386239029981]
#
# 20 [3.86011142e+00 5.00000000e-01 1.00000000e-05 2.16246853e-05]
# [5.146483175845061, 4.8076910484843545, 5.529466024244343]
#
# 21 [2.40119105e+00 5.00000000e-01 3.48922435e-03 7.53323172e-04]
# [5.108347920003258, 4.776411019802928, 5.493225594835618]
#
# 22 [1.93462640e+00 5.00000000e-01 7.48569162e-02 1.00000000e-05]
# [5.200980164285728, 4.862744673190004, 5.583557565624685]
#
# 23 [1.93469762e+00 5.02282737e-01 7.48079176e-02 1.00000000e-05]
# [5.200852818550796, 4.8625018805420925, 5.588646103198913]
#
# 24 [3.84919382e+00 5.00000000e-01 1.00000000e-05 3.00850423e-05]
# [5.158008266541204, 4.826173489373676, 5.5392079077455]
#
# 25 [2.21155480e+00 1.03528020e+00 1.02883503e-02 1.21842681e-05]
# [5.13430208662332, 4.798211657179254, 5.511495563392539]
#
# 26 [2.46087208e+00 5.03777743e-01 2.56936527e-03 6.43596665e-04]
# [5.167826610019207, 4.8340795178933345, 5.5436642857632785]
#
# 27 [3.88299449e+00 5.00000000e-01 1.00000000e-05 1.00000000e-05]
# [5.239859000367323, 4.900596252811563, 5.628763260719957]
#
# 28 [3.84385966e+00 5.00000000e-01 1.00000000e-05 3.54541106e-05]
# [5.215543025554336, 4.885882515853944, 5.588997702214996]
#
# 29 [2.50294285e+00 1.15437997e+00 1.90064370e-03 1.00000000e-05]
# [5.1821812998248005, 4.853104014405764, 5.554559483587788]
#
# 30 [2.50294229e+00 1.15438011e+00 1.90064899e-03 1.00000000e-05]
# [5.1821812636185465, 4.850544767935294, 5.555236464950366]
#
# 31 [2.50294239e+00 1.15438000e+00 1.90064815e-03 1.00000000e-05]
# [5.182181257804608, 4.852666613870709, 5.555160776843181]
#
# 32 [2.17372616e+00 5.00000003e-01 1.35879083e-02 4.65992690e-04]
# [5.133687448318783, 4.8043198184297, 5.513697143186122]
#
# 33 [2.17372466e+00 5.00080210e-01 1.35879861e-02 4.65653882e-04]
# [5.133687362908964, 4.805614572597848, 5.515874110702015]
#
# 34 [2.16971535e+00 5.64213813e-01 1.38998062e-02 2.60208708e-04]
# [5.133115603226463, 4.799443434375566, 5.51318137673196]
#
# 35 [2.17372497e+00 5.00000000e-01 1.35880115e-02 4.65991184e-04]
# [5.133687379268087, 4.7998538623698055, 5.51512777551041]
#
# 36 [2.15732822e+00 9.49127507e-01 1.49077951e-02 1.02411793e-05]
# [5.131785992394209, 4.802863541629382, 5.5143782358806925]

# %%
# Out:
# 27.64720782307286 24.257214295913368 31.681689168314147
