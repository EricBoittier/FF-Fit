# %%
# %load_ext autoreload
# %autoreload 2
# !pip install ipywidgets
import sys
sys.path.append("/home/boittier/Documents/phd/ff_energy")

from ff_energy.structure import Structure
from ff_energy.job import Job
from ff_energy.jobmaker import get_structures_pdbs, JobMaker
from ff_energy.plot import plot_energy_MSE
from ff_energy.configmaker import *

from pathlib import Path
import pandas as pd

# s = Structure("/home/boittier/charmm/mix3/jobs/pdbs/mix0.pdb")

def MakeJob(name, ConfigMaker):
    structures, pdbs = get_structures_pdbs(Path(ConfigMaker.pdbs)) 
    return JobMaker(name, pdbs, structures, ConfigMaker.make().__dict__)

atom_types = {
              # ("LIG", "O"): "OG311",
              # ("LIG", "C"): "CG331",
              # ("LIG", "H1"): "HGP1",
              # ("LIG", "H2"): "HGA3",
              # ("LIG", "H3"): "HGA3",
              # ("LIG", "H4"): "HGA3",
              # ("TIP3", "OH2"): "OT",
              # ("TIP3", "H1"): "HT",
              # ("TIP3", "H2"): "HT",
              ("LIG", "O"): "OT",
              ("LIG", "H1"): "HT",
              ("LIG", "H"): "HT",
              ("LIG", "H2"): "HT",
              }
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
CMS = []
for system in system_names:
    for theory in THEORY.keys():
        print(system, theory)
        cm = ConfigMaker(theory, system, "pc")
        # print(cm.pdbs)
        print(cm.make().kwargs)
        print()
        CMS.append(cm)
# Out:
# water_cluster pbe0dz
# <bound method Config.kwargs of m_basis: avdz
# m_method: hf
# c_files: ['pbe0_dz.pc']
# c_dcm_command: open unit 11 card read name p
# DCM IUDCM 11 TSHIFT XYZ 15
# m_nproc: 8
# m_memory: 150
# m_queue: short
# chmpath: /home/boittier/dev-release-dcm/build/cmake/charmm
# modules: module load cmake/cmake-3.23.0-gcc-11.2.0-openmpi-4.1.3
# >
#
# water_dimer pbe0dz
# <bound method Config.kwargs of m_basis: avdz
# m_method: hf
# c_files: ['pbe0_dz.pc']
# c_dcm_command: open unit 11 card read name p
# DCM IUDCM 11 TSHIFT XYZ 15
# m_nproc: 8
# m_memory: 150
# m_queue: short
# chmpath: /home/boittier/dev-release-dcm/build/cmake/charmm
# modules: module load cmake/cmake-3.23.0-gcc-11.2.0-openmpi-4.1.3
# >
#
# methanol_cluster pbe0dz
# <bound method Config.kwargs of m_basis: avdz
# m_method: hf
# c_files: ['meoh_pbe0dz.pc']
# c_dcm_command: open unit 11 card read name m
# DCM IUDCM 11 TSHIFT XYZ 15
# m_nproc: 8
# m_memory: 150
# m_queue: short
# chmpath: /home/boittier/dev-release-dcm/build/cmake/charmm
# modules: module load cmake/cmake-3.23.0-gcc-11.2.0-openmpi-4.1.3
# >

# %%
jm = MakeJob("clusters/pbe0dz", CMS[0])
jm

# %%
HOMEDIR = "/home/boittier/pcbach"
jm.make_molpro(HOMEDIR)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 500/500 [01:24<00:00,  5.91it/s]

# %%
from ff_energy.slurm import SlurmJobHandler

shj = SlurmJobHandler(max_jobs=100)

print("Running jobs: ", shj.get_running_jobs())

for js in jm.get_cluster_jobs(HOMEDIR):
    shj.add_job(js)

print("Jobs: ", len(jm.get_cluster_jobs(HOMEDIR)))

shj.submit_jobs()
# Out:
# Running jobs:  0
# Jobs:  498
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test306/cluster/test306.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test324/cluster/test324.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test18/cluster/test18.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test105/cluster/test105.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test112/cluster/test112.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test459/cluster/test459.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test471/cluster/test471.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test370/cluster/test370.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test233/cluster/test233.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test181/cluster/test181.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test62/cluster/test62.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test308/cluster/test308.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test149/cluster/test149.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test467/cluster/test467.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test242/cluster/test242.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test362/cluster/test362.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test93/cluster/test93.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test482/cluster/test482.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test30/cluster/test30.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test274/cluster/test274.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test96/cluster/test96.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test347/cluster/test347.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test375/cluster/test375.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test227/cluster/test227.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test66/cluster/test66.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test85/cluster/test85.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test436/cluster/test436.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test266/cluster/test266.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test395/cluster/test395.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test444/cluster/test444.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test57/cluster/test57.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test261/cluster/test261.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test354/cluster/test354.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test336/cluster/test336.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test470/cluster/test470.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test426/cluster/test426.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test314/cluster/test314.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test254/cluster/test254.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test28/cluster/test28.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test469/cluster/test469.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test423/cluster/test423.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test146/cluster/test146.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test32/cluster/test32.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test355/cluster/test355.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test334/cluster/test334.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test158/cluster/test158.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test143/cluster/test143.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test12/cluster/test12.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test49/cluster/test49.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test26/cluster/test26.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test391/cluster/test391.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test98/cluster/test98.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test244/cluster/test244.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test379/cluster/test379.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test231/cluster/test231.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test312/cluster/test312.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test154/cluster/test154.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test485/cluster/test485.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test478/cluster/test478.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test408/cluster/test408.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test213/cluster/test213.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test289/cluster/test289.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test73/cluster/test73.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test326/cluster/test326.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test164/cluster/test164.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test99/cluster/test99.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test180/cluster/test180.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test294/cluster/test294.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test125/cluster/test125.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test393/cluster/test393.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test113/cluster/test113.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test6/cluster/test6.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test215/cluster/test215.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test130/cluster/test130.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test144/cluster/test144.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test458/cluster/test458.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test157/cluster/test157.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test29/cluster/test29.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test430/cluster/test430.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test111/cluster/test111.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test432/cluster/test432.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test466/cluster/test466.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test439/cluster/test439.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test232/cluster/test232.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test411/cluster/test411.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test319/cluster/test319.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test182/cluster/test182.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test448/cluster/test448.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test119/cluster/test119.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test229/cluster/test229.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test348/cluster/test348.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test17/cluster/test17.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test492/cluster/test492.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test262/cluster/test262.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test399/cluster/test399.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test33/cluster/test33.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test480/cluster/test480.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test133/cluster/test133.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test333/cluster/test333.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test188/cluster/test188.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test228/cluster/test228.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test387/cluster/test387.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test106/cluster/test106.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test137/cluster/test137.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test217/cluster/test217.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test61/cluster/test61.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test124/cluster/test124.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test428/cluster/test428.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test152/cluster/test152.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test170/cluster/test170.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test169/cluster/test169.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test38/cluster/test38.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test454/cluster/test454.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test475/cluster/test475.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test54/cluster/test54.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test310/cluster/test310.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test53/cluster/test53.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test299/cluster/test299.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test114/cluster/test114.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test183/cluster/test183.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test201/cluster/test201.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test235/cluster/test235.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test44/cluster/test44.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test271/cluster/test271.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test43/cluster/test43.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test398/cluster/test398.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test302/cluster/test302.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test220/cluster/test220.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test472/cluster/test472.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test59/cluster/test59.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test46/cluster/test46.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test384/cluster/test384.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test335/cluster/test335.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test358/cluster/test358.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test47/cluster/test47.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test286/cluster/test286.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test121/cluster/test121.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test252/cluster/test252.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test381/cluster/test381.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test251/cluster/test251.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test139/cluster/test139.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test212/cluster/test212.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test97/cluster/test97.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test89/cluster/test89.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test457/cluster/test457.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test263/cluster/test263.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test406/cluster/test406.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test456/cluster/test456.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test51/cluster/test51.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test486/cluster/test486.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test155/cluster/test155.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test363/cluster/test363.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test156/cluster/test156.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test110/cluster/test110.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test42/cluster/test42.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test109/cluster/test109.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test148/cluster/test148.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test238/cluster/test238.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test161/cluster/test161.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test236/cluster/test236.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test477/cluster/test477.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test361/cluster/test361.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test491/cluster/test491.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test481/cluster/test481.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test320/cluster/test320.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test372/cluster/test372.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test199/cluster/test199.sh to Slurm scheduler
# Submitted job /home/boittier/pcbach/clusters/pbe0dz/test173/cluster/test173.sh to Slurm scheduler
