# %%
# %load_ext autoreload
# %autoreload 2
# !pip install ipywidgets
import sys
sys.path.append("/home/boittier/Documents/phd/ff_energy")

from ff_energy.structure import Structure
from ff_energy.job import Job
from ff_energy.jobmaker import get_structures_pdbs, JobMaker
from ff_energy.plot import plot_energy_MSE
from ff_energy.configmaker import *

from pathlib import Path
import pandas as pd

# s = Structure("/home/boittier/charmm/mix3/jobs/pdbs/mix0.pdb")

atom_types = {
              # ("LIG", "O"): "OG311",
              # ("LIG", "C"): "CG331",
              # ("LIG", "H1"): "HGP1",
              # ("LIG", "H2"): "HGA3",
              # ("LIG", "H3"): "HGA3",
              # ("LIG", "H4"): "HGA3",
              ("TIP3", "OH2"): "OT",
              ("TIP3", "H1"): "HT",
              ("TIP3", "H2"): "HT",
              # ("LIG", "O"): "OT",
              # ("LIG", "H1"): "HT",
              # ("LIG", "H"): "HT",
              # ("LIG", "H2"): "HT",
              }

def MakeJob(name, ConfigMaker, atom_types=atom_types):
    structures, pdbs = get_structures_pdbs(
        Path(ConfigMaker.pdbs),
        atom_types=atom_types
    ) 
    return JobMaker(name, pdbs, structures, ConfigMaker.make().__dict__)
# Out:
# m_basis: avdz
# m_method: {ks,pbe0}
# c_files: ['pbe0_dz.pc']
# c_dcm_command: open unit 11 card read name p
# DCM IUDCM 11 TSHIFT XYZ 15
# m_nproc: 8
# m_memory: 150
# m_queue: short
# chmpath: /home/boittier/dev-release-dcm/build/cmake/charmm
# modules: module load cmake/cmake-3.23.0-gcc-11.2.0-openmpi-4.1.3
#
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
CMS = []
for system in system_names:
    for theory in THEORY.keys():
        print(system, theory)
        cm = ConfigMaker(theory, system, "pc")
        # print(cm.pdbs)
        # print(cm.make().kwargs)
        print(cm.atom_types)
        CMS.append(cm)
# Out:
# water_cluster pbe0dz
# {('LIG', 'O'): 'OT', ('LIG', 'H1'): 'HT', ('LIG', 'H'): 'HT', ('LIG', 'H2'): 'HT'}
# water_dimer pbe0dz
# {('TIP3', 'OH2'): 'OT', ('TIP3', 'H1'): 'HT', ('TIP3', 'H2'): 'HT'}
# methanol_cluster pbe0dz
# {('LIG', 'O'): 'OG311', ('LIG', 'C'): 'CG331', ('LIG', 'H1'): 'HGP1', ('LIG', 'H2'): 'HGA3', ('LIG', 'H3'): 'HGA3', ('LIG', 'H4'): 'HGA3'}

# %%
jobmakers = []

for cms in CMS:
    job_dir = f"{cms.system_name}/{cms.theory_name}"
    print(job_dir)
    jm = MakeJob(job_dir, cms, 
                 atom_types=cms.atom_types)
    HOMEDIR = "/home/boittier/pcbach"
    jm.make_molpro(HOMEDIR)
    jobmakers.append(jm)
# Out:
# water_cluster/pbe0dz
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 500/500 [01:08<00:00,  7.32it/s]
# water_dimer/pbe0dz
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 104/104 [00:00<00:00, 349.82it/s]
# methanol_cluster/pbe0dz
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:01<00:00, 60.48it/s]

# %%
from ff_energy.slurm import SlurmJobHandler

shj = SlurmJobHandler(max_jobs=100)
print("Running jobs: ", shj.get_running_jobs())

for jm in jobmakers:
    for js in jm.get_cluster_jobs(HOMEDIR):
        shj.add_job(js)

print("Jobs: ", len(jm.get_cluster_jobs(HOMEDIR)))

shj.submit_jobs()
# Out:
# Running jobs:  1
# Jobs:  100
# 0/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test306/cluster/test306.sh to Slurm scheduler
# 1/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test324/cluster/test324.sh to Slurm scheduler
# 2/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test18/cluster/test18.sh to Slurm scheduler
# 3/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test105/cluster/test105.sh to Slurm scheduler
# 4/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test112/cluster/test112.sh to Slurm scheduler
# 5/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test459/cluster/test459.sh to Slurm scheduler
# 6/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test471/cluster/test471.sh to Slurm scheduler
# 7/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test370/cluster/test370.sh to Slurm scheduler
# 8/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test233/cluster/test233.sh to Slurm scheduler
# 9/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test181/cluster/test181.sh to Slurm scheduler
# 10/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test62/cluster/test62.sh to Slurm scheduler
# 11/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test308/cluster/test308.sh to Slurm scheduler
# 12/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test149/cluster/test149.sh to Slurm scheduler
# 13/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test467/cluster/test467.sh to Slurm scheduler
# 14/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test242/cluster/test242.sh to Slurm scheduler
# 15/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test362/cluster/test362.sh to Slurm scheduler
# 16/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test93/cluster/test93.sh to Slurm scheduler
# 17/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test482/cluster/test482.sh to Slurm scheduler
# 18/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test30/cluster/test30.sh to Slurm scheduler
# 19/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test274/cluster/test274.sh to Slurm scheduler
# 20/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test96/cluster/test96.sh to Slurm scheduler
# 21/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test347/cluster/test347.sh to Slurm scheduler
# 22/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test375/cluster/test375.sh to Slurm scheduler
# 23/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test227/cluster/test227.sh to Slurm scheduler
# 24/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test66/cluster/test66.sh to Slurm scheduler
# 25/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test85/cluster/test85.sh to Slurm scheduler
# 26/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test436/cluster/test436.sh to Slurm scheduler
# 27/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test266/cluster/test266.sh to Slurm scheduler
# 28/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test395/cluster/test395.sh to Slurm scheduler
# 29/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test444/cluster/test444.sh to Slurm scheduler
# 30/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test57/cluster/test57.sh to Slurm scheduler
# 31/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test261/cluster/test261.sh to Slurm scheduler
# 32/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test354/cluster/test354.sh to Slurm scheduler
# 33/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test336/cluster/test336.sh to Slurm scheduler
# 34/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test470/cluster/test470.sh to Slurm scheduler
# 35/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test426/cluster/test426.sh to Slurm scheduler
# 36/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test314/cluster/test314.sh to Slurm scheduler
# 37/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test254/cluster/test254.sh to Slurm scheduler
# 38/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test28/cluster/test28.sh to Slurm scheduler
# 39/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test469/cluster/test469.sh to Slurm scheduler
# 40/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test423/cluster/test423.sh to Slurm scheduler
# 41/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test146/cluster/test146.sh to Slurm scheduler
# 42/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test32/cluster/test32.sh to Slurm scheduler
# 43/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test355/cluster/test355.sh to Slurm scheduler
# 44/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test334/cluster/test334.sh to Slurm scheduler
# 45/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test158/cluster/test158.sh to Slurm scheduler
# 46/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test143/cluster/test143.sh to Slurm scheduler
# 47/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test12/cluster/test12.sh to Slurm scheduler
# 48/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test49/cluster/test49.sh to Slurm scheduler
# 49/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test26/cluster/test26.sh to Slurm scheduler
# 50/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test391/cluster/test391.sh to Slurm scheduler
# 51/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test98/cluster/test98.sh to Slurm scheduler
# 52/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test244/cluster/test244.sh to Slurm scheduler
# 53/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test379/cluster/test379.sh to Slurm scheduler
# 54/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test231/cluster/test231.sh to Slurm scheduler
# 55/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test312/cluster/test312.sh to Slurm scheduler
# 56/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test154/cluster/test154.sh to Slurm scheduler
# 57/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test485/cluster/test485.sh to Slurm scheduler
# 58/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test478/cluster/test478.sh to Slurm scheduler
# 59/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test408/cluster/test408.sh to Slurm scheduler
# 60/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test213/cluster/test213.sh to Slurm scheduler
# 61/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test289/cluster/test289.sh to Slurm scheduler
# 62/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test73/cluster/test73.sh to Slurm scheduler
# 63/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test326/cluster/test326.sh to Slurm scheduler
# 64/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test164/cluster/test164.sh to Slurm scheduler
# 65/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test99/cluster/test99.sh to Slurm scheduler
# 66/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test180/cluster/test180.sh to Slurm scheduler
# 67/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test294/cluster/test294.sh to Slurm scheduler
# 68/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test125/cluster/test125.sh to Slurm scheduler
# 69/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test393/cluster/test393.sh to Slurm scheduler
# 70/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test113/cluster/test113.sh to Slurm scheduler
# 71/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test6/cluster/test6.sh to Slurm scheduler
# 72/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test215/cluster/test215.sh to Slurm scheduler
# 73/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test130/cluster/test130.sh to Slurm scheduler
# 74/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test144/cluster/test144.sh to Slurm scheduler
# 75/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test458/cluster/test458.sh to Slurm scheduler
# 76/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test157/cluster/test157.sh to Slurm scheduler
# 77/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test29/cluster/test29.sh to Slurm scheduler
# 78/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test430/cluster/test430.sh to Slurm scheduler
# 79/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test111/cluster/test111.sh to Slurm scheduler
# 80/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test432/cluster/test432.sh to Slurm scheduler
# 81/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test466/cluster/test466.sh to Slurm scheduler
# 82/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test439/cluster/test439.sh to Slurm scheduler
# 83/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test232/cluster/test232.sh to Slurm scheduler
# 84/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test411/cluster/test411.sh to Slurm scheduler
# 85/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test319/cluster/test319.sh to Slurm scheduler
# 86/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test182/cluster/test182.sh to Slurm scheduler
# 87/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test448/cluster/test448.sh to Slurm scheduler
# 88/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test119/cluster/test119.sh to Slurm scheduler
# 89/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test229/cluster/test229.sh to Slurm scheduler
# 90/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test348/cluster/test348.sh to Slurm scheduler
# 91/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test17/cluster/test17.sh to Slurm scheduler
# 92/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test492/cluster/test492.sh to Slurm scheduler
# 93/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test262/cluster/test262.sh to Slurm scheduler
# 94/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test399/cluster/test399.sh to Slurm scheduler
# 95/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test0/cluster/test0.sh to Slurm scheduler
# 96/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test33/cluster/test33.sh to Slurm scheduler
# 97/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test480/cluster/test480.sh to Slurm scheduler
# 98/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test133/cluster/test133.sh to Slurm scheduler
# 99/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test333/cluster/test333.sh to Slurm scheduler
# 100/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test188/cluster/test188.sh to Slurm scheduler
# 101/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test228/cluster/test228.sh to Slurm scheduler
# 102/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test387/cluster/test387.sh to Slurm scheduler
# 103/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test106/cluster/test106.sh to Slurm scheduler
# 104/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test137/cluster/test137.sh to Slurm scheduler
# 105/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test217/cluster/test217.sh to Slurm scheduler
# 106/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test61/cluster/test61.sh to Slurm scheduler
# 107/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test124/cluster/test124.sh to Slurm scheduler
# 108/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test428/cluster/test428.sh to Slurm scheduler
# 109/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test152/cluster/test152.sh to Slurm scheduler
# 110/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test170/cluster/test170.sh to Slurm scheduler
# 111/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test169/cluster/test169.sh to Slurm scheduler
# 112/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test38/cluster/test38.sh to Slurm scheduler
# 113/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test454/cluster/test454.sh to Slurm scheduler
# 114/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test475/cluster/test475.sh to Slurm scheduler
# 115/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test54/cluster/test54.sh to Slurm scheduler
# 116/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test310/cluster/test310.sh to Slurm scheduler
# 117/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test53/cluster/test53.sh to Slurm scheduler
# 118/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test299/cluster/test299.sh to Slurm scheduler
# 119/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test114/cluster/test114.sh to Slurm scheduler
# 120/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test183/cluster/test183.sh to Slurm scheduler
# 121/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test201/cluster/test201.sh to Slurm scheduler
# 122/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test235/cluster/test235.sh to Slurm scheduler
# 123/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test44/cluster/test44.sh to Slurm scheduler
# 124/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test271/cluster/test271.sh to Slurm scheduler
# 125/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test43/cluster/test43.sh to Slurm scheduler
# 126/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test398/cluster/test398.sh to Slurm scheduler
# 127/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test302/cluster/test302.sh to Slurm scheduler
# 128/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test220/cluster/test220.sh to Slurm scheduler
# 129/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test472/cluster/test472.sh to Slurm scheduler
# 130/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test59/cluster/test59.sh to Slurm scheduler
# 131/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test46/cluster/test46.sh to Slurm scheduler
# 132/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test384/cluster/test384.sh to Slurm scheduler
# 133/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test335/cluster/test335.sh to Slurm scheduler
# 134/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test358/cluster/test358.sh to Slurm scheduler
# 135/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test47/cluster/test47.sh to Slurm scheduler
# 136/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test286/cluster/test286.sh to Slurm scheduler
# 137/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test121/cluster/test121.sh to Slurm scheduler
# 138/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test252/cluster/test252.sh to Slurm scheduler
# 139/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test381/cluster/test381.sh to Slurm scheduler
# 140/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test251/cluster/test251.sh to Slurm scheduler
# 141/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test139/cluster/test139.sh to Slurm scheduler
# 142/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test212/cluster/test212.sh to Slurm scheduler
# 143/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test97/cluster/test97.sh to Slurm scheduler
# 144/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test89/cluster/test89.sh to Slurm scheduler
# 145/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test457/cluster/test457.sh to Slurm scheduler
# 146/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test1/cluster/test1.sh to Slurm scheduler
# 147/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test263/cluster/test263.sh to Slurm scheduler
# 148/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test406/cluster/test406.sh to Slurm scheduler
# 149/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test456/cluster/test456.sh to Slurm scheduler
# 150/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test51/cluster/test51.sh to Slurm scheduler
# 151/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test486/cluster/test486.sh to Slurm scheduler
# 152/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test155/cluster/test155.sh to Slurm scheduler
# 153/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test363/cluster/test363.sh to Slurm scheduler
# 154/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test156/cluster/test156.sh to Slurm scheduler
# 155/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test110/cluster/test110.sh to Slurm scheduler
# 156/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test42/cluster/test42.sh to Slurm scheduler
# 157/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test109/cluster/test109.sh to Slurm scheduler
# 158/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test148/cluster/test148.sh to Slurm scheduler
# 159/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test238/cluster/test238.sh to Slurm scheduler
# 160/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test161/cluster/test161.sh to Slurm scheduler
# 161/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test236/cluster/test236.sh to Slurm scheduler
# 162/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test477/cluster/test477.sh to Slurm scheduler
# 163/600 = submitted job /home/boittier/pcbach/water_cluster/pbe0dz/test361/cluster/test361.sh to Slurm scheduler

# %%
CMS = []
for system in system_names:
    for theory in THEORY.keys():
        for elec in ["pc", "mdcm"]:
            print(system, theory, elec)
            cm = ConfigMaker(theory, system, elec)
            # print(cm.pdbs)
            print(cm.make().kwargs)
            print()
            CMS.append(cm)
# Out:
# m_basis: avdz
# m_method: hf
# c_files: ['pbe0_dz.pc']
# c_dcm_command: open unit 11 card read name p
# DCM IUDCM 11 TSHIFT XYZ 15
# m_nproc: 8
# m_memory: 150
# m_queue: short
# chmpath: /home/boittier/dev-release-dcm/build/cmake/charmm
# modules: module load cmake/cmake-3.23.0-gcc-11.2.0-openmpi-4.1.3
#
# water_cluster pbe0dz pc
# <bound method Config.kwargs of m_basis: avdz
# m_method: hf
# c_files: ['pbe0_dz.pc']
# c_dcm_command: open unit 11 card read name p
# DCM IUDCM 11 TSHIFT XYZ 15
# m_nproc: 8
# m_memory: 150
# m_queue: short
# chmpath: /home/boittier/dev-release-dcm/build/cmake/charmm
# modules: module load cmake/cmake-3.23.0-gcc-11.2.0-openmpi-4.1.3
# >
#
# water_cluster pbe0dz mdcm
# <bound method Config.kwargs of m_basis: avdz
# m_method: hf
# c_files: ['pbe0_dz.mdcm']
# c_dcm_command: open unit 11 card read name p
# DCM IUDCM 11 TSHIFT XYZ 15
# m_nproc: 8
# m_memory: 150
# m_queue: short
# chmpath: /home/boittier/dev-release-dcm/build/cmake/charmm
# modules: module load cmake/cmake-3.23.0-gcc-11.2.0-openmpi-4.1.3
# >
#
# water_dimer pbe0dz pc
# <bound method Config.kwargs of m_basis: avdz
# m_method: hf
# c_files: ['pbe0_dz.pc']
# c_dcm_command: open unit 11 card read name p
# DCM IUDCM 11 TSHIFT XYZ 15
# m_nproc: 8
# m_memory: 150
# m_queue: short
# chmpath: /home/boittier/dev-release-dcm/build/cmake/charmm
# modules: module load cmake/cmake-3.23.0-gcc-11.2.0-openmpi-4.1.3
# >
#
# water_dimer pbe0dz mdcm
# <bound method Config.kwargs of m_basis: avdz
# m_method: hf
# c_files: ['pbe0_dz.mdcm']
# c_dcm_command: open unit 11 card read name p
# DCM IUDCM 11 TSHIFT XYZ 15
# m_nproc: 8
# m_memory: 150
# m_queue: short
# chmpath: /home/boittier/dev-release-dcm/build/cmake/charmm
# modules: module load cmake/cmake-3.23.0-gcc-11.2.0-openmpi-4.1.3
# >
#
# methanol_cluster pbe0dz pc
# <bound method Config.kwargs of m_basis: avdz
# m_method: hf
# c_files: ['meoh_pbe0dz.pc']
# c_dcm_command: open unit 11 card read name m
# DCM IUDCM 11 TSHIFT XYZ 15
# m_nproc: 8
# m_memory: 150
# m_queue: short
# chmpath: /home/boittier/dev-release-dcm/build/cmake/charmm
# modules: module load cmake/cmake-3.23.0-gcc-11.2.0-openmpi-4.1.3
# >
#
# methanol_cluster pbe0dz mdcm
# <bound method Config.kwargs of m_basis: avdz
# m_method: hf
# c_files: ['meoh_pbe0dz.pc']
# c_dcm_command: open unit 11 card read name m
# DCM IUDCM 11 TSHIFT XYZ 15
# m_nproc: 8
# m_memory: 150
# m_queue: short
# chmpath: /home/boittier/dev-release-dcm/build/cmake/charmm
# modules: module load cmake/cmake-3.23.0-gcc-11.2.0-openmpi-4.1.3
# >

# %%
CMS[0].theory
# Out:
# {'m_basis': 'avdz', 'm_method': 'hf'}

# %%
jobmakers = []
for cms in CMS:
    jm = MakeJob(f"{cms.system_name}/{cms.theory_name}", cms, 
                 atom_types=cms.atom_types)
    HOMEDIR = "/home/boittier/bhome"
    # jm.make_charmm(HOMEDIR)
    jm.make_coloumb(HOMEDIR,f"/home/boittier/pcbach/{cms.system_type}/{cms.theory_name}/""{}/monomers")
    jobmakers.append(jm)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 500/500 [01:02<00:00,  8.01it/s]
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/boittier/miniconda3/envs/pycharmm/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/boittier/miniconda3/envs/pycharmm/lib/python3.8/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
# TypeError: make_coloumb_job() missing 1 required positional argument: 'mp'
# """
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 7
#       5 HOMEDIR = "/home/boittier/bhome"
#       6 # jm.make_charmm(HOMEDIR)
# ----> 7 jm.make_coloumb(HOMEDIR,f"/home/boittier/pcbach/{cms.system_type}/{cms.theory_name}/""{}/monomers")
#       8 jobmakers.append(jm)
#
# File ~/Documents/phd/ff_energy/ff_energy/jobmaker.py:82, in JobMaker.make_coloumb(self, homedir, mp)
#      81 def make_coloumb(self, homedir, mp):
# ---> 82     self.loop(self.make_coloumb_job, [homedir, mp])
#
# File ~/Documents/phd/ff_energy/ff_energy/jobmaker.py:55, in JobMaker.loop(self, func, *args, **kwargs)
#      53 pool = Pool()
#      54 # Start the jobs
# ---> 55 pool.starmap(func,
#      56              tqdm(zip(self.pdbs, self.structures, repeat(args)),
#      57                   total=len(self.pdbs)))
#      58 # Close the pool and wait for the work to finish
#      59 pool.close()
#
# File ~/miniconda3/envs/pycharmm/lib/python3.8/multiprocessing/pool.py:372, in Pool.starmap(self, func, iterable, chunksize)
#     366 def starmap(self, func, iterable, chunksize=None):
#     367     '''
#     368     Like `map()` method but the elements of the `iterable` are expected to
#     369     be iterables as well and will be unpacked as arguments. Hence
#     370     `func` and (a, b) becomes func(a, b).
#     371     '''
# --> 372     return self._map_async(func, iterable, starmapstar, chunksize).get()
#
# File ~/miniconda3/envs/pycharmm/lib/python3.8/multiprocessing/pool.py:771, in ApplyResult.get(self, timeout)
#     769     return self._value
#     770 else:
# --> 771     raise self._value
#
# TypeError: make_coloumb_job() missing 1 required positional argument: 'mp'
